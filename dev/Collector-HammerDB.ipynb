# %% [markdown]
# # TPC-C Collector Demo

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.float_format = '{:.2f}'.format

from bexhoma import collectors

# %matplotlib inline

# %% [markdown]
# ## Functions for Nice Plots

# %%
from notebookutils import *

# %% [markdown]
# # Collect Results

# %%
#path = r"D:\data\benchmarks"
path = r"/data/benchmarks"
filename_prefix = "demo_"
b_plot_save = False
b_skip_plots = True

# %%
codes = [
    "1777039267",
    "1777041908"
]

codes
# Out:
# ['1777039267', '1777041908']

# %%
collect = collectors.tpcc(path, codes)

# %% [markdown]
# # Get all Metrics Metadata

# %% [markdown]
# ## Metrics Names and Types
#
# Metrics that are derived from monitoring

# %%
collect.get_metrics_metadata()
# Out:
#                                                                                                           title  \
# total_cpu_memory                                                                             Memory Usage [MiB]
# total_cpu_memory_cached                                                               Memory Usage Cached [MiB]
# total_cpu_util                                                                                  CPU Utilization
# total_cpu_throttled                                                                                CPU Throttle
# total_cpu_throttled_s                                                                    CPU Throttled Time [s]
# total_cpu_util_others                                                                    CPU Utilization Others
# total_cpu_util_s                                                                       CPU Utilization Time [s]
# total_cpu_util_user_s                                                                         CPU User Time [s]
# total_cpu_util_sys_s                                                                        CPU System Time [s]
# total_cpu_util_others_s                                                         CPU Utilization Time Others [s]
# total_network_rx                                                                         Network Rx Total [MiB]
# total_network_tx                                                                         Network Tx Total [MiB]
# total_fs_read                                                                       Filesystem Read Total [MiB]
# total_fs_write                                                                     Filesystem Write Total [MiB]
# total_gpu_util                                                                              GPU Utilization [%]
# total_gpu_power                                                                             GPU Power Usage [W]
# total_gpu_memory                                                                         GPU Memory Usage [MiB]
# core_variance                                                                     Core Utilization Variance [%]
# max_core_util                                                                          Max Core Utilization [%]
# io_wait_pct                                                                                        I/O Wait [%]
# io_wait_total                                                                           Total I/O Wait Time [s]
# pg_stat_activity_count_idle                                                             Number of Idle Sessions
# pg_stat_activity_count_idle_transaction                                  Number of Idle-in-transaction Sessions
# pg_stat_activity_count_idle_transaction_aborted                  Number of Idle-in-transaction Aborted Sessions
# pg_stat_activity_count_active                                                         Number of Active Sessions
# pg_stat_activity_count_active_app                                         Number of Active Application Sessions
# pg_stat_activity_max_tx_duration_active                                              Longest Active Transaction
# pg_stat_activity_max_tx_duration_idle                                     Longest Idle Session (no transaction)
# pg_stat_activity_max_tx_duration_idle_in_tx                                         Longest Idle-in-Transaction
# pg_stat_activity_max_tx_duration_idle_in_tx_aborted                       Longest Idle-in-Transaction (Aborted)
# pg_stat_activity_count_io                                                        Active Backends Waiting on I/O
# pg_stat_activity_count_wal                                                       Active Backends Waiting on WAL
# pg_stat_activity_count_lock                                                    Active Backends Waiting on Locks
# pg_stat_activity_max_tx_duration_io                                         Max Transaction Duration (I/O Wait)
# pg_stat_activity_max_tx_duration_wal                                        Max Transaction Duration (WAL Wait)
# pg_stat_activity_max_tx_duration_lock                                      Max Transaction Duration (Lock Wait)
# pg_stat_database_blks_read                                                               Disk Blocks Read Count
# pg_stat_database_blks_hit                                                                Buffer Cache Hit Count
# cache_hit_ratio                                                                          Buffer Cache Hit Ratio
# pg_stat_user_tables_idx_scan                                                                   Index Scan Count
# pg_stat_user_tables_idx_tup_fetch                                                       Index Tuple Fetch Count
# pg_statio_user_tables_idx_cache_hit_ratio                                                 Index Cache Hit Ratio
# pg_statio_user_tables_heap_blocks_hit                                                    Table Buffer Hit Count
# pg_statio_user_tables_heap_blocks_read                                                  Table Blocks Read Count
# pg_statio_user_tables_heap_cache_hit_ratio                                                Table Cache Hit Ratio
# pg_statio_user_tables_total_cache_hit_ratio                                               Total Cache Hit Ratio
# pg_stat_bgwriter_efficiency_ratio                               BGWriter Efficiency Ratio (Cleaned / Allocated)
# pg_stat_bgwriter_maxwritten_clean_total                                       BGWriter Stopped Due to Max Pages
# pg_stat_bgwriter_checkpoint_sync_time_total                                           Checkpoint Sync Time [ms]
# pg_stat_bgwriter_checkpoint_write_time_total                                         Checkpoint Write Time [ms]
# pg_stat_bgwriter_checkpoint_write_time_per_sync_time   Time spent writing vs syncing during checkpoints [ratio]
# pg_locks_count                                                                              Total Locks Current
# pg_locks_count_accessexclusivelock                                                 AccessExclusiveLocks Current
# pg_locks_count_accesssharelock                                                         AccessShareLocks Current
# pg_locks_count_exclusivelock                                                             ExclusiveLocks Current
# pg_locks_count_rowexclusivelock                                                       RowExclusiveLocks Current
# pg_locks_count_rowsharelock                                                               RowShareLocks Current
# pg_locks_count_sharelock                                                                     ShareLocks Current
# pg_locks_count_sharerowexclusivelock                                             ShareRowExclusiveLocks Current
# pg_locks_count_shareupdateexclusivelock                                       ShareUpdateExclusiveLocks Current
# pg_locks_count_sireadlock                                                                   SIReadLocks Current
# pg_stat_user_tables_autoanalyze_count                                                     Autoanalyze Run Count
# pg_stat_user_tables_autovacuum_count                                                       Autovacuum Run Count
# pg_stat_bgwriter_checkpoints_timed_per_req                Frequency of checkpoints (timed vs requested) [ratio]
# pg_stat_wal_volume_bytes_sec                                                Volume of WAL generated [bytes/sec]
# pg_stat_bgwriter_buffers_backend_fsync                Backends forced to flush WAL (I/O contention) [fsync/sec]
# pg_stat_activity_wait_event_count                                  Active sessions waiting on any event [count]
# pg_stat_user_tables_dead_tuples_per_vacuum                     Dead tuples per vacuum operation [tuples/vacuum]
# pg_wal_segments                                                                          Number of WAL Segments
# pg_wal_size_bytes                                                                          Total WAL Size [GiB]
# pg_wal_segments_rate                                                      WAL Segments Growth Rate [segments/s]
# pg_wal_size_rate                                                                        WAL Growth Rate [MiB/s]
# pg_wal_avg_segment_size                                                          Average WAL Segment Size [MiB]
# pg_wal_size_per_checkpoint                                           WAL Size per Checkpoint [bytes/checkpoint]
#
#                                                      active         type  \
# total_cpu_memory                                       True      cluster
# total_cpu_memory_cached                                True      cluster
# total_cpu_util                                         True      cluster
# total_cpu_throttled                                    True      cluster
# total_cpu_throttled_s                                  True      cluster
# total_cpu_util_others                                 False      cluster
# total_cpu_util_s                                       True      cluster
# total_cpu_util_user_s                                  True      cluster
# total_cpu_util_sys_s                                   True      cluster
# total_cpu_util_others_s                               False      cluster
# total_network_rx                                       True      cluster
# total_network_tx                                       True      cluster
# total_fs_read                                          True      cluster
# total_fs_write                                         True      cluster
# total_gpu_util                                        False      cluster
# total_gpu_power                                       False      cluster
# total_gpu_memory                                      False      cluster
# core_variance                                          True      cluster
# max_core_util                                          True      cluster
# io_wait_pct                                            True      cluster
# io_wait_total                                          True      cluster
# pg_stat_activity_count_idle                            True  application
# pg_stat_activity_count_idle_transaction                True  application
# pg_stat_activity_count_idle_transaction_aborted        True  application
# pg_stat_activity_count_active                          True  application
# pg_stat_activity_count_active_app                      True  application
# pg_stat_activity_max_tx_duration_active                True  application
# pg_stat_activity_max_tx_duration_idle                  True  application
# pg_stat_activity_max_tx_duration_idle_in_tx            True  application
# pg_stat_activity_max_tx_duration_idle_in_tx_aborted    True  application
# pg_stat_activity_count_io                              True  application
# pg_stat_activity_count_wal                             True  application
# pg_stat_activity_count_lock                            True  application
# pg_stat_activity_max_tx_duration_io                    True  application
# pg_stat_activity_max_tx_duration_wal                   True  application
# pg_stat_activity_max_tx_duration_lock                  True  application
# pg_stat_database_blks_read                             True  application
# pg_stat_database_blks_hit                              True  application
# cache_hit_ratio                                        True  application
# pg_stat_user_tables_idx_scan                           True  application
# pg_stat_user_tables_idx_tup_fetch                      True  application
# pg_statio_user_tables_idx_cache_hit_ratio              True  application
# pg_statio_user_tables_heap_blocks_hit                  True  application
# pg_statio_user_tables_heap_blocks_read                 True  application
# pg_statio_user_tables_heap_cache_hit_ratio             True  application
# pg_statio_user_tables_total_cache_hit_ratio            True  application
# pg_stat_bgwriter_efficiency_ratio                      True  application
# pg_stat_bgwriter_maxwritten_clean_total                True  application
# pg_stat_bgwriter_checkpoint_sync_time_total           False  application
# pg_stat_bgwriter_checkpoint_write_time_total          False  application
# pg_stat_bgwriter_checkpoint_write_time_per_sync_time  False  application
# pg_locks_count                                         True  application
# pg_locks_count_accessexclusivelock                     True  application
# pg_locks_count_accesssharelock                         True  application
# pg_locks_count_exclusivelock                           True  application
# pg_locks_count_rowexclusivelock                        True  application
# pg_locks_count_rowsharelock                            True  application
# pg_locks_count_sharelock                               True  application
# pg_locks_count_sharerowexclusivelock                   True  application
# pg_locks_count_shareupdateexclusivelock                True  application
# pg_locks_count_sireadlock                              True  application
# pg_stat_user_tables_autoanalyze_count                  True  application
# pg_stat_user_tables_autovacuum_count                   True  application
# pg_stat_bgwriter_checkpoints_timed_per_req            False  application
# pg_stat_wal_volume_bytes_sec                          False  application
# pg_stat_bgwriter_buffers_backend_fsync                False  application
# pg_stat_activity_wait_event_count                     False  application
# pg_stat_user_tables_dead_tuples_per_vacuum             True  application
# pg_wal_segments                                        True  application
# pg_wal_size_bytes                                      True  application
# pg_wal_segments_rate                                   True  application
# pg_wal_size_rate                                       True  application
# pg_wal_avg_segment_size                                True  application
# pg_wal_size_per_checkpoint                            False  application
#
#                                                        metric
# total_cpu_memory                                        gauge
# total_cpu_memory_cached                                 gauge
# total_cpu_util                                          gauge
# total_cpu_throttled                                     gauge
# total_cpu_throttled_s                                 counter
# total_cpu_util_others                                   gauge
# total_cpu_util_s                                      counter
# total_cpu_util_user_s                                 counter
# total_cpu_util_sys_s                                  counter
# total_cpu_util_others_s                               counter
# total_network_rx                                      counter
# total_network_tx                                      counter
# total_fs_read                                         counter
# total_fs_write                                        counter
# total_gpu_util                                          gauge
# total_gpu_power                                         gauge
# total_gpu_memory                                        gauge
# core_variance                                           ratio
# max_core_util                                           ratio
# io_wait_pct                                             ratio
# io_wait_total                                         counter
# pg_stat_activity_count_idle                             gauge
# pg_stat_activity_count_idle_transaction                 gauge
# pg_stat_activity_count_idle_transaction_aborted         gauge
# pg_stat_activity_count_active                         counter
# pg_stat_activity_count_active_app                     counter
# pg_stat_activity_max_tx_duration_active                 ratio
# pg_stat_activity_max_tx_duration_idle                   ratio
# pg_stat_activity_max_tx_duration_idle_in_tx             ratio
# pg_stat_activity_max_tx_duration_idle_in_tx_aborted     ratio
# pg_stat_activity_count_io                               gauge
# pg_stat_activity_count_wal                              gauge
# pg_stat_activity_count_lock                             gauge
# pg_stat_activity_max_tx_duration_io                     ratio
# pg_stat_activity_max_tx_duration_wal                    ratio
# pg_stat_activity_max_tx_duration_lock                   ratio
# pg_stat_database_blks_read                            counter
# pg_stat_database_blks_hit                             counter
# cache_hit_ratio                                         ratio
# pg_stat_user_tables_idx_scan                          counter
# pg_stat_user_tables_idx_tup_fetch                     counter
# pg_statio_user_tables_idx_cache_hit_ratio               ratio
# pg_statio_user_tables_heap_blocks_hit                 counter
# pg_statio_user_tables_heap_blocks_read                counter
# pg_statio_user_tables_heap_cache_hit_ratio              ratio
# pg_statio_user_tables_total_cache_hit_ratio             ratio
# pg_stat_bgwriter_efficiency_ratio                       ratio
# pg_stat_bgwriter_maxwritten_clean_total               counter
# pg_stat_bgwriter_checkpoint_sync_time_total           counter
# pg_stat_bgwriter_checkpoint_write_time_total          counter
# pg_stat_bgwriter_checkpoint_write_time_per_sync_time    ratio
# pg_locks_count                                          gauge
# pg_locks_count_accessexclusivelock                      gauge
# pg_locks_count_accesssharelock                          gauge
# pg_locks_count_exclusivelock                            gauge
# pg_locks_count_rowexclusivelock                         gauge
# pg_locks_count_rowsharelock                             gauge
# pg_locks_count_sharelock                                gauge
# pg_locks_count_sharerowexclusivelock                    gauge
# pg_locks_count_shareupdateexclusivelock                 gauge
# pg_locks_count_sireadlock                               gauge
# pg_stat_user_tables_autoanalyze_count                 counter
# pg_stat_user_tables_autovacuum_count                  counter
# pg_stat_bgwriter_checkpoints_timed_per_req              gauge
# pg_stat_wal_volume_bytes_sec                          counter
# pg_stat_bgwriter_buffers_backend_fsync                counter
# pg_stat_activity_wait_event_count                       gauge
# pg_stat_user_tables_dead_tuples_per_vacuum              ratio
# pg_wal_segments                                         gauge
# pg_wal_size_bytes                                       gauge
# pg_wal_segments_rate                                    gauge
# pg_wal_size_rate                                        gauge
# pg_wal_avg_segment_size                                 gauge
# pg_wal_size_per_checkpoint                              gauge

# %% [markdown]
# ## Names of Monitored Components
#
# Names of components and their phases

# %%
collect.get_monitored_components()
# Out:
#                                         description
# loading               Loading phase: SUT deployment
# loader              Loading phase: component loader
# stream              Execution phase: SUT deployment
# benchmarker  Execution phase: component benchmarker

# %% [markdown]
# # Get Connection Infos
#
# List of states of SUTs, containing loading infos.

# %%
df=collect.get_connections()

# %%
df.T
# Out:
#                                                     1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1
# experiment_run                                                                         1
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                                                         1
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-1-2-2  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                                                         1
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-1
# experiment_run                                                                         2
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3299
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3299
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-2-2  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-1-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-1-1
# experiment_run                                                                         1
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         183.00
# time_ingest                                                                        84.00
# time_check                                                                         98.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154359
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# ...
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-2-2-2
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0

# %%
df = collect.get_loading_per_connection()
df.T
# Out:
#                    1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-1-1-1
# phase                1777039267-PostgreSQL-BHT-16-1-1-1
# experiment_run                                        1
# client                                                1
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  1
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase                1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-1-2-2  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-1-2-2
# phase                1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-2-1-1
# phase                1777039267-PostgreSQL-BHT-16-1-2-1
# experiment_run                                        2
# client                                                1
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  1
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-2-2-1
# phase                1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-2-2  \
# code                                         1777039267
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777039267-PostgreSQL-BHT-16-1-2-2-2
# phase                1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                320.00
#
#                    1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-1-1-1
# phase                1777041908-PostgreSQL-BHT-16-1-1-1
# experiment_run                                        1
# client                                                1
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  1
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-1-2-1  \
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-1-2-1
# phase                1777041908-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-1-2-2  \
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-1-2-2
# phase                1777041908-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-2-1-1  \
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-2-1-1
# phase                1777041908-PostgreSQL-BHT-16-1-2-1
# experiment_run                                        2
# client                                                1
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  1
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                259.46
#
#                    1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-2-2-1
# phase                1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                259.46
#
#                    1777041908-PostgreSQL-BHT-16-1-2-2-2
# code                                         1777041908
# SF                                                   16
# configuration                       PostgreSQL-BHT-16-1
# connection         1777041908-PostgreSQL-BHT-16-1-2-2-2
# phase                1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  2
# type_tenants                                       None
# num_tenants                                           0
# vol_tenants                                       False
# Throughput [SF/h]                                259.46

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'connection', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].T
# Out:
#                 1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# phase             1777039267-PostgreSQL-BHT-16-1-1-1
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-1-1-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             1
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# phase             1777039267-PostgreSQL-BHT-16-1-1-2
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777039267-PostgreSQL-BHT-16-1-1-2-2  \
# phase             1777039267-PostgreSQL-BHT-16-1-1-2
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-2
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# phase             1777039267-PostgreSQL-BHT-16-1-2-1
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-2-1-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             1
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# phase             1777039267-PostgreSQL-BHT-16-1-2-2
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777039267-PostgreSQL-BHT-16-1-2-2-2  \
# phase             1777039267-PostgreSQL-BHT-16-1-2-2
# code                                      1777039267
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-2
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# phase             1777041908-PostgreSQL-BHT-16-1-1-1
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-1-1-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             1
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-1-2-1  \
# phase             1777041908-PostgreSQL-BHT-16-1-1-2
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-1-2-2  \
# phase             1777041908-PostgreSQL-BHT-16-1-1-2
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-2
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-2-1-1  \
# phase             1777041908-PostgreSQL-BHT-16-1-2-1
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-2-1-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             1
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# phase             1777041908-PostgreSQL-BHT-16-1-2-2
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-1
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False
#
#                 1777041908-PostgreSQL-BHT-16-1-2-2-2
# phase             1777041908-PostgreSQL-BHT-16-1-2-2
# code                                      1777041908
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-2
# configuration                    PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# type_tenants                                    None
# num_tenants                                        0
# vol_tenants                                    False

# %% [markdown]
# ## Get Non-Constant Attributes
#
# These attributes are (most probably) used to analyze performance.

# %%
collectors.get_non_constant(df).T
# Out:
#                    1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-1-1-1
# phase                1777039267-PostgreSQL-BHT-16-1-1-1
# experiment_run                                        1
# client                                                1
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  1
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase                1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-1-2-2  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-1-2-2
# phase                1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-2-1-1
# phase                1777039267-PostgreSQL-BHT-16-1-2-1
# experiment_run                                        2
# client                                                1
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  1
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-2-2-1
# phase                1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# Throughput [SF/h]                                320.00
#
#                    1777039267-PostgreSQL-BHT-16-1-2-2-2  \
# code                                         1777039267
# connection         1777039267-PostgreSQL-BHT-16-1-2-2-2
# phase                1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        180.00
# time_ingest                                       84.00
# time_check                                        96.00
# pods                                                  2
# Throughput [SF/h]                                320.00
#
#                    1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-1-1-1
# phase                1777041908-PostgreSQL-BHT-16-1-1-1
# experiment_run                                        1
# client                                                1
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  1
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-1-2-1  \
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-1-2-1
# phase                1777041908-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  2
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-1-2-2  \
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-1-2-2
# phase                1777041908-PostgreSQL-BHT-16-1-1-2
# experiment_run                                        1
# client                                                2
# time_load                                        183.00
# time_ingest                                       84.00
# time_check                                        98.00
# pods                                                  2
# Throughput [SF/h]                                314.75
#
#                    1777041908-PostgreSQL-BHT-16-1-2-1-1  \
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-2-1-1
# phase                1777041908-PostgreSQL-BHT-16-1-2-1
# experiment_run                                        2
# client                                                1
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  1
# Throughput [SF/h]                                259.46
#
#                    1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-2-2-1
# phase                1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  2
# Throughput [SF/h]                                259.46
#
#                    1777041908-PostgreSQL-BHT-16-1-2-2-2
# code                                         1777041908
# connection         1777041908-PostgreSQL-BHT-16-1-2-2-2
# phase                1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                        2
# client                                                2
# time_load                                        222.00
# time_ingest                                       94.00
# time_check                                       128.00
# pods                                                  2
# Throughput [SF/h]                                259.46

# %%
df = collect.get_loading_per_run()
df.T
# Out:
#                   1777039267-PostgreSQL-BHT-16-1-1  \
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# SF                                              16
# time_load                                   180.00
# time_ingest                                  84.00
# time_check                                   96.00
# pods                                             2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
# Throughput [SF/h]                           320.00
#
#                   1777039267-PostgreSQL-BHT-16-1-2  \
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# SF                                              16
# time_load                                   180.00
# time_ingest                                  84.00
# time_check                                   96.00
# pods                                             2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
# Throughput [SF/h]                           320.00
#
#                   1777041908-PostgreSQL-BHT-16-1-1  \
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# SF                                              16
# time_load                                   183.00
# time_ingest                                  84.00
# time_check                                   98.00
# pods                                             2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
# Throughput [SF/h]                           314.75
#
#                   1777041908-PostgreSQL-BHT-16-1-2
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# SF                                              16
# time_load                                   222.00
# time_ingest                                  94.00
# time_check                                  128.00
# pods                                             2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
# Throughput [SF/h]                           259.46

# %% [markdown]
# # Monitoring Aggregated per Phase

# %%
df = collect.get_monitoring_aggregated_per_phase("stream")
df.T
# Out:
#                                                   1777039267-PostgreSQL-BHT-16-1-1-1  \
# Memory Usage [MiB]                                                           7777.19
# Memory Usage Cached [MiB]                                                    8552.64
# CPU Utilization                                                                 0.87
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      389.77
# CPU User Time [s]                                                             326.40
# CPU System Time [s]                                                            63.37
# Network Rx Total [MiB]                                                         94.19
# Network Tx Total [MiB]                                                       1064.29
# Filesystem Read Total [MiB]                                                     0.04
# Filesystem Write Total [MiB]                                                 2373.79
# Core Utilization Variance [%]                                                   0.23
# Max Core Utilization [%]                                                        3.26
# I/O Wait [%]                                                                   35.31
# Total I/O Wait Time [s]                                                       412.76
# Number of Idle Sessions                                                         1.33
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      17.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.03
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                 10.58
# Active Backends Waiting on Locks                                                3.01
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.03
# Max Transaction Duration (Lock Wait)                                            0.01
# Disk Blocks Read Count                                                      28399.00
# Buffer Cache Hit Count                                                   49064412.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           128.69
# AccessExclusiveLocks Current                                                    0.00
# AccessShareLocks Current                                                       45.61
# ExclusiveLocks Current                                                          2.85
# RowExclusiveLocks Current                                                      80.22
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        134.57
# Total WAL Size [GiB]                                                            2.10
# WAL Segments Growth Rate [segments/s]                                           0.24
# WAL Growth Rate [MiB/s]                                                         3.89
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777039267-PostgreSQL-BHT-16-1-1-2  \
# Memory Usage [MiB]                                                           8206.33
# Memory Usage Cached [MiB]                                                    9233.82
# CPU Utilization                                                                 0.89
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      415.60
# CPU User Time [s]                                                             346.78
# CPU System Time [s]                                                            68.82
# Network Rx Total [MiB]                                                         57.70
# Network Tx Total [MiB]                                                         60.79
# Filesystem Read Total [MiB]                                                     0.04
# Filesystem Write Total [MiB]                                                 2426.45
# Core Utilization Variance [%]                                                   0.21
# Max Core Utilization [%]                                                        2.59
# I/O Wait [%]                                                                   39.40
# Total I/O Wait Time [s]                                                       414.37
# Number of Idle Sessions                                                         2.64
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      16.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.03
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                 11.76
# Active Backends Waiting on Locks                                                1.87
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.03
# Max Transaction Duration (Lock Wait)                                            0.01
# Disk Blocks Read Count                                                       8678.00
# Buffer Cache Hit Count                                                   48877544.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           148.06
# AccessExclusiveLocks Current                                                    0.02
# AccessShareLocks Current                                                       54.36
# ExclusiveLocks Current                                                          1.64
# RowExclusiveLocks Current                                                      92.03
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        189.29
# Total WAL Size [GiB]                                                            2.96
# WAL Segments Growth Rate [segments/s]                                           0.11
# WAL Growth Rate [MiB/s]                                                         1.76
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777039267-PostgreSQL-BHT-16-1-2-1  \
# Memory Usage [MiB]                                                           7558.01
# Memory Usage Cached [MiB]                                                    8309.08
# CPU Utilization                                                                 0.57
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      261.09
# CPU User Time [s]                                                             212.53
# CPU System Time [s]                                                            48.56
# Network Rx Total [MiB]                                                         61.90
# Network Tx Total [MiB]                                                        936.34
# Filesystem Read Total [MiB]                                                     0.02
# Filesystem Write Total [MiB]                                                 1626.95
# Core Utilization Variance [%]                                                   0.17
# Max Core Utilization [%]                                                        2.25
# I/O Wait [%]                                                                   40.30
# Total I/O Wait Time [s]                                                       416.70
# Number of Idle Sessions                                                         1.12
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      16.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.08
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  1.00
# Active Backends Waiting on WAL                                                  6.61
# Active Backends Waiting on Locks                                                7.39
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.07
# Max Transaction Duration (Lock Wait)                                            0.06
# Disk Blocks Read Count                                                      15958.00
# Buffer Cache Hit Count                                                   38856965.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                            94.19
# AccessExclusiveLocks Current                                                    0.09
# AccessShareLocks Current                                                       28.25
# ExclusiveLocks Current                                                          4.93
# RowExclusiveLocks Current                                                      60.92
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        123.89
# Total WAL Size [GiB]                                                            1.94
# WAL Segments Growth Rate [segments/s]                                           0.21
# WAL Growth Rate [MiB/s]                                                         3.43
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777039267-PostgreSQL-BHT-16-1-2-2  \
# Memory Usage [MiB]                                                           8017.41
# Memory Usage Cached [MiB]                                                    8940.31
# CPU Utilization                                                                 0.74
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      328.68
# CPU User Time [s]                                                             270.50
# CPU System Time [s]                                                            58.19
# Network Rx Total [MiB]                                                         49.10
# Network Tx Total [MiB]                                                         58.98
# Filesystem Read Total [MiB]                                                     0.02
# Filesystem Write Total [MiB]                                                 2072.73
# Core Utilization Variance [%]                                                   0.19
# Max Core Utilization [%]                                                        2.44
# I/O Wait [%]                                                                   43.38
# Total I/O Wait Time [s]                                                       418.27
# Number of Idle Sessions                                                         2.28
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      16.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.06
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.97
# Active Backends Waiting on WAL                                                 10.16
# Active Backends Waiting on Locks                                                4.51
# Max Transaction Duration (I/O Wait)                                             0.02
# Max Transaction Duration (WAL Wait)                                             0.05
# Max Transaction Duration (Lock Wait)                                            0.05
# Disk Blocks Read Count                                                      16589.00
# Buffer Cache Hit Count                                                   39708346.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           128.52
# AccessExclusiveLocks Current                                                    0.02
# AccessShareLocks Current                                                       44.05
# ExclusiveLocks Current                                                          3.88
# RowExclusiveLocks Current                                                      80.56
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        164.52
# Total WAL Size [GiB]                                                            2.57
# WAL Segments Growth Rate [segments/s]                                           0.09
# WAL Growth Rate [MiB/s]                                                         1.40
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-1-1  \
# Memory Usage [MiB]                                                           7976.66
# Memory Usage Cached [MiB]                                                    8832.62
# CPU Utilization                                                                 1.17
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      538.01
# CPU User Time [s]                                                             436.96
# CPU System Time [s]                                                           101.05
# Network Rx Total [MiB]                                                        120.24
# Network Tx Total [MiB]                                                       1066.13
# Filesystem Read Total [MiB]                                                     0.14
# Filesystem Write Total [MiB]                                                 3154.14
# Core Utilization Variance [%]                                                   0.20
# Max Core Utilization [%]                                                        2.65
# I/O Wait [%]                                                                   32.68
# Total I/O Wait Time [s]                                                       411.15
# Number of Idle Sessions                                                         1.56
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.32
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                 13.44
# Active Backends Waiting on Locks                                               14.69
# Max Transaction Duration (I/O Wait)                                             0.02
# Max Transaction Duration (WAL Wait)                                             0.17
# Max Transaction Duration (Lock Wait)                                            0.29
# Disk Blocks Read Count                                                      26420.00
# Buffer Cache Hit Count                                                   68089848.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           188.04
# AccessExclusiveLocks Current                                                    0.00
# AccessShareLocks Current                                                       55.85
# ExclusiveLocks Current                                                          9.93
# RowExclusiveLocks Current                                                     122.26
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        143.81
# Total WAL Size [GiB]                                                            2.25
# WAL Segments Growth Rate [segments/s]                                           0.27
# WAL Growth Rate [MiB/s]                                                         4.26
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-1-2  \
# Memory Usage [MiB]                                                           8706.85
# Memory Usage Cached [MiB]                                                    9845.80
# CPU Utilization                                                                 1.52
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      716.95
# CPU User Time [s]                                                             633.26
# CPU System Time [s]                                                            83.68
# Network Rx Total [MiB]                                                         70.09
# Network Tx Total [MiB]                                                         54.56
# Filesystem Read Total [MiB]                                                     0.03
# Filesystem Write Total [MiB]                                                 2007.15
# Core Utilization Variance [%]                                                   0.18
# Max Core Utilization [%]                                                        2.50
# I/O Wait [%]                                                                   31.07
# Total I/O Wait Time [s]                                                       419.34
# Number of Idle Sessions                                                         2.52
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.41
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                  8.03
# Active Backends Waiting on Locks                                               19.46
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.15
# Max Transaction Duration (Lock Wait)                                            0.38
# Disk Blocks Read Count                                                      12493.00
# Buffer Cache Hit Count                                                   67871263.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           159.52
# AccessExclusiveLocks Current                                                    0.00
# AccessShareLocks Current                                                       44.94
# ExclusiveLocks Current                                                         11.24
# RowExclusiveLocks Current                                                     103.34
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        199.60
# Total WAL Size [GiB]                                                            3.12
# WAL Segments Growth Rate [segments/s]                                           0.09
# WAL Growth Rate [MiB/s]                                                         1.47
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-2-1  \
# Memory Usage [MiB]                                                           7910.65
# Memory Usage Cached [MiB]                                                    8728.59
# CPU Utilization                                                                 1.28
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      596.33
# CPU User Time [s]                                                             500.50
# CPU System Time [s]                                                            95.83
# Network Rx Total [MiB]                                                        104.97
# Network Tx Total [MiB]                                                       1079.82
# Filesystem Read Total [MiB]                                                     0.02
# Filesystem Write Total [MiB]                                                 2712.57
# Core Utilization Variance [%]                                                   0.17
# Max Core Utilization [%]                                                        2.71
# I/O Wait [%]                                                                   31.67
# Total I/O Wait Time [s]                                                       393.00
# Number of Idle Sessions                                                         1.60
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.22
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.96
# Active Backends Waiting on WAL                                                 11.94
# Active Backends Waiting on Locks                                               16.23
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.13
# Max Transaction Duration (Lock Wait)                                            0.21
# Disk Blocks Read Count                                                      24432.00
# Buffer Cache Hit Count                                                   75181391.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           174.45
# AccessExclusiveLocks Current                                                    0.02
# AccessShareLocks Current                                                       50.67
# ExclusiveLocks Current                                                         10.47
# RowExclusiveLocks Current                                                     113.29
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        138.17
# Total WAL Size [GiB]                                                            2.16
# WAL Segments Growth Rate [segments/s]                                           0.23
# WAL Growth Rate [MiB/s]                                                         3.71
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-2-2
# Memory Usage [MiB]                                                           8745.89
# Memory Usage Cached [MiB]                                                    9834.09
# CPU Utilization                                                                10.09
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                     4769.16
# CPU User Time [s]                                                            4640.84
# CPU System Time [s]                                                           128.32
# Network Rx Total [MiB]                                                         61.79
# Network Tx Total [MiB]                                                         47.12
# Filesystem Read Total [MiB]                                                     0.01
# Filesystem Write Total [MiB]                                                 2236.78
# Core Utilization Variance [%]                                                   1.72
# Max Core Utilization [%]                                                       17.68
# I/O Wait [%]                                                                   11.52
# Total I/O Wait Time [s]                                                       410.38
# Number of Idle Sessions                                                         2.34
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.40
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.98
# Active Backends Waiting on WAL                                                  8.96
# Active Backends Waiting on Locks                                                9.59
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.09
# Max Transaction Duration (Lock Wait)                                            0.17
# Disk Blocks Read Count                                                      14355.00
# Buffer Cache Hit Count                                                  710813686.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           189.00
# AccessExclusiveLocks Current                                                    0.02
# AccessShareLocks Current                                                       95.38
# ExclusiveLocks Current                                                          6.64
# RowExclusiveLocks Current                                                      86.96
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        193.28
# Total WAL Size [GiB]                                                            3.02
# WAL Segments Growth Rate [segments/s]                                           0.10
# WAL Growth Rate [MiB/s]                                                         1.64
# Average WAL Segment Size [MiB]                                                 16.00

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df = collect.add_metadata(df)
df.T
# Out:
# combine on index and column 'phase'
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-1  \
# Memory Usage [MiB]                                                                   7777.19
# Memory Usage Cached [MiB]                                                            8552.64
# CPU Utilization                                                                         0.87
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              389.77
# CPU User Time [s]                                                                     326.40
# CPU System Time [s]                                                                    63.37
# Network Rx Total [MiB]                                                                 94.19
# Network Tx Total [MiB]                                                               1064.29
# Filesystem Read Total [MiB]                                                             0.04
# Filesystem Write Total [MiB]                                                         2373.79
# Core Utilization Variance [%]                                                           0.23
# Max Core Utilization [%]                                                                3.26
# I/O Wait [%]                                                                           35.31
# Total I/O Wait Time [s]                                                               412.76
# Number of Idle Sessions                                                                 1.33
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              17.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.03
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.99
# Active Backends Waiting on WAL                                                         10.58
# Active Backends Waiting on Locks                                                        3.01
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.03
# Max Transaction Duration (Lock Wait)                                                    0.01
# Disk Blocks Read Count                                                              28399.00
# Buffer Cache Hit Count                                                           49064412.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   128.69
# AccessExclusiveLocks Current                                                            0.00
# AccessShareLocks Current                                                               45.61
# ExclusiveLocks Current                                                                  2.85
# RowExclusiveLocks Current                                                              80.22
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                134.57
# Total WAL Size [GiB]                                                                    2.10
# WAL Segments Growth Rate [segments/s]                                                   0.24
# WAL Growth Rate [MiB/s]                                                                 3.89
# Average WAL Segment Size [MiB]                                                         16.00
# code                                                                              1777039267
# configuration                                                            PostgreSQL-BHT-16-1
# experiment_run                                                                             1
# client                                                                                     1
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3298
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154360
# host_datadisk                                                                           3298
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-1
#
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-2  \
# Memory Usage [MiB]                                                                   8206.33
# Memory Usage Cached [MiB]                                                            9233.82
# CPU Utilization                                                                         0.89
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              415.60
# CPU User Time [s]                                                                     346.78
# CPU System Time [s]                                                                    68.82
# Network Rx Total [MiB]                                                                 57.70
# Network Tx Total [MiB]                                                                 60.79
# Filesystem Read Total [MiB]                                                             0.04
# Filesystem Write Total [MiB]                                                         2426.45
# Core Utilization Variance [%]                                                           0.21
# Max Core Utilization [%]                                                                2.59
# I/O Wait [%]                                                                           39.40
# Total I/O Wait Time [s]                                                               414.37
# Number of Idle Sessions                                                                 2.64
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              16.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.03
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.99
# Active Backends Waiting on WAL                                                         11.76
# Active Backends Waiting on Locks                                                        1.87
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.03
# Max Transaction Duration (Lock Wait)                                                    0.01
# Disk Blocks Read Count                                                               8678.00
# Buffer Cache Hit Count                                                           48877544.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   148.06
# AccessExclusiveLocks Current                                                            0.02
# AccessShareLocks Current                                                               54.36
# ExclusiveLocks Current                                                                  1.64
# RowExclusiveLocks Current                                                              92.03
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                189.29
# Total WAL Size [GiB]                                                                    2.96
# WAL Segments Growth Rate [segments/s]                                                   0.11
# WAL Growth Rate [MiB/s]                                                                 1.76
# Average WAL Segment Size [MiB]                                                         16.00
# code                                                                              1777039267
# configuration                                                            PostgreSQL-BHT-16-1
# experiment_run                                                                             1
# client                                                                                     2
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       2
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                4482
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             155544
# host_datadisk                                                                           4482
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    2
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                    8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-2
#
# phase                                                     1777039267-PostgreSQL-BHT-16-1-2-1  \
# Memory Usage [MiB]                                                                   7558.01
# Memory Usage Cached [MiB]                                                            8309.08
# CPU Utilization                                                                         0.57
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              261.09
# CPU User Time [s]                                                                     212.53
# CPU System Time [s]                                                                    48.56
# Network Rx Total [MiB]                                                                 61.90
# Network Tx Total [MiB]                                                                936.34
# Filesystem Read Total [MiB]                                                             0.02
# Filesystem Write Total [MiB]                                                         1626.95
# Core Utilization Variance [%]                                                           0.17
# Max Core Utilization [%]                                                                2.25
# I/O Wait [%]                                                                           40.30
# Total I/O Wait Time [s]                                                               416.70
# Number of Idle Sessions                                                                 1.12
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              16.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.08
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          1.00
# Active Backends Waiting on WAL                                                          6.61
# Active Backends Waiting on Locks                                                        7.39
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.07
# Max Transaction Duration (Lock Wait)                                                    0.06
# Disk Blocks Read Count                                                              15958.00
# Buffer Cache Hit Count                                                           38856965.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                    94.19
# AccessExclusiveLocks Current                                                            0.09
# AccessShareLocks Current                                                               28.25
# ExclusiveLocks Current                                                                  4.93
# RowExclusiveLocks Current                                                              60.92
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                123.89
# Total WAL Size [GiB]                                                                    1.94
# WAL Segments Growth Rate [segments/s]                                                   0.21
# WAL Growth Rate [MiB/s]                                                                 3.43
# Average WAL Segment Size [MiB]                                                         16.00
# code                                                                              1777039267
# configuration                                                            PostgreSQL-BHT-16-1
# experiment_run                                                                             2
# client                                                                                     1
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3299
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154360
# host_datadisk                                                                           3299
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777039267-PostgreSQL-BHT-16-1-2-1
#
# phase                                                     1777039267-PostgreSQL-BHT-16-1-2-2  \
# Memory Usage [MiB]                                                                   8017.41
# Memory Usage Cached [MiB]                                                            8940.31
# CPU Utilization                                                                         0.74
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              328.68
# CPU User Time [s]                                                                     270.50
# CPU System Time [s]                                                                    58.19
# Network Rx Total [MiB]                                                                 49.10
# Network Tx Total [MiB]                                                                 58.98
# Filesystem Read Total [MiB]                                                             0.02
# Filesystem Write Total [MiB]                                                         2072.73
# Core Utilization Variance [%]                                                           0.19
# Max Core Utilization [%]                                                                2.44
# I/O Wait [%]                                                                           43.38
# Total I/O Wait Time [s]                                                               418.27
# Number of Idle Sessions                                                                 2.28
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              16.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.06
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.97
# Active Backends Waiting on WAL                                                         10.16
# Active Backends Waiting on Locks                                                        4.51
# Max Transaction Duration (I/O Wait)                                                     0.02
# Max Transaction Duration (WAL Wait)                                                     0.05
# Max Transaction Duration (Lock Wait)                                                    0.05
# Disk Blocks Read Count                                                              16589.00
# Buffer Cache Hit Count                                                           39708346.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   128.52
# AccessExclusiveLocks Current                                                            0.02
# AccessShareLocks Current                                                               44.05
# ExclusiveLocks Current                                                                  3.88
# RowExclusiveLocks Current                                                              80.56
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                164.52
# Total WAL Size [GiB]                                                                    2.57
# WAL Segments Growth Rate [segments/s]                                                   0.09
# WAL Growth Rate [MiB/s]                                                                 1.40
# Average WAL Segment Size [MiB]                                                         16.00
# code                                                                              1777039267
# configuration                                                            PostgreSQL-BHT-16-1
# experiment_run                                                                             2
# client                                                                                     2
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       2
# tenant
# ...
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777041908-PostgreSQL-BHT-16-1-2-1
#
# phase                                                     1777041908-PostgreSQL-BHT-16-1-2-2
# Memory Usage [MiB]                                                                   8745.89
# Memory Usage Cached [MiB]                                                            9834.09
# CPU Utilization                                                                        10.09
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                             4769.16
# CPU User Time [s]                                                                    4640.84
# CPU System Time [s]                                                                   128.32
# Network Rx Total [MiB]                                                                 61.79
# Network Tx Total [MiB]                                                                 47.12
# Filesystem Read Total [MiB]                                                             0.01
# Filesystem Write Total [MiB]                                                         2236.78
# Core Utilization Variance [%]                                                           1.72
# Max Core Utilization [%]                                                               17.68
# I/O Wait [%]                                                                           11.52
# Total I/O Wait Time [s]                                                               410.38
# Number of Idle Sessions                                                                 2.34
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              32.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.40
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.98
# Active Backends Waiting on WAL                                                          8.96
# Active Backends Waiting on Locks                                                        9.59
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.09
# Max Transaction Duration (Lock Wait)                                                    0.17
# Disk Blocks Read Count                                                              14355.00
# Buffer Cache Hit Count                                                          710813686.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   189.00
# AccessExclusiveLocks Current                                                            0.02
# AccessShareLocks Current                                                               95.38
# ExclusiveLocks Current                                                                  6.64
# RowExclusiveLocks Current                                                              86.96
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                193.28
# Total WAL Size [GiB]                                                                    3.02
# WAL Segments Growth Rate [segments/s]                                                   0.10
# WAL Growth Rate [MiB/s]                                                                 1.64
# Average WAL Segment Size [MiB]                                                         16.00
# code                                                                              1777041908
# configuration                                                            PostgreSQL-BHT-16-1
# experiment_run                                                                             2
# client                                                                                     2
# dockerimage                                                                    postgres:18.3
# time_load                                                                             222.00
# time_ingest                                                                            94.00
# time_check                                                                            128.00
# terminals                                                                                  0
# pods                                                                                       2
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                4642
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             155704
# host_datadisk                                                                           4642
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    2
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777041908-PostgreSQL-BHT-16-1-2-2

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].T
# Out:
# phase           1777039267-PostgreSQL-BHT-16-1-1-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-1-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-1-1  \
# phase           1777041908-PostgreSQL-BHT-16-1-1-1
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-1-2  \
# phase           1777041908-PostgreSQL-BHT-16-1-1-2
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-2-1  \
# phase           1777041908-PostgreSQL-BHT-16-1-2-1
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-2-2
# phase           1777041908-PostgreSQL-BHT-16-1-2-2
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False

# %% [markdown]
# # Time Series of a Single Metric for a Single Experiment
#
# This is particularly important if you require a customized aggregation or wish to monitor a component over time.

# %%
metric = 'total_cpu_memory'
code = codes[0]
df = collect.get_monitoring_timeseries_per_phase(code, metric=metric, component='stream')
df.T
# Out:
#      1777039267-PostgreSQL-BHT-16-1-1-1  1777039267-PostgreSQL-BHT-16-1-1-2  \
# 0                               7177.68                             7800.83
# 1                               7177.68                             7800.83
# 2                               7177.68                             7800.83
# 3                               7177.68                             7800.83
# 4                               7177.68                             7800.83
# 5                               7177.68                             7800.83
# 6                               7177.68                             7800.83
# 7                               7177.68                             7800.83
# 8                               7378.69                             7800.83
# 9                               7378.69                             7800.83
# 10                              7378.69                             7800.83
# 11                              7378.69                             7800.83
# 12                              7378.69                             7800.83
# 13                              7378.69                             7800.83
# 14                              7378.69                             7800.83
# 15                              7378.69                             7800.83
# 16                              7378.69                             7800.83
# 17                              7378.69                             8025.23
# 18                              7378.69                             8025.23
# 19                              7378.69                             8025.23
# 20                              7378.69                             8025.23
# 21                              7378.69                             8025.23
# 22                              7378.69                             8025.23
# 23                              7378.69                             8025.23
# 24                              7378.69                             8025.23
# 25                              7378.69                             8025.23
# 26                              7378.69                             8025.23
# 27                              7378.69                             8025.23
# 28                              7378.69                             8025.23
# 29                              7378.69                             8025.23
# 30                              7378.69                             8025.23
# 31                              7378.69                             8025.23
# 32                              7378.69                             8025.23
# 33                              7378.69                             8025.23
# 34                              7378.69                             8025.23
# 35                              7378.69                             8025.23
# 36                              7378.69                             8025.23
# 37                              7378.69                             8025.23
# 38                              7378.69                             8025.23
# 39                              7625.29                             8025.23
# 40                              7625.29                             8025.23
# 41                              7625.29                             8025.23
# 42                              7625.29                             8025.23
# 43                              7625.29                             8025.23
# 44                              7625.29                             8025.23
# 45                              7625.29                             8025.23
# 46                              7625.29                             8025.23
# 47                              7625.29                             8025.23
# 48                              7625.29                             8025.23
# 49                              7625.29                             8086.74
# 50                              7625.29                             8086.74
# 51                              7625.29                             8086.74
# 52                              7625.29                             8086.74
# 53                              7625.29                             8086.74
# 54                              7625.29                             8086.74
# 55                              7625.29                             8086.74
# 56                              7625.29                             8086.74
# 57                              7625.29                             8086.74
# 58                              7662.25                             8086.74
# 59                              7662.25                             8086.74
# 60                              7662.25                             8086.74
# 61                              7662.25                             8086.74
# 62                              7662.25                             8086.74
# 63                              7662.25                             8086.74
# 64                              7662.25                             8086.74
# 65                              7662.25                             8086.74
# 66                              7662.25                             8086.74
# 67                              7662.25                             8086.74
# 68                              7662.25                             8086.74
# 69                              7662.25                             8086.74
# 70                              7662.25                             8086.74
# 71                              7662.25                             8086.74
# 72                              7662.25                             8086.74
# 73                              7662.25                             8086.74
# 74                              7662.25                             8113.91
# 75                              7662.25                             8113.91
# 76                              7662.25                             8113.91
# 77                              7662.25                             8113.91
# 78                              7662.25                             8113.91
# 79                              7662.25                             8113.91
# 80                              7662.25                             8113.91
# 81                              7662.25                             8113.91
# 82                              7662.25                             8113.91
# 83                              7694.69                             8113.91
# 84                              7694.69                             8113.91
# 85                              7694.69                             8113.91
# 86                              7694.69                             8113.91
# 87                              7694.69                             8113.91
# 88                              7694.69                             8113.91
# 89                              7694.69                             8113.91
# 90                              7694.69                             8113.91
# 91                              7694.69                             8113.91
# 92                              7694.69                             8113.91
# 93                              7694.69                             8113.91
# 94                              7694.69                             8113.91
# 95                              7694.69                             8113.91
# 96                              7694.69                             8113.91
# 97                              7694.69                             8113.91
# 98                              7694.69                             8113.91
# 99                              7694.69                             8113.91
# 100                             7694.69                             8113.91
# 101                             7694.69                             8113.91
# 102                             7694.69                             8113.91
# 103                             7694.69                             8113.91
# 104                             7694.69                             8113.91
# 105                             7694.69                             8113.91
# 106                             7694.69                             8113.91
# 107                             7694.69                             8113.91
# 108                             7694.69                             8113.91
# 109                             7694.69                             8144.05
# 110                             7694.69                             8144.05
# 111                             7694.69                             8144.05
# 112                             7694.69                             8144.05
# 113                             7694.69                             8144.05
# 114                             7694.69                             8144.05
# 115                             7694.69                             8144.05
# 116                             7694.69                             8144.05
# 117                             7694.69                             8144.05
# 118                             7694.69                             8144.05
# 119                             7694.69                             8144.05
# 120                             7694.69                             8144.05
# 121                             7694.69                             8144.05
# 122                             7694.69                             8144.05
# 123                             7694.69                             8144.05
# 124                             7694.69                             8144.05
# 125                             7694.69                             8144.05
# 126                             7694.69                             8144.05
# 127                             7738.99                             8144.05
# 128                             7738.99                             8144.05
# 129                             7738.99                             8144.05
# 130                             7738.99                             8144.05
# 131                             7738.99                             8144.05
# 132                             7738.99                             8144.05
# 133                             7738.99                             8144.05
# 134                             7738.99                             8144.05
# 135                             7738.99                             8144.05
# 136                             7738.99                             8144.05
# 137                             7738.99                             8168.80
# 138                             7738.99                             8168.80
# 139                             7738.99                             8168.80
# 140                             7738.99                             8168.80
# 141                             7738.99                             8168.80
# 142                             7738.99                             8168.80
# 143                             7738.99                             8168.80
# 144                             7738.99                             8168.80
# 145                             7738.99                             8168.80
# 146                             7738.99                             8168.80
# 147                             7738.99                             8168.80
# 148                             7738.99                             8168.80
# 149                             7738.99                             8168.80
# 150                             7738.99                             8168.80
# 151                             7738.99                             8168.80
# 152                             7759.76                             8168.80
# 153                             7759.76                             8168.80
# 154                             7759.76                             8168.80
# 155                             7759.76                             8168.80
# 156                             7759.76                             8168.80
# 157                             7759.76                             8168.80
# 158                             7759.76                             8168.80
# 159                             7759.76                             8168.80
# 160                             7759.76                             8168.80
# 161                             7759.76                             8168.80
# 162                             7759.76                             8168.80
# 163                             7759.76                             8168.80
# 164                             7759.76                             8190.48
# 165                             7759.76                             8190.48
# 166                             7759.76                             8190.48
# 167                             7759.76                             8190.48
# 168                             7759.76                             8190.48
# 169                             7759.76                             8190.48
# 170                             7759.76                             8190.48
# 171                             7759.76                             8190.48
# 172                             7759.76                             8190.48
# 173                             7759.76                             8190.48
# 174                             7759.76                             8190.48
# 175                             7759.76                             8190.48
# 176                             7759.76                             8190.48
# 177                             7759.76                             8190.48
# 178                             7759.76                             8190.48
# 179                             7782.45                             8190.48
# 180                             7782.45                             8190.48
# 181                             7782.45                             8190.48
# 182                             7782.45                             8190.48
# 183                             7782.45                             8190.48
# 184                             7782.45                             8190.48
# 185                             7782.45                             8190.48
# 186                             7782.45                             8190.48
# 187                             7782.45                             8190.48
# 188                             7782.45                             8190.48
# 189                             7782.45                             8190.48
# 190                             7782.45                             8190.48
# 191                             7782.45                             8190.48
# 192                             7782.45                             8190.48
# 193                             7782.45                             8190.48
# 194                             7782.45                             8190.48
# 195                             7782.45                             8190.48
# 196                             7782.45                             8190.48
# 197                             7782.45                             8218.05
# 198                             7782.45                             8218.05
# 199                             7782.45                             8218.05
# 200                             7782.45                             8218.05
# 201                             7782.45                             8218.05
# 202                             7782.45                             8218.05
# 203                             7782.45                             8218.05
# 204                             7782.45                             8218.05
# 205                             7806.09                             8218.05
# 206                             7806.09                             8218.05
# 207                             7806.09                             8218.05
# 208                             7806.09                             8218.05
# 209                             7806.09                             8218.05
# 210                             7806.09                             8218.05
# 211                             7806.09                             8218.05
# 212                             7806.09                             8218.05
# 213                             7806.09                             8218.05
# 214                             7806.09                             8218.05
# 215                             7806.09                             8218.05
# 216                             7806.09                             8218.05
# 217                             7806.09                             8218.05
# 218                             7806.09                             8218.05
# 219                             7806.09                             8218.05
# 220                             7806.09                             8218.05
# 221                             7806.09                             8218.05
# 222                             7806.09                             8218.05
# 223                             7806.09                             8238.18
# 224                             7806.09                             8238.18
# 225                             7806.09                             8238.18
# 226                             7806.09                             8238.18
# 227                             7806.09                             8238.18
# 228                             7806.09                             8238.18
# 229                             7806.09                             8238.18
# 230                             7806.09                             8238.18
# 231                             7806.09                             8238.18
# 232                             7806.09                             8238.18
# 233                             7806.09                             8238.18
# 234                             7806.09                             8238.18
# 235                             7806.09                             8238.18
# 236                             7806.09                             8238.18
# 237                             7806.09                             8238.18
# 238                             7806.09                             8238.18
# 239                             7806.09                             8238.18
# 240                             7806.09                             8238.18
# 241                             7806.09                             8238.18
# 242                             7806.09                             8238.18
# 243                             7806.09                             8238.18
# 244                             7806.09                             8238.18
# 245                             7806.09                             8238.18
# 246                             7806.09                             8238.18
# 247                             7806.09                             8238.18
# 248                             7806.09                             8238.18
# 249                             7843.71                             8238.18
# 250                             7843.71                             8238.18
# 251                             7843.71                             8238.18
# 252                             7843.71                             8238.18
# 253                             7843.71                             8238.18
# 254                             7843.71                             8238.18
# 255                             7843.71                             8238.18
# 256                             7843.71                             8238.18
# 257                             7843.71                             8238.18
# 258                             7843.71                             8238.18
# 259                             7843.71                             8266.32
# 260                             7843.71                             8266.32
# 261                             7843.71                             8266.32
# 262                             7843.71                             8266.32
# 263                             7843.71                             8266.32
# 264                             7843.71                             8266.32
# 265                             7843.71                             8266.32
# 266                             7843.71                             8266.32
# 267                             7843.71                             8266.32
# 268                             7861.88                             8266.32
# 269                             7861.88                             8266.32
# 270                             7861.88                             8266.32
# 271                             7861.88                             8266.32
# 272                             7861.88                             8274.05
# 273                             7861.88                             8274.05
# 274                             7861.88                             8274.05
# 275                             7861.88                             8274.05
# 276                             7861.88                             8274.05
# 277                             7861.88                             8274.05
# 278                             7861.88                             8274.05
# 279                             7861.88                             8274.05
# 280                             7861.88                             8274.05
# 281                             7861.88                             8274.05
# 282                             7861.88                             8274.05
# 283                             7861.88                             8274.05
# 284                             7861.88                             8274.05
# 285                             7861.88                             8274.05
# 286                             7861.88                             8274.05
# 287                             7861.88                             8274.05
# 288                             7861.88                             8274.05
# 289                             7861.88                             8274.05
# 290                             7861.88                             8274.05
# 291                             7861.88                             8274.05
# 292                             7861.88                             8274.05
# 293                             7861.88                             8274.05
# 294                             7861.88                             8274.05
# 295                             7861.88                             8274.05
# 296                             7861.88                             8274.05
# 297                             7861.88                             8274.05
# 298                             7861.88                             8274.05
# 299                             7861.88                             8274.05
# 300                             7861.88                             8274.05
# 301                             7861.88                             8274.05
# 302                             7861.88                             8274.05
# 303                             7861.88                             8274.05
# 304                             7861.88                             8274.05
# 305                             7861.88                             8274.05
# 306                             7861.88                             8274.05
# 307                             7892.12                             8274.05
# 308                             7892.12                             8274.05
# 309                             7892.12                             8274.05
# 310                             7892.12                             8303.09
# 311                             7892.12                             8303.09
# 312                             7892.12                             8303.09
# 313                             7892.12                             8303.09
# 314                             7892.12                             8303.09
# 315                             7892.12                             8303.09
# 316                             7892.12                             8303.09
# 317                             7892.12                             8303.09
# 318                             7892.12                             8303.09
# 319                             7892.12                             8303.09
# 320                             7892.12                             8303.09
# 321                             7892.12                             8303.09
# 322                             7892.12                             8303.09
# 323                             7892.12                             8303.09
# 324                             7892.12                             8303.09
# 325                             7892.12                             8303.09
# 326                             7892.12                             8303.09
# 327                             7892.12                             8303.09
# 328                             7892.12                             8303.09
# 329                             7892.12                             8303.09
# 330                             7892.12                             8303.09
# 331                             7892.12                             8303.09
# 332                             7892.12                             8303.09
# 333                             7892.12                             8303.09
# 334                             7892.12                             8323.08
# 335                             7892.12                             8323.08
# 336                             7892.12                             8323.08
# 337                             7892.12                             8323.08
# 338                             7892.12                             8323.08
# 339                             7916.83                             8323.08
# 340                             7916.83                             8323.08
# 341                             7916.83                             8323.08
# 342                             7916.83                             8323.08
# 343                             7916.83                             8323.08
# 344                             7916.83                             8323.08
# 345                             7916.83                             8323.08
# 346                             7916.83                             8323.08
# 347                             7916.83                             8323.08
# 348                             7916.83                             8323.08
# 349                             7916.83                             8323.08
# 350                             7916.83                             8323.08
# 351                             7916.83                             8323.08
# 352                             7916.83                             8323.08
# 353                             7916.83                             8323.08
# 354                             7916.83                             8323.08
# 355                             7916.83                             8323.08
# 356                             7916.83                             8323.08
# 357                             7916.83                             8323.08
# 358                             7916.83                             8323.08
# 359                             7916.83                             8323.08
# 360                             7916.83                             8323.08
# 361                             7916.83                             8323.08
# 362                             7916.83                             8323.08
# 363                             7916.83                             8323.08
# 364                             7916.83                             8323.08
# 365                             7916.83                             8323.08
# 366                             7916.83                             8323.08
# 367                             7916.83                             8323.08
# 368                             7941.53                             8323.08
# 369                             7941.53                             8323.08
# 370                             7941.53                             8323.08
# 371                             7941.53                             8323.08
# 372                             7941.53                             8323.08
# 373                             7941.53                             8353.85
# 374                             7941.53                             8353.85
# 375                             7941.53                             8353.85
# 376                             7941.53                             8353.85
# 377                             7941.53                             8353.85
# 378                             7941.53                             8353.85
# 379                             7941.53                             8353.85
# 380                             7941.53                             8353.85
# 381                             7941.53                             8353.85
# 382                             7941.53                             8353.85
# 383                             7941.53                             8353.85
# 384                             7941.53                             8353.85
# 385                             7941.53                             8353.85
# 386                             7941.53                             8353.85
# 387                             7957.46                             8353.85
# 388                             7957.46                             8353.85
# 389                             7957.46                             8353.85
# 390                             7957.46                             8353.85
# 391                             7957.46                             8353.85
# 392                             7957.46                             8353.85
# 393                             7957.46                             8353.85
# 394                             7957.46                             8353.85
# 395                             7957.46                             8353.85
# 396                             7957.46                             8353.85
# 397                             7957.46                             8353.85
# 398                             7957.46                             8353.85
# 399                             7957.46                             8353.85
# 400                             7957.46                             8353.85
# 401                             7957.46                             8353.85
# 402                             7957.46                             8353.85
# 403                             7957.46                             8353.85
# 404                             7957.46                             8353.85
# 405                             7957.46                             8353.85
# 406                             7957.46                             8353.85
# 407                             7957.46                             8353.85
# 408                             7957.46                             8353.85
# 409                             7957.46                             8353.85
# 410                             7957.46                             8382.68
# 411                             7957.46                             8382.68
# 412                             7957.46                             8382.68
# 413                             7957.46                             8382.68
# 414                             7957.46                             8382.68
# 415                             7957.46                             8382.68
# 416                             7957.46                             8382.68
# 417                             7957.46                             8382.68
# 418                             7957.46                             8382.68
# 419                             7983.82                             8382.68
# 420                             7983.82                             8382.68
# 421                             7983.82                             8382.68
# 422                             7983.82                             8382.68
# 423                             7983.82                             8382.68
# 424                             7983.82                             8382.68
# 425                             7983.82                             8382.68
# 426                             7983.82                             8382.68
# 427                             7983.82                             8382.68
# 428                             7983.82                             8382.68
# 429                             7983.82                             8382.68
# 430                             7983.82                             8382.68
# 431                             7983.82                             8382.68
# 432                             7983.82                             8382.68
# 433                             7983.82                             8382.68
# 434                             7983.82                             8382.68
# 435                             7983.82                             8382.68
# 436                             7983.82                             8382.68
# 437                             7983.82                             8382.68
# 438                             7983.82                             8382.68
# 439                             7983.82                             8194.39
# 440                             7983.82                             8194.39
# 441                             7983.82                             8194.39
# 442                             7983.82                             8194.39
# 443                             7983.82                             8194.39
# 444                             7983.82                                 NaN
# 445                                 NaN                                 NaN
# 446                                 NaN                                 NaN
# 447                                 NaN                                 NaN
#
#      1777039267-PostgreSQL-BHT-16-1-2-1  1777039267-PostgreSQL-BHT-16-1-2-2
# 0                               7177.31                             7541.44
# 1                               7177.31                             7541.44
# 2                               7177.31                             7541.44
# 3                               7177.31                             7541.44
# 4                               7177.31                             7541.44
# 5                               7177.31                             7541.44
# 6                               7177.31                             7541.44
# 7                               7177.31                             7541.44
# 8                               7177.31                             7758.32
# 9                               7177.31                             7758.32
# 10                              7177.31                             7758.32
# 11                              7177.31                             7758.32
# 12                              7177.31                             7758.32
# 13                              7177.31                             7758.32
# 14                              7177.31                             7758.32
# 15                              7177.31                             7758.32
# 16                              7177.31                             7758.32
# 17                              7177.31                             7758.32
# 18                              7177.31                             7758.32
# 19                              7177.31                             7758.32
# 20                              7177.31                             7758.32
# 21                              7177.31                             7758.32
# 22                              7177.31                             7758.32
# 23                              7177.31                             7758.32
# 24                              7177.31                             7758.32
# 25                              7177.31                             7758.32
# 26                              7177.31                             7758.32
# 27                              7177.31                             7867.18
# 28                              7444.04                             7867.18
# 29                              7444.04                             7867.18
# 30                              7444.04                             7867.18
# 31                              7444.04                             7867.18
# 32                              7444.04                             7867.18
# 33                              7444.04                             7867.18
# 34                              7444.04                             7867.18
# 35                              7444.04                             7867.18
# 36                              7444.04                             7867.18
# 37                              7444.04                             7867.18
# 38                              7444.04                             7867.18
# 39                              7444.04                             7867.18
# 40                              7444.04                             7867.18
# 41                              7444.04                             7867.18
# 42                              7444.04                             7867.18
# 43                              7444.04                             7867.18
# 44                              7444.04                             7867.18
# 45                              7444.04                             7867.18
# 46                              7444.04                             7867.18
# 47                              7444.04                             7867.18
# 48                              7444.04                             7867.18
# 49                              7444.04                             7867.18
# 50                              7444.04                             7867.18
# 51                              7444.04                             7867.18
# 52                              7444.04                             7867.18
# 53                              7444.04                             7867.18
# 54                              7444.04                             7867.18
# 55                              7444.04                             7867.18
# 56                              7444.04                             7867.18
# 57                              7444.04                             7867.18
# 58                              7444.04                             7867.18
# 59                              7444.04                             7867.18
# 60                              7444.04                             7867.18
# 61                              7444.04                             7867.18
# 62                              7444.04                             7867.18
# 63                              7444.04                             7867.18
# 64                              7490.14                             7867.18
# 65                              7490.14                             7867.18
# 66                              7490.14                             7931.63
# 67                              7490.14                             7931.63
# 68                              7490.14                             7931.63
# 69                              7490.14                             7931.63
# 70                              7490.14                             7931.63
# 71                              7490.14                             7931.63
# 72                              7490.14                             7931.63
# 73                              7490.14                             7931.63
# 74                              7490.14                             7931.63
# 75                              7490.14                             7931.63
# 76                              7490.14                             7931.63
# 77                              7490.14                             7931.63
# 78                              7490.14                             7931.63
# 79                              7490.14                             7931.63
# 80                              7490.14                             7931.63
# 81                              7490.14                             7931.63
# 82                              7490.14                             7931.63
# 83                              7499.85                             7931.63
# 84                              7499.85                             7931.63
# 85                              7499.85                             7931.63
# 86                              7499.85                             7931.63
# 87                              7499.85                             7931.63
# 88                              7499.85                             7931.63
# 89                              7499.85                             7931.63
# 90                              7499.85                             7931.63
# 91                              7499.85                             7931.63
# 92                              7499.85                             7931.63
# 93                              7499.85                             7956.00
# 94                              7499.85                             7956.00
# 95                              7499.85                             7956.00
# 96                              7499.85                             7956.00
# 97                              7499.85                             7956.00
# 98                              7499.85                             7956.00
# 99                              7499.85                             7956.00
# 100                             7499.85                             7956.00
# 101                             7499.85                             7956.00
# 102                             7499.85                             7956.00
# 103                             7499.85                             7956.00
# 104                             7499.85                             7956.00
# 105                             7499.85                             7956.00
# 106                             7499.85                             7956.00
# 107                             7499.85                             7956.00
# 108                             7499.85                             7956.00
# 109                             7499.85                             7956.00
# 110                             7499.85                             7956.00
# 111                             7499.85                             7956.00
# 112                             7499.85                             7956.00
# 113                             7499.85                             7956.00
# 114                             7499.85                             7956.00
# 115                             7499.85                             7956.00
# 116                             7499.85                             7956.00
# 117                             7499.85                             7956.00
# 118                             7499.85                             7956.00
# 119                             7499.85                             7956.00
# 120                             7499.85                             7956.00
# 121                             7499.85                             7956.00
# 122                             7499.85                             7956.00
# 123                             7528.90                             7981.62
# 124                             7528.90                             7981.62
# 125                             7528.90                             7981.62
# 126                             7528.90                             7981.62
# 127                             7528.90                             7981.62
# 128                             7528.90                             7981.62
# 129                             7528.90                             7981.62
# 130                             7528.90                             7981.62
# 131                             7528.90                             7981.62
# 132                             7528.90                             7981.62
# 133                             7528.90                             7981.62
# 134                             7528.90                             7981.62
# 135                             7528.90                             7981.62
# 136                             7528.90                             7981.62
# 137                             7528.90                             7981.62
# 138                             7528.90                             7981.62
# 139                             7528.90                             7981.62
# 140                             7528.90                             7981.62
# 141                             7528.90                             7981.62
# 142                             7528.90                             7981.62
# 143                             7528.90                             7981.62
# 144                             7528.90                             7981.62
# 145                             7528.90                             7981.62
# 146                             7528.90                             7981.62
# 147                             7528.90                             7981.62
# 148                             7528.90                             7981.62
# 149                             7528.90                             7981.62
# 150                             7528.90                             7981.62
# 151                             7528.90                             7981.62
# 152                             7528.90                             7981.62
# 153                             7551.91                             7981.62
# 154                             7551.91                             8004.64
# 155                             7551.91                             8004.64
# 156                             7551.91                             8004.64
# 157                             7551.91                             8004.64
# 158                             7551.91                             8004.64
# ...
# 243                             7606.66                             8063.78
# 244                             7606.66                             8063.78
# 245                             7606.66                             8063.78
# 246                             7606.66                             8063.78
# 247                             7606.66                             8063.78
# 248                             7606.66                             8063.78
# 249                             7606.66                             8063.78
# 250                             7606.66                             8063.78
# 251                             7606.66                             8063.78
# 252                             7606.66                             8063.78
# 253                             7606.66                             8063.78
# 254                             7606.66                             8063.78
# 255                             7606.66                             8063.78
# 256                             7606.66                             8063.78
# 257                             7606.66                             8063.78
# 258                             7606.66                             8063.78
# 259                             7606.66                             8063.78
# 260                             7606.66                             8063.78
# 261                             7618.42                             8063.78
# 262                             7618.42                             8063.78
# 263                             7618.42                             8081.09
# 264                             7618.42                             8081.09
# 265                             7618.42                             8081.09
# 266                             7618.42                             8081.09
# 267                             7618.42                             8081.09
# 268                             7618.42                             8081.09
# 269                             7618.42                             8081.09
# 270                             7618.42                             8081.09
# 271                             7618.42                             8081.09
# 272                             7618.42                             8081.09
# 273                             7618.42                             8081.09
# 274                             7618.42                             8081.09
# 275                             7618.42                             8081.09
# 276                             7618.42                             8081.09
# 277                             7618.42                             8081.09
# 278                             7618.42                             8081.09
# 279                             7618.42                             8081.09
# 280                             7618.42                             8081.09
# 281                             7618.42                             8081.09
# 282                             7618.42                             8081.09
# 283                             7618.42                             8081.09
# 284                             7618.42                             8081.09
# 285                             7618.42                             8081.09
# 286                             7618.42                             8081.09
# 287                             7618.42                             8081.09
# 288                             7618.42                             8081.09
# 289                             7618.42                             8081.09
# 290                             7618.42                             8081.09
# 291                             7618.42                             8081.09
# 292                             7618.42                             8081.09
# 293                             7618.42                             8081.09
# 294                             7618.42                             8081.09
# 295                             7618.42                             8081.09
# 296                             7618.42                             8081.09
# 297                             7618.42                             8081.09
# 298                             7618.42                             8081.09
# 299                             7618.42                             8081.09
# 300                             7618.42                             8081.09
# 301                             7618.42                             8081.09
# 302                             7618.42                             8081.09
# 303                             7618.42                             8081.09
# 304                             7618.42                             8081.09
# 305                             7645.18                             8081.09
# 306                             7645.18                             8081.09
# 307                             7645.18                             8081.09
# 308                             7645.18                             8081.09
# 309                             7645.18                             8111.70
# 310                             7645.18                             8111.70
# 311                             7645.18                             8111.70
# 312                             7645.18                             8111.70
# 313                             7645.18                             8111.70
# 314                             7645.18                             8111.70
# 315                             7645.18                             8111.70
# 316                             7645.18                             8111.70
# 317                             7645.18                             8111.70
# 318                             7645.18                             8111.70
# 319                             7645.18                             8111.70
# 320                             7645.18                             8111.70
# 321                             7645.18                             8111.70
# 322                             7645.18                             8111.70
# 323                             7645.18                             8111.70
# 324                             7645.18                             8111.70
# 325                             7645.18                             8111.70
# 326                             7645.18                             8111.70
# 327                             7645.18                             8111.70
# 328                             7645.18                             8111.70
# 329                             7657.89                             8111.70
# 330                             7657.89                             8111.70
# 331                             7657.89                             8111.70
# 332                             7657.89                             8111.70
# 333                             7657.89                             8111.70
# 334                             7657.89                             8111.70
# 335                             7657.89                             8111.70
# 336                             7657.89                             8111.70
# 337                             7657.89                             8111.70
# 338                             7657.89                             8131.21
# 339                             7657.89                             8131.21
# 340                             7657.89                             8131.21
# 341                             7657.89                             8131.21
# 342                             7657.89                             8131.21
# 343                             7657.89                             8131.21
# 344                             7657.89                             8131.21
# 345                             7657.89                             8131.21
# 346                             7657.89                             8131.21
# 347                             7657.89                             8131.21
# 348                             7657.89                             8131.21
# 349                             7657.89                             8131.21
# 350                             7657.89                             8131.21
# 351                             7657.89                             8131.21
# 352                             7670.82                             8131.21
# 353                             7670.82                             8131.21
# 354                             7670.82                             8131.21
# 355                             7670.82                             8131.21
# 356                             7670.82                             8131.21
# 357                             7670.82                             8131.21
# 358                             7670.82                             8131.21
# 359                             7670.82                             8131.21
# 360                             7670.82                             8131.21
# 361                             7670.82                             8131.21
# 362                             7670.82                             8131.21
# 363                             7670.82                             8131.21
# 364                             7670.82                             8131.21
# 365                             7670.82                             8131.21
# 366                             7670.82                             8131.21
# 367                             7670.82                             8131.21
# 368                             7670.82                             8131.21
# 369                             7670.82                             8131.21
# 370                             7670.82                             8151.22
# 371                             7670.82                             8151.22
# 372                             7670.82                             8151.22
# 373                             7670.82                             8151.22
# 374                             7670.82                             8151.22
# 375                             7670.82                             8151.22
# 376                             7670.82                             8151.22
# 377                             7670.82                             8151.22
# 378                             7670.82                             8151.22
# 379                             7670.82                             8151.22
# 380                             7670.82                             8151.22
# 381                             7687.04                             8151.22
# 382                             7687.04                             8151.22
# 383                             7687.04                             8151.22
# 384                             7687.04                             8151.22
# 385                             7687.04                             8151.22
# 386                             7687.04                             8151.22
# 387                             7687.04                             8151.22
# 388                             7687.04                             8151.22
# 389                             7687.04                             8151.22
# 390                             7687.04                             8151.22
# 391                             7687.04                             8151.22
# 392                             7687.04                             8151.22
# 393                             7687.04                             8151.22
# 394                             7687.04                             8151.22
# 395                             7687.04                             8151.22
# 396                             7687.04                             8151.22
# 397                             7687.04                             8151.22
# 398                             7687.04                             8151.22
# 399                             7687.04                             8171.26
# 400                             7687.04                             8171.26
# 401                             7687.04                             8171.26
# 402                             7687.04                             8171.26
# 403                             7687.04                             8171.26
# 404                             7687.04                             8171.26
# 405                             7687.04                             8171.26
# 406                             7687.04                             8171.26
# 407                             7687.04                             8171.26
# 408                             7687.04                             8171.26
# 409                             7687.04                             8171.26
# 410                             7687.04                             8171.26
# 411                             7687.04                             8171.26
# 412                             7687.04                             8171.26
# 413                             7687.04                             8171.26
# 414                             7687.04                             8171.26
# 415                             7687.04                             8171.26
# 416                             7687.04                             8171.26
# 417                             7687.04                             8171.26
# 418                             7687.04                             8171.26
# 419                             7687.04                             8171.26
# 420                             7687.04                             8171.26
# 421                             7687.04                             8171.26
# 422                             7687.04                             8171.26
# 423                             7687.04                             8171.26
# 424                             7687.04                             8171.26
# 425                             7605.62                             8068.55
# 426                             7605.62                             8068.55
# 427                             7605.62                             8068.55
# 428                             7605.62                             8068.55
# 429                             7605.62                             8068.55
# 430                             7605.62                             8068.55
# 431                             7605.62                             8068.55
# 432                             7605.62                             8068.55
# 433                             7605.62                             8068.55
# 434                             7605.62                             8068.55
# 435                             7605.62                             8068.55
# 436                             7605.62                             8068.55
# 437                             7605.62                             8068.55
# 438                             7605.62                             8068.55
# 439                             7605.62                             8068.55
# 440                             7605.62                             8068.55
# 441                             7605.62                             8068.55
# 442                             7605.62                             8068.55
# 443                             7605.62                                 NaN
# 444                             7605.62                                 NaN
# 445                             7605.62                                 NaN
# 446                             7605.62                                 NaN
# 447                             7605.62                                 NaN

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df = collect.add_metadata(df)
df.T
# Out:
# combine on index and column 'phase'
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1  \
# 0                                                                                7177.68
# 1                                                                                7177.68
# 2                                                                                7177.68
# 3                                                                                7177.68
# 4                                                                                7177.68
# 5                                                                                7177.68
# 6                                                                                7177.68
# 7                                                                                7177.68
# 8                                                                                7378.69
# 9                                                                                7378.69
# 10                                                                               7378.69
# 11                                                                               7378.69
# 12                                                                               7378.69
# 13                                                                               7378.69
# 14                                                                               7378.69
# 15                                                                               7378.69
# 16                                                                               7378.69
# 17                                                                               7378.69
# 18                                                                               7378.69
# 19                                                                               7378.69
# 20                                                                               7378.69
# 21                                                                               7378.69
# 22                                                                               7378.69
# 23                                                                               7378.69
# 24                                                                               7378.69
# 25                                                                               7378.69
# 26                                                                               7378.69
# 27                                                                               7378.69
# 28                                                                               7378.69
# 29                                                                               7378.69
# 30                                                                               7378.69
# 31                                                                               7378.69
# 32                                                                               7378.69
# 33                                                                               7378.69
# 34                                                                               7378.69
# 35                                                                               7378.69
# 36                                                                               7378.69
# 37                                                                               7378.69
# 38                                                                               7378.69
# 39                                                                               7625.29
# 40                                                                               7625.29
# 41                                                                               7625.29
# 42                                                                               7625.29
# 43                                                                               7625.29
# 44                                                                               7625.29
# 45                                                                               7625.29
# 46                                                                               7625.29
# 47                                                                               7625.29
# 48                                                                               7625.29
# 49                                                                               7625.29
# 50                                                                               7625.29
# 51                                                                               7625.29
# 52                                                                               7625.29
# 53                                                                               7625.29
# 54                                                                               7625.29
# 55                                                                               7625.29
# 56                                                                               7625.29
# 57                                                                               7625.29
# 58                                                                               7662.25
# 59                                                                               7662.25
# 60                                                                               7662.25
# 61                                                                               7662.25
# 62                                                                               7662.25
# 63                                                                               7662.25
# 64                                                                               7662.25
# 65                                                                               7662.25
# 66                                                                               7662.25
# 67                                                                               7662.25
# 68                                                                               7662.25
# 69                                                                               7662.25
# 70                                                                               7662.25
# 71                                                                               7662.25
# 72                                                                               7662.25
# 73                                                                               7662.25
# 74                                                                               7662.25
# 75                                                                               7662.25
# 76                                                                               7662.25
# 77                                                                               7662.25
# 78                                                                               7662.25
# 79                                                                               7662.25
# 80                                                                               7662.25
# 81                                                                               7662.25
# 82                                                                               7662.25
# 83                                                                               7694.69
# 84                                                                               7694.69
# 85                                                                               7694.69
# 86                                                                               7694.69
# 87                                                                               7694.69
# 88                                                                               7694.69
# 89                                                                               7694.69
# 90                                                                               7694.69
# 91                                                                               7694.69
# 92                                                                               7694.69
# 93                                                                               7694.69
# 94                                                                               7694.69
# 95                                                                               7694.69
# 96                                                                               7694.69
# 97                                                                               7694.69
# 98                                                                               7694.69
# 99                                                                               7694.69
# 100                                                                              7694.69
# 101                                                                              7694.69
# 102                                                                              7694.69
# 103                                                                              7694.69
# 104                                                                              7694.69
# 105                                                                              7694.69
# 106                                                                              7694.69
# 107                                                                              7694.69
# 108                                                                              7694.69
# 109                                                                              7694.69
# 110                                                                              7694.69
# 111                                                                              7694.69
# 112                                                                              7694.69
# 113                                                                              7694.69
# 114                                                                              7694.69
# 115                                                                              7694.69
# 116                                                                              7694.69
# 117                                                                              7694.69
# 118                                                                              7694.69
# 119                                                                              7694.69
# 120                                                                              7694.69
# 121                                                                              7694.69
# 122                                                                              7694.69
# 123                                                                              7694.69
# 124                                                                              7694.69
# 125                                                                              7694.69
# 126                                                                              7694.69
# 127                                                                              7738.99
# 128                                                                              7738.99
# 129                                                                              7738.99
# 130                                                                              7738.99
# 131                                                                              7738.99
# 132                                                                              7738.99
# 133                                                                              7738.99
# 134                                                                              7738.99
# 135                                                                              7738.99
# 136                                                                              7738.99
# 137                                                                              7738.99
# 138                                                                              7738.99
# 139                                                                              7738.99
# 140                                                                              7738.99
# 141                                                                              7738.99
# 142                                                                              7738.99
# 143                                                                              7738.99
# 144                                                                              7738.99
# 145                                                                              7738.99
# 146                                                                              7738.99
# 147                                                                              7738.99
# 148                                                                              7738.99
# 149                                                                              7738.99
# 150                                                                              7738.99
# 151                                                                              7738.99
# 152                                                                              7759.76
# 153                                                                              7759.76
# 154                                                                              7759.76
# 155                                                                              7759.76
# 156                                                                              7759.76
# 157                                                                              7759.76
# 158                                                                              7759.76
# 159                                                                              7759.76
# 160                                                                              7759.76
# 161                                                                              7759.76
# 162                                                                              7759.76
# 163                                                                              7759.76
# 164                                                                              7759.76
# 165                                                                              7759.76
# 166                                                                              7759.76
# 167                                                                              7759.76
# 168                                                                              7759.76
# 169                                                                              7759.76
# 170                                                                              7759.76
# 171                                                                              7759.76
# 172                                                                              7759.76
# 173                                                                              7759.76
# 174                                                                              7759.76
# 175                                                                              7759.76
# 176                                                                              7759.76
# 177                                                                              7759.76
# 178                                                                              7759.76
# 179                                                                              7782.45
# 180                                                                              7782.45
# 181                                                                              7782.45
# 182                                                                              7782.45
# 183                                                                              7782.45
# 184                                                                              7782.45
# 185                                                                              7782.45
# 186                                                                              7782.45
# 187                                                                              7782.45
# 188                                                                              7782.45
# 189                                                                              7782.45
# 190                                                                              7782.45
# 191                                                                              7782.45
# 192                                                                              7782.45
# 193                                                                              7782.45
# 194                                                                              7782.45
# 195                                                                              7782.45
# 196                                                                              7782.45
# 197                                                                              7782.45
# 198                                                                              7782.45
# 199                                                                              7782.45
# 200                                                                              7782.45
# 201                                                                              7782.45
# 202                                                                              7782.45
# 203                                                                              7782.45
# 204                                                                              7782.45
# 205                                                                              7806.09
# 206                                                                              7806.09
# 207                                                                              7806.09
# 208                                                                              7806.09
# 209                                                                              7806.09
# 210                                                                              7806.09
# 211                                                                              7806.09
# 212                                                                              7806.09
# 213                                                                              7806.09
# 214                                                                              7806.09
# 215                                                                              7806.09
# 216                                                                              7806.09
# 217                                                                              7806.09
# 218                                                                              7806.09
# 219                                                                              7806.09
# 220                                                                              7806.09
# 221                                                                              7806.09
# 222                                                                              7806.09
# 223                                                                              7806.09
# 224                                                                              7806.09
# 225                                                                              7806.09
# 226                                                                              7806.09
# 227                                                                              7806.09
# 228                                                                              7806.09
# 229                                                                              7806.09
# 230                                                                              7806.09
# 231                                                                              7806.09
# 232                                                                              7806.09
# 233                                                                              7806.09
# 234                                                                              7806.09
# 235                                                                              7806.09
# 236                                                                              7806.09
# 237                                                                              7806.09
# 238                                                                              7806.09
# 239                                                                              7806.09
# 240                                                                              7806.09
# 241                                                                              7806.09
# 242                                                                              7806.09
# 243                                                                              7806.09
# 244                                                                              7806.09
# 245                                                                              7806.09
# 246                                                                              7806.09
# 247                                                                              7806.09
# 248                                                                              7806.09
# 249                                                                              7843.71
# 250                                                                              7843.71
# 251                                                                              7843.71
# 252                                                                              7843.71
# 253                                                                              7843.71
# 254                                                                              7843.71
# 255                                                                              7843.71
# 256                                                                              7843.71
# 257                                                                              7843.71
# 258                                                                              7843.71
# 259                                                                              7843.71
# 260                                                                              7843.71
# 261                                                                              7843.71
# 262                                                                              7843.71
# 263                                                                              7843.71
# 264                                                                              7843.71
# 265                                                                              7843.71
# 266                                                                              7843.71
# 267                                                                              7843.71
# 268                                                                              7861.88
# 269                                                                              7861.88
# 270                                                                              7861.88
# 271                                                                              7861.88
# 272                                                                              7861.88
# 273                                                                              7861.88
# 274                                                                              7861.88
# 275                                                                              7861.88
# 276                                                                              7861.88
# 277                                                                              7861.88
# 278                                                                              7861.88
# 279                                                                              7861.88
# 280                                                                              7861.88
# 281                                                                              7861.88
# 282                                                                              7861.88
# 283                                                                              7861.88
# 284                                                                              7861.88
# 285                                                                              7861.88
# 286                                                                              7861.88
# 287                                                                              7861.88
# 288                                                                              7861.88
# 289                                                                              7861.88
# 290                                                                              7861.88
# 291                                                                              7861.88
# 292                                                                              7861.88
# 293                                                                              7861.88
# 294                                                                              7861.88
# 295                                                                              7861.88
# 296                                                                              7861.88
# 297                                                                              7861.88
# 298                                                                              7861.88
# 299                                                                              7861.88
# 300                                                                              7861.88
# 301                                                                              7861.88
# 302                                                                              7861.88
# 303                                                                              7861.88
# 304                                                                              7861.88
# 305                                                                              7861.88
# 306                                                                              7861.88
# 307                                                                              7892.12
# 308                                                                              7892.12
# 309                                                                              7892.12
# 310                                                                              7892.12
# 311                                                                              7892.12
# 312                                                                              7892.12
# 313                                                                              7892.12
# 314                                                                              7892.12
# 315                                                                              7892.12
# 316                                                                              7892.12
# 317                                                                              7892.12
# 318                                                                              7892.12
# 319                                                                              7892.12
# 320                                                                              7892.12
# 321                                                                              7892.12
# 322                                                                              7892.12
# 323                                                                              7892.12
# 324                                                                              7892.12
# 325                                                                              7892.12
# 326                                                                              7892.12
# 327                                                                              7892.12
# 328                                                                              7892.12
# 329                                                                              7892.12
# 330                                                                              7892.12
# 331                                                                              7892.12
# 332                                                                              7892.12
# 333                                                                              7892.12
# 334                                                                              7892.12
# 335                                                                              7892.12
# 336                                                                              7892.12
# 337                                                                              7892.12
# 338                                                                              7892.12
# 339                                                                              7916.83
# 340                                                                              7916.83
# 341                                                                              7916.83
# 342                                                                              7916.83
# 343                                                                              7916.83
# 344                                                                              7916.83
# 345                                                                              7916.83
# 346                                                                              7916.83
# 347                                                                              7916.83
# 348                                                                              7916.83
# 349                                                                              7916.83
# 350                                                                              7916.83
# 351                                                                              7916.83
# 352                                                                              7916.83
# 353                                                                              7916.83
# 354                                                                              7916.83
# 355                                                                              7916.83
# 356                                                                              7916.83
# 357                                                                              7916.83
# 358                                                                              7916.83
# 359                                                                              7916.83
# 360                                                                              7916.83
# 361                                                                              7916.83
# 362                                                                              7916.83
# 363                                                                              7916.83
# 364                                                                              7916.83
# 365                                                                              7916.83
# 366                                                                              7916.83
# 367                                                                              7916.83
# 368                                                                              7941.53
# 369                                                                              7941.53
# 370                                                                              7941.53
# 371                                                                              7941.53
# 372                                                                              7941.53
# 373                                                                              7941.53
# 374                                                                              7941.53
# 375                                                                              7941.53
# 376                                                                              7941.53
# 377                                                                              7941.53
# 378                                                                              7941.53
# 379                                                                              7941.53
# 380                                                                              7941.53
# 381                                                                              7941.53
# 382                                                                              7941.53
# 383                                                                              7941.53
# 384                                                                              7941.53
# 385                                                                              7941.53
# 386                                                                              7941.53
# 387                                                                              7957.46
# 388                                                                              7957.46
# 389                                                                              7957.46
# 390                                                                              7957.46
# 391                                                                              7957.46
# 392                                                                              7957.46
# 393                                                                              7957.46
# 394                                                                              7957.46
# 395                                                                              7957.46
# 396                                                                              7957.46
# 397                                                                              7957.46
# 398                                                                              7957.46
# 399                                                                              7957.46
# 400                                                                              7957.46
# 401                                                                              7957.46
# 402                                                                              7957.46
# 403                                                                              7957.46
# 404                                                                              7957.46
# 405                                                                              7957.46
# 406                                                                              7957.46
# 407                                                                              7957.46
# 408                                                                              7957.46
# 409                                                                              7957.46
# 410                                                                              7957.46
# 411                                                                              7957.46
# 412                                                                              7957.46
# 413                                                                              7957.46
# 414                                                                              7957.46
# 415                                                                              7957.46
# 416                                                                              7957.46
# 417                                                                              7957.46
# 418                                                                              7957.46
# 419                                                                              7983.82
# 420                                                                              7983.82
# 421                                                                              7983.82
# 422                                                                              7983.82
# 423                                                                              7983.82
# 424                                                                              7983.82
# 425                                                                              7983.82
# 426                                                                              7983.82
# 427                                                                              7983.82
# 428                                                                              7983.82
# 429                                                                              7983.82
# 430                                                                              7983.82
# 431                                                                              7983.82
# 432                                                                              7983.82
# 433                                                                              7983.82
# 434                                                                              7983.82
# 435                                                                              7983.82
# 436                                                                              7983.82
# 437                                                                              7983.82
# 438                                                                              7983.82
# 439                                                                              7983.82
# 440                                                                              7983.82
# 441                                                                              7983.82
# 442                                                                              7983.82
# 443                                                                              7983.82
# 444                                                                              7983.82
# 445                                                                                  NaN
# 446                                                                                  NaN
# 447                                                                                  NaN
# code                                                                          1777039267
# configuration                                                        PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# ...
# 353                                                                              8131.21
# 354                                                                              8131.21
# 355                                                                              8131.21
# 356                                                                              8131.21
# 357                                                                              8131.21
# 358                                                                              8131.21
# 359                                                                              8131.21
# 360                                                                              8131.21
# 361                                                                              8131.21
# 362                                                                              8131.21
# 363                                                                              8131.21
# 364                                                                              8131.21
# 365                                                                              8131.21
# 366                                                                              8131.21
# 367                                                                              8131.21
# 368                                                                              8131.21
# 369                                                                              8131.21
# 370                                                                              8151.22
# 371                                                                              8151.22
# 372                                                                              8151.22
# 373                                                                              8151.22
# 374                                                                              8151.22
# 375                                                                              8151.22
# 376                                                                              8151.22
# 377                                                                              8151.22
# 378                                                                              8151.22
# 379                                                                              8151.22
# 380                                                                              8151.22
# 381                                                                              8151.22
# 382                                                                              8151.22
# 383                                                                              8151.22
# 384                                                                              8151.22
# 385                                                                              8151.22
# 386                                                                              8151.22
# 387                                                                              8151.22
# 388                                                                              8151.22
# 389                                                                              8151.22
# 390                                                                              8151.22
# 391                                                                              8151.22
# 392                                                                              8151.22
# 393                                                                              8151.22
# 394                                                                              8151.22
# 395                                                                              8151.22
# 396                                                                              8151.22
# 397                                                                              8151.22
# 398                                                                              8151.22
# 399                                                                              8171.26
# 400                                                                              8171.26
# 401                                                                              8171.26
# 402                                                                              8171.26
# 403                                                                              8171.26
# 404                                                                              8171.26
# 405                                                                              8171.26
# 406                                                                              8171.26
# 407                                                                              8171.26
# 408                                                                              8171.26
# 409                                                                              8171.26
# 410                                                                              8171.26
# 411                                                                              8171.26
# 412                                                                              8171.26
# 413                                                                              8171.26
# 414                                                                              8171.26
# 415                                                                              8171.26
# 416                                                                              8171.26
# 417                                                                              8171.26
# 418                                                                              8171.26
# 419                                                                              8171.26
# 420                                                                              8171.26
# 421                                                                              8171.26
# 422                                                                              8171.26
# 423                                                                              8171.26
# 424                                                                              8171.26
# 425                                                                              8068.55
# 426                                                                              8068.55
# 427                                                                              8068.55
# 428                                                                              8068.55
# 429                                                                              8068.55
# 430                                                                              8068.55
# 431                                                                              8068.55
# 432                                                                              8068.55
# 433                                                                              8068.55
# 434                                                                              8068.55
# 435                                                                              8068.55
# 436                                                                              8068.55
# 437                                                                              8068.55
# 438                                                                              8068.55
# 439                                                                              8068.55
# 440                                                                              8068.55
# 441                                                                              8068.55
# 442                                                                              8068.55
# 443                                                                                  NaN
# 444                                                                                  NaN
# 445                                                                                  NaN
# 446                                                                                  NaN
# 447                                                                                  NaN
# code                                                                          1777039267
# configuration                                                        PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].head().T
# Out:
# phase           1777039267-PostgreSQL-BHT-16-1-1-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-1-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False

# %% [markdown]
# # Time Series of a Single Metric for All Experiments
#
# This is particularly important if you require a customized aggregation or wish to monitor a component over time.
# Data is stacked here (long format).

# %%
metric = 'total_cpu_memory'
code = codes[0]
df = collect.get_monitoring_timeseries_all(metric=metric)
df.head()
# Out:
#    timestamp        code                               phase experiment_run  \
# 0          0  1777039267  1777039267-PostgreSQL-BHT-16-1-1-1              1
# 1          0  1777039267  1777039267-PostgreSQL-BHT-16-1-1-2              1
# 2          0  1777039267  1777039267-PostgreSQL-BHT-16-1-2-1              2
# 3          0  1777039267  1777039267-PostgreSQL-BHT-16-1-2-2              2
# 4          0  1777041908  1777041908-PostgreSQL-BHT-16-1-1-1              1
#
#    client type_tenants vol_tenants  num_tenants            metric component  \
# 0       1         None       False            0  total_cpu_memory    stream
# 1       2         None       False            0  total_cpu_memory    stream
# 2       1         None       False            0  total_cpu_memory    stream
# 3       2         None       False            0  total_cpu_memory    stream
# 4       1         None       False            0  total_cpu_memory    stream
#
#      value
# 0  7177.68
# 1 15601.66
# 2  7177.31
# 3 15082.88
# 4  7176.84

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['timestamp', 'phase', 'value']].head(8)
# Out:
#    timestamp                               phase    value
# 0          0  1777039267-PostgreSQL-BHT-16-1-1-1  7177.68
# 1          0  1777039267-PostgreSQL-BHT-16-1-1-2 15601.66
# 2          0  1777039267-PostgreSQL-BHT-16-1-2-1  7177.31
# 3          0  1777039267-PostgreSQL-BHT-16-1-2-2 15082.88
# 4          0  1777041908-PostgreSQL-BHT-16-1-1-1  7176.84
# 5          0  1777041908-PostgreSQL-BHT-16-1-1-2 15808.93
# 6          0  1777041908-PostgreSQL-BHT-16-1-2-1  7176.31
# 7          0  1777041908-PostgreSQL-BHT-16-1-2-2 15641.20

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df=collect.add_metadata(df)
df = df.sort_values(['timestamp', 'phase'])
df[['timestamp', 'phase', 'value']].head(8)
# Out:
# combine on columns phase
#                                     timestamp  \
# 1777039267-PostgreSQL-BHT-16-1-1-1          0
# 1777039267-PostgreSQL-BHT-16-1-1-2          0
# 1777039267-PostgreSQL-BHT-16-1-2-1          0
# 1777039267-PostgreSQL-BHT-16-1-2-2          0
# 1777041908-PostgreSQL-BHT-16-1-1-1          0
# 1777041908-PostgreSQL-BHT-16-1-1-2          0
# 1777041908-PostgreSQL-BHT-16-1-2-1          0
# 1777041908-PostgreSQL-BHT-16-1-2-2          0
#
#                                                                  phase  \
# 1777039267-PostgreSQL-BHT-16-1-1-1  1777039267-PostgreSQL-BHT-16-1-1-1
# 1777039267-PostgreSQL-BHT-16-1-1-2  1777039267-PostgreSQL-BHT-16-1-1-2
# 1777039267-PostgreSQL-BHT-16-1-2-1  1777039267-PostgreSQL-BHT-16-1-2-1
# 1777039267-PostgreSQL-BHT-16-1-2-2  1777039267-PostgreSQL-BHT-16-1-2-2
# 1777041908-PostgreSQL-BHT-16-1-1-1  1777041908-PostgreSQL-BHT-16-1-1-1
# 1777041908-PostgreSQL-BHT-16-1-1-2  1777041908-PostgreSQL-BHT-16-1-1-2
# 1777041908-PostgreSQL-BHT-16-1-2-1  1777041908-PostgreSQL-BHT-16-1-2-1
# 1777041908-PostgreSQL-BHT-16-1-2-2  1777041908-PostgreSQL-BHT-16-1-2-2
#
#                                       value
# 1777039267-PostgreSQL-BHT-16-1-1-1  7177.68
# 1777039267-PostgreSQL-BHT-16-1-1-2 15601.66
# 1777039267-PostgreSQL-BHT-16-1-2-1  7177.31
# 1777039267-PostgreSQL-BHT-16-1-2-2 15082.88
# 1777041908-PostgreSQL-BHT-16-1-1-1  7176.84
# 1777041908-PostgreSQL-BHT-16-1-1-2 15808.93
# 1777041908-PostgreSQL-BHT-16-1-2-1  7176.31
# 1777041908-PostgreSQL-BHT-16-1-2-2 15641.20

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].head().T
# Out:
#                 1777039267-PostgreSQL-BHT-16-1-1-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
#                 1777039267-PostgreSQL-BHT-16-1-1-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
#                 1777039267-PostgreSQL-BHT-16-1-2-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
#                 1777039267-PostgreSQL-BHT-16-1-2-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# code                                    1777039267
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
#                 1777041908-PostgreSQL-BHT-16-1-1-1
# phase           1777041908-PostgreSQL-BHT-16-1-1-1
# code                                    1777041908
# configuration                  PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False

# %% [markdown]
# ## Custom Aggregation and Scale
#
# We here aggregate CPU utilization by max per phase.

# %%
metric = 'total_cpu_util'

df_performance_series = collect.get_monitoring_timeseries_all(metric)

df_agg = (
    df_performance_series.groupby(["code", "experiment_run", "client", "type_tenants", "num_tenants"])["value"]
      .max()
      .reset_index()
)
df_agg.index.name = 'Max ' + collect.df_metrics.loc[metric]['title']
df_agg
# Out:
#                            code experiment_run  client type_tenants  \
# Max CPU Utilization
# 0                    1777039267              1       1         None
# 1                    1777039267              1       2         None
# 2                    1777039267              2       1         None
# 3                    1777039267              2       2         None
# 4                    1777041908              1       1         None
# 5                    1777041908              1       2         None
# 6                    1777041908              2       1         None
# 7                    1777041908              2       2         None
#
#                      num_tenants  value
# Max CPU Utilization
# 0                              0   1.03
# 1                              0   2.01
# 2                              0   0.63
# 3                              0   1.81
# 4                              0   1.34
# 5                              0   4.95
# 6                              0   1.52
# 7                              0  23.74

# %% [markdown]
# # Performance Results per Connection

# %%
df_performance = collect.get_performance_per_connection()

df_performance_first = df_performance[df_performance['client']==1]
df_performance_second = df_performance[df_performance['client']==2]

df_performance.T
# Out:
# connection      1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-1-1-1
# phase             1777039267-PostgreSQL-BHT-16-1-1-1
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             1
# pod                            gtg6k.dbmsbenchmarker
# pod_count                                          1
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     1
# vusers                                            16
# efficiency                                         0
# NOPM                                           19631
# TPM                                            45290
# dbms                                      PostgreSQL
# CALLS                                      278150.00
# MIN [ms]                                        5.92
# AVG [ms]                                       19.17
# MAX [ms]                                      977.06
# TOTAL [ms]                                5331340.94
# P99 [ms]                                       50.37
# P95 [ms]                                       33.73
# P50 [ms]                                       16.86
# SD                                          14832.89
# RATIO                                          39.81
#
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase             1777039267-PostgreSQL-BHT-16-1-1-2
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# pod                            fp6kd.dbmsbenchmarker
# pod_count                                          2
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                             8
# efficiency                                         0
# NOPM                                           21096
# TPM                                            48611
# dbms                                      PostgreSQL
# CALLS                                      160976.00
# MIN [ms]                                        8.13
# AVG [ms]                                       18.68
# MAX [ms]                                      368.17
# TOTAL [ms]                                3007841.52
# P99 [ms]                                       50.23
# P95 [ms]                                       33.51
# P50 [ms]                                       16.84
# SD                                          13372.61
# RATIO                                          44.78
#
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase             1777039267-PostgreSQL-BHT-16-1-1-2
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# pod                            kkbrq.dbmsbenchmarker
# pod_count                                          2
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                             8
# efficiency                                         0
# NOPM                                           21098
# TPM                                            48637
# dbms                                      PostgreSQL
# CALLS                                      138626.00
# MIN [ms]                                        5.78
# AVG [ms]                                       19.47
# MAX [ms]                                      368.15
# TOTAL [ms]                                2699234.63
# P99 [ms]                                       51.44
# P95 [ms]                                       33.77
# P50 [ms]                                       16.85
# SD                                          14240.34
# RATIO                                          40.21
#
# connection      1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-2-1-1
# phase             1777039267-PostgreSQL-BHT-16-1-2-1
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             1
# pod                            8pmhw.dbmsbenchmarker
# pod_count                                          1
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     1
# vusers                                            16
# efficiency                                         0
# NOPM                                           12003
# TPM                                            27756
# dbms                                      PostgreSQL
# CALLS                                      169786.00
# MIN [ms]                                        6.11
# AVG [ms]                                       20.79
# MAX [ms]                                      375.76
# TOTAL [ms]                                3530130.88
# P99 [ms]                                       66.87
# P95 [ms]                                       34.67
# P50 [ms]                                       16.77
# SD                                          15048.81
# RATIO                                          26.28
#
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-1
# phase             1777039267-PostgreSQL-BHT-16-1-2-2
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# pod                            5j5hd.dbmsbenchmarker
# pod_count                                          2
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                             8
# efficiency                                         0
# NOPM                                           16733
# TPM                                            38837
# dbms                                      PostgreSQL
# CALLS                                      101816.00
# MIN [ms]                                        3.50
# AVG [ms]                                       20.43
# MAX [ms]                                     1054.16
# TOTAL [ms]                                2080109.67
# P99 [ms]                                       66.75
# P95 [ms]                                       33.86
# P50 [ms]                                       16.80
# SD                                          16191.41
# RATIO                                          30.97
#
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# connection      1777039267-PostgreSQL-BHT-16-1-2-2-1
# phase             1777039267-PostgreSQL-BHT-16-1-2-2
# configuration         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# pod                            4px6h.dbmsbenchmarker
# pod_count                                          2
# code                                      1777039267
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                             8
# efficiency                                         0
# NOPM                                           16734
# TPM                                            38806
# dbms                                      PostgreSQL
# CALLS                                      136910.00
# MIN [ms]                                        5.62
# AVG [ms]                                       19.38
# MAX [ms]                                     1022.09
# TOTAL [ms]                                2653536.11
# P99 [ms]                                       55.81
# P95 [ms]                                       33.71
# P50 [ms]                                       16.79
# SD                                          15752.78
# RATIO                                          39.63
#
# connection      1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# connection      1777041908-PostgreSQL-BHT-16-1-1-1-1
# phase             1777041908-PostgreSQL-BHT-16-1-1-1
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             1
# pod                            5xlmf.dbmsbenchmarker
# pod_count                                          1
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     1
# vusers                                            32
# efficiency                                         0
# NOPM                                           23827
# TPM                                            54912
# dbms                                      PostgreSQL
# CALLS                                      336188.00
# MIN [ms]                                        6.49
# AVG [ms]                                       20.09
# MAX [ms]                                      926.28
# TOTAL [ms]                                6752879.10
# P99 [ms]                                       52.03
# P95 [ms]                                       34.01
# P50 [ms]                                       16.93
# SD                                          17779.18
# RATIO                                          25.15
#
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-1  \
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-1
# phase             1777041908-PostgreSQL-BHT-16-1-1-2
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# pod                            m68zn.dbmsbenchmarker
# pod_count                                          2
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                            16
# efficiency                                         0
# NOPM                                           15516
# TPM                                            35819
# dbms                                      PostgreSQL
# CALLS                                      103782.00
# MIN [ms]                                        6.04
# AVG [ms]                                       20.93
# MAX [ms]                                      476.46
# TOTAL [ms]                                2172074.74
# P99 [ms]                                       66.89
# P95 [ms]                                       34.65
# P50 [ms]                                       16.79
# SD                                          15413.85
# RATIO                                          16.30
#
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-1  \
# connection      1777041908-PostgreSQL-BHT-16-1-1-2-1
# phase             1777041908-PostgreSQL-BHT-16-1-1-2
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     1
# client                                             2
# pod                            n4nd8.dbmsbenchmarker
# pod_count                                          2
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                            16
# efficiency                                         0
# NOPM                                           15515
# TPM                                            35828
# dbms                                      PostgreSQL
# CALLS                                      113958.00
# MIN [ms]                                        7.36
# AVG [ms]                                       20.21
# MAX [ms]                                      476.50
# TOTAL [ms]                                2303580.65
# P99 [ms]                                       66.52
# P95 [ms]                                       33.91
# P50 [ms]                                       16.78
# SD                                          14991.55
# RATIO                                          17.22
#
# connection      1777041908-PostgreSQL-BHT-16-1-2-1-1  \
# connection      1777041908-PostgreSQL-BHT-16-1-2-1-1
# phase             1777041908-PostgreSQL-BHT-16-1-2-1
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             1
# pod                            5jd9z.dbmsbenchmarker
# pod_count                                          1
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     1
# vusers                                            32
# efficiency                                         0
# NOPM                                           20556
# TPM                                            47326
# dbms                                      PostgreSQL
# CALLS                                      292300.00
# MIN [ms]                                        6.14
# AVG [ms]                                       20.44
# MAX [ms]                                      590.02
# TOTAL [ms]                                5975128.88
# P99 [ms]                                       67.00
# P95 [ms]                                       33.96
# P50 [ms]                                       16.87
# SD                                          16595.88
# RATIO                                          22.51
#
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-1
# phase             1777041908-PostgreSQL-BHT-16-1-2-2
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# pod                            77kh4.dbmsbenchmarker
# pod_count                                          2
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                            16
# efficiency                                         0
# NOPM                                           17175
# TPM                                            39768
# dbms                                      PostgreSQL
# CALLS                                      111446.00
# MIN [ms]                                        7.16
# AVG [ms]                                       20.06
# MAX [ms]                                      417.19
# TOTAL [ms]                                2235465.37
# P99 [ms]                                       67.18
# P95 [ms]                                       33.90
# P50 [ms]                                       16.89
# SD                                          17915.49
# RATIO                                          16.71
#
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-1
# connection      1777041908-PostgreSQL-BHT-16-1-2-2-1
# phase             1777041908-PostgreSQL-BHT-16-1-2-2
# configuration         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                     2
# client                                             2
# pod                            5wtjc.dbmsbenchmarker
# pod_count                                          2
# code                                      1777041908
# iterations                                  10000000
# duration                                           5
# rampup                                             2
# sf                                                16
# run                                                0
# errors                                             0
# vusers_loading                                     2
# vusers                                            16
# efficiency                                         0
# NOPM                                           17172
# TPM                                            39774
# dbms                                      PostgreSQL
# CALLS                                      130982.00
# MIN [ms]                                        3.71
# AVG [ms]                                       19.55
# MAX [ms]                                      400.52
# TOTAL [ms]                                2560647.56
# P99 [ms]                                       60.77
# P95 [ms]                                       33.82
# P50 [ms]                                       16.89
# SD                                          16507.22
# RATIO                                          19.09

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df = collect.add_metadata(df_performance)
df.T
# Out:
# combine on index
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-1-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 1
# pod                                                                gtg6k.dbmsbenchmarker
# pod_count                                                                              1
# code                                                                          1777039267
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         1
# vusers                                                                                16
# efficiency                                                                             0
# NOPM                                                                               19631
# TPM                                                                                45290
# dbms                                                                          PostgreSQL
# CALLS                                                                          278150.00
# MIN [ms]                                                                            5.92
# AVG [ms]                                                                           19.17
# MAX [ms]                                                                          977.06
# TOTAL [ms]                                                                    5331340.94
# P99 [ms]                                                                           50.37
# P95 [ms]                                                                           33.73
# P50 [ms]                                                                           16.86
# SD                                                                              14832.89
# RATIO                                                                              39.81
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 2
# pod                                                                fp6kd.dbmsbenchmarker
# pod_count                                                                              2
# code                                                                          1777039267
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                 8
# efficiency                                                                             0
# NOPM                                                                               21096
# TPM                                                                                48611
# dbms                                                                          PostgreSQL
# CALLS                                                                          160976.00
# MIN [ms]                                                                            8.13
# AVG [ms]                                                                           18.68
# MAX [ms]                                                                          368.17
# TOTAL [ms]                                                                    3007841.52
# P99 [ms]                                                                           50.23
# P95 [ms]                                                                           33.51
# P50 [ms]                                                                           16.84
# SD                                                                              13372.61
# RATIO                                                                              44.78
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 2
# pod                                                                kkbrq.dbmsbenchmarker
# pod_count                                                                              2
# code                                                                          1777039267
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                 8
# efficiency                                                                             0
# NOPM                                                                               21098
# TPM                                                                                48637
# dbms                                                                          PostgreSQL
# CALLS                                                                          138626.00
# MIN [ms]                                                                            5.78
# AVG [ms]                                                                           19.47
# MAX [ms]                                                                          368.15
# TOTAL [ms]                                                                    2699234.63
# P99 [ms]                                                                           51.44
# P95 [ms]                                                                           33.77
# P50 [ms]                                                                           16.85
# SD                                                                              14240.34
# RATIO                                                                              40.21
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-1-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-1
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 1
# pod                                                                8pmhw.dbmsbenchmarker
# pod_count                                                                              1
# code                                                                          1777039267
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         1
# vusers                                                                                16
# efficiency                                                                             0
# NOPM                                                                               12003
# TPM                                                                                27756
# dbms                                                                          PostgreSQL
# CALLS                                                                          169786.00
# MIN [ms]                                                                            6.11
# AVG [ms]                                                                           20.79
# MAX [ms]                                                                          375.76
# TOTAL [ms]                                                                    3530130.88
# P99 [ms]                                                                           66.87
# P95 [ms]                                                                           34.67
# P50 [ms]                                                                           16.77
# SD                                                                              15048.81
# RATIO                                                                              26.28
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3299
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3299
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 2
# pod                                                                5j5hd.dbmsbenchmarker
# pod_count                                                                              2
# code                                                                          1777039267
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                 8
# efficiency                                                                             0
# NOPM                                                                               16733
# TPM                                                                                38837
# dbms                                                                          PostgreSQL
# CALLS                                                                          101816.00
# MIN [ms]                                                                            3.50
# AVG [ms]                                                                           20.43
# MAX [ms]                                                                         1054.16
# TOTAL [ms]                                                                    2080109.67
# P99 [ms]                                                                           66.75
# P95 [ms]                                                                           33.86
# P50 [ms]                                                                           16.80
# SD                                                                              16191.41
# RATIO                                                                              30.97
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# ...
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-1
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# configuration                                             1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 2
# pod                                                                5wtjc.dbmsbenchmarker
# pod_count                                                                              2
# code                                                                          1777041908
# iterations                                                                      10000000
# duration                                                                               5
# rampup                                                                                 2
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                16
# efficiency                                                                             0
# NOPM                                                                               17172
# TPM                                                                                39774
# dbms                                                                          PostgreSQL
# CALLS                                                                          130982.00
# MIN [ms]                                                                            3.71
# AVG [ms]                                                                           19.55
# MAX [ms]                                                                          400.52
# TOTAL [ms]                                                                    2560647.56
# P99 [ms]                                                                           60.77
# P95 [ms]                                                                           33.82
# P50 [ms]                                                                           16.89
# SD                                                                              16507.22
# RATIO                                                                              19.09
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0

# %% [markdown]
# # Performance Results per Phase

# %%
df_performance = collect.get_performance_aggregated_per_phase()

df_performance_first = df_performance[df_performance['client']==1]
df_performance_second = df_performance[df_performance['client']==2]

df_performance.dropna(inplace=True)

# %%
df_performance.T
# Out:
#                 1777039267-PostgreSQL-BHT-16-1-1-1  \
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   1
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# client                                           1
# code                                    1777039267
# pod_count                                        1
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   1
# vusers                                          16
# NOPM                                      19631.00
# TPM                                       45290.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    278150.00
# MIN [ms]                                      5.92
# AVG [ms]                                     19.17
# MAX [ms]                                    977.06
# TOTAL [ms]                              5331340.94
# P99 [ms]                                     50.37
# P95 [ms]                                     33.73
# P50 [ms]                                     16.86
#
#                 1777039267-PostgreSQL-BHT-16-1-1-2  \
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   1
# phase           1777039267-PostgreSQL-BHT-16-1-1-2
# client                                           2
# code                                    1777039267
# pod_count                                        2
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   2
# vusers                                          16
# NOPM                                      21097.00
# TPM                                       48624.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    160976.00
# MIN [ms]                                      8.13
# AVG [ms]                                     19.08
# MAX [ms]                                    368.17
# TOTAL [ms]                              3007841.52
# P99 [ms]                                     51.44
# P95 [ms]                                     33.77
# P50 [ms]                                     16.85
#
#                 1777039267-PostgreSQL-BHT-16-1-2-1  \
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   2
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# client                                           1
# code                                    1777039267
# pod_count                                        1
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   1
# vusers                                          16
# NOPM                                      12003.00
# TPM                                       27756.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    169786.00
# MIN [ms]                                      6.11
# AVG [ms]                                     20.79
# MAX [ms]                                    375.76
# TOTAL [ms]                              3530130.88
# P99 [ms]                                     66.87
# P95 [ms]                                     34.67
# P50 [ms]                                     16.77
#
#                 1777039267-PostgreSQL-BHT-16-1-2-2  \
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   2
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# client                                           2
# code                                    1777039267
# pod_count                                        2
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   2
# vusers                                          16
# NOPM                                      16733.50
# TPM                                       38821.50
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    136910.00
# MIN [ms]                                      5.62
# AVG [ms]                                     19.91
# MAX [ms]                                   1054.16
# TOTAL [ms]                              2653536.11
# P99 [ms]                                     66.75
# P95 [ms]                                     33.86
# P50 [ms]                                     16.80
#
#                 1777041908-PostgreSQL-BHT-16-1-1-1  \
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   1
# phase           1777041908-PostgreSQL-BHT-16-1-1-1
# client                                           1
# code                                    1777041908
# pod_count                                        1
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   1
# vusers                                          32
# NOPM                                      23827.00
# TPM                                       54912.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    336188.00
# MIN [ms]                                      6.49
# AVG [ms]                                     20.09
# MAX [ms]                                    926.28
# TOTAL [ms]                              6752879.10
# P99 [ms]                                     52.03
# P95 [ms]                                     34.01
# P50 [ms]                                     16.93
#
#                 1777041908-PostgreSQL-BHT-16-1-1-2  \
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   1
# phase           1777041908-PostgreSQL-BHT-16-1-1-2
# client                                           2
# code                                    1777041908
# pod_count                                        2
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   2
# vusers                                          32
# NOPM                                      15515.50
# TPM                                       35823.50
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    113958.00
# MIN [ms]                                      7.36
# AVG [ms]                                     20.57
# MAX [ms]                                    476.50
# TOTAL [ms]                              2303580.65
# P99 [ms]                                     66.89
# P95 [ms]                                     34.65
# P50 [ms]                                     16.79
#
#                 1777041908-PostgreSQL-BHT-16-1-2-1  \
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   2
# phase           1777041908-PostgreSQL-BHT-16-1-2-1
# client                                           1
# code                                    1777041908
# pod_count                                        1
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   1
# vusers                                          32
# NOPM                                      20556.00
# TPM                                       47326.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    292300.00
# MIN [ms]                                      6.14
# AVG [ms]                                     20.44
# MAX [ms]                                    590.02
# TOTAL [ms]                              5975128.88
# P99 [ms]                                     67.00
# P95 [ms]                                     33.96
# P50 [ms]                                     16.87
#
#                 1777041908-PostgreSQL-BHT-16-1-2-2
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   2
# phase           1777041908-PostgreSQL-BHT-16-1-2-2
# client                                           2
# code                                    1777041908
# pod_count                                        2
# iterations                                10000000
# duration                                         5
# sf                                              16
# run                                              0
# errors                                           0
# vusers_loading                                   2
# vusers                                          32
# NOPM                                      17173.50
# TPM                                       39771.00
# efficiency                                    0.00
# dbms                                    PostgreSQL
# CALLS                                    130982.00
# MIN [ms]                                      7.16
# AVG [ms]                                     19.80
# MAX [ms]                                    417.19
# TOTAL [ms]                              2560647.56
# P99 [ms]                                     67.18
# P95 [ms]                                     33.90
# P50 [ms]                                     16.89

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df = collect.add_metadata(df_performance)
df.T
# Out:
# combine on index and column 'phase'
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1  \
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 1
# code                                                                          1777039267
# pod_count                                                                              1
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         1
# vusers                                                                                16
# NOPM                                                                            19631.00
# TPM                                                                             45290.00
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          278150.00
# MIN [ms]                                                                            5.92
# AVG [ms]                                                                           19.17
# MAX [ms]                                                                          977.06
# TOTAL [ms]                                                                    5331340.94
# P99 [ms]                                                                           50.37
# P95 [ms]                                                                           33.73
# P50 [ms]                                                                           16.86
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1
#
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2  \
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 2
# code                                                                          1777039267
# pod_count                                                                              2
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                16
# NOPM                                                                            21097.00
# TPM                                                                             48624.00
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          160976.00
# MIN [ms]                                                                            8.13
# AVG [ms]                                                                           19.08
# MAX [ms]                                                                          368.17
# TOTAL [ms]                                                                    3007841.52
# P99 [ms]                                                                           51.44
# P95 [ms]                                                                           33.77
# P50 [ms]                                                                           16.85
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
#
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-1  \
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 1
# code                                                                          1777039267
# pod_count                                                                              1
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         1
# vusers                                                                                16
# NOPM                                                                            12003.00
# TPM                                                                             27756.00
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          169786.00
# MIN [ms]                                                                            6.11
# AVG [ms]                                                                           20.79
# MAX [ms]                                                                          375.76
# TOTAL [ms]                                                                    3530130.88
# P99 [ms]                                                                           66.87
# P95 [ms]                                                                           34.67
# P50 [ms]                                                                           16.77
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3299
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3299
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-1
#
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2  \
# configuration                                             1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 2
# code                                                                          1777039267
# pod_count                                                                              2
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                16
# NOPM                                                                            16733.50
# TPM                                                                             38821.50
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          136910.00
# MIN [ms]                                                                            5.62
# AVG [ms]                                                                           19.91
# MAX [ms]                                                                         1054.16
# TOTAL [ms]                                                                    2653536.11
# P99 [ms]                                                                           66.75
# P95 [ms]                                                                           33.86
# P50 [ms]                                                                           16.80
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
#
# phase                                                 1777041908-PostgreSQL-BHT-16-1-1-1  \
# configuration                                             1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 1
# code                                                                          1777041908
# pod_count                                                                              1
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         1
# vusers                                                                                32
# NOPM                                                                            23827.00
# TPM                                                                             54912.00
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          336188.00
# MIN [ms]                                                                            6.49
# AVG [ms]                                                                           20.09
# MAX [ms]                                                                          926.28
# TOTAL [ms]                                                                    6752879.10
# P99 [ms]                                                                           52.03
# P95 [ms]                                                                           34.01
# P50 [ms]                                                                           16.93
# dockerimage                                                                postgres:18.3
# time_load                                                                         183.00
# time_ingest                                                                        84.00
# time_check                                                                         98.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154359
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               32
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777041908-PostgreSQL-BHT-16-1-1-1
#
# phase                                                 1777041908-PostgreSQL-BHT-16-1-1-2  \
# configuration                                             1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                         1
# client                                                                                 2
# code                                                                          1777041908
# pod_count                                                                              2
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                32
# NOPM                                                                            15515.50
# TPM                                                                             35823.50
# efficiency                                                                          0.00
# ...
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3282
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154343
# host_datadisk                                                                       3282
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               32
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-1
#
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# configuration                                             1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                         2
# client                                                                                 2
# code                                                                          1777041908
# pod_count                                                                              2
# iterations                                                                      10000000
# duration                                                                               5
# sf                                                                                    16
# run                                                                                    0
# errors                                                                                 0
# vusers_loading                                                                         2
# vusers                                                                                32
# NOPM                                                                            17173.50
# TPM                                                                             39771.00
# efficiency                                                                          0.00
# dbms                                                                          PostgreSQL
# CALLS                                                                          130982.00
# MIN [ms]                                                                            7.16
# AVG [ms]                                                                           19.80
# MAX [ms]                                                                          417.19
# TOTAL [ms]                                                                    2560647.56
# P99 [ms]                                                                           67.18
# P95 [ms]                                                                           33.90
# P50 [ms]                                                                           16.89
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].T
# Out:
# phase           1777039267-PostgreSQL-BHT-16-1-1-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-1-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-2
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-2  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-2
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-1-1  \
# phase           1777041908-PostgreSQL-BHT-16-1-1-1
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-1-2  \
# phase           1777041908-PostgreSQL-BHT-16-1-1-2
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-2-1  \
# phase           1777041908-PostgreSQL-BHT-16-1-2-1
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-2-2
# phase           1777041908-PostgreSQL-BHT-16-1-2-2
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           2
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False

# %% [markdown]
# ## Get Non-Constant Attributes
#
# These attributes are (most probably) used to analyze performance.

# %%
collectors.get_non_constant(df).T
# Out:
# phase                                            1777039267-PostgreSQL-BHT-16-1-1-1  \
# configuration                                        1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                    1
# client                                                                            1
# code                                                                     1777039267
# pod_count                                                                         1
# vusers_loading                                                                    1
# vusers                                                                           16
# NOPM                                                                       19631.00
# TPM                                                                        45290.00
# CALLS                                                                     278150.00
# MIN [ms]                                                                       5.92
# AVG [ms]                                                                      19.17
# MAX [ms]                                                                     977.06
# TOTAL [ms]                                                               5331340.94
# P99 [ms]                                                                      50.37
# P95 [ms]                                                                      33.73
# P50 [ms]                                                                      16.86
# time_load                                                                    180.00
# time_ingest                                                                   84.00
# time_check                                                                    96.00
# pods                                                                              1
# datadisk                                                                       3298
# host_disk                                                                    154360
# host_datadisk                                                                  3298
# benchmarking_parameters_HAMMERDB_NUM_VU                                           1
# benchmarking_parameters_HAMMERDB_VUSERS                                          16
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777039267
# phase                                            1777039267-PostgreSQL-BHT-16-1-1-1
#
# phase                                            1777039267-PostgreSQL-BHT-16-1-1-2  \
# configuration                                        1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                    1
# client                                                                            2
# code                                                                     1777039267
# pod_count                                                                         2
# vusers_loading                                                                    2
# vusers                                                                           16
# NOPM                                                                       21097.00
# TPM                                                                        48624.00
# CALLS                                                                     160976.00
# MIN [ms]                                                                       8.13
# AVG [ms]                                                                      19.08
# MAX [ms]                                                                     368.17
# TOTAL [ms]                                                               3007841.52
# P99 [ms]                                                                      51.44
# P95 [ms]                                                                      33.77
# P50 [ms]                                                                      16.85
# time_load                                                                    180.00
# time_ingest                                                                   84.00
# time_check                                                                    96.00
# pods                                                                              2
# datadisk                                                                       4482
# host_disk                                                                    155544
# host_datadisk                                                                  4482
# benchmarking_parameters_HAMMERDB_NUM_VU                                           2
# benchmarking_parameters_HAMMERDB_VUSERS                                           8
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777039267
# phase                                            1777039267-PostgreSQL-BHT-16-1-1-2
#
# phase                                            1777039267-PostgreSQL-BHT-16-1-2-1  \
# configuration                                        1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                    2
# client                                                                            1
# code                                                                     1777039267
# pod_count                                                                         1
# vusers_loading                                                                    1
# vusers                                                                           16
# NOPM                                                                       12003.00
# TPM                                                                        27756.00
# CALLS                                                                     169786.00
# MIN [ms]                                                                       6.11
# AVG [ms]                                                                      20.79
# MAX [ms]                                                                     375.76
# TOTAL [ms]                                                               3530130.88
# P99 [ms]                                                                      66.87
# P95 [ms]                                                                      34.67
# P50 [ms]                                                                      16.77
# time_load                                                                    180.00
# time_ingest                                                                   84.00
# time_check                                                                    96.00
# pods                                                                              1
# datadisk                                                                       3299
# host_disk                                                                    154360
# host_datadisk                                                                  3299
# benchmarking_parameters_HAMMERDB_NUM_VU                                           1
# benchmarking_parameters_HAMMERDB_VUSERS                                          16
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777039267
# phase                                            1777039267-PostgreSQL-BHT-16-1-2-1
#
# phase                                            1777039267-PostgreSQL-BHT-16-1-2-2  \
# configuration                                        1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                    2
# client                                                                            2
# code                                                                     1777039267
# pod_count                                                                         2
# vusers_loading                                                                    2
# vusers                                                                           16
# NOPM                                                                       16733.50
# TPM                                                                        38821.50
# CALLS                                                                     136910.00
# MIN [ms]                                                                       5.62
# AVG [ms]                                                                      19.91
# MAX [ms]                                                                    1054.16
# TOTAL [ms]                                                               2653536.11
# P99 [ms]                                                                      66.75
# P95 [ms]                                                                      33.86
# P50 [ms]                                                                      16.80
# time_load                                                                    180.00
# time_ingest                                                                   84.00
# time_check                                                                    96.00
# pods                                                                              2
# datadisk                                                                       4031
# host_disk                                                                    155093
# host_datadisk                                                                  4031
# benchmarking_parameters_HAMMERDB_NUM_VU                                           2
# benchmarking_parameters_HAMMERDB_VUSERS                                           8
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777039267
# phase                                            1777039267-PostgreSQL-BHT-16-1-2-2
#
# phase                                            1777041908-PostgreSQL-BHT-16-1-1-1  \
# configuration                                        1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                    1
# client                                                                            1
# code                                                                     1777041908
# pod_count                                                                         1
# vusers_loading                                                                    1
# vusers                                                                           32
# NOPM                                                                       23827.00
# TPM                                                                        54912.00
# CALLS                                                                     336188.00
# MIN [ms]                                                                       6.49
# AVG [ms]                                                                      20.09
# MAX [ms]                                                                     926.28
# TOTAL [ms]                                                               6752879.10
# P99 [ms]                                                                      52.03
# P95 [ms]                                                                      34.01
# P50 [ms]                                                                      16.93
# time_load                                                                    183.00
# time_ingest                                                                   84.00
# time_check                                                                    98.00
# pods                                                                              1
# datadisk                                                                       3298
# host_disk                                                                    154359
# host_datadisk                                                                  3298
# benchmarking_parameters_HAMMERDB_NUM_VU                                           1
# benchmarking_parameters_HAMMERDB_VUSERS                                          32
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777041908
# phase                                            1777041908-PostgreSQL-BHT-16-1-1-1
#
# phase                                            1777041908-PostgreSQL-BHT-16-1-1-2  \
# configuration                                        1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                    1
# client                                                                            2
# code                                                                     1777041908
# pod_count                                                                         2
# vusers_loading                                                                    2
# vusers                                                                           32
# NOPM                                                                       15515.50
# TPM                                                                        35823.50
# CALLS                                                                     113958.00
# MIN [ms]                                                                       7.36
# AVG [ms]                                                                      20.57
# MAX [ms]                                                                     476.50
# TOTAL [ms]                                                               2303580.65
# P99 [ms]                                                                      66.89
# P95 [ms]                                                                      34.65
# P50 [ms]                                                                      16.79
# time_load                                                                    183.00
# time_ingest                                                                   84.00
# time_check                                                                    98.00
# pods                                                                              2
# datadisk                                                                       4846
# host_disk                                                                    155908
# host_datadisk                                                                  4846
# benchmarking_parameters_HAMMERDB_NUM_VU                                           2
# benchmarking_parameters_HAMMERDB_VUSERS                                          16
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777041908
# phase                                            1777041908-PostgreSQL-BHT-16-1-1-2
#
# phase                                            1777041908-PostgreSQL-BHT-16-1-2-1  \
# configuration                                        1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                    2
# client                                                                            1
# code                                                                     1777041908
# pod_count                                                                         1
# vusers_loading                                                                    1
# vusers                                                                           32
# NOPM                                                                       20556.00
# TPM                                                                        47326.00
# CALLS                                                                     292300.00
# MIN [ms]                                                                       6.14
# AVG [ms]                                                                      20.44
# MAX [ms]                                                                     590.02
# TOTAL [ms]                                                               5975128.88
# P99 [ms]                                                                      67.00
# P95 [ms]                                                                      33.96
# P50 [ms]                                                                      16.87
# time_load                                                                    222.00
# time_ingest                                                                   94.00
# time_check                                                                   128.00
# pods                                                                              1
# datadisk                                                                       3282
# host_disk                                                                    154343
# host_datadisk                                                                  3282
# benchmarking_parameters_HAMMERDB_NUM_VU                                           1
# benchmarking_parameters_HAMMERDB_VUSERS                                          32
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777041908
# phase                                            1777041908-PostgreSQL-BHT-16-1-2-1
#
# phase                                            1777041908-PostgreSQL-BHT-16-1-2-2
# configuration                                        1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                    2
# client                                                                            2
# code                                                                     1777041908
# pod_count                                                                         2
# vusers_loading                                                                    2
# vusers                                                                           32
# NOPM                                                                       17173.50
# TPM                                                                        39771.00
# CALLS                                                                     130982.00
# MIN [ms]                                                                       7.16
# AVG [ms]                                                                      19.80
# MAX [ms]                                                                     417.19
# TOTAL [ms]                                                               2560647.56
# P99 [ms]                                                                      67.18
# P95 [ms]                                                                      33.90
# P50 [ms]                                                                      16.89
# time_load                                                                    222.00
# time_ingest                                                                   94.00
# time_check                                                                   128.00
# pods                                                                              2
# datadisk                                                                       4642
# host_disk                                                                    155704
# host_datadisk                                                                  4642
# benchmarking_parameters_HAMMERDB_NUM_VU                                           2
# benchmarking_parameters_HAMMERDB_VUSERS                                          16
# sut_parameters_BEXHOMA_SUT_NAME          bexhoma-sut-postgresql-bht-16-1-1777041908
# phase                                            1777041908-PostgreSQL-BHT-16-1-2-2

# %% [markdown]
# # Performance at Ingestion

# %%
df_performance = collect.get_connections()
#df_performance = collect.get_loading_time_max_all()

df_performance_first = df_performance[df_performance['client']==1]
df_performance_second = df_performance[df_performance['client']==2]

df_performance.T
# Out:
#                                                     1777039267-PostgreSQL-BHT-16-1-1-1-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-1
# experiment_run                                                                         1
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-1-2-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                                                         1
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-1-2-2  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-1-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-1-2
# experiment_run                                                                         1
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4482
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155544
# host_datadisk                                                                       4482
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-1-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-1
# experiment_run                                                                         2
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3299
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154360
# host_datadisk                                                                       3299
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                1
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-2-1  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777039267-PostgreSQL-BHT-16-1-2-2-2  \
# code                                                                          1777039267
# connection                                          1777039267-PostgreSQL-BHT-16-1-2-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777039267-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         180.00
# time_ingest                                                                        84.00
# time_check                                                                         96.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4031
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155093
# host_datadisk                                                                       4031
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                8
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-1-1-1  \
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-1-1-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-1-1
# experiment_run                                                                         1
# client                                                                                 1
# dockerimage                                                                postgres:18.3
# time_load                                                                         183.00
# time_ingest                                                                        84.00
# time_check                                                                         98.00
# terminals                                                                              0
# pods                                                                                   1
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            3298
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         154359
# host_datadisk                                                                       3298
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# ...
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-2-2-1  \
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-1
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0
#
#                                                     1777041908-PostgreSQL-BHT-16-1-2-2-2
# code                                                                          1777041908
# connection                                          1777041908-PostgreSQL-BHT-16-1-2-2-2
# configuration                                                        PostgreSQL-BHT-16-1
# phase                                                 1777041908-PostgreSQL-BHT-16-1-2-2
# experiment_run                                                                         2
# client                                                                                 2
# dockerimage                                                                postgres:18.3
# time_load                                                                         222.00
# time_ingest                                                                        94.00
# time_check                                                                        128.00
# terminals                                                                              0
# pods                                                                                   2
# tenant
# num_worker                                                                             0
# type_tenants                                                                        None
# num_tenants                                                                            0
# vol_tenants                                                                        False
# datadisk                                                                            4642
# host_RAM                                                                    541008474112
# host_CPU                                                  AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                            64
# host_host                                                             5.15.0-164-generic
# host_node                                                                    cl-worker14
# host_disk                                                                         155704
# host_datadisk                                                                       4642
# host_volume_size                                                                       0
# host_volume_used                                                                       0
# host_cuda
# host_hugepages_total                                                                   0
# host_hugepages_free                                                                    0
# host_cpu_list                                                                       0-63
# host_requests_cpu                                                                      4
# host_requests_memory                                                                16Gi
# host_limits_cpu                                                                        0
# host_limits_memory                                                                     0
# loading_parameters_HAMMERDB_NUM_VU                                                     1
# loading_parameters_SF                                                                 16
# loading_parameters_HAMMERDB_DURATION                                                   5
# loading_parameters_HAMMERDB_RAMPUP                                                     2
# loading_parameters_HAMMERDB_TYPE                                              postgresql
# loading_parameters_HAMMERDB_VUSERS                                                    16
# loading_parameters_HAMMERDB_KEYANDTHINK                                            false
# loading_parameters_HAMMERDB_TIMEPROFILE                                             true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                2
# benchmarking_parameters_SF                                                            16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                             1
# benchmarking_parameters_HAMMERDB_DURATION                                              5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                2
# benchmarking_parameters_HAMMERDB_TYPE                                         postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                               16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                       false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                        true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                 bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE              bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME               bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                 3000
# arg_max_worker_processes                                                              64
# arg_max_parallel_workers                                                              64
# arg_max_parallel_workers_per_gather                                                   64
# arg_max_parallel_maintenance_workers                                                  64
# arg_effective_io_concurrency                                                          64
# arg_io_method                                                                     worker
# arg_shared_buffers                                                                 256GB
# arg_effective_cache_size                                                           256GB
# arg_work_mem                                                                        32GB
# arg_maintenance_work_mem                                                             4GB
# arg_temp_buffers                                                                     4GB
# arg_wal_buffers                                                                      1GB
# arg_autovacuum                                                                       off
# arg_wal_level                                                                    minimal
# arg_max_wal_senders                                                                    0
# arg_fsync                                                                             on
# arg_wal_compression                                                                   on
# arg_synchronous_commit                                                                on
# arg_max_wal_size                                                                    32GB
# arg_min_wal_size                                                                    32GB
# arg_checkpoint_timeout                                                               12h
# arg_checkpoint_completion_target                                                     1.0

# %% [markdown]
# # Combine Performance and Monitoring
#
# This includes filtering for the first client and incorporating efficiency metrics to track performance relative to resource usage.

# %%
client = 1

df_performance_monitoring = collect.get_monitoring_aggregated_per_phase(type="stream")
df_performance = collect.get_performance_aggregated_per_phase()
merged_df = pd.merge(df_performance, df_performance_monitoring, left_index=True, right_index=True, how='left')

merged_df = merged_df[merged_df['client'] == client]

#merged_df['E_Tpx'] = merged_df['Goodput (requests/second)'] / merged_df['CPU Utilization Time [s]'] * 600.
#merged_df['E_Lat'] = 1./np.sqrt(merged_df['Latency Distribution.Average Latency (microseconds)']*merged_df['CPU Utilization Time [s]']/1E6)
#merged_df['E_RAM'] = (merged_df['Goodput (requests/second)']) / merged_df['Memory Usage [MiB]']
merged_df.T
# Out:
#                                                   1777039267-PostgreSQL-BHT-16-1-1-1  \
# configuration                                         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                     1
# phase                                             1777039267-PostgreSQL-BHT-16-1-1-1
# client                                                                             1
# code                                                                      1777039267
# pod_count                                                                          1
# iterations                                                                  10000000
# duration                                                                           5
# sf                                                                                16
# run                                                                                0
# errors                                                                             0
# vusers_loading                                                                     1
# vusers                                                                            16
# NOPM                                                                        19631.00
# TPM                                                                         45290.00
# efficiency                                                                      0.00
# dbms                                                                      PostgreSQL
# CALLS                                                                      278150.00
# MIN [ms]                                                                        5.92
# AVG [ms]                                                                       19.17
# MAX [ms]                                                                      977.06
# TOTAL [ms]                                                                5331340.94
# P99 [ms]                                                                       50.37
# P95 [ms]                                                                       33.73
# P50 [ms]                                                                       16.86
# Memory Usage [MiB]                                                           7777.19
# Memory Usage Cached [MiB]                                                    8552.64
# CPU Utilization                                                                 0.87
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      389.77
# CPU User Time [s]                                                             326.40
# CPU System Time [s]                                                            63.37
# Network Rx Total [MiB]                                                         94.19
# Network Tx Total [MiB]                                                       1064.29
# Filesystem Read Total [MiB]                                                     0.04
# Filesystem Write Total [MiB]                                                 2373.79
# Core Utilization Variance [%]                                                   0.23
# Max Core Utilization [%]                                                        3.26
# I/O Wait [%]                                                                   35.31
# Total I/O Wait Time [s]                                                       412.76
# Number of Idle Sessions                                                         1.33
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      17.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.03
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                 10.58
# Active Backends Waiting on Locks                                                3.01
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.03
# Max Transaction Duration (Lock Wait)                                            0.01
# Disk Blocks Read Count                                                      28399.00
# Buffer Cache Hit Count                                                   49064412.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           128.69
# AccessExclusiveLocks Current                                                    0.00
# AccessShareLocks Current                                                       45.61
# ExclusiveLocks Current                                                          2.85
# RowExclusiveLocks Current                                                      80.22
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        134.57
# Total WAL Size [GiB]                                                            2.10
# WAL Segments Growth Rate [segments/s]                                           0.24
# WAL Growth Rate [MiB/s]                                                         3.89
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777039267-PostgreSQL-BHT-16-1-2-1  \
# configuration                                         1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                     2
# phase                                             1777039267-PostgreSQL-BHT-16-1-2-1
# client                                                                             1
# code                                                                      1777039267
# pod_count                                                                          1
# iterations                                                                  10000000
# duration                                                                           5
# sf                                                                                16
# run                                                                                0
# errors                                                                             0
# vusers_loading                                                                     1
# vusers                                                                            16
# NOPM                                                                        12003.00
# TPM                                                                         27756.00
# efficiency                                                                      0.00
# dbms                                                                      PostgreSQL
# CALLS                                                                      169786.00
# MIN [ms]                                                                        6.11
# AVG [ms]                                                                       20.79
# MAX [ms]                                                                      375.76
# TOTAL [ms]                                                                3530130.88
# P99 [ms]                                                                       66.87
# P95 [ms]                                                                       34.67
# P50 [ms]                                                                       16.77
# Memory Usage [MiB]                                                           7558.01
# Memory Usage Cached [MiB]                                                    8309.08
# CPU Utilization                                                                 0.57
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      261.09
# CPU User Time [s]                                                             212.53
# CPU System Time [s]                                                            48.56
# Network Rx Total [MiB]                                                         61.90
# Network Tx Total [MiB]                                                        936.34
# Filesystem Read Total [MiB]                                                     0.02
# Filesystem Write Total [MiB]                                                 1626.95
# Core Utilization Variance [%]                                                   0.17
# Max Core Utilization [%]                                                        2.25
# I/O Wait [%]                                                                   40.30
# Total I/O Wait Time [s]                                                       416.70
# Number of Idle Sessions                                                         1.12
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      16.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.08
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  1.00
# Active Backends Waiting on WAL                                                  6.61
# Active Backends Waiting on Locks                                                7.39
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.07
# Max Transaction Duration (Lock Wait)                                            0.06
# Disk Blocks Read Count                                                      15958.00
# Buffer Cache Hit Count                                                   38856965.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                            94.19
# AccessExclusiveLocks Current                                                    0.09
# AccessShareLocks Current                                                       28.25
# ExclusiveLocks Current                                                          4.93
# RowExclusiveLocks Current                                                      60.92
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        123.89
# Total WAL Size [GiB]                                                            1.94
# WAL Segments Growth Rate [segments/s]                                           0.21
# WAL Growth Rate [MiB/s]                                                         3.43
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-1-1  \
# configuration                                         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                     1
# phase                                             1777041908-PostgreSQL-BHT-16-1-1-1
# client                                                                             1
# code                                                                      1777041908
# pod_count                                                                          1
# iterations                                                                  10000000
# duration                                                                           5
# sf                                                                                16
# run                                                                                0
# errors                                                                             0
# vusers_loading                                                                     1
# vusers                                                                            32
# NOPM                                                                        23827.00
# TPM                                                                         54912.00
# efficiency                                                                      0.00
# dbms                                                                      PostgreSQL
# CALLS                                                                      336188.00
# MIN [ms]                                                                        6.49
# AVG [ms]                                                                       20.09
# MAX [ms]                                                                      926.28
# TOTAL [ms]                                                                6752879.10
# P99 [ms]                                                                       52.03
# P95 [ms]                                                                       34.01
# P50 [ms]                                                                       16.93
# Memory Usage [MiB]                                                           7976.66
# Memory Usage Cached [MiB]                                                    8832.62
# CPU Utilization                                                                 1.17
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      538.01
# CPU User Time [s]                                                             436.96
# CPU System Time [s]                                                           101.05
# Network Rx Total [MiB]                                                        120.24
# Network Tx Total [MiB]                                                       1066.13
# Filesystem Read Total [MiB]                                                     0.14
# Filesystem Write Total [MiB]                                                 3154.14
# Core Utilization Variance [%]                                                   0.20
# Max Core Utilization [%]                                                        2.65
# I/O Wait [%]                                                                   32.68
# Total I/O Wait Time [s]                                                       411.15
# Number of Idle Sessions                                                         1.56
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.32
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.99
# Active Backends Waiting on WAL                                                 13.44
# Active Backends Waiting on Locks                                               14.69
# Max Transaction Duration (I/O Wait)                                             0.02
# Max Transaction Duration (WAL Wait)                                             0.17
# Max Transaction Duration (Lock Wait)                                            0.29
# Disk Blocks Read Count                                                      26420.00
# Buffer Cache Hit Count                                                   68089848.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           188.04
# AccessExclusiveLocks Current                                                    0.00
# AccessShareLocks Current                                                       55.85
# ExclusiveLocks Current                                                          9.93
# RowExclusiveLocks Current                                                     122.26
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        143.81
# Total WAL Size [GiB]                                                            2.25
# WAL Segments Growth Rate [segments/s]                                           0.27
# WAL Growth Rate [MiB/s]                                                         4.26
# Average WAL Segment Size [MiB]                                                 16.00
#
#                                                   1777041908-PostgreSQL-BHT-16-1-2-1
# configuration                                         1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                     2
# phase                                             1777041908-PostgreSQL-BHT-16-1-2-1
# client                                                                             1
# code                                                                      1777041908
# pod_count                                                                          1
# iterations                                                                  10000000
# duration                                                                           5
# sf                                                                                16
# run                                                                                0
# errors                                                                             0
# vusers_loading                                                                     1
# vusers                                                                            32
# NOPM                                                                        20556.00
# TPM                                                                         47326.00
# efficiency                                                                      0.00
# dbms                                                                      PostgreSQL
# CALLS                                                                      292300.00
# MIN [ms]                                                                        6.14
# AVG [ms]                                                                       20.44
# MAX [ms]                                                                      590.02
# TOTAL [ms]                                                                5975128.88
# P99 [ms]                                                                       67.00
# P95 [ms]                                                                       33.96
# P50 [ms]                                                                       16.87
# Memory Usage [MiB]                                                           7910.65
# Memory Usage Cached [MiB]                                                    8728.59
# CPU Utilization                                                                 1.28
# CPU Throttle                                                                    0.00
# CPU Throttled Time [s]                                                          0.00
# CPU Utilization Time [s]                                                      596.33
# CPU User Time [s]                                                             500.50
# CPU System Time [s]                                                            95.83
# Network Rx Total [MiB]                                                        104.97
# Network Tx Total [MiB]                                                       1079.82
# Filesystem Read Total [MiB]                                                     0.02
# Filesystem Write Total [MiB]                                                 2712.57
# Core Utilization Variance [%]                                                   0.17
# Max Core Utilization [%]                                                        2.71
# I/O Wait [%]                                                                   31.67
# Total I/O Wait Time [s]                                                       393.00
# Number of Idle Sessions                                                         1.60
# Number of Idle-in-transaction Sessions                                          0.00
# Number of Idle-in-transaction Aborted Sessions                                  0.00
# Number of Active Sessions                                                      32.00
# Number of Active Application Sessions                                           0.00
# Longest Active Transaction                                                      0.22
# Longest Idle Session (no transaction)                                           0.00
# Longest Idle-in-Transaction                                                     0.00
# Longest Idle-in-Transaction (Aborted)                                           0.00
# Active Backends Waiting on I/O                                                  0.96
# Active Backends Waiting on WAL                                                 11.94
# Active Backends Waiting on Locks                                               16.23
# Max Transaction Duration (I/O Wait)                                             0.01
# Max Transaction Duration (WAL Wait)                                             0.13
# Max Transaction Duration (Lock Wait)                                            0.21
# Disk Blocks Read Count                                                      24432.00
# Buffer Cache Hit Count                                                   75181391.00
# Buffer Cache Hit Ratio                                                          1.00
# Index Scan Count                                                                0.00
# Index Tuple Fetch Count                                                         0.00
# Index Cache Hit Ratio                                                           0.00
# Table Buffer Hit Count                                                          0.00
# Table Blocks Read Count                                                         0.00
# Table Cache Hit Ratio                                                           0.00
# Total Cache Hit Ratio                                                           0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                 0.00
# BGWriter Stopped Due to Max Pages                                               0.00
# Total Locks Current                                                           174.45
# AccessExclusiveLocks Current                                                    0.02
# AccessShareLocks Current                                                       50.67
# ExclusiveLocks Current                                                         10.47
# RowExclusiveLocks Current                                                     113.29
# RowShareLocks Current                                                           0.00
# ShareLocks Current                                                              0.00
# ShareRowExclusiveLocks Current                                                  0.00
# ShareUpdateExclusiveLocks Current                                               0.00
# SIReadLocks Current                                                             0.00
# Autoanalyze Run Count                                                           0.00
# Autovacuum Run Count                                                            0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                0.00
# Number of WAL Segments                                                        138.17
# Total WAL Size [GiB]                                                            2.16
# WAL Segments Growth Rate [segments/s]                                           0.23
# WAL Growth Rate [MiB/s]                                                         3.71
# Average WAL Segment Size [MiB]                                                 16.00

# %% [markdown]
# ## With Metadata
#
# Connection infos are added.

# %%
df = collect.add_metadata(merged_df)
df.T
# Out:
# combine on index and column 'phase'
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-1  \
# configuration                                                 1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                             1
# client                                                                                     1
# code                                                                              1777039267
# pod_count                                                                                  1
# iterations                                                                          10000000
# duration                                                                                   5
# sf                                                                                        16
# run                                                                                        0
# errors                                                                                     0
# vusers_loading                                                                             1
# vusers                                                                                    16
# NOPM                                                                                19631.00
# TPM                                                                                 45290.00
# efficiency                                                                              0.00
# dbms                                                                              PostgreSQL
# CALLS                                                                              278150.00
# MIN [ms]                                                                                5.92
# AVG [ms]                                                                               19.17
# MAX [ms]                                                                              977.06
# TOTAL [ms]                                                                        5331340.94
# P99 [ms]                                                                               50.37
# P95 [ms]                                                                               33.73
# P50 [ms]                                                                               16.86
# Memory Usage [MiB]                                                                   7777.19
# Memory Usage Cached [MiB]                                                            8552.64
# CPU Utilization                                                                         0.87
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              389.77
# CPU User Time [s]                                                                     326.40
# CPU System Time [s]                                                                    63.37
# Network Rx Total [MiB]                                                                 94.19
# Network Tx Total [MiB]                                                               1064.29
# Filesystem Read Total [MiB]                                                             0.04
# Filesystem Write Total [MiB]                                                         2373.79
# Core Utilization Variance [%]                                                           0.23
# Max Core Utilization [%]                                                                3.26
# I/O Wait [%]                                                                           35.31
# Total I/O Wait Time [s]                                                               412.76
# Number of Idle Sessions                                                                 1.33
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              17.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.03
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.99
# Active Backends Waiting on WAL                                                         10.58
# Active Backends Waiting on Locks                                                        3.01
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.03
# Max Transaction Duration (Lock Wait)                                                    0.01
# Disk Blocks Read Count                                                              28399.00
# Buffer Cache Hit Count                                                           49064412.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   128.69
# AccessExclusiveLocks Current                                                            0.00
# AccessShareLocks Current                                                               45.61
# ExclusiveLocks Current                                                                  2.85
# RowExclusiveLocks Current                                                              80.22
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                134.57
# Total WAL Size [GiB]                                                                    2.10
# WAL Segments Growth Rate [segments/s]                                                   0.24
# WAL Growth Rate [MiB/s]                                                                 3.89
# Average WAL Segment Size [MiB]                                                         16.00
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3298
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154360
# host_datadisk                                                                           3298
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777039267-PostgreSQL-BHT-16-1-1-1
#
# phase                                                     1777039267-PostgreSQL-BHT-16-1-2-1  \
# configuration                                                 1777039267-PostgreSQL-BHT-16-1
# experiment_run                                                                             2
# client                                                                                     1
# code                                                                              1777039267
# pod_count                                                                                  1
# iterations                                                                          10000000
# duration                                                                                   5
# sf                                                                                        16
# run                                                                                        0
# errors                                                                                     0
# vusers_loading                                                                             1
# vusers                                                                                    16
# NOPM                                                                                12003.00
# TPM                                                                                 27756.00
# efficiency                                                                              0.00
# dbms                                                                              PostgreSQL
# CALLS                                                                              169786.00
# MIN [ms]                                                                                6.11
# AVG [ms]                                                                               20.79
# MAX [ms]                                                                              375.76
# TOTAL [ms]                                                                        3530130.88
# P99 [ms]                                                                               66.87
# P95 [ms]                                                                               34.67
# P50 [ms]                                                                               16.77
# Memory Usage [MiB]                                                                   7558.01
# Memory Usage Cached [MiB]                                                            8309.08
# CPU Utilization                                                                         0.57
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              261.09
# CPU User Time [s]                                                                     212.53
# CPU System Time [s]                                                                    48.56
# Network Rx Total [MiB]                                                                 61.90
# Network Tx Total [MiB]                                                                936.34
# Filesystem Read Total [MiB]                                                             0.02
# Filesystem Write Total [MiB]                                                         1626.95
# Core Utilization Variance [%]                                                           0.17
# Max Core Utilization [%]                                                                2.25
# I/O Wait [%]                                                                           40.30
# Total I/O Wait Time [s]                                                               416.70
# Number of Idle Sessions                                                                 1.12
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              16.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.08
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          1.00
# Active Backends Waiting on WAL                                                          6.61
# Active Backends Waiting on Locks                                                        7.39
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.07
# Max Transaction Duration (Lock Wait)                                                    0.06
# Disk Blocks Read Count                                                              15958.00
# Buffer Cache Hit Count                                                           38856965.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                    94.19
# AccessExclusiveLocks Current                                                            0.09
# AccessShareLocks Current                                                               28.25
# ExclusiveLocks Current                                                                  4.93
# RowExclusiveLocks Current                                                              60.92
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                123.89
# Total WAL Size [GiB]                                                                    1.94
# WAL Segments Growth Rate [segments/s]                                                   0.21
# WAL Growth Rate [MiB/s]                                                                 3.43
# Average WAL Segment Size [MiB]                                                         16.00
# dockerimage                                                                    postgres:18.3
# time_load                                                                             180.00
# time_ingest                                                                            84.00
# time_check                                                                             96.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3299
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154360
# host_datadisk                                                                           3299
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   16
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777039267
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777039267-PostgreSQL-BHT-16-1-2-1
#
# phase                                                     1777041908-PostgreSQL-BHT-16-1-1-1  \
# configuration                                                 1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                             1
# client                                                                                     1
# code                                                                              1777041908
# pod_count                                                                                  1
# iterations                                                                          10000000
# duration                                                                                   5
# sf                                                                                        16
# run                                                                                        0
# errors                                                                                     0
# vusers_loading                                                                             1
# vusers                                                                                    32
# NOPM                                                                                23827.00
# TPM                                                                                 54912.00
# efficiency                                                                              0.00
# dbms                                                                              PostgreSQL
# CALLS                                                                              336188.00
# MIN [ms]                                                                                6.49
# AVG [ms]                                                                               20.09
# MAX [ms]                                                                              926.28
# TOTAL [ms]                                                                        6752879.10
# P99 [ms]                                                                               52.03
# P95 [ms]                                                                               34.01
# P50 [ms]                                                                               16.93
# Memory Usage [MiB]                                                                   7976.66
# Memory Usage Cached [MiB]                                                            8832.62
# CPU Utilization                                                                         1.17
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              538.01
# CPU User Time [s]                                                                     436.96
# CPU System Time [s]                                                                   101.05
# Network Rx Total [MiB]                                                                120.24
# Network Tx Total [MiB]                                                               1066.13
# Filesystem Read Total [MiB]                                                             0.14
# Filesystem Write Total [MiB]                                                         3154.14
# Core Utilization Variance [%]                                                           0.20
# Max Core Utilization [%]                                                                2.65
# I/O Wait [%]                                                                           32.68
# Total I/O Wait Time [s]                                                               411.15
# Number of Idle Sessions                                                                 1.56
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              32.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.32
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.99
# Active Backends Waiting on WAL                                                         13.44
# Active Backends Waiting on Locks                                                       14.69
# Max Transaction Duration (I/O Wait)                                                     0.02
# Max Transaction Duration (WAL Wait)                                                     0.17
# Max Transaction Duration (Lock Wait)                                                    0.29
# Disk Blocks Read Count                                                              26420.00
# Buffer Cache Hit Count                                                           68089848.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   188.04
# AccessExclusiveLocks Current                                                            0.00
# AccessShareLocks Current                                                               55.85
# ExclusiveLocks Current                                                                  9.93
# RowExclusiveLocks Current                                                             122.26
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                143.81
# Total WAL Size [GiB]                                                                    2.25
# WAL Segments Growth Rate [segments/s]                                                   0.27
# WAL Growth Rate [MiB/s]                                                                 4.26
# Average WAL Segment Size [MiB]                                                         16.00
# dockerimage                                                                    postgres:18.3
# time_load                                                                             183.00
# time_ingest                                                                            84.00
# time_check                                                                             98.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3298
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154359
# host_datadisk                                                                           3298
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   32
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777041908-PostgreSQL-BHT-16-1-1-1
#
# phase                                                     1777041908-PostgreSQL-BHT-16-1-2-1
# configuration                                                 1777041908-PostgreSQL-BHT-16-1
# experiment_run                                                                             2
# client                                                                                     1
# code                                                                              1777041908
# pod_count                                                                                  1
# iterations                                                                          10000000
# duration                                                                                   5
# sf                                                                                        16
# run                                                                                        0
# errors                                                                                     0
# vusers_loading                                                                             1
# vusers                                                                                    32
# NOPM                                                                                20556.00
# TPM                                                                                 47326.00
# efficiency                                                                              0.00
# dbms                                                                              PostgreSQL
# CALLS                                                                              292300.00
# MIN [ms]                                                                                6.14
# AVG [ms]                                                                               20.44
# MAX [ms]                                                                              590.02
# TOTAL [ms]                                                                        5975128.88
# P99 [ms]                                                                               67.00
# P95 [ms]                                                                               33.96
# P50 [ms]                                                                               16.87
# Memory Usage [MiB]                                                                   7910.65
# Memory Usage Cached [MiB]                                                            8728.59
# CPU Utilization                                                                         1.28
# CPU Throttle                                                                            0.00
# CPU Throttled Time [s]                                                                  0.00
# CPU Utilization Time [s]                                                              596.33
# CPU User Time [s]                                                                     500.50
# CPU System Time [s]                                                                    95.83
# Network Rx Total [MiB]                                                                104.97
# Network Tx Total [MiB]                                                               1079.82
# Filesystem Read Total [MiB]                                                             0.02
# Filesystem Write Total [MiB]                                                         2712.57
# Core Utilization Variance [%]                                                           0.17
# Max Core Utilization [%]                                                                2.71
# I/O Wait [%]                                                                           31.67
# Total I/O Wait Time [s]                                                               393.00
# Number of Idle Sessions                                                                 1.60
# Number of Idle-in-transaction Sessions                                                  0.00
# Number of Idle-in-transaction Aborted Sessions                                          0.00
# Number of Active Sessions                                                              32.00
# Number of Active Application Sessions                                                   0.00
# Longest Active Transaction                                                              0.22
# Longest Idle Session (no transaction)                                                   0.00
# Longest Idle-in-Transaction                                                             0.00
# Longest Idle-in-Transaction (Aborted)                                                   0.00
# Active Backends Waiting on I/O                                                          0.96
# Active Backends Waiting on WAL                                                         11.94
# Active Backends Waiting on Locks                                                       16.23
# Max Transaction Duration (I/O Wait)                                                     0.01
# Max Transaction Duration (WAL Wait)                                                     0.13
# Max Transaction Duration (Lock Wait)                                                    0.21
# Disk Blocks Read Count                                                              24432.00
# Buffer Cache Hit Count                                                           75181391.00
# Buffer Cache Hit Ratio                                                                  1.00
# Index Scan Count                                                                        0.00
# Index Tuple Fetch Count                                                                 0.00
# Index Cache Hit Ratio                                                                   0.00
# Table Buffer Hit Count                                                                  0.00
# Table Blocks Read Count                                                                 0.00
# Table Cache Hit Ratio                                                                   0.00
# Total Cache Hit Ratio                                                                   0.00
# BGWriter Efficiency Ratio (Cleaned / Allocated)                                         0.00
# BGWriter Stopped Due to Max Pages                                                       0.00
# Total Locks Current                                                                   174.45
# AccessExclusiveLocks Current                                                            0.02
# AccessShareLocks Current                                                               50.67
# ExclusiveLocks Current                                                                 10.47
# RowExclusiveLocks Current                                                             113.29
# RowShareLocks Current                                                                   0.00
# ShareLocks Current                                                                      0.00
# ShareRowExclusiveLocks Current                                                          0.00
# ShareUpdateExclusiveLocks Current                                                       0.00
# SIReadLocks Current                                                                     0.00
# Autoanalyze Run Count                                                                   0.00
# Autovacuum Run Count                                                                    0.00
# Dead tuples per vacuum operation [tuples/vacuum]                                        0.00
# Number of WAL Segments                                                                138.17
# Total WAL Size [GiB]                                                                    2.16
# WAL Segments Growth Rate [segments/s]                                                   0.23
# WAL Growth Rate [MiB/s]                                                                 3.71
# Average WAL Segment Size [MiB]                                                         16.00
# dockerimage                                                                    postgres:18.3
# time_load                                                                             222.00
# time_ingest                                                                            94.00
# time_check                                                                            128.00
# terminals                                                                                  0
# pods                                                                                       1
# tenant
# num_worker                                                                                 0
# type_tenants                                                                            None
# num_tenants                                                                                0
# vol_tenants                                                                            False
# datadisk                                                                                3282
# host_RAM                                                                        541008474112
# host_CPU                                                      AMD Opteron(tm) Processor 6378
# host_GPU
# host_Cores                                                                                64
# host_host                                                                 5.15.0-164-generic
# host_node                                                                        cl-worker14
# host_disk                                                                             154343
# host_datadisk                                                                           3282
# host_volume_size                                                                           0
# host_volume_used                                                                           0
# host_cuda
# host_hugepages_total                                                                       0
# host_hugepages_free                                                                        0
# host_cpu_list                                                                           0-63
# host_requests_cpu                                                                          4
# host_requests_memory                                                                    16Gi
# host_limits_cpu                                                                            0
# host_limits_memory                                                                         0
# loading_parameters_HAMMERDB_NUM_VU                                                         1
# loading_parameters_SF                                                                     16
# loading_parameters_HAMMERDB_DURATION                                                       5
# loading_parameters_HAMMERDB_RAMPUP                                                         2
# loading_parameters_HAMMERDB_TYPE                                                  postgresql
# loading_parameters_HAMMERDB_VUSERS                                                        16
# loading_parameters_HAMMERDB_KEYANDTHINK                                                false
# loading_parameters_HAMMERDB_TIMEPROFILE                                                 true
# benchmarking_parameters_HAMMERDB_NUM_VU                                                    1
# benchmarking_parameters_SF                                                                16
# benchmarking_parameters_BEXHOMA_SYNCH_LOAD                                                 1
# benchmarking_parameters_HAMMERDB_DURATION                                                  5
# benchmarking_parameters_HAMMERDB_RAMPUP                                                    2
# benchmarking_parameters_HAMMERDB_TYPE                                             postgresql
# benchmarking_parameters_HAMMERDB_VUSERS                                                   32
# benchmarking_parameters_HAMMERDB_KEYANDTHINK                                           false
# benchmarking_parameters_HAMMERDB_TIMEPROFILE                                            true
# sut_parameters_BEXHOMA_WORKER_LIST
# sut_parameters_BEXHOMA_WORKER_LIST_SPACE
# sut_parameters_BEXHOMA_WORKER_NAME                     bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_WORKER_SERVICE                  bexhoma-worker-postgresql-hammerdb-16
# sut_parameters_BEXHOMA_SUT_NAME                   bexhoma-sut-postgresql-bht-16-1-1777041908
# arg_max_connections                                                                     3000
# arg_max_worker_processes                                                                  64
# arg_max_parallel_workers                                                                  64
# arg_max_parallel_workers_per_gather                                                       64
# arg_max_parallel_maintenance_workers                                                      64
# arg_effective_io_concurrency                                                              64
# arg_io_method                                                                         worker
# arg_shared_buffers                                                                     256GB
# arg_effective_cache_size                                                               256GB
# arg_work_mem                                                                            32GB
# arg_maintenance_work_mem                                                                 4GB
# arg_temp_buffers                                                                         4GB
# arg_wal_buffers                                                                          1GB
# arg_autovacuum                                                                           off
# arg_wal_level                                                                        minimal
# arg_max_wal_senders                                                                        0
# arg_fsync                                                                                 on
# arg_wal_compression                                                                       on
# arg_synchronous_commit                                                                    on
# arg_max_wal_size                                                                        32GB
# arg_min_wal_size                                                                        32GB
# arg_checkpoint_timeout                                                                   12h
# arg_checkpoint_completion_target                                                         1.0
# phase                                                     1777041908-PostgreSQL-BHT-16-1-2-1

# %% [markdown]
# ## Test for Header Informations
#
# These infos are used to relate connection infos to benchmarking results.

# %%
df[['phase', 'code', 'configuration', 'experiment_run', 'client', 'type_tenants', 'num_tenants', 'vol_tenants']].T
# Out:
# phase           1777039267-PostgreSQL-BHT-16-1-1-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-1-1
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777039267-PostgreSQL-BHT-16-1-2-1  \
# phase           1777039267-PostgreSQL-BHT-16-1-2-1
# code                                    1777039267
# configuration       1777039267-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-1-1  \
# phase           1777041908-PostgreSQL-BHT-16-1-1-1
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   1
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False
#
# phase           1777041908-PostgreSQL-BHT-16-1-2-1
# phase           1777041908-PostgreSQL-BHT-16-1-2-1
# code                                    1777041908
# configuration       1777041908-PostgreSQL-BHT-16-1
# experiment_run                                   2
# client                                           1
# type_tenants                                  None
# num_tenants                                      0
# vol_tenants                                  False

# %%
zip_all_results(path, codes)
# Out:
# Zipping /data/benchmarks/1777039267 to /data/benchmarks/1777039267.zip...
# Zipping /data/benchmarks/1777041908 to /data/benchmarks/1777041908.zip...
# ✅ Done zipping all folders.
