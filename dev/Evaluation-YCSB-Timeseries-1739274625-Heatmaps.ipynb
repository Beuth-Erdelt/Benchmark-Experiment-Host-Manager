# %% [markdown]
# # YCSB Analysis of Grid of Parameters
#
# ```
# nohup python ycsb.py -ms 1 -tr \
#   -sf $BEXHOMA_YCSB_SF_DATA \
#   -sfo $BEXHOMA_YCSB_SF_OPS \
#   --workload c \
#   -dbms PostgreSQL \
#   -rnn $BEXHOMA_NODE_SUT -rnl $BEXHOMA_NODE_LOAD -rnb $BEXHOMA_NODE_BENCHMARK \
#   -tb 16384 \
#   -nlp 8 \
#   -nlt 64 \
#   -nlf 12 \
#   -nbp 1,1,8,16 \
#   -nbt 80,96,112,128,144,160,176,192 \
#   -nbf 0,9,10,11,12,13,14,15,16 \
#   -ne 1 \
#   -nc 2 \
#   -m -mc \
#   -rst shared -rss 50Gi \
#   run </dev/null &>$LOG_DIR/test_ycsb_testcase_cn_13.log &
# ```
# tcase_cn_13.log &

# %%
code = "1739274625"
path = "D:\\data\\benchmarks"
#path = "/home/perdelt/benchmarks"

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown
import seaborn as sns

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
cut_at = 0

#pod_count = 16
#experiment_run = 1
#target = 0
#threads = 128


def plot_timeseries(df_aggregated, metric, pod_count, experiment_run, target, threads, smoothing=0):
    df = df_aggregated.copy()
    if experiment_run > 0:
        df = df[df['experiment_run'] == experiment_run]
    df = df[df['target'] == target]
    df = df[df['threads'] == threads]
    df_subset = df[df['pod_count'] == pod_count]
    df_subset = df_subset[~df_subset.duplicated(subset=['threads', 'target'], keep='last')]
    client = df_subset['client'].iloc[0]
    plot_measures(metric, smoothing=smoothing, preset_experiment_run=experiment_run, preset_client=client)

def plot_measures(metric, smoothing=0, preset_experiment_run=0, preset_client=0):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        for experiment_run in list_experiment_runs:
            if preset_experiment_run > 0:
                if preset_experiment_run != experiment_run:
                    continue
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            if preset_client > 0:
                n_rows = 1
            else:
                n_rows = num_runs
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows), sharex=True)
            fig.suptitle(f"Metric {metric}", fontsize=16)#, fontweight="bold")
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                if preset_client > 0:
                    if preset_client != client:
                        continue
                #################################
                # show plots with aggregated line
                #################################
                # filter data for this run
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]
                df_part = df_part[df_part['client'] == (client)]
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                # Weighted average: Multiply each value by its duration and sum
                weighted_sum = (df_total[metric].multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total[metric] = df_total[metric].rolling(window=smoothing, min_periods=1).mean()
                # optionally leave out data at the end (cool down)
                if cut_at > 0:
                    df_total = df_total[:-cut_at]
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                max_value = df_total[metric].max()
                #print(max_value)
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
                ###############################
                # show plots with lines per pod
                ###############################
                df_list = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                # collect in one dataframe
                df_total = pd.DataFrame()
                j=1
                max_value = 0
                for df in df_list:
                    # optionally leave out data at the end (cool down)
                    if cut_at > 0:
                        df_tmp = df[metric][:-cut_at]
                    else:
                        df_tmp = df[metric]
                    df_single = pd.DataFrame(df_tmp)
                    if max_value < df_single[metric].max():
                        max_value = df_single[metric].max()
                    df_single.columns=["pod "+str(j)]
                    df_total = pd.merge(df_total, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                #print(df_combined)
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                weighted_sum = (df_total.multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time / len(df_list)
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total = df_total.rolling(window=smoothing, min_periods=1).mean()
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True, legend=False)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            filename = f"plot_{preset_experiment_run}_{preset_client}_{metric}.png".replace("\\","").replace("/","").replace(":","")
            #df2img.save_dataframe(styled_df, filename="styled_table.png")
            plt.savefig(filename, dpi=300, bbox_inches="tight")
            plt.show()

def plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=None, vmax_value=None):
    #metric = '[OVERALL].Throughput(ops/sec)'
    #pod_count = 1
    #experiment_run = 1
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df = df.pivot(index='threads', columns='target', values=metric)
    #display(df.style.background_gradient(cmap='Blues', axis=None))
    styled_df = df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient()
    #display(df)
    # Set up the figure size
    plt.figure(figsize=(10, 4))
    # Create the heatmap
    if vmin_value is not None and vmax_value is not None:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7}, vmin=vmin_value, vmax=vmax_value)
    else:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7})
    ax.set_title(metric)
    # Save as PNG
    filename = (f"heatmap_{metric}_{pod_count}_{experiment_run}.png").replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    # Show the plot (optional)
    plt.show()


def plot_prometheus_metric(df_aggregated, metric, component, pod_count, experiment_run):
    df_aggregated = pd.DataFrame(df_aggregated, columns=[metric])
    #print(df_aggregated)
    df_benchmarks2 = df_benchmarks.set_index('connection')
    df_benchmarks2['threads_total'] = df_benchmarks2['threads']*df_benchmarks2['pod_count']
    df = df_aggregated.join(df_benchmarks2, how='inner')
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df_heatmap)
    df = df.pivot(index='threads_total', columns='target', values=metric)
    #display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))
    df.plot.bar(title=f"{component} ({experiment_run}. run with {pod_count} pods): {metric}")
    filename = f"bar_{component}_{experiment_run}_{pod_count}_{metric}.png".replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")

# %%
evaluation = evaluators.ycsb(code=code, path=path)

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-196608-1-151-1  \
# connection                                   PostgreSQL-64-8-196608-1-151
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                151
# pod                                               1526zjf.dbmsbenchmarker
# pod_count                                                               8
# threads                                                                20
# target                                                              24576
# sf                                                                     16
# workload                                                                c
# operations                                                       32000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1302577.0
# [OVERALL].Throughput(ops/sec)                                24566.685885
# [TOTAL_GCS_Copy].Count                                                130
# [TOTAL_GC_TIME_Copy].Time(ms)                                         346
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.02656272911313496
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                     130
# [TOTAL_GC_TIME].Time(ms)                                              346
# [TOTAL_GC_TIME_%].Time(%)                             0.02656272911313496
# [READ].Operations                                                32000000
# [READ].AverageLatency(us)                                      570.775051
# [READ].MinLatency(us)                                               175.0
# [READ].MaxLatency(us)                                             38079.0
# [READ].95thPercentileLatency(us)                                   1116.0
# [READ].99thPercentileLatency(us)                                   1879.0
# [READ].Return=OK                                                 32000000
# [CLEANUP].Operations                                                   20
# [CLEANUP].AverageLatency(us)                                       571.75
# [CLEANUP].MinLatency(us)                                             96.0
# [CLEANUP].MaxLatency(us)                                           2281.0
# [CLEANUP].95thPercentileLatency(us)                                1824.0
# [CLEANUP].99thPercentileLatency(us)                                2281.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-164-1  \
# connection                                   PostgreSQL-64-8-196608-1-164
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                164
# pod                                               16hh4b2.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 5
# target                                                              13312
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1401920.0
# [OVERALL].Throughput(ops/sec)                                11412.919425
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         277
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.019758616754165716
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              277
# [TOTAL_GC_TIME_%].Time(%)                            0.019758616754165716
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                      401.974659
# [READ].MinLatency(us)                                               154.0
# [READ].MaxLatency(us)                                             32143.0
# [READ].95thPercentileLatency(us)                                    721.0
# [READ].99thPercentileLatency(us)                                   1188.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    5
# [CLEANUP].AverageLatency(us)                                        596.0
# [CLEANUP].MinLatency(us)                                            254.0
# [CLEANUP].MaxLatency(us)                                           1367.0
# [CLEANUP].95thPercentileLatency(us)                                1367.0
# [CLEANUP].99thPercentileLatency(us)                                1367.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-11-1  \
# connection                                   PostgreSQL-64-8-196608-2-11
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                11
# pod                                              11pxbt8.dbmsbenchmarker
# pod_count                                                              8
# threads                                                               14
# target                                                                 0
# sf                                                                    16
# workload                                                               c
# operations                                                      32000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1398509.0
# [OVERALL].Throughput(ops/sec)                               22881.511667
# [TOTAL_GCS_Copy].Count                                               130
# [TOTAL_GC_TIME_Copy].Time(ms)                                        367
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.026242233693168936
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                    130
# [TOTAL_GC_TIME].Time(ms)                                             367
# [TOTAL_GC_TIME_%].Time(%)                           0.026242233693168936
# [READ].Operations                                               32000000
# [READ].AverageLatency(us)                                     519.991936
# [READ].MinLatency(us)                                              157.0
# [READ].MaxLatency(us)                                            38079.0
# [READ].95thPercentileLatency(us)                                   913.0
# [READ].99thPercentileLatency(us)                                  1158.0
# [READ].Return=OK                                                32000000
# [CLEANUP].Operations                                                  14
# [CLEANUP].AverageLatency(us)                                  344.214286
# [CLEANUP].MinLatency(us)                                           150.0
# [CLEANUP].MaxLatency(us)                                          1127.0
# [CLEANUP].95thPercentileLatency(us)                                620.0
# [CLEANUP].99thPercentileLatency(us)                               1127.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-204-1  \
# connection                                   PostgreSQL-64-8-196608-2-204
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          2
# client                                                                204
# pod                                               20prjnw.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 7
# target                                                              14336
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1195161.0
# [OVERALL].Throughput(ops/sec)                                13387.317692
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         207
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.017319842263929294
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              207
# [TOTAL_GC_TIME_%].Time(%)                            0.017319842263929294
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                      502.558584
# [READ].MinLatency(us)                                               164.0
# [READ].MaxLatency(us)                                             47647.0
# [READ].95thPercentileLatency(us)                                    917.0
# [READ].99thPercentileLatency(us)                                   1559.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    7
# [CLEANUP].AverageLatency(us)                                        564.0
# [CLEANUP].MinLatency(us)                                            159.0
# [CLEANUP].MaxLatency(us)                                           1466.0
# [CLEANUP].95thPercentileLatency(us)                                1466.0
# [CLEANUP].99thPercentileLatency(us)                                1466.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-7-1  \
# connection                                   PostgreSQL-64-8-196608-1-7
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                7
# pod                                               znt86.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              12
# target                                                                0
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1344986.0
# [OVERALL].Throughput(ops/sec)                              23792.069211
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       294
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02185896358772508
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            294
# [TOTAL_GC_TIME_%].Time(%)                           0.02185896358772508
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    442.099641
# [READ].MinLatency(us)                                             153.0
# [READ].MaxLatency(us)                                           97087.0
# [READ].95thPercentileLatency(us)                                  776.0
# [READ].99thPercentileLatency(us)                                 1199.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 12
# [CLEANUP].AverageLatency(us)                                     308.75
# [CLEANUP].MinLatency(us)                                          125.0
# [CLEANUP].MaxLatency(us)                                         1092.0
# [CLEANUP].95thPercentileLatency(us)                               404.0
# [CLEANUP].99thPercentileLatency(us)                              1092.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-40-1  \
# connection                                   PostgreSQL-64-8-196608-1-40
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         1
# client                                                                40
# pod                                              40ssm7c.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                6
# target                                                              9216
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1736426.0
# [OVERALL].Throughput(ops/sec)                                9214.328742
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        273
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.01572194841588412
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             273
# [TOTAL_GC_TIME_%].Time(%)                            0.01572194841588412
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     349.655017
# [READ].MinLatency(us)                                              169.0
# [READ].MaxLatency(us)                                            44319.0
# [READ].95thPercentileLatency(us)                                   604.0
# [READ].99thPercentileLatency(us)                                   886.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   6
# [CLEANUP].AverageLatency(us)                                       460.0
# [CLEANUP].MinLatency(us)                                            89.0
# [CLEANUP].MaxLatency(us)                                          1403.0
# [CLEANUP].95thPercentileLatency(us)                               1403.0
# [CLEANUP].99thPercentileLatency(us)                               1403.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-252-1  \
# connection                                   PostgreSQL-64-8-196608-1-252
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                252
# pod                                               25b9xz6.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                11
# target                                                              15360
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1480227.0
# [OVERALL].Throughput(ops/sec)                                 10809.15292
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         276
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.01864578878780079
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              276
# [TOTAL_GC_TIME_%].Time(%)                             0.01864578878780079
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                      971.602821
# [READ].MinLatency(us)                                               157.0
# [READ].MaxLatency(us)                                             45919.0
# [READ].95thPercentileLatency(us)                                   1462.0
# [READ].99thPercentileLatency(us)                                   1683.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                   11
# [CLEANUP].AverageLatency(us)                                   345.090909
# [CLEANUP].MinLatency(us)                                            128.0
# [CLEANUP].MaxLatency(us)                                           1200.0
# [CLEANUP].95thPercentileLatency(us)                                 467.0
# [CLEANUP].99thPercentileLatency(us)                                1200.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-256-1  \
# connection                                   PostgreSQL-64-8-196608-1-256
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                256
# pod                                               25q6j97.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                12
# target                                                              15360
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1471926.0
# [OVERALL].Throughput(ops/sec)                                10870.111677
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         279
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.018954757236437157
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              279
# [TOTAL_GC_TIME_%].Time(%)                            0.018954757236437157
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                     1027.458385
# [READ].MinLatency(us)                                               162.0
# [READ].MaxLatency(us)                                             40159.0
# [READ].95thPercentileLatency(us)                                   1527.0
# [READ].99thPercentileLatency(us)                                   1812.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                   12
# [CLEANUP].AverageLatency(us)                                   335.833333
# [CLEANUP].MinLatency(us)                                            135.0
# [CLEANUP].MaxLatency(us)                                           1194.0
# [CLEANUP].95thPercentileLatency(us)                                 691.0
# [CLEANUP].99thPercentileLatency(us)                                1194.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-115-1  \
# connection                                   PostgreSQL-64-8-196608-1-115
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                115
# pod                                               11x45tz.dbmsbenchmarker
# pod_count                                                               8
# threads                                                                18
# target                                                              22528
# sf                                                                     16
# workload                                                                c
# operations                                                       32000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1420809.0
# [OVERALL].Throughput(ops/sec)                                22522.379855
# [TOTAL_GCS_Copy].Count                                                130
# [TOTAL_GC_TIME_Copy].Time(ms)                                         325
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.02287429204066134
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                     130
# [TOTAL_GC_TIME].Time(ms)                                              325
# [TOTAL_GC_TIME_%].Time(%)                             0.02287429204066134
# [READ].Operations                                                32000000
# [READ].AverageLatency(us)                                      463.823212
# [READ].MinLatency(us)                                               173.0
# [READ].MaxLatency(us)                                             41919.0
# [READ].95thPercentileLatency(us)                                    958.0
# [READ].99thPercentileLatency(us)                                   1752.0
# [READ].Return=OK                                                 32000000
# [CLEANUP].Operations                                                   18
# [CLEANUP].AverageLatency(us)                                        379.0
# [CLEANUP].MinLatency(us)                                             83.0
# [CLEANUP].MaxLatency(us)                                           1046.0
# [CLEANUP].95thPercentileLatency(us)                                 885.0
# [CLEANUP].99thPercentileLatency(us)                                1046.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-232-1  \
# connection                                   PostgreSQL-64-8-196608-1-232
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                232
# pod                                               23zqj8h.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 6
# target                                                              15360
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1331445.0
# [OVERALL].Throughput(ops/sec)                                12017.019103
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         262
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.01967786878166203
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              262
# [TOTAL_GC_TIME_%].Time(%)                             0.01967786878166203
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                      422.255905
# [READ].MinLatency(us)                                               159.0
# [READ].MaxLatency(us)                                             46239.0
# [READ].95thPercentileLatency(us)                                    751.0
# [READ].99thPercentileLatency(us)                                   1136.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    6
# [CLEANUP].AverageLatency(us)                                        532.5
# [CLEANUP].MinLatency(us)                                            162.0
# [CLEANUP].MaxLatency(us)                                           1242.0
# [CLEANUP].95thPercentileLatency(us)                                1242.0
# [CLEANUP].99thPercentileLatency(us)                                1242.0
#
# connection_pod                              ...  \
# connection                                  ...
# configuration                               ...
# experiment_run                              ...
# client                                      ...
# pod                                         ...
# pod_count                                   ...
# threads                                     ...
# target                                      ...
# sf                                          ...
# workload                                    ...
# operations                                  ...
# batchsize                                   ...
# exceptions                                  ...
# [OVERALL].RunTime(ms)                       ...
# [OVERALL].Throughput(ops/sec)               ...
# [TOTAL_GCS_Copy].Count                      ...
# [TOTAL_GC_TIME_Copy].Time(ms)               ...
# [TOTAL_GC_TIME_%_Copy].Time(%)              ...
# [TOTAL_GCS_MarkSweepCompact].Count          ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)   ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)  ...
# [TOTAL_GCs].Count                           ...
# [TOTAL_GC_TIME].Time(ms)                    ...
# [TOTAL_GC_TIME_%].Time(%)                   ...
# [READ].Operations                           ...
# [READ].AverageLatency(us)                   ...
# [READ].MinLatency(us)                       ...
# [READ].MaxLatency(us)                       ...
# [READ].95thPercentileLatency(us)            ...
# [READ].99thPercentileLatency(us)            ...
# [READ].Return=OK                            ...
# [CLEANUP].Operations                        ...
# [CLEANUP].AverageLatency(us)                ...
# [CLEANUP].MinLatency(us)                    ...
# [CLEANUP].MaxLatency(us)                    ...
# [CLEANUP].95thPercentileLatency(us)         ...
# [CLEANUP].99thPercentileLatency(us)         ...
#
# connection_pod                             PostgreSQL-64-8-196608-1-143-8  \
# connection                                   PostgreSQL-64-8-196608-1-143
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                143
# pod                                               14hfgng.dbmsbenchmarker
# pod_count                                                               8
# threads                                                                16
# target                                                              24576
# sf                                                                     16
# workload                                                                c
# operations                                                       32000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1302358.0
# [OVERALL].Throughput(ops/sec)                                24570.816934
# [TOTAL_GCS_Copy].Count                                                130
# [TOTAL_GC_TIME_Copy].Time(ms)                                         302
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.023188708481078166
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                     130
# [TOTAL_GC_TIME].Time(ms)                                              302
# [TOTAL_GC_TIME_%].Time(%)                            0.023188708481078166
# [READ].Operations                                                32000000
# [READ].AverageLatency(us)                                      493.546494
# [READ].MinLatency(us)                                               175.0
# [READ].MaxLatency(us)                                             35487.0
# [READ].95thPercentileLatency(us)                                    897.0
# [READ].99thPercentileLatency(us)                                   1419.0
# [READ].Return=OK                                                 32000000
# [CLEANUP].Operations                                                   16
# [CLEANUP].AverageLatency(us)                                    1111.4375
# [CLEANUP].MinLatency(us)                                            138.0
# [CLEANUP].MaxLatency(us)                                           2081.0
# [CLEANUP].95thPercentileLatency(us)                                1862.0
# [CLEANUP].99thPercentileLatency(us)                                2081.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-87-8  \
# connection                                   PostgreSQL-64-8-196608-2-87
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                87
# pod                                              87hng42.dbmsbenchmarker
# pod_count                                                              8
# threads                                                               20
# target                                                             20480
# sf                                                                    16
# workload                                                               c
# operations                                                      32000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1562805.0
# [OVERALL].Throughput(ops/sec)                               20476.003084
# [TOTAL_GCS_Copy].Count                                               130
# [TOTAL_GC_TIME_Copy].Time(ms)                                        377
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.02412329113357073
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                    130
# [TOTAL_GC_TIME].Time(ms)                                             377
# [TOTAL_GC_TIME_%].Time(%)                            0.02412329113357073
# [READ].Operations                                               32000000
# [READ].AverageLatency(us)                                     410.754913
# [READ].MinLatency(us)                                              169.0
# [READ].MaxLatency(us)                                            38751.0
# [READ].95thPercentileLatency(us)                                   716.0
# [READ].99thPercentileLatency(us)                                   990.0
# [READ].Return=OK                                                32000000
# [CLEANUP].Operations                                                  20
# [CLEANUP].AverageLatency(us)                                     1056.35
# [CLEANUP].MinLatency(us)                                            93.0
# [CLEANUP].MaxLatency(us)                                          2049.0
# [CLEANUP].95thPercentileLatency(us)                               1991.0
# [CLEANUP].99thPercentileLatency(us)                               2049.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-48-16  \
# connection                                    PostgreSQL-64-8-196608-1-48
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                 48
# pod                                               48295l4.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 8
# target                                                               9216
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1736411.0
# [OVERALL].Throughput(ops/sec)                                  9214.40834
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         257
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.014800643396062338
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              257
# [TOTAL_GC_TIME_%].Time(%)                            0.014800643396062338
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                       350.52595
# [READ].MinLatency(us)                                               163.0
# [READ].MaxLatency(us)                                             45695.0
# [READ].95thPercentileLatency(us)                                    601.0
# [READ].99thPercentileLatency(us)                                    863.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    8
# [CLEANUP].AverageLatency(us)                                       217.75
# [CLEANUP].MinLatency(us)                                             88.0
# [CLEANUP].MaxLatency(us)                                            780.0
# [CLEANUP].95thPercentileLatency(us)                                 780.0
# [CLEANUP].99thPercentileLatency(us)                                 780.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-199-8  \
# connection                                   PostgreSQL-64-8-196608-2-199
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          2
# client                                                                199
# pod                                               19mc24v.dbmsbenchmarker
# pod_count                                                               8
# threads                                                                12
# target                                                              28672
# sf                                                                     16
# workload                                                                c
# operations                                                       32000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1454721.0
# [OVERALL].Throughput(ops/sec)                                21997.345195
# [TOTAL_GCS_Copy].Count                                                130
# [TOTAL_GC_TIME_Copy].Time(ms)                                         294
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.020210060898275338
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                     130
# [TOTAL_GC_TIME].Time(ms)                                              294
# [TOTAL_GC_TIME_%].Time(%)                            0.020210060898275338
# [READ].Operations                                                32000000
# [READ].AverageLatency(us)                                      477.928169
# [READ].MinLatency(us)                                               143.0
# [READ].MaxLatency(us)                                             34687.0
# [READ].95thPercentileLatency(us)                                    778.0
# [READ].99thPercentileLatency(us)                                   1071.0
# [READ].Return=OK                                                 32000000
# [CLEANUP].Operations                                                   12
# [CLEANUP].AverageLatency(us)                                   288.666667
# [CLEANUP].MinLatency(us)                                            155.0
# [CLEANUP].MaxLatency(us)                                            912.0
# [CLEANUP].95thPercentileLatency(us)                                 601.0
# [CLEANUP].99thPercentileLatency(us)                                 912.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-138-1  \
# connection                                   PostgreSQL-64-8-196608-1-138
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                138
# pod                                               13kl5l4.dbmsbenchmarker
# pod_count                                                               1
# threads                                                               112
# target                                                             196608
# sf                                                                     16
# workload                                                                c
# operations                                                      256000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1332421.0
# [OVERALL].Throughput(ops/sec)                               192131.465956
# [TOTAL_GCS_Copy].Count                                               1055
# [TOTAL_GC_TIME_Copy].Time(ms)                                        2070
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.15535630255001986
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                    1055
# [TOTAL_GC_TIME].Time(ms)                                             2070
# [TOTAL_GC_TIME_%].Time(%)                             0.15535630255001986
# [READ].Operations                                               256000000
# [READ].AverageLatency(us)                                      463.232284
# [READ].MinLatency(us)                                               166.0
# [READ].MaxLatency(us)                                             91903.0
# [READ].95thPercentileLatency(us)                                    723.0
# [READ].99thPercentileLatency(us)                                    920.0
# [READ].Return=OK                                                256000000
# [CLEANUP].Operations                                                  112
# [CLEANUP].AverageLatency(us)                                   358.116071
# [CLEANUP].MinLatency(us)                                             73.0
# [CLEANUP].MaxLatency(us)                                           4195.0
# [CLEANUP].95thPercentileLatency(us)                                1093.0
# [CLEANUP].99thPercentileLatency(us)                                3783.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-16-16  \
# connection                                    PostgreSQL-64-8-196608-2-16
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          2
# client                                                                 16
# pod                                               16km225.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 8
# target                                                                  0
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1504269.0
# [OVERALL].Throughput(ops/sec)                                10636.395485
# [TOTAL_GCS_Copy].Count                                                 64
# [TOTAL_GC_TIME_Copy].Time(ms)                                         256
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.01701823277618564
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      64
# [TOTAL_GC_TIME].Time(ms)                                              256
# [TOTAL_GC_TIME_%].Time(%)                             0.01701823277618564
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                       691.25943
# [READ].MinLatency(us)                                               155.0
# [READ].MaxLatency(us)                                             38431.0
# [READ].95thPercentileLatency(us)                                   1088.0
# [READ].99thPercentileLatency(us)                                   1289.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    8
# [CLEANUP].AverageLatency(us)                                      462.375
# [CLEANUP].MinLatency(us)                                            154.0
# [CLEANUP].MaxLatency(us)                                           1077.0
# [CLEANUP].95thPercentileLatency(us)                                1077.0
# [CLEANUP].99thPercentileLatency(us)                                1077.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-172-16  \
# connection                                    PostgreSQL-64-8-196608-1-172
# configuration                                       PostgreSQL-64-8-196608
# experiment_run                                                           1
# client                                                                 172
# pod                                                17wr59m.dbmsbenchmarker
# pod_count                                                               16
# threads                                                                  7
# target                                                               13312
# sf                                                                      16
# workload                                                                 c
# operations                                                        16000000
# batchsize                                                               -1
# exceptions                                                               0
# [OVERALL].RunTime(ms)                                            1338836.0
# [OVERALL].Throughput(ops/sec)                                 11950.679546
# [TOTAL_GCS_Copy].Count                                                  64
# [TOTAL_GC_TIME_Copy].Time(ms)                                          231
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.017253793593838232
# [TOTAL_GCS_MarkSweepCompact].Count                                       0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                                0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                             0.0
# [TOTAL_GCs].Count                                                       64
# [TOTAL_GC_TIME].Time(ms)                                               231
# [TOTAL_GC_TIME_%].Time(%)                             0.017253793593838232
# [READ].Operations                                                 16000000
# [READ].AverageLatency(us)                                        473.78338
# [READ].MinLatency(us)                                                147.0
# [READ].MaxLatency(us)                                              43295.0
# [READ].95thPercentileLatency(us)                                     912.0
# [READ].99thPercentileLatency(us)                                    1415.0
# [READ].Return=OK                                                  16000000
# [CLEANUP].Operations                                                     7
# [CLEANUP].AverageLatency(us)                                         673.0
# [CLEANUP].MinLatency(us)                                             183.0
# [CLEANUP].MaxLatency(us)                                            1295.0
# [CLEANUP].95thPercentileLatency(us)                                 1295.0
# [CLEANUP].99thPercentileLatency(us)                                 1295.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-280-16  \
# connection                                    PostgreSQL-64-8-196608-1-280
# configuration                                       PostgreSQL-64-8-196608
# experiment_run                                                           1
# client                                                                 280
# pod                                                28qhbgw.dbmsbenchmarker
# pod_count                                                               16
# threads                                                                 10
# target                                                               16384
# sf                                                                      16
# workload                                                                 c
# operations                                                        16000000
# batchsize                                                               -1
# exceptions                                                               0
# [OVERALL].RunTime(ms)                                            1541951.0
# [OVERALL].Throughput(ops/sec)                                 10376.464622
# [TOTAL_GCS_Copy].Count                                                  65
# [TOTAL_GC_TIME_Copy].Time(ms)                                          293
# [TOTAL_GC_TIME_%_Copy].Time(%)                          0.0190019008386129
# [TOTAL_GCS_MarkSweepCompact].Count                                       0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                                0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                             0.0
# [TOTAL_GCs].Count                                                       65
# [TOTAL_GC_TIME].Time(ms)                                               293
# [TOTAL_GC_TIME_%].Time(%)                               0.0190019008386129
# [READ].Operations                                                 16000000
# [READ].AverageLatency(us)                                       899.469398
# [READ].MinLatency(us)                                                155.0
# [READ].MaxLatency(us)                                              35839.0
# [READ].95thPercentileLatency(us)                                    1488.0
# [READ].99thPercentileLatency(us)                                    1790.0
# [READ].Return=OK                                                  16000000
# [CLEANUP].Operations                                                    10
# [CLEANUP].AverageLatency(us)                                         399.9
# [CLEANUP].MinLatency(us)                                             185.0
# [CLEANUP].MaxLatency(us)                                            1290.0
# [CLEANUP].95thPercentileLatency(us)                                 1290.0
# [CLEANUP].99thPercentileLatency(us)                                 1290.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-219-8  \
# connection                                   PostgreSQL-64-8-196608-2-219
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          2
# client                                                                219
# pod                                               21lxkzd.dbmsbenchmarker
# pod_count                                                               8
# threads                                                                22
# target                                                              28672
# sf                                                                     16
# workload                                                                c
# operations                                                       32000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1486584.0
# [OVERALL].Throughput(ops/sec)                                21525.860631
# [TOTAL_GCS_Copy].Count                                                130
# [TOTAL_GC_TIME_Copy].Time(ms)                                         348
# [TOTAL_GC_TIME_%_Copy].Time(%)                        0.02340937343601169
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                     130
# [TOTAL_GC_TIME].Time(ms)                                              348
# [TOTAL_GC_TIME_%].Time(%)                             0.02340937343601169
# [READ].Operations                                                32000000
# [READ].AverageLatency(us)                                      918.260865
# [READ].MinLatency(us)                                               158.0
# [READ].MaxLatency(us)                                             41119.0
# [READ].95thPercentileLatency(us)                                   1415.0
# [READ].99thPercentileLatency(us)                                   1702.0
# [READ].Return=OK                                                 32000000
# [CLEANUP].Operations                                                   22
# [CLEANUP].AverageLatency(us)                                   316.136364
# [CLEANUP].MinLatency(us)                                            130.0
# [CLEANUP].MaxLatency(us)                                           1329.0
# [CLEANUP].95thPercentileLatency(us)                                 807.0
# [CLEANUP].99thPercentileLatency(us)                                1329.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-72-16
# connection                                    PostgreSQL-64-8-196608-1-72
# configuration                                      PostgreSQL-64-8-196608
# experiment_run                                                          1
# client                                                                 72
# pod                                               72nhhv5.dbmsbenchmarker
# pod_count                                                              16
# threads                                                                 6
# target                                                              10240
# sf                                                                     16
# workload                                                                c
# operations                                                       16000000
# batchsize                                                              -1
# exceptions                                                              0
# [OVERALL].RunTime(ms)                                           1562795.0
# [OVERALL].Throughput(ops/sec)                                10238.067053
# [TOTAL_GCS_Copy].Count                                                 65
# [TOTAL_GC_TIME_Copy].Time(ms)                                         232
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.014845197226763586
# [TOTAL_GCS_MarkSweepCompact].Count                                      0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                               0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                            0.0
# [TOTAL_GCs].Count                                                      65
# [TOTAL_GC_TIME].Time(ms)                                              232
# [TOTAL_GC_TIME_%].Time(%)                            0.014845197226763586
# [READ].Operations                                                16000000
# [READ].AverageLatency(us)                                      423.285821
# [READ].MinLatency(us)                                               157.0
# [READ].MaxLatency(us)                                             34847.0
# [READ].95thPercentileLatency(us)                                    800.0
# [READ].99thPercentileLatency(us)                                   1224.0
# [READ].Return=OK                                                 16000000
# [CLEANUP].Operations                                                    6
# [CLEANUP].AverageLatency(us)                                   956.166667
# [CLEANUP].MinLatency(us)                                            104.0
# [CLEANUP].MaxLatency(us)                                           1490.0
# [CLEANUP].95thPercentileLatency(us)                                1490.0
# [CLEANUP].99thPercentileLatency(us)                                1490.0
#
# [37 rows x 3744 columns]

# %%
df_aggregated = evaluation.benchmarking_aggregate_by_parallel_pods(df_benchmarks)
experiment_run = 2

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 1
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 8
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 16
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = 'current_ops_per_sec'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
#metric = 'current_ops_per_sec'
#plot_measures(metric, smoothing=0, preset_client=10)
#plot_measures(metric, smoothing=0, preset_client=11)
#plot_measures(metric, smoothing=0, preset_client=12)

# %%
metric = 'READ_Avg'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_99'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_Max'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_Min'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
#metric = 'UPDATE_99.9'
#plot_measures(metric, smoothing=0, preset_client=3)
#plot_measures(metric, smoothing=0, preset_client=4)

# %%
evaluation.transform_monitoring_results(component='stream')

evaluation.get_monitoring_metrics()
# Out:
# ['total_cpu_memory',
#  'total_cpu_memory_cached',
#  'total_cpu_util',
#  'total_cpu_util_max',
#  'total_cpu_throttled',
#  'total_cpu_util_others',
#  'total_cpu_util_s',
#  'total_cpu_util_user_s',
#  'total_cpu_util_sys_s',
#  'total_cpu_throttled_s',
#  'total_cpu_util_others_s',
#  'total_network_rx',
#  'total_network_tx',
#  'total_fs_read',
#  'total_fs_write',
#  'total_gpu_util',
#  'total_gpu_power',
#  'total_gpu_memory']

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)
