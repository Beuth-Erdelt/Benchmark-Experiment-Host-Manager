# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
cut_at = 0
def plot_measures(metric, smoothing=0, preset_experiment_run=0, preset_client=0):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        for experiment_run in list_experiment_runs:
            if preset_experiment_run > 0:
                if preset_experiment_run != experiment_run:
                    continue
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            if preset_client > 0:
                n_rows = 1
            else:
                n_rows = num_runs
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows), sharex=True)
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                if preset_client > 0:
                    if preset_client != client:
                        continue
                #################################
                # show plots with aggregated line
                #################################
                # filter data for this run
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]
                df_part = df_part[df_part['client'] == (client)]
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                # Weighted average: Multiply each value by its duration and sum
                weighted_sum = (df_total[metric].multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total[metric] = df_total[metric].rolling(window=smoothing, min_periods=1).mean()
                # optionally leave out data at the end (cool down)
                if cut_at > 0:
                    df_total = df_total[:-cut_at]
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                max_value = df_total[metric].max()
                print(max_value)
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
                ###############################
                # show plots with lines per pod
                ###############################
                df_list = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                # collect in one dataframe
                df_total = pd.DataFrame()
                j=1
                max_value = 0
                for df in df_list:
                    # optionally leave out data at the end (cool down)
                    if cut_at > 0:
                        df_tmp = df[metric][:-cut_at]
                    else:
                        df_tmp = df[metric]
                    df_single = pd.DataFrame(df_tmp)
                    if max_value < df_single[metric].max():
                        max_value = df_single[metric].max()
                    df_single.columns=["pod "+str(j)]
                    df_total = pd.merge(df_total, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                #print(df_combined)
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                weighted_sum = (df_total.multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time / len(df_list)
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total = df_total.rolling(window=smoothing, min_periods=1).mean()
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True, legend=False)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            plt.show()

def plot_heatmap(df_aggregated, metric, pod_count, experiment_run):
    #metric = '[OVERALL].Throughput(ops/sec)'
    #pod_count = 1
    #experiment_run = 1
    df_heatmap = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df_heatmap = df_heatmap[df_heatmap['pod_count'] == pod_count]
    df_heatmap = df_heatmap[df_heatmap['experiment_run'] == experiment_run]
    #print(df_heatmap)
    df_heatmap = df_heatmap.pivot(index='threads', columns='target', values=metric)
    display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))

# %%
code = "1737453595"
path = "D:\\data\\benchmarks-250126"
evaluation = evaluators.ycsb(code=code, path=path)

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-196608-40-1  \
# connection                                   PostgreSQL-64-8-196608-40
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              40
# pod                                            4099sgz.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             17
# target                                                           26624
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2763586.0
# [OVERALL].Throughput(ops/sec)                             23158.316767
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      519
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01877994750299068
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           519
# [TOTAL_GC_TIME_%].Time(%)                          0.01877994750299068
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   589.729218
# [READ].MinLatency(us)                                            159.0
# [READ].MaxLatency(us)                                          52639.0
# [READ].95thPercentileLatency(us)                                1120.0
# [READ].99thPercentileLatency(us)                                1441.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                17
# [CLEANUP].AverageLatency(us)                                721.588235
# [CLEANUP].MinLatency(us)                                         103.0
# [CLEANUP].MaxLatency(us)                                        1826.0
# [CLEANUP].95thPercentileLatency(us)                             1703.0
# [CLEANUP].99thPercentileLatency(us)                             1826.0
#
# connection_pod                             PostgreSQL-64-8-196608-30-1  \
# connection                                   PostgreSQL-64-8-196608-30
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              30
# pod                                            30vqvdw.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             17
# target                                                           24576
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2620747.0
# [OVERALL].Throughput(ops/sec)                             24420.518272
# [TOTAL_GCS_Copy].Count                                             257
# [TOTAL_GC_TIME_Copy].Time(ms)                                      475
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.018124603405059704
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  257
# [TOTAL_GC_TIME].Time(ms)                                           475
# [TOTAL_GC_TIME_%].Time(%)                         0.018124603405059704
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   503.789231
# [READ].MinLatency(us)                                            156.0
# [READ].MaxLatency(us)                                         205951.0
# [READ].95thPercentileLatency(us)                                 960.0
# [READ].99thPercentileLatency(us)                                1676.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                17
# [CLEANUP].AverageLatency(us)                                251.588235
# [CLEANUP].MinLatency(us)                                          90.0
# [CLEANUP].MaxLatency(us)                                         768.0
# [CLEANUP].95thPercentileLatency(us)                              761.0
# [CLEANUP].99thPercentileLatency(us)                              768.0
#
# connection_pod                             PostgreSQL-64-8-196608-16-1  \
# connection                                   PostgreSQL-64-8-196608-16
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              16
# pod                                            16jfr5n.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             15
# target                                                           22528
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2841167.0
# [OVERALL].Throughput(ops/sec)                             22525.955004
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      532
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.018724700096826412
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           532
# [TOTAL_GC_TIME_%].Time(%)                         0.018724700096826412
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   423.859407
# [READ].MinLatency(us)                                            166.0
# [READ].MaxLatency(us)                                          34079.0
# [READ].95thPercentileLatency(us)                                 818.0
# [READ].99thPercentileLatency(us)                                1361.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                15
# [CLEANUP].AverageLatency(us)                               1002.933333
# [CLEANUP].MinLatency(us)                                         101.0
# [CLEANUP].MaxLatency(us)                                        2949.0
# [CLEANUP].95thPercentileLatency(us)                             2631.0
# [CLEANUP].99thPercentileLatency(us)                             2949.0
#
# connection_pod                             PostgreSQL-64-8-196608-44-1  \
# connection                                   PostgreSQL-64-8-196608-44
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              44
# pod                                            44fkcc2.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             14
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2742137.0
# [OVERALL].Throughput(ops/sec)                             23339.461157
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      519
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01892684428239727
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           519
# [TOTAL_GC_TIME_%].Time(%)                          0.01892684428239727
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                    530.23476
# [READ].MinLatency(us)                                            153.0
# [READ].MaxLatency(us)                                          31503.0
# [READ].95thPercentileLatency(us)                                 881.0
# [READ].99thPercentileLatency(us)                                1159.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                14
# [CLEANUP].AverageLatency(us)                                482.928571
# [CLEANUP].MinLatency(us)                                         186.0
# [CLEANUP].MaxLatency(us)                                        1404.0
# [CLEANUP].95thPercentileLatency(us)                             1018.0
# [CLEANUP].99thPercentileLatency(us)                             1404.0
#
# connection_pod                             PostgreSQL-64-8-196608-46-1  \
# connection                                   PostgreSQL-64-8-196608-46
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              46
# pod                                            46nnc9k.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             15
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2850737.0
# [OVERALL].Throughput(ops/sec)                             22450.334773
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      411
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.014417324362086016
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           411
# [TOTAL_GC_TIME_%].Time(%)                         0.014417324362086016
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   535.146599
# [READ].MinLatency(us)                                            157.0
# [READ].MaxLatency(us)                                          32191.0
# [READ].95thPercentileLatency(us)                                 952.0
# [READ].99thPercentileLatency(us)                                1294.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                15
# [CLEANUP].AverageLatency(us)                                     279.2
# [CLEANUP].MinLatency(us)                                         102.0
# [CLEANUP].MaxLatency(us)                                        1016.0
# [CLEANUP].95thPercentileLatency(us)                              810.0
# [CLEANUP].99thPercentileLatency(us)                             1016.0
#
# connection_pod                             PostgreSQL-64-8-196608-38-1  \
# connection                                   PostgreSQL-64-8-196608-38
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              38
# pod                                            384v9nj.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             16
# target                                                           26624
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        3122760.0
# [OVERALL].Throughput(ops/sec)                             20494.690594
# [TOTAL_GCS_Copy].Count                                             261
# [TOTAL_GC_TIME_Copy].Time(ms)                                      505
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01617159179700009
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  261
# [TOTAL_GC_TIME].Time(ms)                                           505
# [TOTAL_GC_TIME_%].Time(%)                          0.01617159179700009
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   726.369947
# [READ].MinLatency(us)                                            155.0
# [READ].MaxLatency(us)                                          30607.0
# [READ].95thPercentileLatency(us)                                1118.0
# [READ].99thPercentileLatency(us)                                1327.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                16
# [CLEANUP].AverageLatency(us)                                    384.25
# [CLEANUP].MinLatency(us)                                         133.0
# [CLEANUP].MaxLatency(us)                                        1456.0
# [CLEANUP].95thPercentileLatency(us)                              836.0
# [CLEANUP].99thPercentileLatency(us)                             1456.0
#
# connection_pod                             PostgreSQL-64-8-196608-45-1  \
# connection                                   PostgreSQL-64-8-196608-45
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              45
# pod                                            459cq9l.dbmsbenchmarker
# pod_count                                                            1
# threads                                                            120
# target                                                          229376
# sf                                                                  16
# workload                                                             c
# operations                                                   512000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2744669.0
# [OVERALL].Throughput(ops/sec)                            186543.441122
# [TOTAL_GCS_Copy].Count                                            2109
# [TOTAL_GC_TIME_Copy].Time(ms)                                     5927
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.2159458936578509
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                 2109
# [TOTAL_GC_TIME].Time(ms)                                          5927
# [TOTAL_GC_TIME_%].Time(%)                           0.2159458936578509
# [READ].Operations                                            512000000
# [READ].AverageLatency(us)                                   547.919253
# [READ].MinLatency(us)                                            155.0
# [READ].MaxLatency(us)                                          64959.0
# [READ].95thPercentileLatency(us)                                 952.0
# [READ].99thPercentileLatency(us)                                1128.0
# [READ].Return=OK                                             512000000
# [CLEANUP].Operations                                               120
# [CLEANUP].AverageLatency(us)                                254.541667
# [CLEANUP].MinLatency(us)                                          93.0
# [CLEANUP].MaxLatency(us)                                        1588.0
# [CLEANUP].95thPercentileLatency(us)                              581.0
# [CLEANUP].99thPercentileLatency(us)                             1373.0
#
# connection_pod                             PostgreSQL-64-8-196608-42-1  \
# connection                                   PostgreSQL-64-8-196608-42
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              42
# pod                                            42lrkbf.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             13
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2430449.0
# [OVERALL].Throughput(ops/sec)                             26332.582992
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      484
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01991401588759937
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           484
# [TOTAL_GC_TIME_%].Time(%)                          0.01991401588759937
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   454.171305
# [READ].MinLatency(us)                                            154.0
# [READ].MaxLatency(us)                                          46975.0
# [READ].95thPercentileLatency(us)                                 830.0
# [READ].99thPercentileLatency(us)                                1396.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                13
# [CLEANUP].AverageLatency(us)                                371.769231
# [CLEANUP].MinLatency(us)                                         149.0
# [CLEANUP].MaxLatency(us)                                         910.0
# [CLEANUP].95thPercentileLatency(us)                              785.0
# [CLEANUP].99thPercentileLatency(us)                              910.0
#
# connection_pod                             PostgreSQL-64-8-196608-6-1  \
# connection                                   PostgreSQL-64-8-196608-6
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              6
# pod                                             kqd2k.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            15
# target                                                          20480
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       3125237.0
# [OVERALL].Throughput(ops/sec)                            20478.446915
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     459
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.014686886146554645
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          459
# [TOTAL_GC_TIME_%].Time(%)                        0.014686886146554645
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                   386.94605
# [READ].MinLatency(us)                                           169.0
# [READ].MaxLatency(us)                                         29599.0
# [READ].95thPercentileLatency(us)                                720.0
# [READ].99thPercentileLatency(us)                               1021.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               15
# [CLEANUP].AverageLatency(us)                               346.266667
# [CLEANUP].MinLatency(us)                                         90.0
# [CLEANUP].MaxLatency(us)                                       1045.0
# [CLEANUP].95thPercentileLatency(us)                             974.0
# [CLEANUP].99thPercentileLatency(us)                            1045.0
#
# connection_pod                             PostgreSQL-64-8-196608-28-1  ...  \
# connection                                   PostgreSQL-64-8-196608-28  ...
# configuration                                   PostgreSQL-64-8-196608  ...
# experiment_run                                                       1  ...
# client                                                              28  ...
# pod                                            28grn4v.dbmsbenchmarker  ...
# pod_count                                                            8  ...
# threads                                                             16  ...
# target                                                           24576  ...
# sf                                                                  16  ...
# workload                                                             c  ...
# operations                                                    64000000  ...
# batchsize                                                           -1  ...
# exceptions                                                           0  ...
# [OVERALL].RunTime(ms)                                        2746433.0  ...
# [OVERALL].Throughput(ops/sec)                             23302.953322  ...
# [TOTAL_GCS_Copy].Count                                             261  ...
# [TOTAL_GC_TIME_Copy].Time(ms)                                      536  ...
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01951622340686993  ...
# [TOTAL_GCS_MarkSweepCompact].Count                                   0  ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0  ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0  ...
# [TOTAL_GCs].Count                                                  261  ...
# [TOTAL_GC_TIME].Time(ms)                                           536  ...
# [TOTAL_GC_TIME_%].Time(%)                          0.01951622340686993  ...
# [READ].Operations                                             64000000  ...
# [READ].AverageLatency(us)                                   566.882983  ...
# [READ].MinLatency(us)                                            162.0  ...
# [READ].MaxLatency(us)                                          31727.0  ...
# [READ].95thPercentileLatency(us)                                 963.0  ...
# [READ].99thPercentileLatency(us)                                1231.0  ...
# [READ].Return=OK                                              64000000  ...
# [CLEANUP].Operations                                                16  ...
# [CLEANUP].AverageLatency(us)                                  396.3125  ...
# [CLEANUP].MinLatency(us)                                          95.0  ...
# [CLEANUP].MaxLatency(us)                                        1706.0  ...
# [CLEANUP].95thPercentileLatency(us)                              939.0  ...
# [CLEANUP].99thPercentileLatency(us)                             1706.0  ...
#
# connection_pod                             PostgreSQL-64-8-196608-24-8  \
# connection                                   PostgreSQL-64-8-196608-24
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              24
# pod                                            24tgd7g.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             14
# target                                                           24576
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2704442.0
# [OVERALL].Throughput(ops/sec)                             23664.770773
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      509
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01882088800573279
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           509
# [TOTAL_GC_TIME_%].Time(%)                          0.01882088800573279
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   496.643923
# [READ].MinLatency(us)                                            155.0
# [READ].MaxLatency(us)                                          31871.0
# [READ].95thPercentileLatency(us)                                 858.0
# [READ].99thPercentileLatency(us)                                1264.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                14
# [CLEANUP].AverageLatency(us)                                793.714286
# [CLEANUP].MinLatency(us)                                         147.0
# [CLEANUP].MaxLatency(us)                                        1367.0
# [CLEANUP].95thPercentileLatency(us)                             1261.0
# [CLEANUP].99thPercentileLatency(us)                             1367.0
#
# connection_pod                             PostgreSQL-64-8-196608-46-8  \
# connection                                   PostgreSQL-64-8-196608-46
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              46
# pod                                            469q67p.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             15
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2895365.0
# [OVERALL].Throughput(ops/sec)                             22104.294277
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      462
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01595653743137739
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           462
# [TOTAL_GC_TIME_%].Time(%)                          0.01595653743137739
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   547.243048
# [READ].MinLatency(us)                                            151.0
# [READ].MaxLatency(us)                                          38911.0
# [READ].95thPercentileLatency(us)                                 981.0
# [READ].99thPercentileLatency(us)                                1322.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                15
# [CLEANUP].AverageLatency(us)                                     427.4
# [CLEANUP].MinLatency(us)                                         154.0
# [CLEANUP].MaxLatency(us)                                        1349.0
# [CLEANUP].95thPercentileLatency(us)                             1339.0
# [CLEANUP].99thPercentileLatency(us)                             1349.0
#
# connection_pod                             PostgreSQL-64-8-196608-44-8  \
# connection                                   PostgreSQL-64-8-196608-44
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              44
# pod                                            44stk2s.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             14
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2738552.0
# [OVERALL].Throughput(ops/sec)                             23370.014519
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      427
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.015592181561642793
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           427
# [TOTAL_GC_TIME_%].Time(%)                         0.015592181561642793
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   506.188902
# [READ].MinLatency(us)                                            156.0
# [READ].MaxLatency(us)                                          29007.0
# [READ].95thPercentileLatency(us)                                 861.0
# [READ].99thPercentileLatency(us)                                1179.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                14
# [CLEANUP].AverageLatency(us)                                     384.0
# [CLEANUP].MinLatency(us)                                         121.0
# [CLEANUP].MaxLatency(us)                                        1011.0
# [CLEANUP].95thPercentileLatency(us)                              984.0
# [CLEANUP].99thPercentileLatency(us)                             1011.0
#
# connection_pod                             PostgreSQL-64-8-196608-6-8  \
# connection                                   PostgreSQL-64-8-196608-6
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              6
# pod                                             sdf8t.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            15
# target                                                          20480
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       3125245.0
# [OVERALL].Throughput(ops/sec)                            20478.394494
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     537
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.017182652880014207
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          537
# [TOTAL_GC_TIME_%].Time(%)                        0.017182652880014207
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  384.551237
# [READ].MinLatency(us)                                           171.0
# [READ].MaxLatency(us)                                         28671.0
# [READ].95thPercentileLatency(us)                                670.0
# [READ].99thPercentileLatency(us)                                906.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               15
# [CLEANUP].AverageLatency(us)                              1053.933333
# [CLEANUP].MinLatency(us)                                        110.0
# [CLEANUP].MaxLatency(us)                                       2071.0
# [CLEANUP].95thPercentileLatency(us)                            2027.0
# [CLEANUP].99thPercentileLatency(us)                            2071.0
#
# connection_pod                             PostgreSQL-64-8-196608-26-8  \
# connection                                   PostgreSQL-64-8-196608-26
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              26
# pod                                            26kcr4z.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             15
# target                                                           24576
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2807040.0
# [OVERALL].Throughput(ops/sec)                             22799.817601
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      512
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01823985408116735
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           512
# [TOTAL_GC_TIME_%].Time(%)                          0.01823985408116735
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   593.038928
# [READ].MinLatency(us)                                            156.0
# [READ].MaxLatency(us)                                          36447.0
# [READ].95thPercentileLatency(us)                                 945.0
# [READ].99thPercentileLatency(us)                                1159.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                15
# [CLEANUP].AverageLatency(us)                                     358.2
# [CLEANUP].MinLatency(us)                                         143.0
# [CLEANUP].MaxLatency(us)                                        1431.0
# [CLEANUP].95thPercentileLatency(us)                             1154.0
# [CLEANUP].99thPercentileLatency(us)                             1431.0
#
# connection_pod                             PostgreSQL-64-8-196608-4-8  \
# connection                                   PostgreSQL-64-8-196608-4
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              4
# pod                                             gvspc.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            14
# target                                                          20480
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       3125256.0
# [OVERALL].Throughput(ops/sec)                            20478.322416
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     546
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.017470568811003003
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          546
# [TOTAL_GC_TIME_%].Time(%)                        0.017470568811003003
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  358.520459
# [READ].MinLatency(us)                                           167.0
# [READ].MaxLatency(us)                                         31055.0
# [READ].95thPercentileLatency(us)                                670.0
# [READ].99thPercentileLatency(us)                                950.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               14
# [CLEANUP].AverageLatency(us)                                   1238.5
# [CLEANUP].MinLatency(us)                                         82.0
# [CLEANUP].MaxLatency(us)                                       2217.0
# [CLEANUP].95thPercentileLatency(us)                            2149.0
# [CLEANUP].99thPercentileLatency(us)                            2217.0
#
# connection_pod                             PostgreSQL-64-8-196608-14-8  \
# connection                                   PostgreSQL-64-8-196608-14
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              14
# pod                                            14549z6.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             14
# target                                                           22528
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2880665.0
# [OVERALL].Throughput(ops/sec)                             22217.092234
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      475
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.016489248142356017
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           475
# [TOTAL_GC_TIME_%].Time(%)                         0.016489248142356017
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   443.111299
# [READ].MinLatency(us)                                            161.0
# [READ].MaxLatency(us)                                          26991.0
# [READ].95thPercentileLatency(us)                                 783.0
# [READ].99thPercentileLatency(us)                                1113.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                14
# [CLEANUP].AverageLatency(us)                                623.357143
# [CLEANUP].MinLatency(us)                                          84.0
# [CLEANUP].MaxLatency(us)                                        1462.0
# [CLEANUP].95thPercentileLatency(us)                             1398.0
# [CLEANUP].99thPercentileLatency(us)                             1462.0
#
# connection_pod                             PostgreSQL-64-8-196608-12-8  \
# connection                                   PostgreSQL-64-8-196608-12
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              12
# pod                                            126jdbx.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             13
# target                                                           22528
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2842859.0
# [OVERALL].Throughput(ops/sec)                             22512.548107
# [TOTAL_GCS_Copy].Count                                             256
# [TOTAL_GC_TIME_Copy].Time(ms)                                      495
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.017412048926802207
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  256
# [TOTAL_GC_TIME].Time(ms)                                           495
# [TOTAL_GC_TIME_%].Time(%)                         0.017412048926802207
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   445.324988
# [READ].MinLatency(us)                                            168.0
# [READ].MaxLatency(us)                                          27551.0
# [READ].95thPercentileLatency(us)                                 806.0
# [READ].99thPercentileLatency(us)                                1199.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                13
# [CLEANUP].AverageLatency(us)                                344.307692
# [CLEANUP].MinLatency(us)                                         103.0
# [CLEANUP].MaxLatency(us)                                        1160.0
# [CLEANUP].95thPercentileLatency(us)                              865.0
# [CLEANUP].99thPercentileLatency(us)                             1160.0
#
# connection_pod                             PostgreSQL-64-8-196608-34-8  \
# connection                                   PostgreSQL-64-8-196608-34
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              34
# pod                                            34mpgcg.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             14
# target                                                           26624
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2796763.0
# [OVERALL].Throughput(ops/sec)                             22883.597931
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      473
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01691240909580111
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           473
# [TOTAL_GC_TIME_%].Time(%)                          0.01691240909580111
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   467.322372
# [READ].MinLatency(us)                                            157.0
# [READ].MaxLatency(us)                                          39199.0
# [READ].95thPercentileLatency(us)                                 809.0
# [READ].99thPercentileLatency(us)                                1209.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                14
# [CLEANUP].AverageLatency(us)                                     313.0
# [CLEANUP].MinLatency(us)                                          89.0
# [CLEANUP].MaxLatency(us)                                         830.0
# [CLEANUP].95thPercentileLatency(us)                              830.0
# [CLEANUP].99thPercentileLatency(us)                              887.0
#
# connection_pod                             PostgreSQL-64-8-196608-42-8
# connection                                   PostgreSQL-64-8-196608-42
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              42
# pod                                            42wxgk6.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             13
# target                                                           28672
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2434077.0
# [OVERALL].Throughput(ops/sec)                             26293.334188
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      439
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01803558391948981
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           439
# [TOTAL_GC_TIME_%].Time(%)                          0.01803558391948981
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   461.807303
# [READ].MinLatency(us)                                            155.0
# [READ].MaxLatency(us)                                          49471.0
# [READ].95thPercentileLatency(us)                                 834.0
# [READ].99thPercentileLatency(us)                                1338.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                13
# [CLEANUP].AverageLatency(us)                                     362.0
# [CLEANUP].MinLatency(us)                                         146.0
# [CLEANUP].MaxLatency(us)                                         865.0
# [CLEANUP].95thPercentileLatency(us)                              787.0
# [CLEANUP].99thPercentileLatency(us)                              865.0
#
# [37 rows x 225 columns]

# %%
df_aggregated = evaluation.benchmarking_aggregate_by_parallel_pods(df_benchmarks)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_d2d6f_row0_col0, #T_d2d6f_row1_col0, #T_d2d6f_row2_col0, #T_d2d6f_row4_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_d2d6f_row0_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_d2d6f_row0_col2 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_d2d6f_row0_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_d2d6f_row0_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_d2d6f_row1_col1 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_d2d6f_row1_col2 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_d2d6f_row1_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_d2d6f_row1_col4 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_d2d6f_row2_col1, #T_d2d6f_row3_col1, #T_d2d6f_row4_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_d2d6f_row2_col2 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_d2d6f_row2_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_d2d6f_row2_col4, #T_d2d6f_row3_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_d2d6f_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d2d6f_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d2d6f_row3_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_d2d6f_row4_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_d2d6f_row4_col3 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_d2d6f_row4_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# </style>
# <table id="T_d2d6f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_d2d6f_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_d2d6f_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_d2d6f_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_d2d6f_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_d2d6f_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2d6f_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_d2d6f_row0_col0" class="data row0 col0" >163812.689148</td>
#       <td id="T_d2d6f_row0_col1" class="data row0 col1" >176137.254956</td>
#       <td id="T_d2d6f_row0_col2" class="data row0 col2" >190515.526829</td>
#       <td id="T_d2d6f_row0_col3" class="data row0 col3" >172278.852165</td>
#       <td id="T_d2d6f_row0_col4" class="data row0 col4" >175055.183411</td>
#     </tr>
#     <tr>
#       <th id="T_d2d6f_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_d2d6f_row1_col0" class="data row1 col0" >163813.475322</td>
#       <td id="T_d2d6f_row1_col1" class="data row1 col1" >174579.219754</td>
#       <td id="T_d2d6f_row1_col2" class="data row1 col2" >188304.662232</td>
#       <td id="T_d2d6f_row1_col3" class="data row1 col3" >182269.454060</td>
#       <td id="T_d2d6f_row1_col4" class="data row1 col4" >167778.197223</td>
#     </tr>
#     <tr>
#       <th id="T_d2d6f_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_d2d6f_row2_col0" class="data row2 col0" >163817.301475</td>
#       <td id="T_d2d6f_row2_col1" class="data row2 col1" >180187.979702</td>
#       <td id="T_d2d6f_row2_col2" class="data row2 col2" >190206.377635</td>
#       <td id="T_d2d6f_row2_col3" class="data row2 col3" >190907.152008</td>
#       <td id="T_d2d6f_row2_col4" class="data row2 col4" >186543.441122</td>
#     </tr>
#     <tr>
#       <th id="T_d2d6f_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_d2d6f_row3_col0" class="data row3 col0" >161557.770313</td>
#       <td id="T_d2d6f_row3_col1" class="data row3 col1" >180188.867495</td>
#       <td id="T_d2d6f_row3_col2" class="data row3 col2" >196571.214449</td>
#       <td id="T_d2d6f_row3_col3" class="data row3 col3" >186548.334783</td>
#       <td id="T_d2d6f_row3_col4" class="data row3 col4" >173774.389931</td>
#     </tr>
#     <tr>
#       <th id="T_d2d6f_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_d2d6f_row4_col0" class="data row4 col0" >163812.793971</td>
#       <td id="T_d2d6f_row4_col1" class="data row4 col1" >180188.423598</td>
#       <td id="T_d2d6f_row4_col2" class="data row4 col2" >188880.473706</td>
#       <td id="T_d2d6f_row4_col3" class="data row4 col3" >186605.446474</td>
#       <td id="T_d2d6f_row4_col4" class="data row4 col4" >165483.181802</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_fb230_row0_col0, #T_fb230_row1_col0, #T_fb230_row2_col0, #T_fb230_row3_col0, #T_fb230_row3_col3, #T_fb230_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fb230_row0_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_fb230_row0_col2, #T_fb230_row2_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_fb230_row0_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_fb230_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fb230_row1_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_fb230_row1_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_fb230_row1_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_fb230_row1_col4 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_fb230_row2_col1, #T_fb230_row3_col1, #T_fb230_row4_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_fb230_row2_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_fb230_row2_col4 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_fb230_row3_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_fb230_row3_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_fb230_row4_col2 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_fb230_row4_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_fb230_row4_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# </style>
# <table id="T_fb230">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_fb230_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_fb230_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_fb230_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_fb230_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_fb230_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb230_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_fb230_row0_col0" class="data row0 col0" >163826.782459</td>
#       <td id="T_fb230_row0_col1" class="data row0 col1" >180048.040791</td>
#       <td id="T_fb230_row0_col2" class="data row0 col2" >182553.200580</td>
#       <td id="T_fb230_row0_col3" class="data row0 col3" >181985.062956</td>
#       <td id="T_fb230_row0_col4" class="data row0 col4" >209561.037422</td>
#     </tr>
#     <tr>
#       <th id="T_fb230_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_fb230_row1_col0" class="data row1 col0" >163826.009272</td>
#       <td id="T_fb230_row1_col1" class="data row1 col1" >177463.311391</td>
#       <td id="T_fb230_row1_col2" class="data row1 col2" >190382.903016</td>
#       <td id="T_fb230_row1_col3" class="data row1 col3" >179338.961808</td>
#       <td id="T_fb230_row1_col4" class="data row1 col4" >187566.852246</td>
#     </tr>
#     <tr>
#       <th id="T_fb230_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_fb230_row2_col0" class="data row2 col0" >163826.985586</td>
#       <td id="T_fb230_row2_col1" class="data row2 col1" >180207.045412</td>
#       <td id="T_fb230_row2_col2" class="data row2 col2" >182408.029545</td>
#       <td id="T_fb230_row2_col3" class="data row2 col3" >181322.679101</td>
#       <td id="T_fb230_row2_col4" class="data row2 col4" >178064.512465</td>
#     </tr>
#     <tr>
#       <th id="T_fb230_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_fb230_row3_col0" class="data row3 col0" >163823.021543</td>
#       <td id="T_fb230_row3_col1" class="data row3 col1" >180204.968247</td>
#       <td id="T_fb230_row3_col2" class="data row3 col2" >187009.006350</td>
#       <td id="T_fb230_row3_col3" class="data row3 col3" >163843.025793</td>
#       <td id="T_fb230_row3_col4" class="data row3 col4" >172328.263504</td>
#     </tr>
#     <tr>
#       <th id="T_fb230_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_fb230_row4_col0" class="data row4 col0" >163825.753714</td>
#       <td id="T_fb230_row4_col1" class="data row4 col1" >180205.705559</td>
#       <td id="T_fb230_row4_col2" class="data row4 col2" >195129.884680</td>
#       <td id="T_fb230_row4_col3" class="data row4 col3" >185276.038700</td>
#       <td id="T_fb230_row4_col4" class="data row4 col4" >185605.774533</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_e3e59_row0_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_e3e59_row0_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_e3e59_row0_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_e3e59_row0_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_e3e59_row0_col4 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_e3e59_row1_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e3e59_row1_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_e3e59_row1_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_e3e59_row1_col3 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_e3e59_row1_col4 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_e3e59_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e3e59_row2_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_e3e59_row2_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_e3e59_row2_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_e3e59_row2_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_e3e59_row3_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_e3e59_row3_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_e3e59_row3_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e3e59_row3_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_e3e59_row3_col4 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_e3e59_row4_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_e3e59_row4_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_e3e59_row4_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_e3e59_row4_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_e3e59_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e3e59">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_e3e59_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_e3e59_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_e3e59_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_e3e59_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_e3e59_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3e59_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_e3e59_row0_col0" class="data row0 col0" >336.021366</td>
#       <td id="T_e3e59_row0_col1" class="data row0 col1" >403.887559</td>
#       <td id="T_e3e59_row0_col2" class="data row0 col2" >441.814624</td>
#       <td id="T_e3e59_row0_col3" class="data row0 col3" >462.541097</td>
#       <td id="T_e3e59_row0_col4" class="data row0 col4" >501.079682</td>
#     </tr>
#     <tr>
#       <th id="T_e3e59_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_e3e59_row1_col0" class="data row1 col0" >295.323180</td>
#       <td id="T_e3e59_row1_col1" class="data row1 col1" >421.548489</td>
#       <td id="T_e3e59_row1_col2" class="data row1 col2" >484.056472</td>
#       <td id="T_e3e59_row1_col3" class="data row1 col3" >523.631618</td>
#       <td id="T_e3e59_row1_col4" class="data row1 col4" >563.913956</td>
#     </tr>
#     <tr>
#       <th id="T_e3e59_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_e3e59_row2_col0" class="data row2 col0" >277.890491</td>
#       <td id="T_e3e59_row2_col1" class="data row2 col1" >359.318789</td>
#       <td id="T_e3e59_row2_col2" class="data row2 col2" >451.711333</td>
#       <td id="T_e3e59_row2_col3" class="data row2 col3" >506.509129</td>
#       <td id="T_e3e59_row2_col4" class="data row2 col4" >547.919253</td>
#     </tr>
#     <tr>
#       <th id="T_e3e59_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_e3e59_row3_col0" class="data row3 col0" >320.942369</td>
#       <td id="T_e3e59_row3_col1" class="data row3 col1" >311.011567</td>
#       <td id="T_e3e59_row3_col2" class="data row3 col2" >466.712642</td>
#       <td id="T_e3e59_row3_col3" class="data row3 col3" >511.809158</td>
#       <td id="T_e3e59_row3_col4" class="data row3 col4" >667.874081</td>
#     </tr>
#     <tr>
#       <th id="T_e3e59_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_e3e59_row4_col0" class="data row4 col0" >304.991314</td>
#       <td id="T_e3e59_row4_col1" class="data row4 col1" >349.191796</td>
#       <td id="T_e3e59_row4_col2" class="data row4 col2" >594.019796</td>
#       <td id="T_e3e59_row4_col3" class="data row4 col3" >585.942298</td>
#       <td id="T_e3e59_row4_col4" class="data row4 col4" >719.425321</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_abf98_row0_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_abf98_row0_col1, #T_abf98_row4_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_abf98_row0_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_abf98_row0_col3, #T_abf98_row1_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_abf98_row0_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_abf98_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_abf98_row1_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_abf98_row1_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_abf98_row1_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_abf98_row2_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_abf98_row2_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_abf98_row2_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_abf98_row2_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_abf98_row2_col4 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_abf98_row3_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_abf98_row3_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_abf98_row3_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_abf98_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_abf98_row3_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_abf98_row4_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_abf98_row4_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_abf98_row4_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_abf98_row4_col4 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_abf98">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_abf98_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_abf98_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_abf98_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_abf98_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_abf98_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abf98_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_abf98_row0_col0" class="data row0 col0" >364.883933</td>
#       <td id="T_abf98_row0_col1" class="data row0 col1" >438.766119</td>
#       <td id="T_abf98_row0_col2" class="data row0 col2" >483.365148</td>
#       <td id="T_abf98_row0_col3" class="data row0 col3" >491.463420</td>
#       <td id="T_abf98_row0_col4" class="data row0 col4" >461.772299</td>
#     </tr>
#     <tr>
#       <th id="T_abf98_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_abf98_row1_col0" class="data row1 col0" >358.155950</td>
#       <td id="T_abf98_row1_col1" class="data row1 col1" >472.156995</td>
#       <td id="T_abf98_row1_col2" class="data row1 col2" >496.266044</td>
#       <td id="T_abf98_row1_col3" class="data row1 col3" >491.190559</td>
#       <td id="T_abf98_row1_col4" class="data row1 col4" >509.115113</td>
#     </tr>
#     <tr>
#       <th id="T_abf98_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_abf98_row2_col0" class="data row2 col0" >381.762125</td>
#       <td id="T_abf98_row2_col1" class="data row2 col1" >410.417411</td>
#       <td id="T_abf98_row2_col2" class="data row2 col2" >554.230801</td>
#       <td id="T_abf98_row2_col3" class="data row2 col3" >522.445026</td>
#       <td id="T_abf98_row2_col4" class="data row2 col4" >542.521738</td>
#     </tr>
#     <tr>
#       <th id="T_abf98_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_abf98_row3_col0" class="data row3 col0" >512.472296</td>
#       <td id="T_abf98_row3_col1" class="data row3 col1" >425.485452</td>
#       <td id="T_abf98_row3_col2" class="data row3 col2" >568.360720</td>
#       <td id="T_abf98_row3_col3" class="data row3 col3" >710.030374</td>
#       <td id="T_abf98_row3_col4" class="data row3 col4" >584.239583</td>
#     </tr>
#     <tr>
#       <th id="T_abf98_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_abf98_row4_col0" class="data row4 col0" >374.595678</td>
#       <td id="T_abf98_row4_col1" class="data row4 col1" >438.302840</td>
#       <td id="T_abf98_row4_col2" class="data row4 col2" >530.545805</td>
#       <td id="T_abf98_row4_col3" class="data row4 col3" >583.264496</td>
#       <td id="T_abf98_row4_col4" class="data row4 col4" >638.263494</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_483b0_row0_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_483b0_row0_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_483b0_row0_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_483b0_row0_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_483b0_row0_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_483b0_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_483b0_row1_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_483b0_row1_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_483b0_row1_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_483b0_row1_col4 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_483b0_row2_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_483b0_row2_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_483b0_row2_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_483b0_row2_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_483b0_row2_col4, #T_483b0_row4_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_483b0_row3_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_483b0_row3_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_483b0_row3_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_483b0_row3_col3 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_483b0_row3_col4 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_483b0_row4_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_483b0_row4_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_483b0_row4_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_483b0_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_483b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_483b0_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_483b0_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_483b0_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_483b0_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_483b0_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_483b0_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_483b0_row0_col0" class="data row0 col0" >700.000000</td>
#       <td id="T_483b0_row0_col1" class="data row0 col1" >936.000000</td>
#       <td id="T_483b0_row0_col2" class="data row0 col2" >988.000000</td>
#       <td id="T_483b0_row0_col3" class="data row0 col3" >1053.000000</td>
#       <td id="T_483b0_row0_col4" class="data row0 col4" >1015.000000</td>
#     </tr>
#     <tr>
#       <th id="T_483b0_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_483b0_row1_col0" class="data row1 col0" >606.000000</td>
#       <td id="T_483b0_row1_col1" class="data row1 col1" >861.000000</td>
#       <td id="T_483b0_row1_col2" class="data row1 col2" >1028.000000</td>
#       <td id="T_483b0_row1_col3" class="data row1 col3" >1018.000000</td>
#       <td id="T_483b0_row1_col4" class="data row1 col4" >1196.000000</td>
#     </tr>
#     <tr>
#       <th id="T_483b0_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_483b0_row2_col0" class="data row2 col0" >640.000000</td>
#       <td id="T_483b0_row2_col1" class="data row2 col1" >831.000000</td>
#       <td id="T_483b0_row2_col2" class="data row2 col2" >967.000000</td>
#       <td id="T_483b0_row2_col3" class="data row2 col3" >1073.000000</td>
#       <td id="T_483b0_row2_col4" class="data row2 col4" >1128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_483b0_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_483b0_row3_col0" class="data row3 col0" >981.000000</td>
#       <td id="T_483b0_row3_col1" class="data row3 col1" >832.000000</td>
#       <td id="T_483b0_row3_col2" class="data row3 col2" >1120.000000</td>
#       <td id="T_483b0_row3_col3" class="data row3 col3" >1216.000000</td>
#       <td id="T_483b0_row3_col4" class="data row3 col4" >1174.000000</td>
#     </tr>
#     <tr>
#       <th id="T_483b0_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_483b0_row4_col0" class="data row4 col0" >692.000000</td>
#       <td id="T_483b0_row4_col1" class="data row4 col1" >823.000000</td>
#       <td id="T_483b0_row4_col2" class="data row4 col2" >1130.000000</td>
#       <td id="T_483b0_row4_col3" class="data row4 col3" >1199.000000</td>
#       <td id="T_483b0_row4_col4" class="data row4 col4" >1468.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_ed053_row0_col0, #T_ed053_row2_col0, #T_ed053_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ed053_row0_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_ed053_row0_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_ed053_row0_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ed053_row0_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_ed053_row1_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ed053_row1_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_ed053_row1_col2, #T_ed053_row4_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_ed053_row1_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_ed053_row1_col4, #T_ed053_row3_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_ed053_row2_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_ed053_row2_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_ed053_row2_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_ed053_row2_col4, #T_ed053_row3_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_ed053_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ed053_row3_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_ed053_row3_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_ed053_row4_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_ed053_row4_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_ed053_row4_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_ed053">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_ed053_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_ed053_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_ed053_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_ed053_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_ed053_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed053_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_ed053_row0_col0" class="data row0 col0" >1024.000000</td>
#       <td id="T_ed053_row0_col1" class="data row0 col1" >1231.000000</td>
#       <td id="T_ed053_row0_col2" class="data row0 col2" >1133.000000</td>
#       <td id="T_ed053_row0_col3" class="data row0 col3" >1064.000000</td>
#       <td id="T_ed053_row0_col4" class="data row0 col4" >1396.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed053_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_ed053_row1_col0" class="data row1 col0" >1034.000000</td>
#       <td id="T_ed053_row1_col1" class="data row1 col1" >1167.000000</td>
#       <td id="T_ed053_row1_col2" class="data row1 col2" >1324.000000</td>
#       <td id="T_ed053_row1_col3" class="data row1 col3" >1465.000000</td>
#       <td id="T_ed053_row1_col4" class="data row1 col4" >1296.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed053_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_ed053_row2_col0" class="data row2 col0" >1021.000000</td>
#       <td id="T_ed053_row2_col1" class="data row2 col1" >1458.000000</td>
#       <td id="T_ed053_row2_col2" class="data row2 col2" >1205.000000</td>
#       <td id="T_ed053_row2_col3" class="data row2 col3" >1337.000000</td>
#       <td id="T_ed053_row2_col4" class="data row2 col4" >1385.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed053_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_ed053_row3_col0" class="data row3 col0" >3901.000000</td>
#       <td id="T_ed053_row3_col1" class="data row3 col1" >1381.000000</td>
#       <td id="T_ed053_row3_col2" class="data row3 col2" >1292.000000</td>
#       <td id="T_ed053_row3_col3" class="data row3 col3" >1349.000000</td>
#       <td id="T_ed053_row3_col4" class="data row3 col4" >1508.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed053_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_ed053_row4_col0" class="data row4 col0" >1020.000000</td>
#       <td id="T_ed053_row4_col1" class="data row4 col1" >1440.000000</td>
#       <td id="T_ed053_row4_col2" class="data row4 col2" >1686.000000</td>
#       <td id="T_ed053_row4_col3" class="data row4 col3" >1497.000000</td>
#       <td id="T_ed053_row4_col4" class="data row4 col4" >1325.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_f3df6_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f3df6_row0_col1, #T_f3df6_row0_col2, #T_f3df6_row0_col3, #T_f3df6_row1_col0, #T_f3df6_row1_col1, #T_f3df6_row1_col3, #T_f3df6_row1_col4, #T_f3df6_row2_col0, #T_f3df6_row2_col1, #T_f3df6_row2_col2, #T_f3df6_row2_col3, #T_f3df6_row2_col4, #T_f3df6_row3_col1, #T_f3df6_row3_col2, #T_f3df6_row3_col3, #T_f3df6_row4_col1, #T_f3df6_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f3df6_row0_col4, #T_f3df6_row3_col4, #T_f3df6_row4_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f3df6_row1_col2, #T_f3df6_row3_col0, #T_f3df6_row4_col4 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f3df6_row4_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_f3df6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_f3df6_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_f3df6_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_f3df6_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_f3df6_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_f3df6_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3df6_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_f3df6_row0_col0" class="data row0 col0" >7053311.000000</td>
#       <td id="T_f3df6_row0_col1" class="data row0 col1" >53727.000000</td>
#       <td id="T_f3df6_row0_col2" class="data row0 col2" >42207.000000</td>
#       <td id="T_f3df6_row0_col3" class="data row0 col3" >47519.000000</td>
#       <td id="T_f3df6_row0_col4" class="data row0 col4" >206079.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3df6_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_f3df6_row1_col0" class="data row1 col0" >64735.000000</td>
#       <td id="T_f3df6_row1_col1" class="data row1 col1" >47391.000000</td>
#       <td id="T_f3df6_row1_col2" class="data row1 col2" >207871.000000</td>
#       <td id="T_f3df6_row1_col3" class="data row1 col3" >60127.000000</td>
#       <td id="T_f3df6_row1_col4" class="data row1 col4" >50463.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3df6_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_f3df6_row2_col0" class="data row2 col0" >47679.000000</td>
#       <td id="T_f3df6_row2_col1" class="data row2 col1" >52191.000000</td>
#       <td id="T_f3df6_row2_col2" class="data row2 col2" >51487.000000</td>
#       <td id="T_f3df6_row2_col3" class="data row2 col3" >49855.000000</td>
#       <td id="T_f3df6_row2_col4" class="data row2 col4" >64959.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3df6_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_f3df6_row3_col0" class="data row3 col0" >209151.000000</td>
#       <td id="T_f3df6_row3_col1" class="data row3 col1" >48799.000000</td>
#       <td id="T_f3df6_row3_col2" class="data row3 col2" >54271.000000</td>
#       <td id="T_f3df6_row3_col3" class="data row3 col3" >52511.000000</td>
#       <td id="T_f3df6_row3_col4" class="data row3 col4" >206335.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3df6_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_f3df6_row4_col0" class="data row4 col0" >71103.000000</td>
#       <td id="T_f3df6_row4_col1" class="data row4 col1" >56415.000000</td>
#       <td id="T_f3df6_row4_col2" class="data row4 col2" >54847.000000</td>
#       <td id="T_f3df6_row4_col3" class="data row4 col3" >206335.000000</td>
#       <td id="T_f3df6_row4_col4" class="data row4 col4" >211711.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_8711f_row0_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8711f_row0_col1, #T_8711f_row1_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8711f_row0_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8711f_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8711f_row0_col4, #T_8711f_row3_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_8711f_row1_col0 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_8711f_row1_col1, #T_8711f_row4_col0, #T_8711f_row4_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_8711f_row1_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8711f_row1_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_8711f_row2_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8711f_row2_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8711f_row2_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_8711f_row2_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_8711f_row2_col4 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_8711f_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8711f_row3_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8711f_row3_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_8711f_row3_col4 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_8711f_row4_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_8711f_row4_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_8711f_row4_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_8711f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_8711f_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_8711f_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_8711f_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_8711f_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_8711f_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8711f_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_8711f_row0_col0" class="data row0 col0" >46751.000000</td>
#       <td id="T_8711f_row0_col1" class="data row0 col1" >33567.000000</td>
#       <td id="T_8711f_row0_col2" class="data row0 col2" >41119.000000</td>
#       <td id="T_8711f_row0_col3" class="data row0 col3" >32015.000000</td>
#       <td id="T_8711f_row0_col4" class="data row0 col4" >207103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8711f_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_8711f_row1_col0" class="data row1 col0" >205695.000000</td>
#       <td id="T_8711f_row1_col1" class="data row1 col1" >37311.000000</td>
#       <td id="T_8711f_row1_col2" class="data row1 col2" >39391.000000</td>
#       <td id="T_8711f_row1_col3" class="data row1 col3" >67199.000000</td>
#       <td id="T_8711f_row1_col4" class="data row1 col4" >34143.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8711f_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_8711f_row2_col0" class="data row2 col0" >32959.000000</td>
#       <td id="T_8711f_row2_col1" class="data row2 col1" >43967.000000</td>
#       <td id="T_8711f_row2_col2" class="data row2 col2" >69695.000000</td>
#       <td id="T_8711f_row2_col3" class="data row2 col3" >38751.000000</td>
#       <td id="T_8711f_row2_col4" class="data row2 col4" >41823.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8711f_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_8711f_row3_col0" class="data row3 col0" >213759.000000</td>
#       <td id="T_8711f_row3_col1" class="data row3 col1" >38143.000000</td>
#       <td id="T_8711f_row3_col2" class="data row3 col2" >208255.000000</td>
#       <td id="T_8711f_row3_col3" class="data row3 col3" >207359.000000</td>
#       <td id="T_8711f_row3_col4" class="data row3 col4" >209407.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8711f_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_8711f_row4_col0" class="data row4 col0" >37023.000000</td>
#       <td id="T_8711f_row4_col1" class="data row4 col1" >61439.000000</td>
#       <td id="T_8711f_row4_col2" class="data row4 col2" >205951.000000</td>
#       <td id="T_8711f_row4_col3" class="data row4 col3" >54559.000000</td>
#       <td id="T_8711f_row4_col4" class="data row4 col4" >37631.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MinLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_4aa90_row0_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_4aa90_row0_col1, #T_4aa90_row1_col2, #T_4aa90_row3_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_4aa90_row0_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_4aa90_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4aa90_row0_col4, #T_4aa90_row4_col4 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_4aa90_row1_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_4aa90_row1_col1, #T_4aa90_row2_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_4aa90_row1_col3, #T_4aa90_row4_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_4aa90_row1_col4 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_4aa90_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4aa90_row2_col2, #T_4aa90_row3_col4 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_4aa90_row2_col3, #T_4aa90_row3_col2, #T_4aa90_row4_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_4aa90_row2_col4, #T_4aa90_row4_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_4aa90_row3_col1, #T_4aa90_row4_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_4aa90_row3_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_4aa90">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_4aa90_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_4aa90_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_4aa90_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_4aa90_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_4aa90_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4aa90_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_4aa90_row0_col0" class="data row0 col0" >145.000000</td>
#       <td id="T_4aa90_row0_col1" class="data row0 col1" >158.000000</td>
#       <td id="T_4aa90_row0_col2" class="data row0 col2" >152.000000</td>
#       <td id="T_4aa90_row0_col3" class="data row0 col3" >144.000000</td>
#       <td id="T_4aa90_row0_col4" class="data row0 col4" >157.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4aa90_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_4aa90_row1_col0" class="data row1 col0" >163.000000</td>
#       <td id="T_4aa90_row1_col1" class="data row1 col1" >161.000000</td>
#       <td id="T_4aa90_row1_col2" class="data row1 col2" >158.000000</td>
#       <td id="T_4aa90_row1_col3" class="data row1 col3" >156.000000</td>
#       <td id="T_4aa90_row1_col4" class="data row1 col4" >154.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4aa90_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_4aa90_row2_col0" class="data row2 col0" >161.000000</td>
#       <td id="T_4aa90_row2_col1" class="data row2 col1" >166.000000</td>
#       <td id="T_4aa90_row2_col2" class="data row2 col2" >153.000000</td>
#       <td id="T_4aa90_row2_col3" class="data row2 col3" >162.000000</td>
#       <td id="T_4aa90_row2_col4" class="data row2 col4" >155.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4aa90_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_4aa90_row3_col0" class="data row3 col0" >158.000000</td>
#       <td id="T_4aa90_row3_col1" class="data row3 col1" >165.000000</td>
#       <td id="T_4aa90_row3_col2" class="data row3 col2" >162.000000</td>
#       <td id="T_4aa90_row3_col3" class="data row3 col3" >151.000000</td>
#       <td id="T_4aa90_row3_col4" class="data row3 col4" >153.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4aa90_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_4aa90_row4_col0" class="data row4 col0" >162.000000</td>
#       <td id="T_4aa90_row4_col1" class="data row4 col1" >165.000000</td>
#       <td id="T_4aa90_row4_col2" class="data row4 col2" >155.000000</td>
#       <td id="T_4aa90_row4_col3" class="data row4 col3" >156.000000</td>
#       <td id="T_4aa90_row4_col4" class="data row4 col4" >157.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MinLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_8db9a_row0_col0, #T_8db9a_row1_col0, #T_8db9a_row2_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_8db9a_row0_col1, #T_8db9a_row1_col1, #T_8db9a_row2_col2, #T_8db9a_row2_col3, #T_8db9a_row2_col4, #T_8db9a_row4_col2, #T_8db9a_row4_col3 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_8db9a_row0_col2, #T_8db9a_row3_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_8db9a_row0_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_8db9a_row0_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8db9a_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_8db9a_row1_col3, #T_8db9a_row4_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_8db9a_row1_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_8db9a_row2_col0, #T_8db9a_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8db9a_row3_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_8db9a_row3_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_8db9a_row3_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8db9a_row3_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8db9a_row4_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8db9a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_8db9a_level0_col0" class="col_heading level0 col0" >163840</th>
#       <th id="T_8db9a_level0_col1" class="col_heading level0 col1" >180224</th>
#       <th id="T_8db9a_level0_col2" class="col_heading level0 col2" >196608</th>
#       <th id="T_8db9a_level0_col3" class="col_heading level0 col3" >212992</th>
#       <th id="T_8db9a_level0_col4" class="col_heading level0 col4" >229376</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8db9a_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_8db9a_row0_col0" class="data row0 col0" >165.000000</td>
#       <td id="T_8db9a_row0_col1" class="data row0 col1" >151.000000</td>
#       <td id="T_8db9a_row0_col2" class="data row0 col2" >150.000000</td>
#       <td id="T_8db9a_row0_col3" class="data row0 col3" >148.000000</td>
#       <td id="T_8db9a_row0_col4" class="data row0 col4" >144.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db9a_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_8db9a_row1_col0" class="data row1 col0" >165.000000</td>
#       <td id="T_8db9a_row1_col1" class="data row1 col1" >151.000000</td>
#       <td id="T_8db9a_row1_col2" class="data row1 col2" >152.000000</td>
#       <td id="T_8db9a_row1_col3" class="data row1 col3" >147.000000</td>
#       <td id="T_8db9a_row1_col4" class="data row1 col4" >153.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db9a_level0_row2" class="row_heading level0 row2" >120</th>
#       <td id="T_8db9a_row2_col0" class="data row2 col0" >169.000000</td>
#       <td id="T_8db9a_row2_col1" class="data row2 col1" >165.000000</td>
#       <td id="T_8db9a_row2_col2" class="data row2 col2" >151.000000</td>
#       <td id="T_8db9a_row2_col3" class="data row2 col3" >151.000000</td>
#       <td id="T_8db9a_row2_col4" class="data row2 col4" >151.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db9a_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_8db9a_row3_col0" class="data row3 col0" >162.000000</td>
#       <td id="T_8db9a_row3_col1" class="data row3 col1" >168.000000</td>
#       <td id="T_8db9a_row3_col2" class="data row3 col2" >150.000000</td>
#       <td id="T_8db9a_row3_col3" class="data row3 col3" >145.000000</td>
#       <td id="T_8db9a_row3_col4" class="data row3 col4" >146.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db9a_level0_row4" class="row_heading level0 row4" >136</th>
#       <td id="T_8db9a_row4_col0" class="data row4 col0" >166.000000</td>
#       <td id="T_8db9a_row4_col1" class="data row4 col1" >169.000000</td>
#       <td id="T_8db9a_row4_col2" class="data row4 col2" >151.000000</td>
#       <td id="T_8db9a_row4_col3" class="data row4 col3" >151.000000</td>
#       <td id="T_8db9a_row4_col4" class="data row4 col4" >147.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = 'current_ops_per_sec'
plot_measures(metric, smoothing=0, preset_client=3)
plot_measures(metric, smoothing=0, preset_client=4)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 163904.19
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 163888.13000000003

# %%
metric = 'READ_Avg'
plot_measures(metric, smoothing=0, preset_client=3)
plot_measures(metric, smoothing=0, preset_client=4)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 389.16
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 403.86375

# %%
metric = 'READ_99'
plot_measures(metric, smoothing=0, preset_client=3)
plot_measures(metric, smoothing=0, preset_client=4)
# Out:
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 849
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 1558

# %%
metric = 'READ_Max'
plot_measures(metric, smoothing=0, preset_client=3)
plot_measures(metric, smoothing=0, preset_client=4)
# Out:
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 64735
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 205695

# %%
metric = 'READ_Min'
plot_measures(metric, smoothing=0, preset_client=3)
plot_measures(metric, smoothing=0, preset_client=4)
# Out:
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 171
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 178

# %%
#metric = 'UPDATE_99.9'
#plot_measures(metric, smoothing=0, preset_client=3)
#plot_measures(metric, smoothing=0, preset_client=4)
