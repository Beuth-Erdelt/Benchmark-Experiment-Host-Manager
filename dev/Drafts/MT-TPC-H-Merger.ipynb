# %% [markdown]
# # TPC-H Multi-Tenant in PostgreSQL with PVC

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown
import seaborn as sns
from math import floor
import ast
import json
import re
import numpy as np
from scipy.stats import gmean

from dbmsbenchmarker import parameter, inspector

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
#path = r"C:\data\benchmarks"
path = r"/home/perdelt/benchmarks"
filename_prefix = ''

# %%
def get_workload(code):
    """
    Maps a query index string (e.g., 'q1', 'q2', etc.) to a human-readable query title 
    from the global ``query_properties`` dictionary.

    If the title is not found in ``query_properties``, the input string is returned as-is.

    :param numQuery: A string representing the query index, typically starting with a letter 
                     followed by a number (e.g., ``'q1'``, ``'q2'``).
    :type numQuery: str
    :return: The title of the query if available in ``query_properties``, otherwise the original input string.
    :rtype: str
    """
    with open(path+"/"+code+"/queries.config",'r') as inp:
        workload_properties = ast.literal_eval(inp.read())
        return workload_properties


def map_index_to_queryname(numQuery):
    """
    Maps a query index string (e.g., 'q1', 'q2', etc.) to a human-readable query title 
    from the global `query_properties` dictionary.

    If the title is not found in `query_properties`, the input string is returned as-is.

    Parameters
    ----------
    numQuery : str
        A string representing the query index, typically starting with a letter followed by a number (e.g., 'q1').

    Returns
    -------
    str
        The title of the query if available in `query_properties`, otherwise the original input string.
    """
    global query_properties
    if numQuery[1:] in query_properties and 'config' in query_properties[numQuery[1:]] and 'title' in query_properties[numQuery[1:]]['config']:
        return query_properties[numQuery[1:]]['config']['title']
    else:
        return numQuery


def get_performance_single(evaluate):
    """
    Reads the performance metrics and returns them without any aggregation across clients.
    Computes performance metrics for a single experiment run, including latency, execution power,
    throughput, and timing details for each connection/client.

    This function uses benchmarking results from a given evaluator instance, maps query indices
    to human-readable names, and calculates a set of performance indicators such as:
    - Power@Size: estimated performance at a given scale factor
    - Geo Times: geometric mean of execution runtimes
    - Throughput@Size: estimated throughput per hour at a given scale factor, is number of queries executed per hour scaled by SF and number of clients

    :param evaluate: An evaluator object containing benchmarking and experiment data.
    :type evaluate: object
    :return: A DataFrame containing various aggregated performance metrics including runtime, throughput,
             number of queries, and associated configuration like client count and SF.
    :rtype: pandas.DataFrame
    """
    global query_properties
    query_properties = evaluate.get_experiment_query_properties()
    num_of_queries = 0
    df = evaluate.get_aggregated_query_statistics(type='latency', name='execution', query_aggregate='Mean')
    if not df is None:
        df = df.sort_index().T.round(2)
        df.index = df.index.map(map_index_to_queryname)
        num_of_queries = len(df.index)
    df = evaluate.get_aggregated_experiment_statistics(type='timer', name='execution', query_aggregate='Median', total_aggregate='Geo')
    df = (df/1000.0).sort_index().astype('float')
    df['Power@Size [~Q/h]'] = float(parameter.defaultParameters['SF'])*3600./df
    df_power = df.copy()
    df = evaluate.get_aggregated_experiment_statistics(type='timer', name='run', query_aggregate='Median', total_aggregate='Geo')
    df = (df/1000.0).sort_index()
    df.columns = ['Geo Times [s]']
    df_geo_mean_runtime = df.copy()
    df = pd.concat([df_power, df_geo_mean_runtime], axis=1)
    df_merged_time = pd.DataFrame()
    for connection_nr, connection in evaluate.benchmarks.dbms.items():
        df_time = pd.DataFrame()
        c = connection.connectiondata
        connection_name = c['name']
        orig_name = c['orig_name']
        eva = evaluate.get_experiment_connection_properties(c['name'])
        df_time.index = [connection_name]
        df_time['orig_name'] = orig_name
        df_time['connection_name'] = connection_name
        df_time['SF'] = float(c['parameter']['connection_parameter']['loading_parameters']['SF'])
        df_time['pods'] = int(c['parameter']['connection_parameter']['loading_parameters']['PODS_PARALLEL'])
        df_time['num_experiment'] = int(c['parameter']['numExperiment'])
        df_time['num_client'] = int(c['parameter']['client'])
        df_time['benchmark_start'] = eva['times']['total'][c['name']]['time_start']
        df_time['benchmark_end'] = eva['times']['total'][c['name']]['time_end']
        df_merged_time = pd.concat([df_merged_time, df_time])
    df_time = df_merged_time.sort_index()
    # aggregate per parallel pods per dbms - not valid for model=container?
    #benchmark_start = df_time.groupby(['orig_name', 'SF', 'num_experiment', 'num_client']).min('benchmark_start')
    #benchmark_end = df_time.groupby(['orig_name', 'SF', 'num_experiment', 'num_client']).max('benchmark_end')
    benchmark_start = df_time.groupby(['connection_name', 'SF', 'num_experiment', 'num_client']).min('benchmark_start')
    benchmark_end = df_time.groupby(['connection_name', 'SF', 'num_experiment', 'num_client']).max('benchmark_end')
    df_benchmark = pd.DataFrame(benchmark_end['benchmark_end'] - benchmark_start['benchmark_start'])
    df_benchmark.columns = ['time [s]']
    benchmark_count = df_time.groupby(['connection_name', 'SF', 'num_experiment', 'num_client']).count()
    df_benchmark['count'] = benchmark_count['benchmark_end']
    df_benchmark['SF2'] = df_benchmark.index.map(lambda x: x[1])
    df_benchmark['num_of_queries'] = num_of_queries
    df_benchmark['Throughput@Size'] = (num_of_queries*3600.*df_benchmark['count']/df_benchmark['time [s]']*df_benchmark['SF2']).round(2)
    index_names = list(df_benchmark.index.names)
    index_names[0] = "DBMS"
    df_benchmark.rename_axis(index_names, inplace=True)
    df_benchmark = df_benchmark.reset_index(level=['SF', 'num_experiment', 'num_client'])
    df = pd.concat([df, df_benchmark], axis=1)
    df.drop('SF2', axis=1, inplace=True)
    df.rename(columns={'num_experiment': 'experiment_run'}, inplace=True)
    df.rename(columns={'num_client': 'client'}, inplace=True)
    df['Power@Size [~Q/h]'] = df['SF']*3600./df['total_timer_execution']
    df = df.sort_values(['experiment_run', 'client'])
    return df


def get_performance(evaluation):
    """
    Aggregates performance metrics from a single experiment evaluation across parallel clients.

    This function retrieves detailed metrics using `get_performance_single()`, sorts the data,
    and groups it by client to compute throughput, execution time, and power metrics. The 
    throughput is recomputed based on the total number of queries, count, and execution time.

    :param evaluation: The evaluation object containing benchmarking data.
    :type evaluation: object
    :return: A DataFrame with aggregated performance metrics per client.
    :rtype: pandas.DataFrame
    """
    df = get_performance_single(evaluation)
    result = df.groupby('client').agg({
        'Throughput@Size': 'sum',
        'time [s]': 'max',
        'num_of_queries': 'max',
        'SF': 'max',
        'count': 'sum',
        'Power@Size [~Q/h]': lambda x: gmean(x.dropna()), # 'prod',
        #'num_errors': 'sum',
        #'Latency Distribution.Average Latency (microseconds)': 'mean'
    }).reset_index()
    result['Throughput@Size'] = (result['num_of_queries']*3600.*result['count']/result['time [s]']*result['SF']).round(2)
    return result


def get_performance_all(codes):
    """
    Aggregates performance metrics for multiple experiment codes.

    For each experiment code, this function:
    - Initializes a benchmarking evaluator
    - Retrieves the corresponding workload configuration
    - Extracts aggregated performance metrics per client
    - Annotates the results with workload metadata (`type` and `num_tenants`)
    - Concatenates the results into a single DataFrame

    :param codes: A list of unique experiment codes to process.
    :type codes: list[str]
    :return: A DataFrame combining aggregated performance metrics and workload metadata for all experiments.
    :rtype: pandas.DataFrame
    """
    df_performance = pd.DataFrame()
    for code in codes:
        evaluation = inspector.inspector(path)
        #print(code)
        evaluation.load_experiment(code=code, silent=True)
        #evaluation = evaluators.base(code=code, path=path)
        workload = get_workload(code)
        df = get_performance(evaluation)
        df['type']=workload['tenant_per']
        df['num_tenants']=workload['num_tenants']
        #print(df)
        df_performance = pd.concat([df_performance, df])
    return df_performance


def get_performance_all_single(codes):
    """
    Loops over multiple experiments and combines their unaggregated performance results into a single DataFrame.

    For each experiment code, this function:
    - Initializes a benchmarking evaluator
    - Retrieves the corresponding workload configuration
    - Extracts unaggregated performance metrics per client
    - Annotates the results with workload metadata (`type` and `num_tenants`)
    - Concatenates the results into a single DataFrame

    :param codes: A list of experiment identifiers to process.
    :type codes: list[str]
    :return: A combined DataFrame containing unaggregated performance metrics for all experiments.
    :rtype: pandas.DataFrame
    """
    df_performance = pd.DataFrame()
    for code in codes:
        evaluation = inspector.inspector(path)
        evaluation.load_experiment(code=code, silent=True)
        #evaluation = evaluators.benchbase(code=code, path=path)
        workload = get_workload(code)
        df = get_performance_single(evaluation)
        df['type']=workload['tenant_per']
        df['num_tenants']=workload['num_tenants']
        #print(df)
        df_performance = pd.concat([df_performance, df])
    return df_performance


def get_loading_time_max(evaluation):
    """
    Collects information about the loading processes from the experiment configuration.

    This function reads the `connections.config` file associated with the given evaluation,
    extracts metadata related to data loading operations for each connection, and returns
    the results as a DataFrame.

    The resulting DataFrame includes, for each connection:
    - `time_load`: Total time taken for the load phase
    - `time_ingest`: Time spent ingesting data
    - `time_check`: Time spent indexing or verifying the data
    - `terminals`: Number of BenchBase terminals used
    - `pods`: Degree of parallelism (e.g., number of pods or workers)
    - `tenant`: Tenant identifier (if applicable)
    - `client`: Client name or identifier
    - `datadisk`: Size of the data disk used on the host system (in MB)

    :param evaluation: The evaluation object containing the experiment code.
    :type evaluation: object
    :return: A DataFrame with loading-related metrics and parameters for each connection.
    :rtype: pandas.DataFrame
    """
    with open(path+"/"+evaluation.code+"/connections.config",'r') as inf:
        connections = ast.literal_eval(inf.read())
        pretty_connections = json.dumps(connections, indent=2)
        #print(pretty_connections)
        connections_sorted = sorted(connections, key=lambda c: c['name'])
        result = dict()
        for c in connections_sorted:
            result[c['name']] = {
                'time_load': c['timeLoad'],
                'time_ingest': c['timeIngesting'],
                'time_check': c['timeIndex'],
                #'terminals': c['parameter']['connection_parameter']['loading_parameters']['BENCHBASE_TERMINALS'],
                #'target': c['parameter']['connection_parameter']['loading_parameters']['BENCHBASE_TARGET'],
                'pods': c['parameter']['parallelism'],
                'tenant': c['parameter']['TENANT'] if 'TENANT' in c['parameter'] else '',
                'client': c['parameter']['client'],
                'datadisk': c['hostsystem']['datadisk'],
            }
            #result[c['parameter']['connection_parameter']['loading_parameters']['BENCHBASE_TERMINALS']] = c['timeIngesting']
        df = pd.DataFrame(result).T
        return df#df['time_load'].max()


def get_loading_time_max_all(codes):
    """
    Collects loading process information for a list of experiments and combines the results into a single DataFrame.

    For each experiment code in the input list, this function:
    - Initializes a benchmarking evaluator
    - Retrieves workload metadata
    - Extracts loading-related metrics for each connection
    - Annotates the data with workload attributes (`type`, `num_tenants`)
    - Appends the result to a cumulative DataFrame

    The resulting DataFrame provides a consolidated view of the loading phase across multiple experiments,
    including timings, configuration parameters, and hardware context.

    :param codes: A list of experiment identifiers to process.
    :type codes: list[str]
    :return: A combined DataFrame containing loading metrics and metadata for all experiments.
    :rtype: pandas.DataFrame
    """
    df_performance = pd.DataFrame()
    for code in codes:
        evaluation = evaluators.benchbase(code=code, path=path)
        workload = get_workload(code)
        df = get_loading_time_max(evaluation)
        df['type']=workload['tenant_per']
        df['num_tenants']=workload['num_tenants']
        #print(df)
        df_performance = pd.concat([df_performance, df])
    return df_performance


def show_summary_monitoring_table_old(evaluate, component):
    df_monitoring = list()
    ##########
    df = evaluate.get_monitoring_metric(metric='total_cpu_util_s', component=component)
    df = df.max().sort_index() - df.min().sort_index() # compute difference of counter
    #df = df.T.max().sort_index() - df.T.min().sort_index() # compute difference of counter
    df_cleaned = pd.DataFrame(df)
    df_cleaned.columns = ["CPU [CPUs]"]
    if not df_cleaned.empty:
        df_monitoring.append(df_cleaned.copy())
    ##########
    df = evaluate.get_monitoring_metric(metric='total_cpu_util', component=component)
    df = df.max().sort_index()
    df_cleaned = pd.DataFrame(df)
    df_cleaned.columns = ["Max CPU"]
    if not df_cleaned.empty:
        df_monitoring.append(df_cleaned.copy())
    ##########
    df = evaluate.get_monitoring_metric(metric='total_cpu_memory', component=component)/1024
    #df = evaluate.get_loading_metrics('total_cpu_memory')/1024
    df = df.max().sort_index()
    df_cleaned = pd.DataFrame(df).round(2)
    df_cleaned.columns = ["Max RAM [Gb]"]
    if not df_cleaned.empty:
        df_monitoring.append(df_cleaned.copy())
    ##########
    df = evaluate.get_monitoring_metric(metric='total_cpu_memory_cached', component=component)/1024
    #df = evaluate.get_loading_metrics('total_cpu_memory_cached')/1024
    df = df.max().sort_index()
    df_cleaned = pd.DataFrame(df)
    df_cleaned.columns = ["Max RAM Cached [Gb]"]
    if not df_cleaned.empty:
        df_monitoring.append(df_cleaned.copy())
    return df_monitoring


def show_summary_monitoring_table(evaluate, component):
    """
    Collects hardware and application monitoring metrics for a specified component without aggregation.

    This function retrieves multiple monitoring metrics from the evaluation object related to
    CPU usage, memory, PostgreSQL activity, cache statistics, and background writer performance.
    Each metric is processed (e.g., max-min differences, means, or max values) and combined into a single DataFrame.

    :param evaluate: The evaluation object containing monitoring data and methods to retrieve metrics.
    :type evaluate: object
    :param component: The component name for which to retrieve metrics (e.g., 'database', 'worker').
    :type component: str
    :return: A DataFrame combining all monitored metrics indexed by monitored entities.
    :rtype: pandas.DataFrame
    """
    # Define metrics with the processing method and resulting column name
    metrics_info = [
        ('total_cpu_util_s', 'diff', 'CPU [CPUs]'),
        ('total_cpu_throttled', 'max', 'CPU Throttled'),
        ('total_cpu_util', 'max', 'Max CPU'),
        ('total_cpu_memory', 'max', 'Max RAM [Gb]', 1024),
        ('total_cpu_memory_cached', 'max', 'Max RAM Cached [Gb]', 1024),
    ]
    results = []
    for metric in metrics_info:
        metric_name = metric[0]
        method = metric[1]
        col_name = metric[2]
        scale = metric[3] if len(metric) > 3 else 1
        df = evaluate.get_monitoring_metric(metric=metric_name, component=component)
        # Apply scaling if needed
        if scale != 1:
            df = df * scale
        # Process dataframe according to method
        if method == 'diff':
            processed = df.max().sort_index() - df.min().sort_index()
        elif method == 'max':
            processed = df.max().sort_index()
        elif method == 'mean':
            processed = df.mean().sort_index()
        else:
            raise ValueError(f"Unknown processing method: {method}")
        df_cleaned = pd.DataFrame(processed)
        df_cleaned.columns = [col_name]
        results.append(df_cleaned)
    # Combine all dataframes horizontally (join on index)
    summary_df = pd.concat(results, axis=1).round(2)
    summary_df = summary_df.reindex(index=evaluators.natural_sort(summary_df.index))
    return summary_df


def get_monitoring_timeseries_single(code, metric='pg_locks_count', component="stream"):
    """
    Retrieves a single monitoring metric as a time series DataFrame for a given experiment code and component.

    The function initializes the evaluation object for the specified experiment,
    then fetches the time series data for the specified metric and component.

    :param code: The experiment identifier code.
    :type code: str
    :param metric: The name of the monitoring metric to retrieve (default is 'pg_locks_count').
    :type metric: str, optional
    :param component: The component name to filter metrics (default is 'stream').
    :type component: str, optional
    :return: A DataFrame containing the time series of the requested metric indexed by timestamps or monitoring targets.
    :rtype: pandas.DataFrame
    """
    evaluate = evaluators.benchbase(code=code, path=path)
    df = evaluate.get_monitoring_metric(metric=metric, component=component)
    return df


def get_monitoring(evaluation, type="stream"):
    """
    Retrieves and aggregates monitoring metrics for a specified component type, grouped by client.

    This function obtains detailed monitoring data using `show_summary_monitoring_table` for the
    specified component type (default "stream"). It adds a 'client' column extracted from the DataFrame index,
    then aggregates various hardware and application metrics by client using sum or mean as appropriate.

    :param evaluation: The evaluation object containing monitoring data.
    :type evaluation: object
    :param type: The component type to filter monitoring metrics (default is "stream").
    :type type: str, optional
    :return: A DataFrame with aggregated monitoring metrics grouped by client. If no data is available, returns None.
    :rtype: pandas.DataFrame or None
    """
    df_monitoring = show_summary_monitoring_table(evaluation, type)
    if len(df_monitoring) > 0:
        df = df_monitoring.copy()  # avoid modifying original
        df['client'] = df.index.str.rsplit('-', n=1).str[-1]
        result = df.groupby('client').agg({
            'CPU [CPUs]': 'sum',
            'Max RAM [Gb]': 'sum',
            'Max RAM Cached [Gb]': 'sum',
            'Max CPU': 'sum',
            'CPU Throttled': 'sum',
        }).reset_index()
        return result


def get_monitoring_all(codes, type="stream"):
    """
    Aggregates monitoring metrics across multiple experiments for a specified component type.

    For each experiment code provided, this function:
    - Initializes the evaluation object,
    - Retrieves workload metadata,
    - Collects aggregated monitoring metrics for the specified component type,
    - Adds workload-related metadata columns ('type' and 'num_tenants'),
    - Concatenates the results into a single DataFrame.

    :param codes: A list of experiment codes to process.
    :type codes: list of str
    :param type: The component type to filter monitoring metrics (default is "stream").
    :type type: str, optional
    :return: A concatenated DataFrame containing aggregated monitoring metrics for all experiments,
             enriched with workload metadata.
    :rtype: pandas.DataFrame
    """
    df_performance = pd.DataFrame()
    for code in codes:
        evaluation = evaluators.benchbase(code=code, path=path)
        workload = get_workload(code)
        df = get_monitoring(evaluation, type)
        df['type'] = workload['tenant_per']
        df['num_tenants'] = workload['num_tenants']
        df_performance = pd.concat([df_performance, df])
    return df_performance


def get_monitoring_single_all(codes, type="stream"):
    """
    Retrieves non-aggregated monitoring metrics for multiple experiments and combines them into a single DataFrame.

    For each experiment code, this function:
    - Initializes the evaluation object,
    - Retrieves workload metadata,
    - Collects detailed monitoring metrics for the specified component type without aggregation across clients,
    - Adds workload-related metadata columns ('type' and 'num_tenants'),
    - Concatenates the results into a single DataFrame.

    :param codes: A list of experiment codes to process.
    :type codes: list of str
    :param type: The component type to filter monitoring metrics (default is "stream").
    :type type: str, optional
    :return: A DataFrame containing detailed (non-aggregated) monitoring metrics for all experiments,
             enriched with workload metadata.
    :rtype: pandas.DataFrame
    """
    df_performance = pd.DataFrame()
    for code in codes:
        evaluation = evaluators.benchbase(code=code, path=path)
        workload = get_workload(code)
        df_monitoring = show_summary_monitoring_table(evaluation, type)
        if len(df_monitoring) > 0:
            df = df_monitoring.copy()  # avoid modifying original
            df['client'] = df.index.str.rsplit('-', n=1).str[-1]
            df['type'] = workload['tenant_per']
            df['num_tenants'] = workload['num_tenants']
            df_performance = pd.concat([df_performance, df])
    return df_performance

# %%
def sanitize_filename(title, max_length=100):
    # Replace non-alphanumeric characters with underscores
    safe = re.sub(r'[^a-zA-Z0-9-_]+', '_', title.strip())
    # Truncate to a safe length
    return safe[:max_length].rstrip('_')
    
def plot_bars(df, y, title, estimator):
    df_plot = df.copy()
    #df_plot = df_plot[df_plot['client']=='1']
    df_plot = df_plot.sort_values(['num_tenants','type'])
    # Hatch styles for each type
    hatch_map = {
        'container': '/',
        'database': '\\',
        'schema': 'x'
    }
    hue_order = ['container', 'database', 'schema']
    # Create the plot
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(
        data=df_plot,
        x='num_tenants',
        y=y,
        hue='type',
        estimator=estimator,
        palette='Set2',
        hue_order=hue_order
    )
    """
    for bar in ax.patches:
        height = bar.get_height()
        if height > 0:
            ax.text(
                bar.get_x() + bar.get_width() / 2,  # X: center of bar
                height,                             # Y: top of bar
                f'{height:.1f}',                    # Text (1 decimal place)
                ha='center', va='bottom', fontsize=8
            )
    """
    # Get tick positions (i.e., the x-axis categories)
    xticks = ax.get_xticks()
    bar_width = ax.patches[0].get_width()
    # Create a mapping from (num_tenants, type) to hatch
    grouped = df_plot.groupby(['num_tenants', 'type']).agg({y: estimator}).reset_index()
    #print(grouped)
    grouped_dict = {(row['num_tenants'], row['type']): hatch_map[row['type']] for _, row in grouped.iterrows()}
    bars = sorted(ax.patches, key=lambda bar: bar.get_x() if bar.get_height() > 0 else 10000)
    for bar, (_, row) in zip(bars, grouped.iterrows()):
        bar.my_id = (row['num_tenants'], row['type'])  # or anything else like an index or uuid
        bar.set_hatch(hatch_map[row['type']]) #grouped_dict[(bar.my_id)])
        bar.set_edgecolor('black')
        bar.set_linewidth(1)
    handles, labels = ax.get_legend_handles_labels()
    for handle, label in zip(handles, labels):
        hatch = hatch_map.get(label, '')
        handle.set_hatch(hatch)
    # Final touches
    plt.legend(title='Type')
    ax.legend(fontsize=18)
    #ax.legend(fontsize=18, loc='upper left', bbox_to_anchor=(1, 1))  # move outside
    plt.title(f"{title}", fontsize=24)
    #plt.title(f"{title} by Number of Tenants and Type", fontsize=24)
    plt.xlabel("Number of Tenants", fontsize=18)
    ax.tick_params(axis='both', labelsize=16)
    # Remove y-axis label
    ax.set_ylabel('')  # or ax.set(ylabel='')
    plt.tight_layout()
    filename = "tpch_" + sanitize_filename(title) + ".png"    
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

# %%
def plot_boxplots(df, y, title):
    plt.figure(figsize=(10, 6))
    # Hatch styles for each type
    hatch_map = {
        'container': '/',
        'database': '\\',
        'schema': 'x'
    }
    hue_order = ['container', 'database', 'schema']
    
    # Plot boxplots grouped by num_tenants and colored by type
    ax = sns.boxplot(
        data=df,
        x='num_tenants',
        y=y,#'Goodput (requests/second)',
        hue='type',
        palette='Set2'  # consistent colors per type
    )
    # Add vertical separator lines between groups
    # Get the number of unique num_tenants and type
    num_groups = df['num_tenants'].nunique()
    num_types = df['type'].nunique()
    
    # Extract hue order
    hue_order = ax.get_legend_handles_labels()[1]
    num_hue = len(hue_order)
    
    # Get hue order from seaborn (types)
    _, type_order = ax.get_legend_handles_labels()
    num_types = len(type_order)
    
    #print(len(ax.patches))
    # Set hatches correctly: patches are grouped by x then by hue
    for i, patch in enumerate(ax.patches):
        #print(i)
        type_index = i // (num_groups)
        if type_index >= num_types:
            break
        type_name = type_order[type_index]
        patch.set_hatch(hatch_map.get(type_name, ''))
        #print(hatch_map.get(type_name, ''))
        patch.set_edgecolor('black')
        patch.set_linewidth(1)
    
    # Each num_tenants group has num_types boxes
    for i in range(1, num_groups):
        xpos = i - 0.5 #0.5
        ax.axvline(x=xpos, color='gray', linestyle='--', alpha=0.5)
    
    
    # Update legend with matching hatches
    handles, labels = ax.get_legend_handles_labels()
    for handle, label in zip(handles, labels):
        hatch = hatch_map.get(label, '')
        handle.set_hatch(hatch)
        handle.set_edgecolor('black')
        handle.set_linewidth(1)
    
    #title = "Goodput [req/s] Distribution per Tenant"
    plt.title(title, fontsize=24)
    plt.xlabel("Number of Tenants")
    plt.ylabel("")#"Goodput (requests/second)")
    plt.xlabel("Number of Tenants", fontsize=18)
    ax.tick_params(axis='both', labelsize=16)
    plt.legend(title="Type")
    ax.legend(fontsize=18)
    plt.tight_layout()
    filename = "tpch_" + filename_prefix + sanitize_filename(title) + ".png"    
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

# %% [markdown]
# # Container

# %%
codes = ['1751049830', '1751042932', '1751036351', '1751030495', '1751024409', '1751018248', '1751119375', '1751111813', '1751104451', '1751126280', '1751134502', '1751142830',
         '1751150564', '1751178052', '1751186509',
         '1751194758', # schema 6
         '1751204267', # db 6
         '1751223797', # container 6
         '1751270408',
         '1751281756',
         #'1751270408', # schema 7
         #'1751281756', # db 7
         #'1751294606', # container 7
         '1751303210', # schema 8
         '1751315193', # db 8
         #'1751327437', # container 8
         '1751337551', # schema 9
         #'1751351420', # db 9 OOM
         '1751437705', # db 9
         '1751359843', # schema 10
         '1751468423', # db 10
        ]

codes
# Out:
# ['1751049830',
#  '1751042932',
#  '1751036351',
#  '1751030495',
#  '1751024409',
#  '1751018248',
#  '1751119375',
#  '1751111813',
#  '1751104451',
#  '1751126280',
#  '1751134502',
#  '1751142830',
#  '1751150564',
#  '1751178052',
#  '1751186509',
#  '1751194758',
#  '1751204267',
#  '1751223797',
#  '1751270408',
#  '1751281756',
#  '1751303210',
#  '1751315193',
#  '1751337551',
#  '1751437705',
#  '1751359843',
#  '1751468423']

# %% [markdown]
# ## Per Tenant

# %%
df_performance = get_performance_all_single(codes)
df_performance
# Out:
#                         total_timer_execution  Power@Size [~Q/h]  \
# DBMS
# PostgreSQL-BHT-1-0-1-1               5.581958        6449.350079
# PostgreSQL-BHT-1-1-1-1               5.725308        6287.871693
# PostgreSQL-BHT-1-0-2-1               5.600174        6428.371549
# PostgreSQL-BHT-1-1-2-1               5.662387        6357.742695
# PostgreSQL-BHT-2-1-1                 5.805220        6201.315561
# PostgreSQL-BHT-2-1-2                 5.859996        6143.349100
# PostgreSQL-BHT-2-2-1                 5.786509        6221.367407
# PostgreSQL-BHT-2-2-2                 5.816515        6189.273202
# PostgreSQL-BHT-2-1-1                 5.804136        6202.473081
# PostgreSQL-BHT-2-1-2                 5.799652        6207.269260
# PostgreSQL-BHT-2-2-1                 5.818923        6186.711568
# PostgreSQL-BHT-2-2-2                 5.805793        6200.703804
# PostgreSQL-BHT-1-0-1-1               5.578556        6453.282885
# PostgreSQL-BHT-1-0-2-1               5.625816        6399.072262
# PostgreSQL-BHT-1-1-1                 5.782133        6226.076538
# PostgreSQL-BHT-1-2-1                 5.740931        6270.759668
# PostgreSQL-BHT-1-1-1                 5.737534        6274.472477
# PostgreSQL-BHT-1-2-1                 5.772405        6236.568739
# PostgreSQL-BHT-1-0-1-1               5.655383        6365.616890
# PostgreSQL-BHT-1-1-1-1               5.720550        6293.101030
# PostgreSQL-BHT-1-2-1-1               5.711477        6303.098122
# PostgreSQL-BHT-1-0-2-1               5.714150        6300.150163
# PostgreSQL-BHT-1-1-2-1               5.779226        6229.208072
# PostgreSQL-BHT-4-2-4         5.934530  10.0               1       2      2030
# PostgreSQL-BHT-1-0-1-1       5.791958  10.0               1       1      1981
# PostgreSQL-BHT-1-1-1-1       5.808974  10.0               1       1      2023
# PostgreSQL-BHT-1-2-1-1       5.742669  10.0               1       1      1962
# PostgreSQL-BHT-1-3-1-1       5.739902  10.0               1       1      1986
# PostgreSQL-BHT-1-0-2-1       5.800947  10.0               1       2      2025
# PostgreSQL-BHT-1-1-2-1       5.790568  10.0               1       2      1992
# PostgreSQL-BHT-1-2-2-1       5.722868  10.0               1       2      1974
# PostgreSQL-BHT-1-3-2-1       5.760033  10.0               1       2      2020
# PostgreSQL-BHT-5-1-1         6.354490  10.0               1       1      2154
# PostgreSQL-BHT-5-1-2         6.451569  10.0               1       1      2217
# PostgreSQL-BHT-5-1-3         6.411264  10.0               1       1      2184
# PostgreSQL-BHT-5-1-4         6.479418  10.0               1       1      2198
# PostgreSQL-BHT-5-1-5         6.236118  10.0               1       1      2127
# PostgreSQL-BHT-5-2-1         6.426233  10.0               1       2      2165
# PostgreSQL-BHT-5-2-2         6.543610  10.0               1       2      2191
# PostgreSQL-BHT-5-2-3         6.472346  10.0               1       2      2174
# PostgreSQL-BHT-5-2-4         6.526100  10.0               1       2      2182
# PostgreSQL-BHT-5-2-5         6.426717  10.0               1       2      2176
# PostgreSQL-BHT-5-1-1         6.344939  10.0               1       1      2134
# PostgreSQL-BHT-5-1-2         6.402263  10.0               1       1      2147
# PostgreSQL-BHT-5-1-3         6.423947  10.0               1       1      2172
# PostgreSQL-BHT-5-1-4         6.455482  10.0               1       1      2167
# PostgreSQL-BHT-5-1-5         6.252448  10.0               1       1      2136
# PostgreSQL-BHT-5-2-1         6.387186  10.0               1       2      2146
# PostgreSQL-BHT-5-2-2         6.439293  10.0               1       2      2155
# PostgreSQL-BHT-5-2-3         6.420081  10.0               1       2      2196
# PostgreSQL-BHT-5-2-4         6.450552  10.0               1       2      2161
# PostgreSQL-BHT-5-2-5         6.205874  10.0               1       2      2104
# PostgreSQL-BHT-1-0-1-1       5.986050  10.0               1       1      2096
# PostgreSQL-BHT-1-1-1-1       6.086641  10.0               1       1      2194
# PostgreSQL-BHT-1-2-1-1       5.961722  10.0               1       1      2111
# PostgreSQL-BHT-1-3-1-1       6.092408  10.0               1       1      2146
# PostgreSQL-BHT-1-4-1-1       6.090993  10.0               1       1      2171
# PostgreSQL-BHT-1-0-2-1       5.997386  10.0               1       2      2152
# PostgreSQL-BHT-1-1-2-1       6.106265  10.0               1       2      2213
# PostgreSQL-BHT-1-2-2-1       6.021099  10.0               1       2      2135
# PostgreSQL-BHT-1-3-2-1       6.035737  10.0               1       2      2181
# PostgreSQL-BHT-1-4-2-1       6.073189  10.0               1       2      2191
# PostgreSQL-BHT-6-1-1         6.756693  10.0               1       1      2372
# PostgreSQL-BHT-6-1-2         6.602031  10.0               1       1      2253
# PostgreSQL-BHT-6-1-3         6.872220  10.0               1       1      2359
# PostgreSQL-BHT-6-1-4         6.919298  10.0               1       1      2333
# PostgreSQL-BHT-6-1-5         6.877752  10.0               1       1      2415
# PostgreSQL-BHT-7-2-6         7.577622  10.0               1       2      2560
# PostgreSQL-BHT-7-2-7         7.370142  10.0               1       2      2574
# PostgreSQL-BHT-7-1-1         7.071441  10.0               1       1      2497
# PostgreSQL-BHT-7-1-2         7.121081  10.0               1       1      2496
# PostgreSQL-BHT-7-1-3         7.109461  10.0               1       1      2524
# PostgreSQL-BHT-7-1-4         7.306159  10.0               1       1      2483
# PostgreSQL-BHT-7-1-5         6.779237  10.0               1       1      3366
# PostgreSQL-BHT-7-1-6         7.232394  10.0               1       1      2656
# PostgreSQL-BHT-7-1-7         7.187893  10.0               1       1      2555
# PostgreSQL-BHT-7-2-1         7.140786  10.0               1       2      2675
# PostgreSQL-BHT-7-2-2         7.346714  10.0               1       2      2562
# PostgreSQL-BHT-7-2-3         7.342265  10.0               1       2      2504
# PostgreSQL-BHT-7-2-4         7.385110  10.0               1       2      2524
# PostgreSQL-BHT-7-2-5         7.196915  10.0               1       2      2610
# PostgreSQL-BHT-7-2-6         7.355328  10.0               1       2      2502
# PostgreSQL-BHT-7-2-7         7.277540  10.0               1       2      2622
# PostgreSQL-BHT-8-1-1         7.879505  10.0               1       1      2783
# PostgreSQL-BHT-8-1-2         7.972403  10.0               1       1      2763
# PostgreSQL-BHT-8-1-3         8.182296  10.0               1       1      2763
# PostgreSQL-BHT-8-1-4         8.191556  10.0               1       1      2731
# PostgreSQL-BHT-8-1-5         7.933180  10.0               1       1      2782
# PostgreSQL-BHT-8-1-6         8.143448  10.0               1       1      2805
# PostgreSQL-BHT-8-1-7         8.029040  10.0               1       1      2827
# PostgreSQL-BHT-8-1-8         7.999271  10.0               1       1      2700
# PostgreSQL-BHT-8-2-1         7.981900  10.0               1       2      2761
# PostgreSQL-BHT-8-2-2         8.053646  10.0               1       2      2772
# PostgreSQL-BHT-8-2-3         8.282085  10.0               1       2      2810
# PostgreSQL-BHT-8-2-4         8.394260  10.0               1       2      2768
# PostgreSQL-BHT-8-2-5         7.903274  10.0               1       2      2775
# PostgreSQL-BHT-8-2-6         7.970937  10.0               1       2      2814
# PostgreSQL-BHT-8-2-7         8.107752  10.0               1       2      2819
# PostgreSQL-BHT-8-2-8         7.900321  10.0               1       2      2789
# PostgreSQL-BHT-8-1-1         7.910094  10.0               1       1      2696
# PostgreSQL-BHT-8-1-2         7.808692  10.0               1       1      2738
# PostgreSQL-BHT-8-1-3         8.106900  10.0               1       1      2911
# PostgreSQL-BHT-8-1-4         7.857850  10.0               1       1      2851
# PostgreSQL-BHT-8-1-5         7.844049  10.0               1       1      2770
# PostgreSQL-BHT-8-1-6         8.062416  10.0               1       1      2755
# PostgreSQL-BHT-8-1-7         8.052574  10.0               1       1      2763
# PostgreSQL-BHT-8-1-8         7.810274  10.0               1       1      2706
# PostgreSQL-BHT-8-2-1         8.002872  10.0               1       2      2792
# PostgreSQL-BHT-8-2-2         8.087164  10.0               1       2      2792
# PostgreSQL-BHT-8-2-3         8.332367  10.0               1       2      2782
# PostgreSQL-BHT-8-2-4         8.215316  10.0               1       2      2817
# PostgreSQL-BHT-2-1-2        1              22           399.19     schema
# PostgreSQL-BHT-2-2-1        1              22           396.59     schema
# PostgreSQL-BHT-2-2-2        1              22           399.19     schema
# PostgreSQL-BHT-1-0-1-1      1              22           416.84  container
# PostgreSQL-BHT-1-0-2-1      1              22           412.29  container
# PostgreSQL-BHT-1-1-1        1              22           400.00   database
# PostgreSQL-BHT-1-2-1        1              22           402.64   database
# PostgreSQL-BHT-1-1-1        1              22           404.70     schema
# PostgreSQL-BHT-1-2-1        1              22           398.19     schema
# PostgreSQL-BHT-1-0-1-1      1              22           408.88  container
# PostgreSQL-BHT-1-1-1-1      1              22           405.74  container
# PostgreSQL-BHT-1-2-1-1      1              22           398.99  container
# PostgreSQL-BHT-1-0-2-1      1              22           400.00  container
# PostgreSQL-BHT-1-1-2-1      1              22           398.59  container
# PostgreSQL-BHT-1-2-2-1      1              22           396.00  container
# PostgreSQL-BHT-3-1-1        1              22           386.91   database
# PostgreSQL-BHT-3-1-2        1              22           386.34   database
# PostgreSQL-BHT-3-1-3        1              22           388.62   database
# PostgreSQL-BHT-3-2-1        1              22           385.59   database
# PostgreSQL-BHT-3-2-2        1              22           385.40   database
# PostgreSQL-BHT-3-2-3        1              22           388.24   database
# PostgreSQL-BHT-3-1-1        1              22           387.10     schema
# PostgreSQL-BHT-3-1-2        1              22           389.96     schema
# PostgreSQL-BHT-3-1-3        1              22           395.01     schema
# PostgreSQL-BHT-3-2-1        1              22           386.34     schema
# PostgreSQL-BHT-3-2-2        1              22           392.27     schema
# PostgreSQL-BHT-3-2-3        1              22           394.03     schema
# PostgreSQL-BHT-4-1-1        1              22           385.59     schema
# PostgreSQL-BHT-4-1-2        1              22           378.95     schema
# PostgreSQL-BHT-4-1-3        1              22           379.86     schema
# PostgreSQL-BHT-4-1-4        1              22           381.87     schema
# PostgreSQL-BHT-4-2-1        1              22           378.59     schema
# PostgreSQL-BHT-4-2-2        1              22           375.53     schema
# PostgreSQL-BHT-4-2-3        1              22           379.49     schema
# PostgreSQL-BHT-4-2-4        1              22           384.65     schema
# PostgreSQL-BHT-4-1-1        1              22           380.22   database
# PostgreSQL-BHT-4-1-2        1              22           380.95   database
# PostgreSQL-BHT-4-1-3        1              22           378.59   database
# PostgreSQL-BHT-4-1-4        1              22           386.15   database
# PostgreSQL-BHT-4-2-1        1              22           382.24   database
# PostgreSQL-BHT-4-2-2        1              22           377.50   database
# PostgreSQL-BHT-4-2-3        1              22           378.95   database
# PostgreSQL-BHT-4-2-4        1              22           390.15   database
# PostgreSQL-BHT-1-0-1-1      1              22           399.80  container
# PostgreSQL-BHT-1-1-1-1      1              22           391.50  container
# PostgreSQL-BHT-1-2-1-1      1              22           403.67  container
# PostgreSQL-BHT-1-3-1-1      1              22           398.79  container
# PostgreSQL-BHT-1-0-2-1      1              22           391.11  container
# PostgreSQL-BHT-1-1-2-1      1              22           397.59  container
# PostgreSQL-BHT-1-2-2-1      1              22           401.22  container
# PostgreSQL-BHT-1-3-2-1      1              22           392.08  container
# PostgreSQL-BHT-5-1-1        1              22           367.69     schema
# PostgreSQL-BHT-5-1-2        1              22           357.24     schema
# PostgreSQL-BHT-5-1-3        1              22           362.64     schema
# PostgreSQL-BHT-5-1-4        1              22           360.33     schema
# PostgreSQL-BHT-5-1-5        1              22           372.36     schema
# PostgreSQL-BHT-5-2-1        1              22           365.82     schema
# PostgreSQL-BHT-5-2-2        1              22           361.48     schema
# PostgreSQL-BHT-5-2-3        1              22           364.31     schema
# PostgreSQL-BHT-5-2-4        1              22           362.97     schema
# PostgreSQL-BHT-5-2-5        1              22           363.97     schema
# PostgreSQL-BHT-5-1-1        1              22           371.13   database
# PostgreSQL-BHT-5-1-2        1              22           368.89   database
# PostgreSQL-BHT-5-1-3        1              22           364.64   database
# PostgreSQL-BHT-5-1-4        1              22           365.48   database
# PostgreSQL-BHT-5-1-5        1              22           370.79   database
# PostgreSQL-BHT-5-2-1        1              22           369.06   database
# PostgreSQL-BHT-5-2-2        1              22           367.52   database
# PostgreSQL-BHT-5-2-3        1              22           360.66   database
# PostgreSQL-BHT-5-2-4        1              22           366.50   database
# PostgreSQL-BHT-5-2-5        1              22           376.43   database
# PostgreSQL-BHT-1-0-1-1      1              22           377.86  container
# PostgreSQL-BHT-1-1-1-1      1              22           360.98  container
# PostgreSQL-BHT-1-2-1-1      1              22           375.18  container
# PostgreSQL-BHT-1-3-1-1      1              22           369.06  container
# PostgreSQL-BHT-1-4-1-1      1              22           364.81  container
# PostgreSQL-BHT-1-0-2-1      1              22           368.03  container
# PostgreSQL-BHT-1-1-2-1      1              22           357.89  container
# PostgreSQL-BHT-1-2-2-1      1              22           370.96  container
# PostgreSQL-BHT-1-3-2-1      1              22           363.14  container
# PostgreSQL-BHT-1-4-2-1      1              22           361.48  container
# PostgreSQL-BHT-6-1-1        1              22           333.90     schema
# PostgreSQL-BHT-6-1-2        1              22           351.53     schema
# PostgreSQL-BHT-6-1-3        1              22           335.74     schema
# PostgreSQL-BHT-6-1-4        1              22           339.48     schema
# PostgreSQL-BHT-6-1-5        1              22           327.95     schema
# PostgreSQL-BHT-6-1-6        1              22           338.17     schema
# PostgreSQL-BHT-6-2-1        1              22           339.62     schema
# PostgreSQL-BHT-6-2-2        1              22           341.97     schema
# PostgreSQL-BHT-6-2-3        1              22           335.88     schema
# PostgreSQL-BHT-6-2-4        1              22           326.60     schema
# PostgreSQL-BHT-6-2-5        1              22           334.04     schema
# PostgreSQL-BHT-6-2-6        1              22           337.02     schema
# PostgreSQL-BHT-6-1-1        1              22           340.65   database
# PostgreSQL-BHT-6-1-2        1              22           342.71   database
# PostgreSQL-BHT-6-1-3        1              22           327.68   database
# PostgreSQL-BHT-6-1-4        1              22           336.45   database
# PostgreSQL-BHT-6-1-5        1              22           334.18   database
# PostgreSQL-BHT-6-1-6        1              22           336.16   database
# PostgreSQL-BHT-6-2-1        1              22           340.21   database
# PostgreSQL-BHT-6-2-2        1              22           341.67   database
# ...
# PostgreSQL-BHT-8-2-8        1              22           280.45   database
# PostgreSQL-BHT-9-1-1        1              22           249.37     schema
# PostgreSQL-BHT-9-1-2        1              22           260.78     schema
# PostgreSQL-BHT-9-1-3        1              22           231.24     schema
# PostgreSQL-BHT-9-1-4        1              22           230.70     schema
# PostgreSQL-BHT-9-1-5        1              22           248.35     schema
# PostgreSQL-BHT-9-1-6        1              22           270.12     schema
# PostgreSQL-BHT-9-1-7        1              22           259.50     schema
# PostgreSQL-BHT-9-1-8        1              22           250.87     schema
# PostgreSQL-BHT-9-1-9        1              22           263.04     schema
# PostgreSQL-BHT-9-2-1        1              22           257.14     schema
# PostgreSQL-BHT-9-2-2        1              22           257.56     schema
# PostgreSQL-BHT-9-2-3        1              22           264.88     schema
# PostgreSQL-BHT-9-2-4        1              22           256.48     schema
# PostgreSQL-BHT-9-2-5        1              22           264.44     schema
# PostgreSQL-BHT-9-2-6        1              22           236.42     schema
# PostgreSQL-BHT-9-2-7        1              22           239.64     schema
# PostgreSQL-BHT-9-2-8        1              22           247.81     schema
# PostgreSQL-BHT-9-2-9        1              22           238.05     schema
# PostgreSQL-BHT-9-1-1        1              22           279.76   database
# PostgreSQL-BHT-9-1-2        1              22           273.10   database
# PostgreSQL-BHT-9-1-3        1              22           269.75   database
# PostgreSQL-BHT-9-1-4        1              22           276.92   database
# PostgreSQL-BHT-9-1-5        1              22           269.94   database
# PostgreSQL-BHT-9-1-6        1              22           269.48   database
# PostgreSQL-BHT-9-1-7        1              22           205.55   database
# PostgreSQL-BHT-9-1-8        1              22           263.91   database
# PostgreSQL-BHT-9-1-9        1              22           263.82   database
# PostgreSQL-BHT-9-2-1        1              22           261.99   database
# PostgreSQL-BHT-9-2-2        1              22           259.33   database
# PostgreSQL-BHT-9-2-3        1              22           261.39   database
# PostgreSQL-BHT-9-2-4        1              22           260.96   database
# PostgreSQL-BHT-9-2-5        1              22           260.61   database
# PostgreSQL-BHT-9-2-6        1              22           262.86   database
# PostgreSQL-BHT-9-2-7        1              22           256.89   database
# PostgreSQL-BHT-9-2-8        1              22           265.24   database
# PostgreSQL-BHT-9-2-9        1              22           262.08   database
# PostgreSQL-BHT-10-1-1       1              22           222.53     schema
# PostgreSQL-BHT-10-1-10      1              22           259.33     schema
# PostgreSQL-BHT-10-1-2       1              22           207.82     schema
# PostgreSQL-BHT-10-1-3       1              22           218.42     schema
# PostgreSQL-BHT-10-1-4       1              22           230.23     schema
# PostgreSQL-BHT-10-1-5       1              22           231.78     schema
# PostgreSQL-BHT-10-1-6       1              22           250.87     schema
# PostgreSQL-BHT-10-1-7       1              22           223.41     schema
# PostgreSQL-BHT-10-1-8       1              22           204.44     schema
# PostgreSQL-BHT-10-1-9       1              22           247.42     schema
# PostgreSQL-BHT-10-2-1       1              22           236.49     schema
# PostgreSQL-BHT-10-2-10      1              22           232.33     schema
# PostgreSQL-BHT-10-2-2       1              22           227.85     schema
# PostgreSQL-BHT-10-2-3       1              22           240.29     schema
# PostgreSQL-BHT-10-2-4       1              22           240.22     schema
# PostgreSQL-BHT-10-2-5       1              22           245.89     schema
# PostgreSQL-BHT-10-2-6       1              22           237.70     schema
# PostgreSQL-BHT-4-1-4              4
# PostgreSQL-BHT-4-2-1              4
# PostgreSQL-BHT-4-2-2              4
# PostgreSQL-BHT-4-2-3              4
# PostgreSQL-BHT-4-2-4              4
# PostgreSQL-BHT-4-1-1              4
# PostgreSQL-BHT-4-1-2              4
# PostgreSQL-BHT-4-1-3              4
# PostgreSQL-BHT-4-1-4              4
# PostgreSQL-BHT-4-2-1              4
# PostgreSQL-BHT-4-2-2              4
# PostgreSQL-BHT-4-2-3              4
# PostgreSQL-BHT-4-2-4              4
# PostgreSQL-BHT-1-0-1-1            4
# PostgreSQL-BHT-1-1-1-1            4
# PostgreSQL-BHT-1-2-1-1            4
# PostgreSQL-BHT-1-3-1-1            4
# PostgreSQL-BHT-1-0-2-1            4
# PostgreSQL-BHT-1-1-2-1            4
# PostgreSQL-BHT-1-2-2-1            4
# PostgreSQL-BHT-1-3-2-1            4
# PostgreSQL-BHT-5-1-1              5
# PostgreSQL-BHT-5-1-2              5
# PostgreSQL-BHT-5-1-3              5
# PostgreSQL-BHT-5-1-4              5
# PostgreSQL-BHT-5-1-5              5
# PostgreSQL-BHT-5-2-1              5
# PostgreSQL-BHT-5-2-2              5
# PostgreSQL-BHT-5-2-3              5
# PostgreSQL-BHT-5-2-4              5
# PostgreSQL-BHT-5-2-5              5
# PostgreSQL-BHT-5-1-1              5
# PostgreSQL-BHT-5-1-2              5
# PostgreSQL-BHT-5-1-3              5
# PostgreSQL-BHT-5-1-4              5
# PostgreSQL-BHT-5-1-5              5
# PostgreSQL-BHT-5-2-1              5
# PostgreSQL-BHT-5-2-2              5
# PostgreSQL-BHT-5-2-3              5
# PostgreSQL-BHT-5-2-4              5
# PostgreSQL-BHT-5-2-5              5
# PostgreSQL-BHT-1-0-1-1            5
# PostgreSQL-BHT-1-1-1-1            5
# PostgreSQL-BHT-1-2-1-1            5
# PostgreSQL-BHT-1-3-1-1            5
# PostgreSQL-BHT-1-4-1-1            5
# PostgreSQL-BHT-1-0-2-1            5
# PostgreSQL-BHT-1-1-2-1            5
# PostgreSQL-BHT-1-2-2-1            5
# PostgreSQL-BHT-1-3-2-1            5
# PostgreSQL-BHT-1-4-2-1            5
# PostgreSQL-BHT-6-1-1              6
# PostgreSQL-BHT-6-1-2              6
# PostgreSQL-BHT-6-1-3              6
# PostgreSQL-BHT-6-1-4              6
# PostgreSQL-BHT-6-1-5              6
# PostgreSQL-BHT-6-1-6              6
# PostgreSQL-BHT-6-2-1              6
# PostgreSQL-BHT-6-2-2              6
# PostgreSQL-BHT-6-2-3              6
# PostgreSQL-BHT-6-2-4              6
# PostgreSQL-BHT-6-2-5              6
# PostgreSQL-BHT-6-2-6              6
# PostgreSQL-BHT-6-1-1              6
# PostgreSQL-BHT-6-1-2              6
# PostgreSQL-BHT-6-1-3              6
# PostgreSQL-BHT-6-1-4              6
# PostgreSQL-BHT-6-1-5              6
# PostgreSQL-BHT-6-1-6              6
# PostgreSQL-BHT-6-2-1              6
# PostgreSQL-BHT-6-2-2              6
# PostgreSQL-BHT-6-2-3              6
# PostgreSQL-BHT-6-2-4              6
# PostgreSQL-BHT-6-2-5              6
# PostgreSQL-BHT-6-2-6              6
# PostgreSQL-BHT-1-0-1-1            6
# PostgreSQL-BHT-1-1-1-1            6
# PostgreSQL-BHT-1-2-1-1            6
# PostgreSQL-BHT-1-3-1-1            6
# PostgreSQL-BHT-1-4-1-1            6
# PostgreSQL-BHT-1-5-1-1            6
# PostgreSQL-BHT-1-0-2-1            6
# PostgreSQL-BHT-1-1-2-1            6
# PostgreSQL-BHT-1-2-2-1            6
# PostgreSQL-BHT-1-3-2-1            6
# PostgreSQL-BHT-1-4-2-1            6
# PostgreSQL-BHT-1-5-2-1            6
# PostgreSQL-BHT-7-1-1              7
# PostgreSQL-BHT-7-1-2              7
# PostgreSQL-BHT-7-1-3              7
# PostgreSQL-BHT-7-1-4              7
# PostgreSQL-BHT-7-1-5              7
# PostgreSQL-BHT-7-1-6              7
# PostgreSQL-BHT-7-1-7              7
# PostgreSQL-BHT-7-2-1              7
# PostgreSQL-BHT-7-2-2              7
# PostgreSQL-BHT-7-2-3              7
# PostgreSQL-BHT-7-2-4              7
# PostgreSQL-BHT-7-2-5              7
# PostgreSQL-BHT-7-2-6              7
# PostgreSQL-BHT-7-2-7              7
# PostgreSQL-BHT-7-1-1              7
# PostgreSQL-BHT-7-1-2              7
# PostgreSQL-BHT-7-1-3              7
# PostgreSQL-BHT-7-1-4              7
# PostgreSQL-BHT-7-1-5              7
# PostgreSQL-BHT-7-1-6              7
# PostgreSQL-BHT-7-1-7              7
# PostgreSQL-BHT-7-2-1              7
# PostgreSQL-BHT-7-2-2              7
# PostgreSQL-BHT-7-2-3              7
# PostgreSQL-BHT-7-2-4              7
# PostgreSQL-BHT-7-2-5              7
# PostgreSQL-BHT-7-2-6              7
# PostgreSQL-BHT-7-2-7              7
# PostgreSQL-BHT-8-1-1              8
# PostgreSQL-BHT-8-1-2              8
# PostgreSQL-BHT-8-1-3              8
# PostgreSQL-BHT-8-1-4              8
# PostgreSQL-BHT-8-1-5              8
# PostgreSQL-BHT-8-1-6              8
# PostgreSQL-BHT-8-1-7              8
# PostgreSQL-BHT-8-1-8              8
# PostgreSQL-BHT-8-2-1              8
# PostgreSQL-BHT-8-2-2              8
# PostgreSQL-BHT-8-2-3              8
# PostgreSQL-BHT-8-2-4              8
# PostgreSQL-BHT-8-2-5              8
# PostgreSQL-BHT-8-2-6              8
# PostgreSQL-BHT-8-2-7              8
# PostgreSQL-BHT-8-2-8              8
# PostgreSQL-BHT-8-1-1              8
# PostgreSQL-BHT-8-1-2              8
# PostgreSQL-BHT-8-1-3              8
# PostgreSQL-BHT-8-1-4              8
# PostgreSQL-BHT-8-1-5              8
# PostgreSQL-BHT-8-1-6              8
# PostgreSQL-BHT-8-1-7              8
# PostgreSQL-BHT-8-1-8              8
# PostgreSQL-BHT-8-2-1              8
# PostgreSQL-BHT-8-2-2              8
# PostgreSQL-BHT-8-2-3              8
# PostgreSQL-BHT-8-2-4              8
# PostgreSQL-BHT-8-2-5              8
# PostgreSQL-BHT-10-2-5            10
# PostgreSQL-BHT-10-2-6            10
# PostgreSQL-BHT-10-2-7            10
# PostgreSQL-BHT-10-2-8            10
# PostgreSQL-BHT-10-2-9            10

# %%
df = df_performance[df_performance['client']==1]
#df = df_performance.copy()
plot_boxplots(df, y='Throughput@Size', title='Throughput@Size Distribution per tenant')

# %%
df = df_performance[df_performance['client']==1]
#df = df_performance.copy()
plot_boxplots(df, y='Power@Size [~Q/h]', title='Power@Size Distribution per tenant')

# %% [markdown]
# ## Per Total

# %%
df_performance = get_performance_all(codes)
df_performance
# Out:
#    client  Throughput@Size  time [s]  num_of_queries    SF  count  \
# 0       1           807.75      1961              22  10.0      2
# 1       2           818.60      1935              22  10.0      2
# 0       1           793.98      1995              22  10.0      2
# 1       2           798.79      1983              22  10.0      2
# 0       1           792.40      1999              22  10.0      2
# 1       2           793.19      1997              22  10.0      2
# 0       1           416.84      1900              22  10.0      1
# 1       2           412.29      1921              22  10.0      1
# 0       1           400.00      1980              22  10.0      1
# 1       2           402.64      1967              22  10.0      1
# 0       1           404.70      1957              22  10.0      1
# 1       2           398.19      1989              22  10.0      1
# 0       1          1196.98      1985              22  10.0      3
# 1       2          1188.00      2000              22  10.0      3
# 0       1          1159.02      2050              22  10.0      3
# 1       2          1156.20      2055              22  10.0      3
# 0       1          1161.29      2046              22  10.0      3
# 1       2          1159.02      2050              22  10.0      3
# 0       1          1515.79      2090              22  10.0      4
# 1       2          1502.13      2109              22  10.0      4
# 0       1          1514.34      2092              22  10.0      4
# 1       2          1510.01      2098              22  10.0      4
# 0       1          1565.99      2023              22  10.0      4
# 1       2          1564.44      2025              22  10.0      4
# 0       1          1786.20      2217              22  10.0      5
# 1       2          1807.39      2191              22  10.0      5
# 0       1          1823.20      2172              22  10.0      5
# 1       2          1803.28      2196              22  10.0      5
# 0       1          1804.92      2194              22  10.0      5
# 1       2          1789.43      2213              22  10.0      5
# 0       1          1967.70      2415              22  10.0      6
# 1       2          1959.59      2425              22  10.0      6
# 0       1          1966.07      2417              22  10.0      6
# 1       2          1864.26      2549              22  10.0      6
# 0       1          1640.51      2370              18  10.0      6
# 1       2          1658.70      2344              18  10.0      6
# 0       1          2072.52      2675              22  10.0      7
# 1       2          2145.51      2584              22  10.0      7
# 0       1          1647.06      3366              22  10.0      7
# 1       2          2072.52      2675              22  10.0      7
# 0       1          2241.25      2827              22  10.0      8
# 1       2          2247.61      2819              22  10.0      8
# 0       1          2176.57      2911              22  10.0      8
# 1       2          2243.63      2824              22  10.0      8
# 0       1          2076.32      3433              22  10.0      9
# 1       2          2127.76      3350              22  10.0      9
# 0       1          1849.99      3853              22  10.0      9
# 1       2          2312.03      3083              22  10.0      9
# 0       1          2044.40      3874              22  10.0     10
# 1       2          2278.48      3476              22  10.0     10
# 0       1          1968.19      4024              22  10.0     10
# 1       2          2232.87      3547              22  10.0     10
#
#    Power@Size [~Q/h]       type  num_tenants
# 0        6368.099072  container            2
# 1        6392.959585  container            2
# 0        6172.264282   database            2
# 1        6205.299555   database            2
# 0        6204.870707     schema            2
# 1        6193.703735     schema            2
# 0        6453.282885  container            1
# 1        6399.072262  container            1
# 0        6226.076538   database            1
# 1        6270.759668   database            1
# 0        6274.472477     schema            1
# 1        6236.568739     schema            1
# 0        6320.524073  container            3
# 1        6266.801892  container            3
# 0        6038.466204   database            3
# 1        6033.349474   database            3
# 0        6058.351172     schema            3
# 1        6073.307784     schema            3
# 0        5935.299218     schema            4
# 1        5907.812948     schema            4
# 0        5947.088284   database            4
# 1        5950.421957   database            4
# 0        6238.306867  container            4
# 1        6240.765123  container            4
# 0        5637.343511     schema            5
# 1        5556.570007     schema            5
# 0        5646.692777   database            5
# 1        5642.672957   database            5
# 0        5957.020872  container            5
# 1        5953.747156  container            5
# 0        5261.782817     schema            6
# 1        5196.053450     schema            6
# 0        5273.955826   database            6
# 1        5228.775644   database            6
# 0        5825.939065  container            6
# 1        5840.145561  container            6
# 0        4897.546882     schema            7
# 1        4822.098086     schema            7
# 0        5060.698810   database            7
# 1        4937.189049   database            7
# 0        4477.288432     schema            8
# 1        4459.561868     schema            8
# 0        4539.278935   database            8
# 1        4457.792609   database            8
# 0        4283.258637     schema            9
# 1        4138.271176     schema            9
# 0        4324.968186   database            9
# 1        4076.222086   database            9
# 0        4169.105404     schema           10
# 1        3909.960248     schema           10
# 0        4371.301687   database           10
# 1        3980.093555   database           10

# %%
plot_bars(df_performance, y='Throughput@Size', title='Throughput@Size', estimator='min')

# %%
plot_bars(df_performance, y='Power@Size [~Q/h]', title='Power@Size', estimator='min')

# %%
df_performance = get_loading_time_max_all(codes)
df_performance
# Out:
#                        time_load time_ingest time_check pods tenant client  \
# PostgreSQL-BHT-1-0-1-1    2436.0       875.0     1558.0    1      0      1
# PostgreSQL-BHT-1-0-2-1    2436.0       875.0     1558.0    1      0      2
# PostgreSQL-BHT-1-1-1-1    2419.0       871.0     1544.0    1      1      1
# PostgreSQL-BHT-1-1-2-1    2419.0       871.0     1544.0    1      1      2
# PostgreSQL-BHT-2-1-1      3616.0      1206.0     2172.0    2             1
# PostgreSQL-BHT-2-1-2      3616.0      1206.0     2172.0    2             1
# PostgreSQL-BHT-2-2-1      3616.0      1206.0     2172.0    2             2
# PostgreSQL-BHT-2-2-2      3616.0      1206.0     2172.0    2             2
# PostgreSQL-BHT-2-1-1      3103.0      1194.0     1905.0    2             1
# PostgreSQL-BHT-2-1-2      3103.0      1194.0     1905.0    2             1
# PostgreSQL-BHT-2-2-1      3103.0      1194.0     1905.0    2             2
# PostgreSQL-BHT-2-2-2      3103.0      1194.0     1905.0    2             2
# PostgreSQL-BHT-1-0-1-1    2383.0       847.0     1535.0    1      0      1
# PostgreSQL-BHT-1-0-2-1    2383.0       847.0     1535.0    1      0      2
# PostgreSQL-BHT-1-1-1      2583.0       940.0     1641.0    1             1
# PostgreSQL-BHT-1-2-1      2583.0       940.0     1641.0    1             2
# PostgreSQL-BHT-1-1-1      2657.0       978.0     1677.0    1             1
# PostgreSQL-BHT-1-2-1      2657.0       978.0     1677.0    1             2
# PostgreSQL-BHT-10-2-7     7267.0      2836.0     4322.0   10             2
# PostgreSQL-BHT-10-2-8     7267.0      2836.0     4322.0   10             2
# PostgreSQL-BHT-10-2-9     7267.0      2836.0     4322.0   10             2
#
#                        datadisk       type  num_tenants
# PostgreSQL-BHT-1-0-1-1    27211  container            2
# PostgreSQL-BHT-1-0-2-1    27211  container            2
# PostgreSQL-BHT-1-1-1-1    27211  container            2
# PostgreSQL-BHT-1-1-2-1    27211  container            2
# PostgreSQL-BHT-2-1-1      54413   database            2
# PostgreSQL-BHT-2-1-2      54413   database            2
# PostgreSQL-BHT-2-2-1      54413   database            2
# PostgreSQL-BHT-2-2-2      54413   database            2
# PostgreSQL-BHT-2-1-1      54383     schema            2
# PostgreSQL-BHT-2-1-2      54383     schema            2
# PostgreSQL-BHT-2-2-1      54383     schema            2
# PostgreSQL-BHT-2-2-2      54383     schema            2
# PostgreSQL-BHT-1-0-1-1    27211  container            1
# PostgreSQL-BHT-1-0-2-1    27211  container            1
# PostgreSQL-BHT-1-1-1      27218   database            1
# PostgreSQL-BHT-1-2-1      27218   database            1
# PostgreSQL-BHT-1-1-1      27211     schema            1
# PostgreSQL-BHT-1-2-1      27211     schema            1
# PostgreSQL-BHT-1-0-1-1    27211  container            3
# PostgreSQL-BHT-1-0-2-1    27211  container            3
# PostgreSQL-BHT-1-1-1-1    27211  container            3
# PostgreSQL-BHT-1-1-2-1    27211  container            3
# PostgreSQL-BHT-1-2-1-1    27211  container            3
# PostgreSQL-BHT-1-2-2-1    27211  container            3
# PostgreSQL-BHT-3-1-1      81593   database            3
# PostgreSQL-BHT-3-1-2      81593   database            3
# PostgreSQL-BHT-3-1-3      81593   database            3
# PostgreSQL-BHT-3-2-1      81593   database            3
# PostgreSQL-BHT-3-2-2      81593   database            3
# PostgreSQL-BHT-3-2-3      81593   database            3
# PostgreSQL-BHT-3-1-1      81555     schema            3
# PostgreSQL-BHT-3-1-2      81555     schema            3
# PostgreSQL-BHT-3-1-3      81555     schema            3
# PostgreSQL-BHT-3-2-1      81555     schema            3
# PostgreSQL-BHT-3-2-2      81555     schema            3
# PostgreSQL-BHT-3-2-3      81555     schema            3
# PostgreSQL-BHT-4-1-1      97895     schema            4
# PostgreSQL-BHT-4-1-2      97895     schema            4
# PostgreSQL-BHT-4-1-3      97895     schema            4
# PostgreSQL-BHT-4-1-4      97895     schema            4
# PostgreSQL-BHT-4-2-1      97895     schema            4
# PostgreSQL-BHT-4-2-2      97895     schema            4
# PostgreSQL-BHT-4-2-3      97895     schema            4
# PostgreSQL-BHT-4-2-4      97895     schema            4
# PostgreSQL-BHT-4-1-1      97924   database            4
# PostgreSQL-BHT-4-1-2      97924   database            4
# PostgreSQL-BHT-4-1-3      97924   database            4
# PostgreSQL-BHT-4-1-4      97924   database            4
# PostgreSQL-BHT-4-2-1      97924   database            4
# PostgreSQL-BHT-4-2-2      97924   database            4
# PostgreSQL-BHT-4-2-3      97924   database            4
# PostgreSQL-BHT-4-2-4      97924   database            4
# PostgreSQL-BHT-1-0-1-1    27211  container            4
# PostgreSQL-BHT-1-0-2-1    27211  container            4
# PostgreSQL-BHT-1-1-1-1    27211  container            4
# PostgreSQL-BHT-1-1-2-1    27211  container            4
# PostgreSQL-BHT-1-2-1-1    27211  container            4
# PostgreSQL-BHT-1-2-2-1    27211  container            4
# PostgreSQL-BHT-1-3-1-1    27211  container            4
# PostgreSQL-BHT-1-3-2-1    27211  container            4
# PostgreSQL-BHT-5-1-1     114171     schema            5
# PostgreSQL-BHT-5-1-2     114171     schema            5
# PostgreSQL-BHT-5-1-3     114171     schema            5
# PostgreSQL-BHT-5-1-4     114171     schema            5
# PostgreSQL-BHT-5-1-5     114171     schema            5
# PostgreSQL-BHT-5-2-1     114171     schema            5
# PostgreSQL-BHT-5-2-2     114171     schema            5
# PostgreSQL-BHT-5-2-3     114171     schema            5
# PostgreSQL-BHT-5-2-4     114171     schema            5
# PostgreSQL-BHT-5-2-5     114171     schema            5
# PostgreSQL-BHT-5-1-1     114207   database            5
# PostgreSQL-BHT-5-1-2     114207   database            5
# PostgreSQL-BHT-5-1-3     114207   database            5
# PostgreSQL-BHT-5-1-4     114207   database            5
# PostgreSQL-BHT-5-1-5     114207   database            5
# PostgreSQL-BHT-5-2-1     114207   database            5
# PostgreSQL-BHT-5-2-2     114207   database            5
# PostgreSQL-BHT-5-2-3     114207   database            5
# PostgreSQL-BHT-5-2-4     114207   database            5
# PostgreSQL-BHT-5-2-5     114207   database            5
# PostgreSQL-BHT-1-0-1-1    27211  container            5
# PostgreSQL-BHT-1-0-2-1    27211  container            5
# PostgreSQL-BHT-1-1-1-1    27211  container            5
# PostgreSQL-BHT-1-1-2-1    27211  container            5
# PostgreSQL-BHT-1-2-1-1    27211  container            5
# PostgreSQL-BHT-1-2-2-1    27211  container            5
# PostgreSQL-BHT-1-3-1-1    27211  container            5
# PostgreSQL-BHT-1-3-2-1    27211  container            5
# PostgreSQL-BHT-1-4-1-1    27211  container            5
# PostgreSQL-BHT-1-4-2-1    27211  container            5
# PostgreSQL-BHT-6-1-1     130447     schema            6
# PostgreSQL-BHT-6-1-2     130447     schema            6
# PostgreSQL-BHT-6-1-3     130447     schema            6
# PostgreSQL-BHT-6-1-4     130447     schema            6
# PostgreSQL-BHT-6-1-5     130447     schema            6
# PostgreSQL-BHT-6-1-6     130447     schema            6
# PostgreSQL-BHT-6-2-1     130447     schema            6
# PostgreSQL-BHT-6-2-2     130447     schema            6
# PostgreSQL-BHT-6-2-3     130447     schema            6
# PostgreSQL-BHT-6-2-4     130447     schema            6
# PostgreSQL-BHT-6-2-5     130447     schema            6
# PostgreSQL-BHT-6-2-6     130447     schema            6
# PostgreSQL-BHT-6-1-1     130491   database            6
# PostgreSQL-BHT-6-1-2     130491   database            6
# PostgreSQL-BHT-6-1-3     130491   database            6
# PostgreSQL-BHT-6-1-4     130491   database            6
# PostgreSQL-BHT-6-1-5     130491   database            6
# PostgreSQL-BHT-6-1-6     130491   database            6
# PostgreSQL-BHT-6-2-1     130491   database            6
# PostgreSQL-BHT-6-2-2     130491   database            6
# PostgreSQL-BHT-6-2-3     130491   database            6
# PostgreSQL-BHT-6-2-4     130491   database            6
# PostgreSQL-BHT-6-2-5     130491   database            6
# PostgreSQL-BHT-6-2-6     130491   database            6
# PostgreSQL-BHT-1-0-1-1    27211  container            6
# PostgreSQL-BHT-1-0-2-1    27211  container            6
# PostgreSQL-BHT-1-1-1-1    27211  container            6
# PostgreSQL-BHT-1-1-2-1    27211  container            6
# PostgreSQL-BHT-1-2-1-1    27211  container            6
# PostgreSQL-BHT-1-2-2-1    27211  container            6
# PostgreSQL-BHT-1-3-1-1    27211  container            6
# PostgreSQL-BHT-1-3-2-1    27211  container            6
# PostgreSQL-BHT-1-4-1-1    27211  container            6
# PostgreSQL-BHT-1-4-2-1    27211  container            6
# PostgreSQL-BHT-1-5-1-1    27211  container            6
# PostgreSQL-BHT-1-5-2-1    27211  container            6
# PostgreSQL-BHT-7-1-1     146723     schema            7
# PostgreSQL-BHT-7-1-2     146723     schema            7
# PostgreSQL-BHT-7-1-3     146723     schema            7
# PostgreSQL-BHT-7-1-4     146723     schema            7
# PostgreSQL-BHT-7-1-5     146723     schema            7
# PostgreSQL-BHT-7-1-6     146723     schema            7
# PostgreSQL-BHT-7-1-7     146723     schema            7
# PostgreSQL-BHT-7-2-1     146723     schema            7
# PostgreSQL-BHT-7-2-2     146723     schema            7
# PostgreSQL-BHT-7-2-3     146723     schema            7
# PostgreSQL-BHT-7-2-4     146723     schema            7
# PostgreSQL-BHT-7-2-5     146723     schema            7
# PostgreSQL-BHT-7-2-6     146723     schema            7
# PostgreSQL-BHT-7-2-7     146723     schema            7
# PostgreSQL-BHT-7-1-1     146774   database            7
# PostgreSQL-BHT-7-1-2     146774   database            7
# PostgreSQL-BHT-7-1-3     146774   database            7
# PostgreSQL-BHT-7-1-4     146774   database            7
# PostgreSQL-BHT-7-1-5     146774   database            7
# PostgreSQL-BHT-7-1-6     146774   database            7
# PostgreSQL-BHT-7-1-7     146774   database            7
# PostgreSQL-BHT-7-2-1     146774   database            7
# PostgreSQL-BHT-7-2-2     146774   database            7
# PostgreSQL-BHT-7-2-3     146774   database            7
# PostgreSQL-BHT-7-2-4     146774   database            7
# PostgreSQL-BHT-7-2-5     146774   database            7
# PostgreSQL-BHT-7-2-6     146774   database            7
# PostgreSQL-BHT-7-2-7     146774   database            7
# PostgreSQL-BHT-8-1-1     162999     schema            8
# PostgreSQL-BHT-8-1-2     162999     schema            8
# PostgreSQL-BHT-8-1-3     162999     schema            8
# PostgreSQL-BHT-8-1-4     162999     schema            8
# PostgreSQL-BHT-8-1-5     162999     schema            8
# PostgreSQL-BHT-8-1-6     162999     schema            8
# PostgreSQL-BHT-8-1-7     162999     schema            8
# PostgreSQL-BHT-8-1-8     162999     schema            8
# PostgreSQL-BHT-8-2-1     162999     schema            8
# PostgreSQL-BHT-8-2-2     162999     schema            8
# PostgreSQL-BHT-8-2-3     162999     schema            8
# PostgreSQL-BHT-8-2-4     162999     schema            8
# PostgreSQL-BHT-8-2-5     162999     schema            8
# PostgreSQL-BHT-8-2-6     162999     schema            8
# PostgreSQL-BHT-8-2-7     162999     schema            8
# PostgreSQL-BHT-8-2-8     162999     schema            8
# PostgreSQL-BHT-8-1-1     163058   database            8
# PostgreSQL-BHT-8-1-2     163058   database            8
# PostgreSQL-BHT-8-1-3     163058   database            8
# PostgreSQL-BHT-8-1-4     163058   database            8
# PostgreSQL-BHT-8-1-5     163058   database            8
# PostgreSQL-BHT-8-1-6     163058   database            8
# PostgreSQL-BHT-8-1-7     163058   database            8
# PostgreSQL-BHT-8-1-8     163058   database            8
# PostgreSQL-BHT-8-2-1     163058   database            8
# PostgreSQL-BHT-8-2-2     163058   database            8
# PostgreSQL-BHT-8-2-3     163058   database            8
# PostgreSQL-BHT-8-2-4     163058   database            8
# PostgreSQL-BHT-8-2-5     163058   database            8
# PostgreSQL-BHT-8-2-6     163058   database            8
# PostgreSQL-BHT-8-2-7     163058   database            8
# PostgreSQL-BHT-8-2-8     163058   database            8
# PostgreSQL-BHT-9-1-1     179275     schema            9
# PostgreSQL-BHT-9-1-2     179275     schema            9
# PostgreSQL-BHT-9-1-3     179275     schema            9
# PostgreSQL-BHT-9-1-4     179275     schema            9
# PostgreSQL-BHT-9-1-5     179275     schema            9
# PostgreSQL-BHT-9-1-6     179275     schema            9
# PostgreSQL-BHT-9-1-7     179275     schema            9
# PostgreSQL-BHT-9-1-8     179275     schema            9
# PostgreSQL-BHT-9-1-9     179275     schema            9
# PostgreSQL-BHT-9-2-1     179275     schema            9
# PostgreSQL-BHT-9-2-2     179275     schema            9
# PostgreSQL-BHT-9-2-3     179275     schema            9
# PostgreSQL-BHT-9-2-4     179275     schema            9
# PostgreSQL-BHT-9-2-5     179275     schema            9
# PostgreSQL-BHT-9-2-6     179275     schema            9
# PostgreSQL-BHT-9-2-7     179275     schema            9
# PostgreSQL-BHT-9-2-8     179275     schema            9
# PostgreSQL-BHT-9-2-9     179275     schema            9
# PostgreSQL-BHT-9-1-1     179341   database            9
# PostgreSQL-BHT-9-1-2     179341   database            9
# PostgreSQL-BHT-9-1-3     179341   database            9
# PostgreSQL-BHT-9-1-4     179341   database            9
# PostgreSQL-BHT-9-1-5     179341   database            9
# PostgreSQL-BHT-9-1-6     179341   database            9
# PostgreSQL-BHT-9-1-7     179341   database            9
# PostgreSQL-BHT-9-1-8     179341   database            9
# PostgreSQL-BHT-9-1-9     179341   database            9
# PostgreSQL-BHT-9-2-1     179341   database            9
# PostgreSQL-BHT-9-2-2     179341   database            9
# PostgreSQL-BHT-9-2-3     179341   database            9
# PostgreSQL-BHT-9-2-4     179341   database            9
# PostgreSQL-BHT-9-2-5     179341   database            9
# PostgreSQL-BHT-9-2-6     179341   database            9
# PostgreSQL-BHT-9-2-7     179341   database            9
# PostgreSQL-BHT-9-2-8     179341   database            9
# PostgreSQL-BHT-9-2-9     179341   database            9
# PostgreSQL-BHT-10-1-1    195551     schema           10
# PostgreSQL-BHT-10-1-10   195551     schema           10
# PostgreSQL-BHT-10-1-2    195551     schema           10
# PostgreSQL-BHT-10-1-3    195551     schema           10
# PostgreSQL-BHT-10-1-4    195551     schema           10
# PostgreSQL-BHT-10-1-5    195551     schema           10
# PostgreSQL-BHT-10-1-6    195551     schema           10
# PostgreSQL-BHT-10-1-7    195551     schema           10
# PostgreSQL-BHT-10-1-8    195551     schema           10
# PostgreSQL-BHT-10-1-9    195551     schema           10
# PostgreSQL-BHT-10-2-1    195551     schema           10
# PostgreSQL-BHT-10-2-10   195551     schema           10
# PostgreSQL-BHT-10-2-2    195551     schema           10
# PostgreSQL-BHT-10-2-3    195551     schema           10
# PostgreSQL-BHT-10-2-4    195551     schema           10
# PostgreSQL-BHT-10-2-5    195551     schema           10
# PostgreSQL-BHT-10-2-6    195551     schema           10
# PostgreSQL-BHT-10-2-7    195551     schema           10
# PostgreSQL-BHT-10-2-8    195551     schema           10
# PostgreSQL-BHT-10-2-9    195551     schema           10
# PostgreSQL-BHT-10-1-1    195624   database           10
# PostgreSQL-BHT-10-1-10   195624   database           10
# PostgreSQL-BHT-10-1-2    195624   database           10
# PostgreSQL-BHT-10-1-3    195624   database           10
# PostgreSQL-BHT-10-1-4    195624   database           10
# PostgreSQL-BHT-10-1-5    195624   database           10
# PostgreSQL-BHT-10-1-6    195624   database           10
# PostgreSQL-BHT-10-1-7    195624   database           10
# PostgreSQL-BHT-10-1-8    195624   database           10
# PostgreSQL-BHT-10-1-9    195624   database           10
# PostgreSQL-BHT-10-2-1    195624   database           10
# PostgreSQL-BHT-10-2-10   195624   database           10
# PostgreSQL-BHT-10-2-2    195624   database           10
# PostgreSQL-BHT-10-2-3    195624   database           10
# PostgreSQL-BHT-10-2-4    195624   database           10
# PostgreSQL-BHT-10-2-5    195624   database           10
# PostgreSQL-BHT-10-2-6    195624   database           10
# PostgreSQL-BHT-10-2-7    195624   database           10
# PostgreSQL-BHT-10-2-8    195624   database           10
# PostgreSQL-BHT-10-2-9    195624   database           10

# %%
df_performance_first = df_performance[df_performance['client'] == '1']
# Divide datadisk by the count of rows with the same type and num_tenants
df = df_performance_first.copy()
# Create a mask for rows where type is not "container"
mask = df['type'] != 'container'

# Only apply the group count to the relevant rows
group_counts = df[mask].groupby(['type', 'num_tenants'])['datadisk'].transform('count')

# Initialize the column with NaN (or 0, if preferred)
df['datadisk_normalized'] = df['datadisk'] / 1024

# Apply the normalized value only where the mask is True
df.loc[mask, 'datadisk_normalized'] = df.loc[mask, 'datadisk'] / group_counts / 1024

plot_bars(df, y='datadisk_normalized', title='Database Size [GB]', estimator='sum')

# %%
plot_bars(df_performance, y='time_ingest', title='Time for Ingestion [s]', estimator='max')

# %%
plot_bars(df_performance, y='time_check', title='Time for Indexing [s]', estimator='max')

# %% [markdown]
# ## Hardware Benchmarking

# %%
df_performance = get_monitoring_all(codes, type="stream")
df_performance = df_performance[df_performance['client'] == '1']
df_performance = df_performance.sort_values(['num_tenants', 'type'])
df_performance
# Out:
#   client  CPU [CPUs]  Max RAM [Gb]  Max RAM Cached [Gb]  Max CPU  \
# 0      1    10249.41    60226992.0           76912696.0     7.95
# 0      1    10597.67    60240188.0           76928000.0     7.98
# 0      1    10827.06    60226092.0           76911800.0     7.98
# 0      1    21122.16   106961044.0          140332456.0    15.92
# 0      1    21627.18    76992836.0          109955520.0    14.84
# 0      1    21782.59    61838664.0           95177476.0    14.08
# 0      1    32000.65   172692476.0          219040864.0    23.93
# 0      1    33336.32   133409072.0          183423176.0    21.61
# 0      1    33096.24    89283572.0          138175136.0    20.91
# 0      1    43177.98   240911232.0          300782360.0    31.30
# 0      1    45106.87   148100964.0          214490060.0    26.72
# 0      1    44905.47   142366884.0          208088876.0    28.60
# 0      1    57732.70   300234584.0          376893988.0    39.72
# 0      1    59205.43   177863900.0          256278572.0    35.16
# 0      1    59665.11   166278640.0          244431248.0    35.29
# 0      1    75858.11   357500756.0          442039436.0    47.56
# 0      1    77324.15   243021884.0          297422576.0    40.08
# 0      1    76272.03   254014856.0          308185332.0    42.41
# 0      1    94371.93   264472960.0          315318912.0    48.82
# 0      1    97380.42   292656400.0          347509848.0    46.25
# 0      1   119016.54   271032560.0          330729024.0    53.68
# 0      1   121982.24   292489936.0          337979416.0    55.54
# 0      1   137910.32   323356496.0          374976508.0    56.24
# 0      1   139006.38   349343900.0          390621348.0    56.44
# 0      1   153305.21   365233000.0          415363808.0    59.43
# 0      1   155529.37   348722676.0          400094464.0    57.74
#
#    CPU Throttled       type  num_tenants
# 0            0.0  container            1
# 0            0.0   database            1
# 0            0.0     schema            1
# 0            0.0  container            2
# 0            0.0   database            2
# 0            0.0     schema            2
# 0            0.0  container            3
# 0            0.0   database            3
# 0            0.0     schema            3
# 0            0.0  container            4
# 0            0.0   database            4
# 0            0.0     schema            4
# 0            0.0  container            5
# 0            0.0   database            5
# 0            0.0     schema            5
# 0            0.0  container            6
# 0            0.0   database            6
# 0            0.0     schema            6
# 0            0.0   database            7
# 0            0.0     schema            7
# 0            0.0   database            8
# 0            0.0     schema            8
# 0            0.0   database            9
# 0            0.0     schema            9
# 0            0.0   database           10
# 0            0.0     schema           10

# %%
plot_bars(df_performance, y='CPU [CPUs]', title='CPU [CPUs]', estimator='max')

# %%
plot_bars(df_performance, y='Max CPU', title='Max CPU', estimator='sum')

# %%
plot_bars(df_performance, y='Max RAM Cached [Gb]', title='Max RAM Cached [Gb]', estimator='sum')

# %%
plot_bars(df_performance, y='Max RAM [Gb]', title='Max RAM [Gb]', estimator='sum')

# %% [markdown]
# ## Hardware Loading

# %%
df_performance = get_monitoring_all(codes, type="loading")
df_performance = df_performance[df_performance['client'] == '1']
df_performance = df_performance.sort_values(['num_tenants', 'type'])
df_performance
# Out:
#   client  CPU [CPUs]  Max RAM [Gb]  Max RAM Cached [Gb]  Max CPU  \
# 0      1     1348.45    16933060.0           33431272.0     2.73
# 0      1     1364.01    17164308.0           33153012.0     3.88
# 0      1     1343.99    17919172.0           33431820.0     2.41
# 0      1     2639.58    35030480.0           66623128.0     5.20
# 0      1     2769.23    30773280.0           65497128.0     5.46
# 0      1     2776.29    31866440.0           63125852.0     2.00
# 0      1     4188.86    52395148.0           99349000.0    11.95
# 0      1     4253.43    46653580.0           95135940.0     3.51
# 0      1     4281.17    44594876.0           94512524.0     7.66
# 0      1     5468.21    67243588.0          132751524.0    11.94
# 0      1     5735.39    59354072.0          125609808.0     5.05
# 0      1     5762.57    62792156.0          126068528.0    10.39
# 0      1     6808.24    85347340.0          164628720.0    15.01
# 0      1     7447.60    76332876.0          159036760.0    11.34
# 0      1     7381.90    79926776.0          158803440.0     5.00
# 0      1     8246.04   102221724.0          198433324.0    15.19
# 0      1    10065.25   110752056.0          176082516.0    19.75
# 0      1    10201.78   109210660.0          176467820.0    22.79
# 0      1    12627.19   117776236.0          192680332.0    17.56
# 0      1    12491.86   118805956.0          192083972.0    24.36
# 0      1    16070.88   128877252.0          218045452.0    35.71
# 0      1    15813.55   129607632.0          216173736.0    27.37
# 0      1    18443.46   137268372.0          228163092.0    38.06
# 0      1    17985.38   137249452.0          228054852.0    30.12
# 0      1    19382.79   144142100.0          250766008.0    38.14
# 0      1    19521.26   139588084.0          243026716.0    36.58
#
#    CPU Throttled       type  num_tenants
# 0            0.0  container            1
# 0            0.0   database            1
# 0            0.0     schema            1
# 0            0.0  container            2
# 0            0.0   database            2
# 0            0.0     schema            2
# 0            0.0  container            3
# 0            0.0   database            3
# 0            0.0     schema            3
# 0            0.0  container            4
# 0            0.0   database            4
# 0            0.0     schema            4
# 0            0.0  container            5
# 0            0.0   database            5
# 0            0.0     schema            5
# 0            0.0  container            6
# 0            0.0   database            6
# 0            0.0     schema            6
# 0            0.0   database            7
# 0            0.0     schema            7
# 0            0.0   database            8
# 0            0.0     schema            8
# 0            0.0   database            9
# 0            0.0     schema            9
# 0            0.0   database           10
# 0            0.0     schema           10

# %%
plot_bars(df_performance, y='CPU [CPUs]', title='CPU [CPUs]', estimator='max')

# %%
plot_bars(df_performance, y='Max RAM [Gb]', title='Max RAM [Gb]', estimator='sum')

# %% [markdown]
# # Efficiency

# %%
client = 1

df_performance_monitoring = get_monitoring_all(codes, type="stream")
df_performance_monitoring["client"] = df_performance_monitoring["client"].astype(int)
df_performance_monitoring = df_performance_monitoring[df_performance_monitoring['client'] == client]
df_performance = get_performance_all(codes)
df_performance["client"] = df_performance["client"].astype(int)
df_performance = df_performance[df_performance['client'] == client]
merged_df = pd.merge(df_performance, df_performance_monitoring, on=['type', 'num_tenants', 'client'], how='inner')
merged_df['RAM/Throughput'] = merged_df['Max RAM [Gb]'] / (merged_df['Throughput@Size'])
merged_df['CPUs/Throughput'] = merged_df['CPU [CPUs]'] / (merged_df['Throughput@Size'] / 3600.)
#merged_df['E_RAM'] = (merged_df['Throughput@Size']) / merged_df['Max RAM [Gb]']
#merged_df['E_CPU'] = (merged_df['Throughput@Size'] * 3600.) / merged_df['CPU [CPUs]']
merged_df['E_CPU'] = (10. * merged_df['num_tenants'] * merged_df['num_of_queries'] * merged_df['SF']) / merged_df['CPU [CPUs]']
merged_df['E_RAM'] = (10. * merged_df['num_tenants'] * merged_df['num_of_queries'] * merged_df['SF']) / merged_df['Max RAM [Gb]']

merged_df
# Out:
#     client  Throughput@Size  time [s]  num_of_queries    SF  count  \
# 0        1           807.75      1961              22  10.0      2
# 1        1           793.98      1995              22  10.0      2
# 2        1           792.40      1999              22  10.0      2
# 3        1           416.84      1900              22  10.0      1
# 4        1           400.00      1980              22  10.0      1
# 5        1           404.70      1957              22  10.0      1
# 6        1          1196.98      1985              22  10.0      3
# 7        1          1159.02      2050              22  10.0      3
# 8        1          1161.29      2046              22  10.0      3
# 9        1          1515.79      2090              22  10.0      4
# 10       1          1514.34      2092              22  10.0      4
# 11       1          1565.99      2023              22  10.0      4
# 12       1          1786.20      2217              22  10.0      5
# 13       1          1823.20      2172              22  10.0      5
# 14       1          1804.92      2194              22  10.0      5
# 15       1          1967.70      2415              22  10.0      6
# 16       1          1966.07      2417              22  10.0      6
# 17       1          1640.51      2370              18  10.0      6
# 18       1          2072.52      2675              22  10.0      7
# 19       1          1647.06      3366              22  10.0      7
# 20       1          2241.25      2827              22  10.0      8
# 21       1          2176.57      2911              22  10.0      8
# 22       1          2076.32      3433              22  10.0      9
# 23       1          1849.99      3853              22  10.0      9
# 24       1          2044.40      3874              22  10.0     10
# 25       1          1968.19      4024              22  10.0     10
#
#     Power@Size [~Q/h]       type  num_tenants  CPU [CPUs]  Max RAM [Gb]  \
# 0         6368.099072  container            2    21122.16   106961044.0
# 1         6172.264282   database            2    21627.18    76992836.0
# 2         6204.870707     schema            2    21782.59    61838664.0
# 3         6453.282885  container            1    10249.41    60226992.0
# 4         6226.076538   database            1    10597.67    60240188.0
# 5         6274.472477     schema            1    10827.06    60226092.0
# 6         6320.524073  container            3    32000.65   172692476.0
# 7         6038.466204   database            3    33336.32   133409072.0
# 8         6058.351172     schema            3    33096.24    89283572.0
# 9         5935.299218     schema            4    44905.47   142366884.0
# 10        5947.088284   database            4    45106.87   148100964.0
# 11        6238.306867  container            4    43177.98   240911232.0
# 12        5637.343511     schema            5    59665.11   166278640.0
# 13        5646.692777   database            5    59205.43   177863900.0
# 14        5957.020872  container            5    57732.70   300234584.0
# 15        5261.782817     schema            6    76272.03   254014856.0
# 16        5273.955826   database            6    77324.15   243021884.0
# 17        5825.939065  container            6    75858.11   357500756.0
# 18        4897.546882     schema            7    97380.42   292656400.0
# 19        5060.698810   database            7    94371.93   264472960.0
# 20        4477.288432     schema            8   121982.24   292489936.0
# 21        4539.278935   database            8   119016.54   271032560.0
# 22        4283.258637     schema            9   139006.38   349343900.0
# 23        4324.968186   database            9   137910.32   323356496.0
# 24        4169.105404     schema           10   155529.37   348722676.0
# 25        4371.301687   database           10   153305.21   365233000.0
#
#     Max RAM Cached [Gb]  Max CPU  CPU Throttled  RAM/Throughput  \
# 0           140332456.0    15.92            0.0   132418.500774
# 1           109955520.0    14.84            0.0    96970.749893
# 2            95177476.0    14.08            0.0    78039.707219
# 3            76912696.0     7.95            0.0   144484.675175
# 4            76928000.0     7.98            0.0   150600.470000
# 5            76911800.0     7.98            0.0   148816.634544
# 6           219040864.0    23.93            0.0   144273.484937
# 7           183423176.0    21.61            0.0   115105.064624
# 8           138175136.0    20.91            0.0    76883.097245
# 9           208088876.0    28.60            0.0    93922.564471
# 10          214490060.0    26.72            0.0    97799.017394
# 11          300782360.0    31.30            0.0   153839.572411
# 12          244431248.0    35.29            0.0    93090.717725
# 13          256278572.0    35.16            0.0    97555.890742
# 14          376893988.0    39.72            0.0   166342.322097
# 15          308185332.0    42.41            0.0   129092.268130
# 16          297422576.0    40.08            0.0   123607.950887
# 17          442039436.0    47.56            0.0   217920.497894
# 18          347509848.0    46.25            0.0   141207.997993
# 19          315318912.0    48.82            0.0   160572.753877
# 20          337979416.0    55.54            0.0   130503.038929
# 21          330729024.0    53.68            0.0   124522.785851
# 22          390621348.0    56.44            0.0   168251.473761
# 23          374976508.0    56.24            0.0   174788.239936
# 24          400094464.0    57.74            0.0   170574.582274
# 25          415363808.0    59.43            0.0   185567.958378
#
#     CPUs/Throughput     E_CPU     E_RAM
# 0      94137.760446  0.208312  0.000041
# 1      98060.213104  0.203448  0.000057
# 2      98961.792024  0.201996  0.000071
# 3      88518.078879  0.214647  0.000037
# 4      95379.030000  0.207593  0.000037
# 5      96311.875463  0.203195  0.000037
# 6      96244.164481  0.206246  0.000038
# 7     103545.022519  0.197982  0.000049
# 8     102598.372500  0.199418  0.000074
# 9     106650.454219  0.195967  0.000062
# 10    107231.356234  0.195092  0.000059
# 11     99260.357984  0.203808  0.000037
# 12    120252.153174  0.184362  0.000066
# 13    116904.096095  0.185794  0.000062
# 14    115150.654877  0.190533  0.000037
# 15    139543.277939  0.173065  0.000052
# 16    141585.467455  0.170710  0.000054
# 17    166466.035562  0.142371  0.000030
# 18    169151.328817  0.158143  0.000053
# 19    206269.928236  0.163184  0.000058
# 20    195933.547797  0.144283  0.000060
# 21    196850.799193  0.147879  0.000065
# 22    241014.375433  0.142440  0.000057
# 23    268367.478743  0.143572  0.000061
# 24    273872.887889  0.141452  0.000063
# 25    280409.287721  0.143505  0.000060

# %%
plot_bars(merged_df, y='E_CPU', title='1st run - $E_{CPU}$', estimator='max')

# %%
plot_bars(merged_df, y='E_RAM', title='1st run - $E_{RAM}$', estimator='max')

# %%
client = 2

df_performance_monitoring = get_monitoring_all(codes, type="stream")
df_performance_monitoring["client"] = df_performance_monitoring["client"].astype(int)
df_performance_monitoring = df_performance_monitoring[df_performance_monitoring['client'] == client]
df_performance = get_performance_all(codes)
df_performance["client"] = df_performance["client"].astype(int)
df_performance = df_performance[df_performance['client'] == client]
merged_df = pd.merge(df_performance, df_performance_monitoring, on=['type', 'num_tenants', 'client'], how='inner')
merged_df['RAM/Throughput'] = merged_df['Max RAM [Gb]'] / (merged_df['Throughput@Size'])
merged_df['CPUs/Throughput'] = merged_df['CPU [CPUs]'] / (merged_df['Throughput@Size'] / 3600.)
#merged_df['E_RAM'] = (merged_df['Throughput@Size']) / merged_df['Max RAM [Gb]']
#merged_df['E_CPU'] = (merged_df['Throughput@Size'] * 3600.) / merged_df['CPU [CPUs]']
merged_df['E_CPU'] = (10. * merged_df['num_tenants'] * merged_df['num_of_queries'] * merged_df['SF']) / merged_df['CPU [CPUs]']
merged_df['E_RAM'] = (10. * merged_df['num_tenants'] * merged_df['num_of_queries'] * merged_df['SF']) / merged_df['Max RAM [Gb]']

merged_df
# Out:
#     client  Throughput@Size  time [s]  num_of_queries    SF  count  \
# 0        2           818.60      1935              22  10.0      2
# 1        2           798.79      1983              22  10.0      2
# 2        2           793.19      1997              22  10.0      2
# 3        2           412.29      1921              22  10.0      1
# 4        2           402.64      1967              22  10.0      1
# 5        2           398.19      1989              22  10.0      1
# 6        2          1188.00      2000              22  10.0      3
# 7        2          1156.20      2055              22  10.0      3
# 8        2          1159.02      2050              22  10.0      3
# 9        2          1502.13      2109              22  10.0      4
# 10       2          1510.01      2098              22  10.0      4
# 11       2          1564.44      2025              22  10.0      4
# 12       2          1807.39      2191              22  10.0      5
# 13       2          1803.28      2196              22  10.0      5
# 14       2          1789.43      2213              22  10.0      5
# 15       2          1959.59      2425              22  10.0      6
# 16       2          1864.26      2549              22  10.0      6
# 17       2          1658.70      2344              18  10.0      6
# 18       2          2145.51      2584              22  10.0      7
# 19       2          2072.52      2675              22  10.0      7
# 20       2          2247.61      2819              22  10.0      8
# 21       2          2243.63      2824              22  10.0      8
# 22       2          2127.76      3350              22  10.0      9
# 23       2          2312.03      3083              22  10.0      9
# 24       2          2278.48      3476              22  10.0     10
# 25       2          2232.87      3547              22  10.0     10
#
#     Power@Size [~Q/h]       type  num_tenants  CPU [CPUs]  Max RAM [Gb]  \
# 0         6392.959585  container            2    20536.07   122321660.0
# 1         6205.299555   database            2    21213.02    77585200.0
# 2         6193.703735     schema            2    21532.46    77244816.0
# 3         6399.072262  container            1    10563.69    61160432.0
# 4         6270.759668   database            1    10686.47    61174784.0
# 5         6236.568739     schema            1    10890.06    61160932.0
# 6         6266.801892  container            3    32211.67   182187040.0
# 7         6033.349474   database            3    33425.27   134907052.0
# 8         6073.307784     schema            3    33183.98   122960044.0
# 9         5907.812948     schema            4    45464.51   138526352.0
# 10        5950.421957   database            4    45201.56   147783400.0
# 11        6240.765123  container            4    43163.66   217665844.0
# 12        5556.570007     schema            5    59996.48   175681112.0
# 13        5642.672957   database            5    59103.55   180487552.0
# 14        5953.747156  container            5    58445.82   302744072.0
# 15        5196.053450     schema            6    77222.06   266504276.0
# 16        5228.775644   database            6    77279.26   245586128.0
# 17        5840.145561  container            6    76087.71   353281620.0
# 18        4822.098086     schema            7    98369.00   313534748.0
# 19        4937.189049   database            7    96808.20   299016448.0
# 20        4459.561868     schema            8   121742.73   317319080.0
# 21        4457.792609   database            8   120306.31   311058544.0
# 22        4138.271176     schema            9   143098.45   355121576.0
# 23        4076.222086   database            9   143797.09   358755292.0
# 24        3909.960248     schema           10   163993.79   376113028.0
# 25        3980.093555   database           10   162176.12   384300288.0
#
#     Max RAM Cached [Gb]  Max CPU  CPU Throttled  RAM/Throughput  \
# 0           155693072.0    15.94            0.0   149427.876863
# 1           110399704.0    15.30            0.0    97128.406715
# 2           110583628.0    14.96            0.0    97385.009897
# 3            77846136.0     7.96            0.0   148343.234131
# 4            77867972.0     7.96            0.0   151934.194318
# 5            77846640.0     7.95            0.0   153597.358045
# 6           229661008.0    23.47            0.0   153356.094276
# 7           184587300.0    21.15            0.0   116681.414980
# 8           171293744.0    21.21            0.0   106089.665407
# 9           204725788.0    28.90            0.0    92219.949006
# 10          213623400.0    28.80            0.0    97869.153184
# 11          279087040.0    31.34            0.0   139133.392140
# 12          238179832.0    34.59            0.0    97201.551408
# 13          251983896.0    33.70            0.0   100088.478772
# 14          382109544.0    38.93            0.0   169184.640919
# 15          305846456.0    41.60            0.0   136000.018371
# 16          282298388.0    41.59            0.0   131733.839700
# 17          446646844.0    47.86            0.0   212987.050099
# 18          340791108.0    47.72            0.0   146135.300232
# 19          332783060.0    47.36            0.0   144276.749078
# 20          341872688.0    55.73            0.0   141180.667465
# 21          339312904.0    54.60            0.0   138640.749143
# 22          377022684.0    56.53            0.0   166899.263075
# 23          381238804.0    55.97            0.0   155168.960610
# 24          398783428.0    56.61            0.0   165071.902321
# 25          404901456.0    56.05            0.0   172110.462320
#
#     CPUs/Throughput     E_CPU     E_RAM
# 0      90312.548253  0.214257  0.000036
# 1      95603.189825  0.207420  0.000057
# 2      97727.979425  0.204343  0.000057
# 3      92239.161755  0.208261  0.000036
# 4      95547.615736  0.205868  0.000036
# 5      98456.053643  0.202019  0.000036
# 6      97611.121212  0.204895  0.000036
# 7     104074.530358  0.197455  0.000049
# 8     103071.843454  0.198891  0.000054
# 9     108960.100657  0.193558  0.000064
# 10    107764.594936  0.194684  0.000060
# 11     99325.749789  0.203875  0.000040
# 12    119502.336518  0.183344  0.000063
# 13    117992.092188  0.186114  0.000061
# 14    117582.108269  0.188208  0.000036
# 15    141866.112809  0.170936  0.000050
# 16    149230.974220  0.170809  0.000054
# 17    165138.817146  0.141941  0.000031
# 18    165055.581190  0.156553  0.000049
# 19    168157.373632  0.159077  0.000052
# 20    194995.496550  0.144567  0.000055
# 21    193036.604075  0.146293  0.000057
# 22    242111.149754  0.138366  0.000056
# 23    223902.598150  0.137694  0.000055
# 24    259110.303360  0.134151  0.000058
# 25    261472.469064  0.135655  0.000057

# %%
plot_bars(merged_df, y='E_CPU', title='2nd run - $E_{CPU}$', estimator='max')

# %%
plot_bars(merged_df, y='E_RAM', title='2nd run - $E_{RAM}$', estimator='max')

# %%
import os
import zipfile

def zip_all_results():
    # Set the base directory containing the folders
    base_dir = path # "/path/to/your/folders"  # CHANGE THIS to your actual directory
    # List all folder names in the directory
    folder_names = codes
    # Create a zip for each folder
    for folder in folder_names:
        folder_path = os.path.join(base_dir, folder)
        zip_path = os.path.join(base_dir, f"{folder}.zip")
        print(f"Zipping {folder_path} to {zip_path}...")
        with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, _, files in os.walk(folder_path):
                for file in files:
                    abs_path = os.path.join(root, file)
                    rel_path = os.path.relpath(abs_path, folder_path)
                    zipf.write(abs_path, arcname=os.path.join(folder, rel_path))
    print("✅ Done zipping all folders.")

# %%
#zip_all_results()
