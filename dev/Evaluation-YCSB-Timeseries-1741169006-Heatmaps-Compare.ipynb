# %% [markdown]
# # YCSB Analysis of Grid of Parameters
# Loop over
# * several target throughputs
# * several numers of threads
# * split into 1, 8 and 16 driver pods
#
#
# ```
# nohup python ycsb.py -ms 1 -tr \
#   -sf $BEXHOMA_YCSB_SF_DATA \
#   -sfo $BEXHOMA_YCSB_SF_OPS \
#   --workload c \
#   -dbms PostgreSQL \
#   -rnn $BEXHOMA_NODE_SUT -rnl $BEXHOMA_NODE_LOAD -rnb $BEXHOMA_NODE_BENCHMARK \
#   -tb 16384 \
#   -nlp 8 \
#   -nlt 64 \
#   -nlf 12 \
#   -nbp 1,1,8,16 \
#   -nbt 80,96,112,128,144,160,176,192 \
#   -nbf 0,9,10,11,12,13,14,15,16 \
#   -ne 1 \
#   -nc 2 \
#   -m -mc \
#   -rst shared -rss 50Gi run
# ```

# %%
code = "1741169006"
#path = "D:\\data\\benchmarks"
path = "/home/perdelt/benchmarks"

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown
import seaborn as sns

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
cut_at = 0

#pod_count = 16
#experiment_run = 1
#target = 0
#threads = 128


def plot_timeseries(df_aggregated, metric, pod_count, experiment_run, target, threads, smoothing=0):
    df = df_aggregated.copy()
    if experiment_run > 0:
        df = df[df['experiment_run'] == experiment_run]
    df = df[df['target'] == target]
    df = df[df['threads'] == threads]
    df_subset = df[df['pod_count'] == pod_count]
    df_subset = df_subset[~df_subset.duplicated(subset=['threads', 'target'], keep='last')]
    client = df_subset['client'].iloc[0]
    plot_measures(metric, smoothing=smoothing, preset_experiment_run=experiment_run, preset_client=client)

def plot_measures(metric, smoothing=0, preset_experiment_run=0, preset_client=0):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        for experiment_run in list_experiment_runs:
            if preset_experiment_run > 0:
                if preset_experiment_run != experiment_run:
                    continue
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            if preset_client > 0:
                n_rows = 1
            else:
                n_rows = num_runs
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows), sharex=True)
            fig.suptitle(f"{metric}", fontsize=16)#, fontweight="bold")
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                if preset_client > 0:
                    if preset_client != client:
                        continue
                #################################
                # show plots with aggregated line
                #################################
                # filter data for this run
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]
                df_part = df_part[df_part['client'] == (client)]
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                # Weighted average: Multiply each value by its duration and sum
                weighted_sum = (df_total[metric].multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total[metric] = df_total[metric].rolling(window=smoothing, min_periods=1).mean()
                # optionally leave out data at the end (cool down)
                if cut_at > 0:
                    df_total = df_total[:-cut_at]
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                max_value = df_total[metric].max()
                #print(max_value)
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
                ###############################
                # show plots with lines per pod
                ###############################
                df_list = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                # collect in one dataframe
                df_total = pd.DataFrame()
                j=1
                max_value = 0
                for df in df_list:
                    # optionally leave out data at the end (cool down)
                    if cut_at > 0:
                        df_tmp = df[metric][:-cut_at]
                    else:
                        df_tmp = df[metric]
                    df_single = pd.DataFrame(df_tmp)
                    if max_value < df_single[metric].max():
                        max_value = df_single[metric].max()
                    df_single.columns=["pod "+str(j)]
                    df_total = pd.merge(df_total, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                #print(df_combined)
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                weighted_sum = (df_total.multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time / len(df_list)
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total = df_total.rolling(window=smoothing, min_periods=1).mean()
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True, legend=False)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            filename = f"plot_{preset_experiment_run}_{preset_client}_{metric}.png".replace("\\","").replace("/","").replace(":","")
            #df2img.save_dataframe(styled_df, filename="styled_table.png")
            plt.savefig(filename, dpi=300, bbox_inches="tight")
            plt.show()

def plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=None, vmax_value=None):
    #metric = '[OVERALL].Throughput(ops/sec)'
    #pod_count = 1
    #experiment_run = 1
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df = df.pivot(index='threads', columns='target', values=metric)
    #display(df.style.background_gradient(cmap='Blues', axis=None))
    styled_df = df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient()
    #display(df)
    # Set up the figure size
    plt.figure(figsize=(10, 4))
    # Create the heatmap
    if vmin_value is not None and vmax_value is not None:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7}, vmin=vmin_value, vmax=vmax_value)
    else:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7})
    ax.set_title(metric)
    # Save as PNG
    filename = (f"heatmap_{metric}_{pod_count}_{experiment_run}.png").replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    # Show the plot (optional)
    plt.show()


def plot_heatmap_compare(df_aggregated, metric, pod_count_1, pod_count_2, experiment_run, vmin_value=None, vmax_value=None):
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count_1]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df_1 = df.pivot(index='threads', columns='target', values=metric)
    pod_count = 8
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count_2]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df_2 = df.pivot(index='threads', columns='target', values=metric)
    df = df_2/df_1*100
    #print(df)
    #vmin_value = 0
    #vmax_value = 200
    #display(df.style.background_gradient(cmap='Blues', axis=None))
    styled_df = df.style.background_gradient(cmap='YlOrBr', axis=None).set_caption(metric)
    #df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient()
    #display(df)
    # Set up the figure size
    plt.figure(figsize=(10, 4))
    # Create the heatmap
    if vmin_value is not None and vmax_value is not None:
        ax = sns.heatmap(df, annot=True, cmap="YlOrBr", fmt=".0f", linewidths=0.5, annot_kws={"size": 7}, vmin=vmin_value, vmax=vmax_value)
    else:
        ax = sns.heatmap(df, annot=True, cmap="YlOrBr", fmt=".0f", linewidths=0.5, annot_kws={"size": 7})
    ax.set_title(f"Increasement of {metric} in %")
    # Save as PNG
    filename = (f"heatmap_increase_{metric}_{pod_count}_{experiment_run}.png").replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    # Show the plot (optional)
    plt.show()


def plot_prometheus_metric(df_aggregated, metric, component, pod_count, experiment_run):
    df_aggregated = pd.DataFrame(df_aggregated, columns=[metric])
    #print(df_aggregated)
    df_benchmarks2 = df_benchmarks.set_index('connection')
    df_benchmarks2['threads_total'] = df_benchmarks2['threads']*df_benchmarks2['pod_count']
    df = df_aggregated.join(df_benchmarks2, how='inner')
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df_heatmap)
    df = df.pivot(index='threads_total', columns='target', values=metric)
    #display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))
    df.plot.bar(title=f"{component} ({experiment_run}. run with {pod_count} pods): {metric}")
    filename = f"bar_{component}_{experiment_run}_{pod_count}_{metric}.png".replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")

# %%
evaluation = evaluators.ycsb(code=code, path=path)

# %% [markdown]
# ## Table of Data

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-196608-2-3-1  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               rmf4f.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420848.0
# [OVERALL].Throughput(ops/sec)                              22521.761652
# [TOTAL_GCS_Copy].Count                                              129
# [TOTAL_GC_TIME_Copy].Time(ms)                                       327
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.023014425188338232
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   129
# [TOTAL_GC_TIME].Time(ms)                                            327
# [TOTAL_GC_TIME_%].Time(%)                          0.023014425188338232
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    427.272783
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                           46879.0
# [READ].95thPercentileLatency(us)                                  815.0
# [READ].99thPercentileLatency(us)                                 1321.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   1062.125
# [CLEANUP].MinLatency(us)                                          114.0
# [CLEANUP].MaxLatency(us)                                         1966.0
# [CLEANUP].95thPercentileLatency(us)                              1862.0
# [CLEANUP].99thPercentileLatency(us)                              1966.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-1  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               gmr77.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420878.0
# [OVERALL].Throughput(ops/sec)                              11260.643067
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       253
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.017805891849968822
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            253
# [TOTAL_GC_TIME_%].Time(%)                          0.017805891849968822
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    456.802715
# [READ].MinLatency(us)                                             173.0
# [READ].MaxLatency(us)                                           53983.0
# [READ].95thPercentileLatency(us)                                  948.0
# [READ].99thPercentileLatency(us)                                 1614.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    241.625
# [CLEANUP].MinLatency(us)                                           84.0
# [CLEANUP].MaxLatency(us)                                         1082.0
# [CLEANUP].95thPercentileLatency(us)                              1082.0
# [CLEANUP].99thPercentileLatency(us)                              1082.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-2  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               nzwjw.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420772.0
# [OVERALL].Throughput(ops/sec)                              11261.483194
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       242
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.01703299333038658
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            242
# [TOTAL_GC_TIME_%].Time(%)                           0.01703299333038658
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    472.602887
# [READ].MinLatency(us)                                             169.0
# [READ].MaxLatency(us)                                           51583.0
# [READ].95thPercentileLatency(us)                                  970.0
# [READ].99thPercentileLatency(us)                                 1606.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    520.875
# [CLEANUP].MinLatency(us)                                           99.0
# [CLEANUP].MaxLatency(us)                                         1031.0
# [CLEANUP].95thPercentileLatency(us)                              1031.0
# [CLEANUP].99thPercentileLatency(us)                              1031.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-3  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               c4pzv.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420759.0
# [OVERALL].Throughput(ops/sec)                              11261.586237
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       269
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.018933541860371814
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            269
# [TOTAL_GC_TIME_%].Time(%)                          0.018933541860371814
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    474.576278
# [READ].MinLatency(us)                                             173.0
# [READ].MaxLatency(us)                                           46911.0
# [READ].95thPercentileLatency(us)                                  969.0
# [READ].99thPercentileLatency(us)                                 1585.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    366.375
# [CLEANUP].MinLatency(us)                                          106.0
# [CLEANUP].MaxLatency(us)                                         1414.0
# [CLEANUP].95thPercentileLatency(us)                              1414.0
# [CLEANUP].99thPercentileLatency(us)                              1414.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-1  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               l8vl9.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420768.0
# [OVERALL].Throughput(ops/sec)                              22523.029798
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       294
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02069303362688349
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            294
# [TOTAL_GC_TIME_%].Time(%)                           0.02069303362688349
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    462.006685
# [READ].MinLatency(us)                                             171.0
# [READ].MaxLatency(us)                                           40735.0
# [READ].95thPercentileLatency(us)                                  883.0
# [READ].99thPercentileLatency(us)                                 1457.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   716.4375
# [CLEANUP].MinLatency(us)                                           81.0
# [CLEANUP].MaxLatency(us)                                         1882.0
# [CLEANUP].95thPercentileLatency(us)                              1855.0
# [CLEANUP].99thPercentileLatency(us)                              1882.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-4  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               x548w.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420779.0
# [OVERALL].Throughput(ops/sec)                               11261.42771
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       290
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.020411337723882463
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            290
# [TOTAL_GC_TIME_%].Time(%)                          0.020411337723882463
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    443.640315
# [READ].MinLatency(us)                                             172.0
# [READ].MaxLatency(us)                                           54623.0
# [READ].95thPercentileLatency(us)                                  876.0
# [READ].99thPercentileLatency(us)                                 1465.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                      443.5
# [CLEANUP].MinLatency(us)                                           89.0
# [CLEANUP].MaxLatency(us)                                         2769.0
# [CLEANUP].95thPercentileLatency(us)                              2769.0
# [CLEANUP].99thPercentileLatency(us)                              2769.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-3-2  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               z7752.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420713.0
# [OVERALL].Throughput(ops/sec)                              22523.901731
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       351
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02470590471122598
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            351
# [TOTAL_GC_TIME_%].Time(%)                           0.02470590471122598
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    433.651465
# [READ].MinLatency(us)                                             166.0
# [READ].MaxLatency(us)                                           48191.0
# [READ].95thPercentileLatency(us)                                  854.0
# [READ].99thPercentileLatency(us)                                 1374.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   1312.375
# [CLEANUP].MinLatency(us)                                           93.0
# [CLEANUP].MaxLatency(us)                                         1979.0
# [CLEANUP].95thPercentileLatency(us)                              1958.0
# [CLEANUP].99thPercentileLatency(us)                              1979.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-1  \
# connection                                   PostgreSQL-64-8-196608-1-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                4
# pod                                               pmjhm.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420940.0
# [OVERALL].Throughput(ops/sec)                              11260.151731
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       205
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.01442706940476023
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            205
# [TOTAL_GC_TIME_%].Time(%)                           0.01442706940476023
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    472.284618
# [READ].MinLatency(us)                                             176.0
# [READ].MaxLatency(us)                                           46047.0
# [READ].95thPercentileLatency(us)                                  894.0
# [READ].99thPercentileLatency(us)                                 1423.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    410.125
# [CLEANUP].MinLatency(us)                                           86.0
# [CLEANUP].MaxLatency(us)                                         1155.0
# [CLEANUP].95thPercentileLatency(us)                              1155.0
# [CLEANUP].99thPercentileLatency(us)                              1155.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-3-3  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               zgvkn.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420717.0
# [OVERALL].Throughput(ops/sec)                              22523.838315
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       333
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.023438869247006968
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            333
# [TOTAL_GC_TIME_%].Time(%)                          0.023438869247006968
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    434.195072
# [READ].MinLatency(us)                                             168.0
# [READ].MaxLatency(us)                                           49631.0
# [READ].95thPercentileLatency(us)                                  877.0
# [READ].99thPercentileLatency(us)                                 1428.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   596.3125
# [CLEANUP].MinLatency(us)                                           77.0
# [CLEANUP].MaxLatency(us)                                         1217.0
# [CLEANUP].95thPercentileLatency(us)                              1207.0
# [CLEANUP].99thPercentileLatency(us)                              1217.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-2  ...  \
# connection                                   PostgreSQL-64-8-196608-1-3  ...
# configuration                                    PostgreSQL-64-8-196608  ...
# experiment_run                                                        1  ...
# client                                                                3  ...
# pod                                               xzhk7.dbmsbenchmarker  ...
# pod_count                                                             8  ...
# threads                                                              16  ...
# target                                                            22528  ...
# sf                                                                   16  ...
# workload                                                              c  ...
# operations                                                     32000000  ...
# batchsize                                                            -1  ...
# exceptions                                                            0  ...
# [OVERALL].RunTime(ms)                                         1420701.0  ...
# [OVERALL].Throughput(ops/sec)                               22524.09198  ...
# [TOTAL_GCS_Copy].Count                                              130  ...
# [TOTAL_GC_TIME_Copy].Time(ms)                                       323  ...
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.022735255342257097  ...
# [TOTAL_GCS_MarkSweepCompact].Count                                    0  ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0  ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0  ...
# [TOTAL_GCs].Count                                                   130  ...
# [TOTAL_GC_TIME].Time(ms)                                            323  ...
# [TOTAL_GC_TIME_%].Time(%)                          0.022735255342257097  ...
# [READ].Operations                                              32000000  ...
# [READ].AverageLatency(us)                                    466.018895  ...
# [READ].MinLatency(us)                                             170.0  ...
# [READ].MaxLatency(us)                                           34047.0  ...
# [READ].95thPercentileLatency(us)                                  886.0  ...
# [READ].99thPercentileLatency(us)                                 1426.0  ...
# [READ].Return=OK                                               32000000  ...
# [CLEANUP].Operations                                                 16  ...
# [CLEANUP].AverageLatency(us)                                     1093.0  ...
# [CLEANUP].MinLatency(us)                                           89.0  ...
# [CLEANUP].MaxLatency(us)                                         2757.0  ...
# [CLEANUP].95thPercentileLatency(us)                              1706.0  ...
# [CLEANUP].99thPercentileLatency(us)                              2757.0  ...
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-16  \
# connection                                    PostgreSQL-64-8-196608-1-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         1
# client                                                                 4
# pod                                                lkrq7.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420765.0
# [OVERALL].Throughput(ops/sec)                               11261.538678
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        229
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.016118077233039946
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             229
# [TOTAL_GC_TIME_%].Time(%)                           0.016118077233039946
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     475.294614
# [READ].MinLatency(us)                                              176.0
# [READ].MaxLatency(us)                                            49343.0
# [READ].95thPercentileLatency(us)                                   908.0
# [READ].99thPercentileLatency(us)                                  1484.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                      841.75
# [CLEANUP].MinLatency(us)                                           131.0
# [CLEANUP].MaxLatency(us)                                          1730.0
# [CLEANUP].95thPercentileLatency(us)                               1730.0
# [CLEANUP].99thPercentileLatency(us)                               1730.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-14  \
# connection                                    PostgreSQL-64-8-196608-2-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                 4
# pod                                                mnhg8.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420796.0
# [OVERALL].Throughput(ops/sec)                               11261.292965
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        251
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.01766615333939566
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             251
# [TOTAL_GC_TIME_%].Time(%)                            0.01766615333939566
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     477.364588
# [READ].MinLatency(us)                                              171.0
# [READ].MaxLatency(us)                                            41983.0
# [READ].95thPercentileLatency(us)                                   878.0
# [READ].99thPercentileLatency(us)                                  1374.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                       209.5
# [CLEANUP].MinLatency(us)                                            88.0
# [CLEANUP].MaxLatency(us)                                           942.0
# [CLEANUP].95thPercentileLatency(us)                                942.0
# [CLEANUP].99thPercentileLatency(us)                                942.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-15  \
# connection                                    PostgreSQL-64-8-196608-2-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                 4
# pod                                                8lp7m.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420713.0
# [OVERALL].Throughput(ops/sec)                               11261.950866
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        233
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.016400215947907845
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             233
# [TOTAL_GC_TIME_%].Time(%)                           0.016400215947907845
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     474.931565
# [READ].MinLatency(us)                                              169.0
# [READ].MaxLatency(us)                                            32991.0
# [READ].95thPercentileLatency(us)                                   896.0
# [READ].99thPercentileLatency(us)                                  1448.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                     824.625
# [CLEANUP].MinLatency(us)                                            97.0
# [CLEANUP].MaxLatency(us)                                          2707.0
# [CLEANUP].95thPercentileLatency(us)                               2707.0
# [CLEANUP].99thPercentileLatency(us)                               2707.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-3-7  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               pgntf.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420714.0
# [OVERALL].Throughput(ops/sec)                              22523.885877
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       319
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02245349873373529
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            319
# [TOTAL_GC_TIME_%].Time(%)                           0.02245349873373529
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    436.997711
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                           46847.0
# [READ].95thPercentileLatency(us)                                  879.0
# [READ].99thPercentileLatency(us)                                 1445.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                    981.125
# [CLEANUP].MinLatency(us)                                          121.0
# [CLEANUP].MaxLatency(us)                                         1595.0
# [CLEANUP].95thPercentileLatency(us)                              1527.0
# [CLEANUP].99thPercentileLatency(us)                              1595.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-3-8  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               tnndr.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420769.0
# [OVERALL].Throughput(ops/sec)                              22523.013945
# [TOTAL_GCS_Copy].Count                                              129
# [TOTAL_GC_TIME_Copy].Time(ms)                                       319
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.0224526295266859
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   129
# [TOTAL_GC_TIME].Time(ms)                                            319
# [TOTAL_GC_TIME_%].Time(%)                            0.0224526295266859
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    434.831379
# [READ].MinLatency(us)                                             169.0
# [READ].MaxLatency(us)                                           46975.0
# [READ].95thPercentileLatency(us)                                  845.0
# [READ].99thPercentileLatency(us)                                 1368.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   292.5625
# [CLEANUP].MinLatency(us)                                           84.0
# [CLEANUP].MaxLatency(us)                                         1070.0
# [CLEANUP].95thPercentileLatency(us)                               981.0
# [CLEANUP].99thPercentileLatency(us)                              1070.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-7  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               8drp6.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420779.0
# [OVERALL].Throughput(ops/sec)                              22522.855419
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       305
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.021467096571669484
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            305
# [TOTAL_GC_TIME_%].Time(%)                          0.021467096571669484
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                     470.85955
# [READ].MinLatency(us)                                             172.0
# [READ].MaxLatency(us)                                           50719.0
# [READ].95thPercentileLatency(us)                                  885.0
# [READ].99thPercentileLatency(us)                                 1405.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   717.8125
# [CLEANUP].MinLatency(us)                                           92.0
# [CLEANUP].MaxLatency(us)                                         1527.0
# [CLEANUP].95thPercentileLatency(us)                              1222.0
# [CLEANUP].99thPercentileLatency(us)                              1527.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-8  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               fnw9r.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420720.0
# [OVERALL].Throughput(ops/sec)                              22523.790754
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       318
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.022383017061771496
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            318
# [TOTAL_GC_TIME_%].Time(%)                          0.022383017061771496
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    441.425033
# [READ].MinLatency(us)                                             163.0
# [READ].MaxLatency(us)                                           38079.0
# [READ].95thPercentileLatency(us)                                  837.0
# [READ].99thPercentileLatency(us)                                 1295.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                  1321.8125
# [CLEANUP].MinLatency(us)                                          393.0
# [CLEANUP].MaxLatency(us)                                         2101.0
# [CLEANUP].95thPercentileLatency(us)                              1870.0
# [CLEANUP].99thPercentileLatency(us)                              2101.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-2-1  \
# connection                                   PostgreSQL-64-8-196608-1-2
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                2
# pod                                               fw2w2.dbmsbenchmarker
# pod_count                                                             1
# threads                                                             128
# target                                                           180224
# sf                                                                   16
# workload                                                              c
# operations                                                    256000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1490067.0
# [OVERALL].Throughput(ops/sec)                             171804.355106
# [TOTAL_GCS_Copy].Count                                             1045
# [TOTAL_GC_TIME_Copy].Time(ms)                                      3074
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.20629944827984242
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                  1045
# [TOTAL_GC_TIME].Time(ms)                                           3074
# [TOTAL_GC_TIME_%].Time(%)                           0.20629944827984242
# [READ].Operations                                             256000000
# [READ].AverageLatency(us)                                    456.838056
# [READ].MinLatency(us)                                             156.0
# [READ].MaxLatency(us)                                          208255.0
# [READ].95thPercentileLatency(us)                                  864.0
# [READ].99thPercentileLatency(us)                                 1015.0
# [READ].Return=OK                                              256000000
# [CLEANUP].Operations                                                128
# [CLEANUP].AverageLatency(us)                                 349.015625
# [CLEANUP].MinLatency(us)                                           69.0
# [CLEANUP].MaxLatency(us)                                         3301.0
# [CLEANUP].95thPercentileLatency(us)                              1564.0
# [CLEANUP].99thPercentileLatency(us)                              2655.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-2-1  \
# connection                                   PostgreSQL-64-8-196608-2-2
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                2
# pod                                               tsf75.dbmsbenchmarker
# pod_count                                                             1
# threads                                                             128
# target                                                           180224
# sf                                                                   16
# workload                                                              c
# operations                                                    256000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420980.0
# [OVERALL].Throughput(ops/sec)                             180157.356191
# [TOTAL_GCS_Copy].Count                                             1055
# [TOTAL_GC_TIME_Copy].Time(ms)                                      1658
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.11668003772044644
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                  1055
# [TOTAL_GC_TIME].Time(ms)                                           1658
# [TOTAL_GC_TIME_%].Time(%)                           0.11668003772044644
# [READ].Operations                                             256000000
# [READ].AverageLatency(us)                                    345.596582
# [READ].MinLatency(us)                                             157.0
# [READ].MaxLatency(us)                                          105215.0
# [READ].95thPercentileLatency(us)                                  690.0
# [READ].99thPercentileLatency(us)                                  925.0
# [READ].Return=OK                                              256000000
# [CLEANUP].Operations                                                128
# [CLEANUP].AverageLatency(us)                                 507.039062
# [CLEANUP].MinLatency(us)                                           66.0
# [CLEANUP].MaxLatency(us)                                         7331.0
# [CLEANUP].95thPercentileLatency(us)                              2189.0
# [CLEANUP].99thPercentileLatency(us)                              6519.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-16
# connection                                    PostgreSQL-64-8-196608-2-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                 4
# pod                                                ltj8l.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420762.0
# [OVERALL].Throughput(ops/sec)                               11261.562457
# [TOTAL_GCS_Copy].Count                                                64
# [TOTAL_GC_TIME_Copy].Time(ms)                                        237
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.016681189389918933
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     64
# [TOTAL_GC_TIME].Time(ms)                                             237
# [TOTAL_GC_TIME_%].Time(%)                           0.016681189389918933
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     467.285048
# [READ].MinLatency(us)                                              163.0
# [READ].MaxLatency(us)                                            43519.0
# [READ].95thPercentileLatency(us)                                   938.0
# [READ].99thPercentileLatency(us)                                  1580.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                     354.875
# [CLEANUP].MinLatency(us)                                            84.0
# [CLEANUP].MaxLatency(us)                                          1424.0
# [CLEANUP].95thPercentileLatency(us)                               1424.0
# [CLEANUP].99thPercentileLatency(us)                               1424.0
#
# [37 rows x 52 columns]

# %% [markdown]
# ## Heatmaps of Macro Values

# %%
df_aggregated = evaluation.benchmarking_aggregate_by_parallel_pods(df_benchmarks)
experiment_run = 2

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 1
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
#metric = '[OVERALL].Throughput(ops/sec)'
#metric = '[READ].AverageLatency(us)'
#metric = '[READ].MaxLatency(us)'
#metric = '[READ].MinLatency(us)'
metric = '[READ].99thPercentileLatency(us)'
pod_count_1 = 1
pod_count_2 = 8
experiment_run = 2
vmin_value = 0
vmax_value = 200
plot_heatmap_compare(df_aggregated, metric, pod_count_1, pod_count_2, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 8
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 16
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %% [markdown]
# ## Line Plots of Micro Data

# %%
metric = 'current_ops_per_sec'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
#metric = 'current_ops_per_sec'
#plot_measures(metric, smoothing=0, preset_client=10)
#plot_measures(metric, smoothing=0, preset_client=11)
#plot_measures(metric, smoothing=0, preset_client=12)

# %%
metric = 'READ_Avg'
experiment_run = 2
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_99'
experiment_run = 2
target = 147456
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_Max'
experiment_run = 2
target = 147456
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_Min'
experiment_run = 2
target = 147456
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
#metric = 'UPDATE_99.9'
#plot_measures(metric, smoothing=0, preset_client=3)
#plot_measures(metric, smoothing=0, preset_client=4)

# %% [markdown]
# ## Bar Plots of Hardware Metrics

# %%
evaluation.transform_monitoring_results(component='stream')

evaluation.get_monitoring_metrics()
# Out:
# ['total_cpu_memory',
#  'total_cpu_memory_cached',
#  'total_cpu_util',
#  'total_cpu_util_max',
#  'total_cpu_throttled',
#  'total_cpu_util_others',
#  'total_cpu_util_s',
#  'total_cpu_util_user_s',
#  'total_cpu_util_sys_s',
#  'total_cpu_throttled_s',
#  'total_cpu_util_others_s',
#  'total_network_rx',
#  'total_network_tx',
#  'total_fs_read',
#  'total_fs_write',
#  'total_gpu_util',
#  'total_gpu_power',
#  'total_gpu_memory']

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)
