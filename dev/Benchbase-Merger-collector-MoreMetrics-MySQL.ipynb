# %% [markdown]
# # TPC-C MySQL 17.5 - Application Metrics
#
# * data is generated and loaded into databases in a distributed filesystem
# * experiments do not use preloaded data

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np

from bexhoma import collectors

# %matplotlib inline

# %% [markdown]
# # Collect Results

# %%
path = r"C:\data\benchmarks"
#path = r"/home/perdelt/benchmarks"

# %%
codes = [
    "1757496209"
]

codes
# Out:
# ['1757496209']

# %%
collect = collectors.benchbase(path, codes)

# %% [markdown]
# # Get all Metrics Metadata

# %%
code = codes[0]
evaluate = collect.get_evaluator(code)
collect.df_metrics = collect.get_metrics(evaluate)

collect.df_metrics
# Out:
#                                                        title active  \
# total_cpu_memory                          Memory Usage [MiB]   True
# total_cpu_memory_cached            Memory Usage Cached [MiB]   True
# total_cpu_util                               CPU Utilization   True
# total_cpu_throttled                             CPU Throttle   True
# total_cpu_throttled_s                 CPU Throttled Time [s]   True
# total_cpu_util_others                 CPU Utilization Others  False
# total_cpu_util_s                    CPU Utilization Time [s]   True
# total_cpu_util_user_s                      CPU User Time [s]   True
# total_cpu_util_sys_s                     CPU System Time [s]   True
# total_cpu_util_others_s      CPU Utilization Time Others [s]  False
# total_network_rx                      Network Rx Total [MiB]   True
# total_network_tx                      Network Tx Total [MiB]   True
# total_fs_read                    Filesystem Read Total [MiB]   True
# total_fs_write                  Filesystem Write Total [MiB]   True
# total_gpu_util                           GPU Utilization [%]  False
# total_gpu_power                          GPU Power Usage [W]  False
# total_gpu_memory                      GPU Memory Usage [MiB]  False
# core_variance                  Core Utilization Variance [%]   True
# max_core_util                       Max Core Utilization [%]   True
# io_wait_pct                                     I/O Wait [%]   True
# io_wait_total                        Total I/O Wait Time [s]   True
# mysql_buffer_pool_hit_ratio     InnoDB Buffer Pool Hit Ratio   True
# mysql_queries_per_second            Queries Per Second (QPS)   True
# mysql_connections_usage               Connection Usage Ratio   True
# mysql_slow_queries                         Slow Queries Rate   True
# mysql_innodb_log_waits                 InnoDB Log Waits Rate   True
# mysql_threads_running                        Threads Running   True
# mysql_handler_rollback_rate         Rollback Operations Rate   True
# mysql_table_locks_waited               Table Lock Waits Rate   True
# mysql_tmp_disk_tables             Temporary Disk Tables Rate   True
# mysql_open_files_ratio                Open Files Usage Ratio   True
#
#                                     type   metric
# total_cpu_memory                 cluster    gauge
# total_cpu_memory_cached          cluster    gauge
# total_cpu_util                   cluster    gauge
# total_cpu_throttled              cluster    gauge
# total_cpu_throttled_s            cluster  counter
# total_cpu_util_others            cluster    gauge
# total_cpu_util_s                 cluster  counter
# total_cpu_util_user_s            cluster  counter
# total_cpu_util_sys_s             cluster  counter
# total_cpu_util_others_s          cluster  counter
# total_network_rx                 cluster  counter
# total_network_tx                 cluster  counter
# total_fs_read                    cluster  counter
# total_fs_write                   cluster  counter
# total_gpu_util                   cluster    gauge
# total_gpu_power                  cluster    gauge
# total_gpu_memory                 cluster    gauge
# core_variance                    cluster    ratio
# max_core_util                    cluster    ratio
# io_wait_pct                      cluster    ratio
# io_wait_total                    cluster  counter
# mysql_buffer_pool_hit_ratio  application    gauge
# mysql_queries_per_second     application    gauge
# mysql_connections_usage      application    gauge
# mysql_slow_queries           application  counter
# mysql_innodb_log_waits       application  counter
# mysql_threads_running        application    gauge
# mysql_handler_rollback_rate  application  counter
# mysql_table_locks_waited     application  counter
# mysql_tmp_disk_tables        application  counter
# mysql_open_files_ratio       application    gauge

# %% [markdown]
# # Get Values Aggregated per SUT and per Experiment

# %%
df_performance = collect.get_monitoring_all(type="stream")
df_performance.T
# Out:
#                                         0           1
# client                                  1           2
# Memory Usage [MiB]                6395.93     6845.26
# Memory Usage Cached [MiB]        11232.61    14630.25
# CPU Utilization                      7.42        9.54
# CPU Throttle                          0.0         0.0
# CPU Throttled Time [s]                0.0         0.0
# CPU Utilization Time [s]          2832.33     3015.87
# CPU User Time [s]                 1930.53     2051.38
# CPU System Time [s]                 901.8      964.49
# Network Rx Total [MiB]            4378.91     3096.74
# Network Tx Total [MiB]            3310.58      3764.0
# Filesystem Read Total [MiB]          0.05        0.02
# Filesystem Write Total [MiB]       3910.0      3763.0
# Core Utilization Variance [%]        7.64       10.93
# Max Core Utilization [%]            24.28       40.43
# I/O Wait [%]                        64.22       59.72
# Total I/O Wait Time [s]            4233.5     4348.52
# InnoDB Buffer Pool Hit Ratio          1.0         0.0
# Queries Per Second (QPS)          15041.4    23743.96
# Connection Usage Ratio                0.1         0.1
# Slow Queries Rate                    0.06         0.0
# InnoDB Log Waits Rate                 0.0         0.0
# Threads Running                    144.38      141.85
# Rollback Operations Rate              0.0         0.0
# Table Lock Waits Rate                 0.0         0.0
# Temporary Disk Tables Rate            0.0         0.0
# Open Files Usage Ratio                0.0         0.0
# type
# num_tenants                             0           0
# code                           1757496209  1757496209

# %% [markdown]
# # Barplot of All Metrics for a Single Experiment

# %%
results = []
code = codes[0]
for idx, row in collect.df_metrics.iterrows():
    if row["active"] == False:
        continue
    #print(idx, row["title"])
    metric_name = idx
    method = 'diff' if row["metric"] == 'counter' else 'mean'
    col_name = row["title"]
    #df_monitoring = collect.get_monitoring_single(code, metric=metric_name)
    #print(df_monitoring)
    #plot_boxplots(df_monitoring, y=metric_name, title=col_name)
    ax = df_performance[col_name].plot.bar()
    ax.set_title(col_name)
    plt.show()
    #plot_boxplots(df_performance_first, y='value', title=collect.df_metrics.loc[metric]['title'])

# %% [markdown]
# # Boxplot of All Metrics for a Single Experiment

# %%
results = []
code = codes[0]
for idx, row in collect.df_metrics.iterrows():
    if row["active"] == False:
        continue
    #print(idx, row["title"])
    metric_name = idx
    method = 'diff' if row["metric"] == 'counter' else 'mean'
    col_name = row["title"]
    df_monitoring = collect.get_monitoring_timeseries_single(code, metric=metric_name)
    #print(df_monitoring)
    #plot_boxplots(df_monitoring, y=metric_name, title=col_name)
    ax = df_monitoring.boxplot()
    ax.set_title(col_name)
    plt.show()
    #plot_boxplots(df_performance_first, y='value', title=collect.df_metrics.loc[metric]['title'])

# %% [markdown]
# # Boxplot of A Single Metric for a Single Experiment

# %%
metric = 'mysql_buffer_pool_hit_ratio'
#metric = 'pg_stat_database_blks_reads'
#metric = 'pg_stat_activity_count_idle_transaction'
#metric = 'total_cpu_memory'
code = codes[0]
df_monitoring = collect.get_monitoring_timeseries_single(code, metric=metric)

#df_monitoring.plot(title=metric)
#df_monitoring.boxplot()
ax = df_monitoring.boxplot()
ax.set_title(collect.df_metrics.loc[metric]['title'])#metric)
plt.show()

# %% [markdown]
# # Lineplot of a Single Metric for a Single Experiment

# %%
metric = 'pg_stat_database_blks_hit'
metric = 'pg_stat_activity_count_idle_transaction'
metric = 'total_cpu_memory'
metric = 'total_cpu_util'
metric = 'total_cpu_util_s'
metric = 'mysql_buffer_pool_hit_ratio'

code = codes[0]
df_monitoring = collect.get_monitoring_timeseries_single(code, metric=metric)

#df_monitoring.plot(title=metric)
ax = df_monitoring.plot()
ax.set_title(metric)
plt.show()
#df_monitoring

# %% [markdown]
# # Performance Metrics

# %%
df_performance = collect.get_performance_all()
df_performance.plot.bar()
# Out:
# <Axes: >
