# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
cut_at = 0
def plot_measures(metric, smoothing=0, preset_experiment_run=0, preset_client=0):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        for experiment_run in list_experiment_runs:
            if preset_experiment_run > 0:
                if preset_experiment_run != experiment_run:
                    continue
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            if preset_client > 0:
                n_rows = 1
            else:
                n_rows = num_runs
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows), sharex=True)
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                if preset_client > 0:
                    if preset_client != client:
                        continue
                #################################
                # show plots with aggregated line
                #################################
                # filter data for this run
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]
                df_part = df_part[df_part['client'] == (client)]
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                # Weighted average: Multiply each value by its duration and sum
                weighted_sum = (df_total[metric].multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total[metric] = df_total[metric].rolling(window=smoothing, min_periods=1).mean()
                # optionally leave out data at the end (cool down)
                if cut_at > 0:
                    df_total = df_total[:-cut_at]
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                max_value = df_total[metric].max()
                print(max_value)
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
                ###############################
                # show plots with lines per pod
                ###############################
                df_list = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                # collect in one dataframe
                df_total = pd.DataFrame()
                j=1
                max_value = 0
                for df in df_list:
                    # optionally leave out data at the end (cool down)
                    if cut_at > 0:
                        df_tmp = df[metric][:-cut_at]
                    else:
                        df_tmp = df[metric]
                    df_single = pd.DataFrame(df_tmp)
                    if max_value < df_single[metric].max():
                        max_value = df_single[metric].max()
                    df_single.columns=["pod "+str(j)]
                    df_total = pd.merge(df_total, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                #print(df_combined)
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                weighted_sum = (df_total.multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time / len(df_list)
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total = df_total.rolling(window=smoothing, min_periods=1).mean()
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True, legend=False)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            plt.show()

def plot_heatmap(df_aggregated, metric, pod_count, experiment_run):
    #metric = '[OVERALL].Throughput(ops/sec)'
    #pod_count = 1
    #experiment_run = 1
    df_heatmap = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df_heatmap = df_heatmap[df_heatmap['pod_count'] == pod_count]
    df_heatmap = df_heatmap[df_heatmap['experiment_run'] == experiment_run]
    #print(df_heatmap)
    df_heatmap = df_heatmap.pivot(index='threads', columns='target', values=metric)
    display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))


def plot_prometheus_metric(df_aggregated, metric, component, pod_count, experiment_run):
    df_aggregated = pd.DataFrame(df_aggregated, columns=[metric])
    #print(df_aggregated)
    df_benchmarks2 = df_benchmarks.set_index('connection')
    df_benchmarks2['threads_total'] = df_benchmarks2['threads']*df_benchmarks2['pod_count']
    df = df_aggregated.join(df_benchmarks2, how='inner')
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='first')]
    #print(df_heatmap)
    df = df.pivot(index='threads_total', columns='target', values=metric)
    #display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))
    df.plot.bar(title=f"{component} ({experiment_run}. run with {pod_count} pods): {metric}")

# %%
code = "1738060417"
#path = "D:\\data\\benchmarks-250126"
path = "/home/perdelt/benchmarks"
evaluation = evaluators.ycsb(code=code, path=path)

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-196608-12-1  \
# connection                                   PostgreSQL-64-8-196608-12
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              12
# pod                                            12d95xt.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              7
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2422149.0
# [OVERALL].Throughput(ops/sec)                             13211.408547
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      344
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.014202264187710995
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           344
# [TOTAL_GC_TIME_%].Time(%)                         0.014202264187710995
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   500.302474
# [READ].MinLatency(us)                                            164.0
# [READ].MaxLatency(us)                                          47583.0
# [READ].95thPercentileLatency(us)                                 931.0
# [READ].99thPercentileLatency(us)                                1451.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 7
# [CLEANUP].AverageLatency(us)                                451.857143
# [CLEANUP].MinLatency(us)                                         152.0
# [CLEANUP].MaxLatency(us)                                         893.0
# [CLEANUP].95thPercentileLatency(us)                              893.0
# [CLEANUP].99thPercentileLatency(us)                              893.0
#
# connection_pod                             PostgreSQL-64-8-196608-12-2  \
# connection                                   PostgreSQL-64-8-196608-12
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              12
# pod                                            12p7hvg.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              7
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2635080.0
# [OVERALL].Throughput(ops/sec)                              12143.84383
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      350
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.013282329189246626
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           350
# [TOTAL_GC_TIME_%].Time(%)                         0.013282329189246626
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   518.952631
# [READ].MinLatency(us)                                            159.0
# [READ].MaxLatency(us)                                          47359.0
# [READ].95thPercentileLatency(us)                                 992.0
# [READ].99thPercentileLatency(us)                                1542.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 7
# [CLEANUP].AverageLatency(us)                                506.714286
# [CLEANUP].MinLatency(us)                                         157.0
# [CLEANUP].MaxLatency(us)                                        1231.0
# [CLEANUP].95thPercentileLatency(us)                             1231.0
# [CLEANUP].99thPercentileLatency(us)                             1231.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-1  \
# connection                                   PostgreSQL-64-8-196608-2
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              2
# pod                                             7fqzw.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            12
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2826931.0
# [OVERALL].Throughput(ops/sec)                             22639.39233
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     538
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.01903123917775142
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          538
# [TOTAL_GC_TIME_%].Time(%)                         0.01903123917775142
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  458.893937
# [READ].MinLatency(us)                                           163.0
# [READ].MaxLatency(us)                                         44703.0
# [READ].95thPercentileLatency(us)                                872.0
# [READ].99thPercentileLatency(us)                               1272.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               12
# [CLEANUP].AverageLatency(us)                               340.916667
# [CLEANUP].MinLatency(us)                                        151.0
# [CLEANUP].MaxLatency(us)                                        945.0
# [CLEANUP].95thPercentileLatency(us)                             579.0
# [CLEANUP].99thPercentileLatency(us)                             945.0
#
# connection_pod                             PostgreSQL-64-8-196608-3-1  \
# connection                                   PostgreSQL-64-8-196608-3
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              3
# pod                                             vpljc.dbmsbenchmarker
# pod_count                                                          16
# threads                                                             6
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   32000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2818528.0
# [OVERALL].Throughput(ops/sec)                            11353.444067
# [TOTAL_GCS_Copy].Count                                            130
# [TOTAL_GC_TIME_Copy].Time(ms)                                     381
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.013517694342578821
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 130
# [TOTAL_GC_TIME].Time(ms)                                          381
# [TOTAL_GC_TIME_%].Time(%)                        0.013517694342578821
# [READ].Operations                                            32000000
# [READ].AverageLatency(us)                                  480.421495
# [READ].MinLatency(us)                                           162.0
# [READ].MaxLatency(us)                                         38175.0
# [READ].95thPercentileLatency(us)                                785.0
# [READ].99thPercentileLatency(us)                               1009.0
# [READ].Return=OK                                             32000000
# [CLEANUP].Operations                                                6
# [CLEANUP].AverageLatency(us)                               529.333333
# [CLEANUP].MinLatency(us)                                        261.0
# [CLEANUP].MaxLatency(us)                                        984.0
# [CLEANUP].95thPercentileLatency(us)                             984.0
# [CLEANUP].99thPercentileLatency(us)                             984.0
#
# connection_pod                             PostgreSQL-64-8-196608-15-1  \
# connection                                   PostgreSQL-64-8-196608-15
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              15
# pod                                            15bx6m9.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              8
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2654376.0
# [OVERALL].Throughput(ops/sec)                             12055.564095
# [TOTAL_GCS_Copy].Count                                             128
# [TOTAL_GC_TIME_Copy].Time(ms)                                      242
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.0091170203467783
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  128
# [TOTAL_GC_TIME].Time(ms)                                           242
# [TOTAL_GC_TIME_%].Time(%)                           0.0091170203467783
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   531.110888
# [READ].MinLatency(us)                                            154.0
# [READ].MaxLatency(us)                                          54239.0
# [READ].95thPercentileLatency(us)                                1001.0
# [READ].99thPercentileLatency(us)                                1446.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                    532.25
# [CLEANUP].MinLatency(us)                                         122.0
# [CLEANUP].MaxLatency(us)                                        2153.0
# [CLEANUP].95thPercentileLatency(us)                             2153.0
# [CLEANUP].99thPercentileLatency(us)                             2153.0
#
# connection_pod                             PostgreSQL-64-8-196608-7-1  \
# connection                                   PostgreSQL-64-8-196608-7
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              7
# pod                                             tqh84.dbmsbenchmarker
# pod_count                                                           1
# threads                                                           112
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                  512000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2750202.0
# [OVERALL].Throughput(ops/sec)                           186168.143285
# [TOTAL_GCS_Copy].Count                                           2110
# [TOTAL_GC_TIME_Copy].Time(ms)                                    3426
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.1245726677531323
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                2110
# [TOTAL_GC_TIME].Time(ms)                                         3426
# [TOTAL_GC_TIME_%].Time(%)                          0.1245726677531323
# [READ].Operations                                           512000000
# [READ].AverageLatency(us)                                  511.591911
# [READ].MinLatency(us)                                           163.0
# [READ].MaxLatency(us)                                         89151.0
# [READ].95thPercentileLatency(us)                                967.0
# [READ].99thPercentileLatency(us)                               1269.0
# [READ].Return=OK                                            512000000
# [CLEANUP].Operations                                              112
# [CLEANUP].AverageLatency(us)                                 265.0625
# [CLEANUP].MinLatency(us)                                        109.0
# [CLEANUP].MaxLatency(us)                                       1360.0
# [CLEANUP].95thPercentileLatency(us)                             575.0
# [CLEANUP].99thPercentileLatency(us)                             840.0
#
# connection_pod                             PostgreSQL-64-8-196608-18-1  \
# connection                                   PostgreSQL-64-8-196608-18
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              18
# pod                                            18t6bll.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              8
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2595417.0
# [OVERALL].Throughput(ops/sec)                             12329.425291
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      340
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.013100014371486354
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           340
# [TOTAL_GC_TIME_%].Time(%)                         0.013100014371486354
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   592.202307
# [READ].MinLatency(us)                                            164.0
# [READ].MaxLatency(us)                                          47807.0
# [READ].95thPercentileLatency(us)                                1093.0
# [READ].99thPercentileLatency(us)                                1446.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                   410.875
# [CLEANUP].MinLatency(us)                                         144.0
# [CLEANUP].MaxLatency(us)                                         856.0
# [CLEANUP].95thPercentileLatency(us)                              856.0
# [CLEANUP].99thPercentileLatency(us)                              856.0
#
# connection_pod                             PostgreSQL-64-8-196608-5-1  \
# connection                                   PostgreSQL-64-8-196608-5
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              5
# pod                                             jh4w7.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            13
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2897009.0
# [OVERALL].Throughput(ops/sec)                            22091.750492
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     483
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.016672367949150314
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          483
# [TOTAL_GC_TIME_%].Time(%)                        0.016672367949150314
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  508.299585
# [READ].MinLatency(us)                                           154.0
# [READ].MaxLatency(us)                                         34271.0
# [READ].95thPercentileLatency(us)                                968.0
# [READ].99thPercentileLatency(us)                               1340.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               13
# [CLEANUP].AverageLatency(us)                               410.615385
# [CLEANUP].MinLatency(us)                                        138.0
# [CLEANUP].MaxLatency(us)                                       1971.0
# [CLEANUP].95thPercentileLatency(us)                             540.0
# [CLEANUP].99thPercentileLatency(us)                            1971.0
#
# connection_pod                             PostgreSQL-64-8-196608-3-2  \
# connection                                   PostgreSQL-64-8-196608-3
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              3
# pod                                             bx9fp.dbmsbenchmarker
# pod_count                                                          16
# threads                                                             6
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   32000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2879454.0
# [OVERALL].Throughput(ops/sec)                            11113.217992
# [TOTAL_GCS_Copy].Count                                            130
# [TOTAL_GC_TIME_Copy].Time(ms)                                     336
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.011668878891623203
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 130
# [TOTAL_GC_TIME].Time(ms)                                          336
# [TOTAL_GC_TIME_%].Time(%)                        0.011668878891623203
# [READ].Operations                                            32000000
# [READ].AverageLatency(us)                                  479.667124
# [READ].MinLatency(us)                                           158.0
# [READ].MaxLatency(us)                                         39167.0
# [READ].95thPercentileLatency(us)                                804.0
# [READ].99thPercentileLatency(us)                               1091.0
# [READ].Return=OK                                             32000000
# [CLEANUP].Operations                                                6
# [CLEANUP].AverageLatency(us)                               447.333333
# [CLEANUP].MinLatency(us)                                        195.0
# [CLEANUP].MaxLatency(us)                                       1244.0
# [CLEANUP].95thPercentileLatency(us)                            1244.0
# [CLEANUP].99thPercentileLatency(us)                            1244.0
#
# connection_pod                             PostgreSQL-64-8-196608-3-3  ...  \
# connection                                   PostgreSQL-64-8-196608-3  ...
# configuration                                  PostgreSQL-64-8-196608  ...
# experiment_run                                                      1  ...
# client                                                              3  ...
# pod                                             6sdhm.dbmsbenchmarker  ...
# pod_count                                                          16  ...
# threads                                                             6  ...
# target                                                              0  ...
# sf                                                                 16  ...
# workload                                                            c  ...
# operations                                                   32000000  ...
# batchsize                                                          -1  ...
# exceptions                                                          0  ...
# [OVERALL].RunTime(ms)                                       2815663.0  ...
# [OVERALL].Throughput(ops/sec)                             11364.99645  ...
# [TOTAL_GCS_Copy].Count                                            130  ...
# [TOTAL_GC_TIME_Copy].Time(ms)                                     391  ...
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.013886605037605708  ...
# [TOTAL_GCS_MarkSweepCompact].Count                                  0  ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0  ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0  ...
# [TOTAL_GCs].Count                                                 130  ...
# [TOTAL_GC_TIME].Time(ms)                                          391  ...
# [TOTAL_GC_TIME_%].Time(%)                        0.013886605037605708  ...
# [READ].Operations                                            32000000  ...
# [READ].AverageLatency(us)                                  464.417461  ...
# [READ].MinLatency(us)                                           159.0  ...
# [READ].MaxLatency(us)                                         40223.0  ...
# [READ].95thPercentileLatency(us)                                786.0  ...
# [READ].99thPercentileLatency(us)                               1114.0  ...
# [READ].Return=OK                                             32000000  ...
# [CLEANUP].Operations                                                6  ...
# [CLEANUP].AverageLatency(us)                               585.333333  ...
# [CLEANUP].MinLatency(us)                                        301.0  ...
# [CLEANUP].MaxLatency(us)                                       1547.0  ...
# [CLEANUP].95thPercentileLatency(us)                            1547.0  ...
# [CLEANUP].99thPercentileLatency(us)                            1547.0  ...
#
# connection_pod                             PostgreSQL-64-8-196608-3-16  \
# connection                                    PostgreSQL-64-8-196608-3
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                               3
# pod                                              vzv7k.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              6
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2792171.0
# [OVERALL].Throughput(ops/sec)                              11460.61613
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      396
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.014182512460733961
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           396
# [TOTAL_GC_TIME_%].Time(%)                         0.014182512460733961
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   464.598861
# [READ].MinLatency(us)                                            163.0
# [READ].MaxLatency(us)                                          43199.0
# [READ].95thPercentileLatency(us)                                 775.0
# [READ].99thPercentileLatency(us)                                1010.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 6
# [CLEANUP].AverageLatency(us)                                     477.5
# [CLEANUP].MinLatency(us)                                         262.0
# [CLEANUP].MaxLatency(us)                                        1202.0
# [CLEANUP].95thPercentileLatency(us)                             1202.0
# [CLEANUP].99thPercentileLatency(us)                             1202.0
#
# connection_pod                             PostgreSQL-64-8-196608-6-15  \
# connection                                    PostgreSQL-64-8-196608-6
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                               6
# pod                                              dhrfh.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              6
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2810390.0
# [OVERALL].Throughput(ops/sec)                             11386.320048
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      330
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.011742142549610552
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           330
# [TOTAL_GC_TIME_%].Time(%)                         0.011742142549610552
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   483.745892
# [READ].MinLatency(us)                                            160.0
# [READ].MaxLatency(us)                                          47199.0
# [READ].95thPercentileLatency(us)                                 847.0
# [READ].99thPercentileLatency(us)                                1111.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 6
# [CLEANUP].AverageLatency(us)                                467.166667
# [CLEANUP].MinLatency(us)                                         269.0
# [CLEANUP].MaxLatency(us)                                         790.0
# [CLEANUP].95thPercentileLatency(us)                              790.0
# [CLEANUP].99thPercentileLatency(us)                              790.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-8  \
# connection                                   PostgreSQL-64-8-196608-2
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              2
# pod                                             mzvfw.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            12
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2760375.0
# [OVERALL].Throughput(ops/sec)                            23185.255627
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     490
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.01775121133903908
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          490
# [TOTAL_GC_TIME_%].Time(%)                         0.01775121133903908
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  437.037688
# [READ].MinLatency(us)                                           167.0
# [READ].MaxLatency(us)                                         44767.0
# [READ].95thPercentileLatency(us)                                822.0
# [READ].99thPercentileLatency(us)                               1214.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               12
# [CLEANUP].AverageLatency(us)                                    309.5
# [CLEANUP].MinLatency(us)                                        128.0
# [CLEANUP].MaxLatency(us)                                       1080.0
# [CLEANUP].95thPercentileLatency(us)                             379.0
# [CLEANUP].99thPercentileLatency(us)                            1080.0
#
# connection_pod                             PostgreSQL-64-8-196608-15-15  \
# connection                                    PostgreSQL-64-8-196608-15
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                               15
# pod                                             157vx4x.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                                0
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         2623379.0
# [OVERALL].Throughput(ops/sec)                              12198.008751
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       331
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.012617315302135146
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            331
# [TOTAL_GC_TIME_%].Time(%)                          0.012617315302135146
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                     557.36685
# [READ].MinLatency(us)                                             164.0
# [READ].MaxLatency(us)                                           66559.0
# [READ].95thPercentileLatency(us)                                 1041.0
# [READ].99thPercentileLatency(us)                                 1480.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    440.625
# [CLEANUP].MinLatency(us)                                          126.0
# [CLEANUP].MaxLatency(us)                                          950.0
# [CLEANUP].95thPercentileLatency(us)                               950.0
# [CLEANUP].99thPercentileLatency(us)                               950.0
#
# connection_pod                             PostgreSQL-64-8-196608-12-16  \
# connection                                    PostgreSQL-64-8-196608-12
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                               12
# pod                                             12vmw9m.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               7
# target                                                                0
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         2587381.0
# [OVERALL].Throughput(ops/sec)                              12367.718554
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       264
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.010203367807060498
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            264
# [TOTAL_GC_TIME_%].Time(%)                          0.010203367807060498
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    512.977384
# [READ].MinLatency(us)                                             159.0
# [READ].MaxLatency(us)                                           47359.0
# [READ].95thPercentileLatency(us)                                  948.0
# [READ].99thPercentileLatency(us)                                 1393.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                  7
# [CLEANUP].AverageLatency(us)                                 476.571429
# [CLEANUP].MinLatency(us)                                          131.0
# [CLEANUP].MaxLatency(us)                                         1397.0
# [CLEANUP].95thPercentileLatency(us)                              1397.0
# [CLEANUP].99thPercentileLatency(us)                              1397.0
#
# connection_pod                             PostgreSQL-64-8-196608-15-16  \
# connection                                    PostgreSQL-64-8-196608-15
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                               15
# pod                                             156hjvs.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                                0
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         2644655.0
# [OVERALL].Throughput(ops/sec)                              12099.876922
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       340
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.012856119229162214
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            340
# [TOTAL_GC_TIME_%].Time(%)                          0.012856119229162214
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    604.648751
# [READ].MinLatency(us)                                             156.0
# [READ].MaxLatency(us)                                           45439.0
# [READ].95thPercentileLatency(us)                                 1116.0
# [READ].99thPercentileLatency(us)                                 1499.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    440.625
# [CLEANUP].MinLatency(us)                                          157.0
# [CLEANUP].MaxLatency(us)                                         1431.0
# [CLEANUP].95thPercentileLatency(us)                              1431.0
# [CLEANUP].99thPercentileLatency(us)                              1431.0
#
# connection_pod                             PostgreSQL-64-8-196608-6-16  \
# connection                                    PostgreSQL-64-8-196608-6
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                               6
# pod                                              qx929.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              6
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    32000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2861629.0
# [OVERALL].Throughput(ops/sec)                             11182.441889
# [TOTAL_GCS_Copy].Count                                             130
# [TOTAL_GC_TIME_Copy].Time(ms)                                      387
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.013523765659349972
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  130
# [TOTAL_GC_TIME].Time(ms)                                           387
# [TOTAL_GC_TIME_%].Time(%)                         0.013523765659349972
# [READ].Operations                                             32000000
# [READ].AverageLatency(us)                                   469.760021
# [READ].MinLatency(us)                                            163.0
# [READ].MaxLatency(us)                                          39999.0
# [READ].95thPercentileLatency(us)                                 850.0
# [READ].99thPercentileLatency(us)                                1183.0
# [READ].Return=OK                                              32000000
# [CLEANUP].Operations                                                 6
# [CLEANUP].AverageLatency(us)                                643.333333
# [CLEANUP].MinLatency(us)                                         256.0
# [CLEANUP].MaxLatency(us)                                        1918.0
# [CLEANUP].95thPercentileLatency(us)                             1918.0
# [CLEANUP].99thPercentileLatency(us)                             1918.0
#
# connection_pod                             PostgreSQL-64-8-196608-5-8  \
# connection                                   PostgreSQL-64-8-196608-5
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              5
# pod                                             p2tzv.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            13
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2878911.0
# [OVERALL].Throughput(ops/sec)                            22230.628179
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     491
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.01705506005569467
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          491
# [TOTAL_GC_TIME_%].Time(%)                         0.01705506005569467
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  490.193284
# [READ].MinLatency(us)                                           159.0
# [READ].MaxLatency(us)                                         50751.0
# [READ].95thPercentileLatency(us)                                892.0
# [READ].99thPercentileLatency(us)                               1214.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               13
# [CLEANUP].AverageLatency(us)                               449.153846
# [CLEANUP].MinLatency(us)                                        143.0
# [CLEANUP].MaxLatency(us)                                       2279.0
# [CLEANUP].95thPercentileLatency(us)                             680.0
# [CLEANUP].99thPercentileLatency(us)                            2279.0
#
# connection_pod                             PostgreSQL-64-8-196608-8-8  \
# connection                                   PostgreSQL-64-8-196608-8
# configuration                                  PostgreSQL-64-8-196608
# experiment_run                                                      1
# client                                                              8
# pod                                             76d5r.dbmsbenchmarker
# pod_count                                                           8
# threads                                                            14
# target                                                              0
# sf                                                                 16
# workload                                                            c
# operations                                                   64000000
# batchsize                                                          -1
# exceptions                                                          0
# [OVERALL].RunTime(ms)                                       2736373.0
# [OVERALL].Throughput(ops/sec)                            23388.624285
# [TOTAL_GCS_Copy].Count                                            260
# [TOTAL_GC_TIME_Copy].Time(ms)                                     492
# [TOTAL_GC_TIME_%_Copy].Time(%)                   0.017980004918920045
# [TOTAL_GCS_MarkSweepCompact].Count                                  0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                           0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                        0.0
# [TOTAL_GCs].Count                                                 260
# [TOTAL_GC_TIME].Time(ms)                                          492
# [TOTAL_GC_TIME_%].Time(%)                        0.017980004918920045
# [READ].Operations                                            64000000
# [READ].AverageLatency(us)                                  539.686595
# [READ].MinLatency(us)                                           156.0
# [READ].MaxLatency(us)                                         48895.0
# [READ].95thPercentileLatency(us)                                977.0
# [READ].99thPercentileLatency(us)                               1282.0
# [READ].Return=OK                                             64000000
# [CLEANUP].Operations                                               14
# [CLEANUP].AverageLatency(us)                               352.571429
# [CLEANUP].MinLatency(us)                                        134.0
# [CLEANUP].MaxLatency(us)                                       1095.0
# [CLEANUP].95thPercentileLatency(us)                             552.0
# [CLEANUP].99thPercentileLatency(us)                            1095.0
#
# connection_pod                             PostgreSQL-64-8-196608-11-8
# connection                                   PostgreSQL-64-8-196608-11
# configuration                                   PostgreSQL-64-8-196608
# experiment_run                                                       1
# client                                                              11
# pod                                            11rfq6b.dbmsbenchmarker
# pod_count                                                            8
# threads                                                             15
# target                                                               0
# sf                                                                  16
# workload                                                             c
# operations                                                    64000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                        2974803.0
# [OVERALL].Throughput(ops/sec)                             21514.029669
# [TOTAL_GCS_Copy].Count                                             260
# [TOTAL_GC_TIME_Copy].Time(ms)                                      566
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01902646998809669
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                  260
# [TOTAL_GC_TIME].Time(ms)                                           566
# [TOTAL_GC_TIME_%].Time(%)                          0.01902646998809669
# [READ].Operations                                             64000000
# [READ].AverageLatency(us)                                   634.247285
# [READ].MinLatency(us)                                            149.0
# [READ].MaxLatency(us)                                         205311.0
# [READ].95thPercentileLatency(us)                                1121.0
# [READ].99thPercentileLatency(us)                                1409.0
# [READ].Return=OK                                              64000000
# [CLEANUP].Operations                                                15
# [CLEANUP].AverageLatency(us)                                     401.6
# [CLEANUP].MinLatency(us)                                         140.0
# [CLEANUP].MaxLatency(us)                                        1420.0
# [CLEANUP].95thPercentileLatency(us)                              874.0
# [CLEANUP].99thPercentileLatency(us)                             1420.0
#
# [37 rows x 150 columns]

# %%
df_aggregated = evaluation.benchmarking_aggregate_by_parallel_pods(df_benchmarks)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_09c91_row0_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_09c91_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_09c91_row2_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_09c91_row3_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_09c91_row4_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_09c91_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_09c91">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_09c91_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09c91_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_09c91_row0_col0" class="data row0 col0" >175123.681100</td>
#     </tr>
#     <tr>
#       <th id="T_09c91_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_09c91_row1_col0" class="data row1 col0" >193223.077930</td>
#     </tr>
#     <tr>
#       <th id="T_09c91_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_09c91_row2_col0" class="data row2 col0" >186168.143285</td>
#     </tr>
#     <tr>
#       <th id="T_09c91_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_09c91_row3_col0" class="data row3 col0" >190270.347407</td>
#     </tr>
#     <tr>
#       <th id="T_09c91_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_09c91_row4_col0" class="data row4 col0" >163981.102459</td>
#     </tr>
#     <tr>
#       <th id="T_09c91_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_09c91_row5_col0" class="data row5 col0" >161941.629531</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_6cf20_row0_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_6cf20_row1_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_6cf20_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6cf20_row3_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_6cf20_row4_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_6cf20_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_6cf20">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_6cf20_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cf20_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_6cf20_row0_col0" class="data row0 col0" >180483.411926</td>
#     </tr>
#     <tr>
#       <th id="T_6cf20_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_6cf20_row1_col0" class="data row1 col0" >176951.656210</td>
#     </tr>
#     <tr>
#       <th id="T_6cf20_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_6cf20_row2_col0" class="data row2 col0" >188020.095816</td>
#     </tr>
#     <tr>
#       <th id="T_6cf20_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_6cf20_row3_col0" class="data row3 col0" >173329.167261</td>
#     </tr>
#     <tr>
#       <th id="T_6cf20_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_6cf20_row4_col0" class="data row4 col0" >181703.626588</td>
#     </tr>
#     <tr>
#       <th id="T_6cf20_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_6cf20_row5_col0" class="data row5 col0" >159902.663013</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 16
experiment_run = 1
#plot_heatmap(df_aggregated, metric, pod_count, experiment_run)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_3f6e8_row0_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3f6e8_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3f6e8_row2_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_3f6e8_row3_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_3f6e8_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3f6e8_row5_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f6e8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_3f6e8_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f6e8_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_3f6e8_row0_col0" class="data row0 col0" >483.575868</td>
#     </tr>
#     <tr>
#       <th id="T_3f6e8_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_3f6e8_row1_col0" class="data row1 col0" >470.957636</td>
#     </tr>
#     <tr>
#       <th id="T_3f6e8_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_3f6e8_row2_col0" class="data row2 col0" >511.591911</td>
#     </tr>
#     <tr>
#       <th id="T_3f6e8_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_3f6e8_row3_col0" class="data row3 col0" >520.580863</td>
#     </tr>
#     <tr>
#       <th id="T_3f6e8_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_3f6e8_row4_col0" class="data row4 col0" >699.557571</td>
#     </tr>
#     <tr>
#       <th id="T_3f6e8_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_3f6e8_row5_col0" class="data row5 col0" >693.791023</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_99eae_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_99eae_row1_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_99eae_row2_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_99eae_row3_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_99eae_row4_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_99eae_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_99eae">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_99eae_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99eae_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_99eae_row0_col0" class="data row0 col0" >462.500361</td>
#     </tr>
#     <tr>
#       <th id="T_99eae_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_99eae_row1_col0" class="data row1 col0" >494.518923</td>
#     </tr>
#     <tr>
#       <th id="T_99eae_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_99eae_row2_col0" class="data row2 col0" >540.055148</td>
#     </tr>
#     <tr>
#       <th id="T_99eae_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_99eae_row3_col0" class="data row3 col0" >631.829863</td>
#     </tr>
#     <tr>
#       <th id="T_99eae_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_99eae_row4_col0" class="data row4 col0" >597.274593</td>
#     </tr>
#     <tr>
#       <th id="T_99eae_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_99eae_row5_col0" class="data row5 col0" >721.991125</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_eeea2_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_eeea2_row1_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_eeea2_row2_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_eeea2_row3_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_eeea2_row4_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_eeea2_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eeea2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_eeea2_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeea2_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_eeea2_row0_col0" class="data row0 col0" >986.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeea2_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_eeea2_row1_col0" class="data row1 col0" >1077.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeea2_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_eeea2_row2_col0" class="data row2 col0" >1269.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeea2_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_eeea2_row3_col0" class="data row3 col0" >1220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeea2_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_eeea2_row4_col0" class="data row4 col0" >1444.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeea2_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_eeea2_row5_col0" class="data row5 col0" >1636.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_7c171_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7c171_row1_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7c171_row2_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7c171_row3_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_7c171_row4_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_7c171_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c171">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_7c171_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c171_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_7c171_row0_col0" class="data row0 col0" >1235.375000</td>
#     </tr>
#     <tr>
#       <th id="T_7c171_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_7c171_row1_col0" class="data row1 col0" >1302.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c171_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_7c171_row2_col0" class="data row2 col0" >1281.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c171_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_7c171_row3_col0" class="data row3 col0" >1405.875000</td>
#     </tr>
#     <tr>
#       <th id="T_7c171_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_7c171_row4_col0" class="data row4 col0" >1457.750000</td>
#     </tr>
#     <tr>
#       <th id="T_7c171_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_7c171_row5_col0" class="data row5 col0" >1614.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_df5a8_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_df5a8_row1_col0, #T_df5a8_row2_col0, #T_df5a8_row3_col0, #T_df5a8_row4_col0, #T_df5a8_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_df5a8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_df5a8_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df5a8_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_df5a8_row0_col0" class="data row0 col0" >13787135.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df5a8_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_df5a8_row1_col0" class="data row1 col0" >88959.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df5a8_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_df5a8_row2_col0" class="data row2 col0" >89151.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df5a8_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_df5a8_row3_col0" class="data row3 col0" >101247.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df5a8_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_df5a8_row4_col0" class="data row4 col0" >106623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df5a8_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_df5a8_row5_col0" class="data row5 col0" >107199.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_c22aa_row0_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c22aa_row1_col0, #T_c22aa_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c22aa_row3_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_c22aa_row4_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c22aa_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c22aa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_c22aa_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c22aa_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_c22aa_row0_col0" class="data row0 col0" >56223.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c22aa_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_c22aa_row1_col0" class="data row1 col0" >52671.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c22aa_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_c22aa_row2_col0" class="data row2 col0" >52351.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c22aa_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_c22aa_row3_col0" class="data row3 col0" >205311.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c22aa_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_c22aa_row4_col0" class="data row4 col0" >53759.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c22aa_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_c22aa_row5_col0" class="data row5 col0" >208767.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MinLatency(us)'
pod_count = 1
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_ebd9a_row0_col0, #T_ebd9a_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ebd9a_row2_col0, #T_ebd9a_row5_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_ebd9a_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ebd9a_row4_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# </style>
# <table id="T_ebd9a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_ebd9a_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebd9a_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_ebd9a_row0_col0" class="data row0 col0" >157.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9a_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_ebd9a_row1_col0" class="data row1 col0" >157.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9a_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_ebd9a_row2_col0" class="data row2 col0" >163.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9a_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_ebd9a_row3_col0" class="data row3 col0" >166.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9a_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_ebd9a_row4_col0" class="data row4 col0" >158.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9a_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_ebd9a_row5_col0" class="data row5 col0" >163.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = '[READ].MinLatency(us)'
pod_count = 8
experiment_run = 1
plot_heatmap(df_aggregated, metric, pod_count, experiment_run)
# Out:
# <style type="text/css">
# #T_8d8f7_row0_col0, #T_8d8f7_row1_col0, #T_8d8f7_row5_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_8d8f7_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d8f7_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d8f7_row4_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d8f7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_8d8f7_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >threads</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d8f7_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_8d8f7_row0_col0" class="data row0 col0" >153.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8f7_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_8d8f7_row1_col0" class="data row1 col0" >153.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8f7_level0_row2" class="row_heading level0 row2" >112</th>
#       <td id="T_8d8f7_row2_col0" class="data row2 col0" >156.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8f7_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_8d8f7_row3_col0" class="data row3 col0" >149.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8f7_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_8d8f7_row4_col0" class="data row4 col0" >154.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8f7_level0_row5" class="row_heading level0 row5" >136</th>
#       <td id="T_8d8f7_row5_col0" class="data row5 col0" >153.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric = 'current_ops_per_sec'
plot_measures(metric, smoothing=0, preset_client=10)
plot_measures(metric, smoothing=0, preset_client=11)
plot_measures(metric, smoothing=0, preset_client=12)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 237172.8
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 219891.66999999998
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 219190.30000000002

# %%
metric = 'READ_Avg'
plot_measures(metric, smoothing=0, preset_client=10)
plot_measures(metric, smoothing=0, preset_client=11)
plot_measures(metric, smoothing=0, preset_client=12)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 690.08
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 736.3699999999999
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 633.803125

# %%
metric = 'READ_99'
plot_measures(metric, smoothing=0, preset_client=10)
plot_measures(metric, smoothing=0, preset_client=11)
plot_measures(metric, smoothing=0, preset_client=12)
# Out:
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 1544
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 2209
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 2545

# %%
metric = 'READ_Max'
plot_measures(metric, smoothing=0, preset_client=10)
plot_measures(metric, smoothing=0, preset_client=11)
plot_measures(metric, smoothing=0, preset_client=12)
# Out:
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 101247.0
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 41117.0
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 43538.5

# %%
metric = 'READ_Min'
plot_measures(metric, smoothing=0, preset_client=10)
plot_measures(metric, smoothing=0, preset_client=11)
plot_measures(metric, smoothing=0, preset_client=12)
# Out:
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 189.0
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 186.125
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# 187.3125

# %%
#metric = 'UPDATE_99.9'
#plot_measures(metric, smoothing=0, preset_client=3)
#plot_measures(metric, smoothing=0, preset_client=4)

# %%
evaluation.transform_monitoring_results(component='stream')

evaluation.get_monitoring_metrics()
# Out:
# ['total_cpu_memory',
#  'total_cpu_memory_cached',
#  'total_cpu_util',
#  'total_cpu_util_max',
#  'total_cpu_throttled',
#  'total_cpu_util_others',
#  'total_cpu_util_s',
#  'total_cpu_util_user_s',
#  'total_cpu_util_sys_s',
#  'total_cpu_throttled_s',
#  'total_cpu_util_others_s',
#  'total_network_rx',
#  'total_network_tx',
#  'total_fs_read',
#  'total_fs_write',
#  'total_gpu_util',
#  'total_gpu_power',
#  'total_gpu_memory']

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)
