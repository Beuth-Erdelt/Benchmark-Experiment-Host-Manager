# %% [markdown]
# # YCSB Analysis of Grid of Parameters
# Loop over
# * several target throughputs
# * several numers of threads
# * split into 1, 8 and 16 driver pods
#
#
# ```
# nohup python ycsb.py -ms 1 -tr \
#   -sf $BEXHOMA_YCSB_SF_DATA \
#   -sfo $BEXHOMA_YCSB_SF_OPS \
#   --workload c \
#   -dbms PostgreSQL \
#   -rnn $BEXHOMA_NODE_SUT -rnl $BEXHOMA_NODE_LOAD -rnb $BEXHOMA_NODE_BENCHMARK \
#   -tb 16384 \
#   -nlp 8 \
#   -nlt 64 \
#   -nlf 12 \
#   -nbp 1,1,8,16 \
#   -nbt 80,96,112,128,144,160,176,192 \
#   -nbf 0,9,10,11,12,13,14,15,16 \
#   -ne 1 \
#   -nc 2 \
#   -m -mc \
#   -rst shared -rss 50Gi run
# ```

# %%
code = "1741249986"
#path = "D:\\data\\benchmarks"
path = "/home/perdelt/benchmarks"

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
#import os
#import re
import matplotlib.pyplot as plt
#import pickle
from IPython.display import display, Markdown
import seaborn as sns

#import dbmsbenchmarker
#import bexhoma
from bexhoma import evaluators

# %matplotlib inline

# %%
cut_at = 0

#pod_count = 16
#experiment_run = 1
#target = 0
#threads = 128


def plot_timeseries(df_aggregated, metric, pod_count, experiment_run, target, threads, smoothing=0):
    df = df_aggregated.copy()
    if experiment_run > 0:
        df = df[df['experiment_run'] == experiment_run]
    df = df[df['target'] == target]
    df = df[df['threads'] == threads]
    df_subset = df[df['pod_count'] == pod_count]
    df_subset = df_subset[~df_subset.duplicated(subset=['threads', 'target'], keep='last')]
    client = df_subset['client'].iloc[0]
    plot_measures(metric, smoothing=smoothing, preset_experiment_run=experiment_run, preset_client=client)

def plot_measures(metric, smoothing=0, preset_experiment_run=0, preset_client=0):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        for experiment_run in list_experiment_runs:
            if preset_experiment_run > 0:
                if preset_experiment_run != experiment_run:
                    continue
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            if preset_client > 0:
                n_rows = 1
            else:
                n_rows = num_runs
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows), sharex=True)
            fig.suptitle(f"{metric}", fontsize=16)#, fontweight="bold")
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                if preset_client > 0:
                    if preset_client != client:
                        continue
                #################################
                # show plots with aggregated line
                #################################
                # filter data for this run
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]
                df_part = df_part[df_part['client'] == (client)]
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                # Weighted average: Multiply each value by its duration and sum
                weighted_sum = (df_total[metric].multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total[metric] = df_total[metric].rolling(window=smoothing, min_periods=1).mean()
                # optionally leave out data at the end (cool down)
                if cut_at > 0:
                    df_total = df_total[:-cut_at]
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                max_value = df_total[metric].max()
                #print(max_value)
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
                ###############################
                # show plots with lines per pod
                ###############################
                df_list = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                # collect in one dataframe
                df_total = pd.DataFrame()
                j=1
                max_value = 0
                for df in df_list:
                    # optionally leave out data at the end (cool down)
                    if cut_at > 0:
                        df_tmp = df[metric][:-cut_at]
                    else:
                        df_tmp = df[metric]
                    df_single = pd.DataFrame(df_tmp)
                    if max_value < df_single[metric].max():
                        max_value = df_single[metric].max()
                    df_single.columns=["pod "+str(j)]
                    df_total = pd.merge(df_total, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                #print(df_combined)
                # Compute the time spans
                time_spans = df_total.index.to_series().diff().shift(-1).fillna(0)  # Difference between consecutive time indices
                weighted_sum = (df_total.multiply(time_spans, axis=0)).sum().sum()  # Multiply each value by its time span, sum all values
                total_time = time_spans.sum()  # Total time span
                # Compute the weighted average
                weighted_average = weighted_sum / total_time / len(df_list)
                df_total['avg'] = weighted_average
                df_total = df_total.rename(columns={'avg': f'avg={weighted_average}'})
                #df_total = df_total.fillna(0)
                # optionally smoothen graph
                if smoothing > 0:
                    df_total = df_total.rolling(window=smoothing, min_periods=1).mean()
                # generate plot
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                ax = axes[i]
                i = i + 1
                df_total.plot(title=title, ax=ax, ylim=(0,max_value*1.1), use_index=True, legend=False)
                last_x = df_total.index[-1] # Get the last datapoint's x-coordinate (the last index)
                ax.axvline(x=last_x, color='red', linestyle='--', label='Last Datapoint') # Add a vertical line at the last datapoint
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            filename = f"plot_{preset_experiment_run}_{preset_client}_{metric}.png".replace("\\","").replace("/","").replace(":","")
            #df2img.save_dataframe(styled_df, filename="styled_table.png")
            plt.savefig(filename, dpi=300, bbox_inches="tight")
            plt.show()

def plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=None, vmax_value=None):
    #metric = '[OVERALL].Throughput(ops/sec)'
    #pod_count = 1
    #experiment_run = 1
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df = df.pivot(index='threads', columns='target', values=metric)
    #display(df.style.background_gradient(cmap='Blues', axis=None))
    styled_df = df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient()
    #display(df)
    # Set up the figure size
    plt.figure(figsize=(10, 4))
    # Create the heatmap
    if vmin_value is not None and vmax_value is not None:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7}, vmin=vmin_value, vmax=vmax_value)
    else:
        ax = sns.heatmap(df, annot=True, cmap="Blues", fmt=".0f", linewidths=0.5, annot_kws={"size": 7})
    ax.set_title(metric)
    # Save as PNG
    filename = (f"heatmap_{metric}_{pod_count}_{experiment_run}.png").replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    # Show the plot (optional)
    plt.show()


def plot_heatmap_compare(df_aggregated, metric, pod_count_1, pod_count_2, experiment_run, vmin_value=None, vmax_value=None):
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count_1]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df_1 = df.pivot(index='threads', columns='target', values=metric)
    pod_count = 8
    df = df_aggregated[['experiment_run', 'threads', 'target', 'pod_count', metric]]
    df = df[df['pod_count'] == pod_count_2]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df)
    df_2 = df.pivot(index='threads', columns='target', values=metric)
    df = df_2/df_1*100
    #print(df)
    #vmin_value = 0
    #vmax_value = 200
    #display(df.style.background_gradient(cmap='Blues', axis=None))
    styled_df = df.style.background_gradient(cmap='YlOrBr', axis=None).set_caption(metric)
    #df.style.background_gradient(cmap='Blues', axis=None).set_caption(metric)
    #df.style.background_gradient()
    #display(df)
    # Set up the figure size
    plt.figure(figsize=(10, 4))
    # Create the heatmap
    if vmin_value is not None and vmax_value is not None:
        ax = sns.heatmap(df, annot=True, cmap="YlOrBr", fmt=".0f", linewidths=0.5, annot_kws={"size": 7}, vmin=vmin_value, vmax=vmax_value)
    else:
        ax = sns.heatmap(df, annot=True, cmap="YlOrBr", fmt=".0f", linewidths=0.5, annot_kws={"size": 7})
    ax.set_title(f"Increasement of {metric} in %")
    # Save as PNG
    filename = (f"heatmap_increase_{metric}_{pod_count}_{experiment_run}.png").replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    # Show the plot (optional)
    plt.show()


def plot_prometheus_metric(df_aggregated, metric, component, pod_count, experiment_run):
    df_aggregated = pd.DataFrame(df_aggregated, columns=[metric])
    #print(df_aggregated)
    df_benchmarks2 = df_benchmarks.set_index('connection')
    df_benchmarks2['threads_total'] = df_benchmarks2['threads']*df_benchmarks2['pod_count']
    df = df_aggregated.join(df_benchmarks2, how='inner')
    df = df[df['pod_count'] == pod_count]
    df = df[df['experiment_run'] == experiment_run]
    df = df[~df.index.duplicated(keep='last')]
    df = df[~df.duplicated(subset=['threads', 'target'], keep='last')]
    #print(df_heatmap)
    df = df.pivot(index='threads_total', columns='target', values=metric)
    #display(df_heatmap.style.background_gradient(cmap='Blues', axis=None))
    df.plot.bar(title=f"{component} ({experiment_run}. run with {pod_count} pods): {metric}")
    filename = f"bar_{component}_{experiment_run}_{pod_count}_{metric}.png".replace("\\","").replace("/","").replace(":","")
    plt.savefig(filename, dpi=300, bbox_inches="tight")

# %%
evaluation = evaluators.ycsb(code=code, path=path)

# %% [markdown]
# ## Table of Data

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-196608-2-4-1  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               bqzdw.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420741.0
# [OVERALL].Throughput(ops/sec)                              11261.728915
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       257
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.01808915206923711
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            257
# [TOTAL_GC_TIME_%].Time(%)                           0.01808915206923711
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                     488.65973
# [READ].MinLatency(us)                                             172.0
# [READ].MaxLatency(us)                                          207615.0
# [READ].95thPercentileLatency(us)                                 1042.0
# [READ].99thPercentileLatency(us)                                 1833.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    2309.75
# [CLEANUP].MinLatency(us)                                          139.0
# [CLEANUP].MaxLatency(us)                                         3613.0
# [CLEANUP].95thPercentileLatency(us)                              3613.0
# [CLEANUP].99thPercentileLatency(us)                              3613.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-2  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               8rgg4.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1421565.0
# [OVERALL].Throughput(ops/sec)                              11255.201134
# [TOTAL_GCS_Copy].Count                                               64
# [TOTAL_GC_TIME_Copy].Time(ms)                                       259
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.0182193568356002
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    64
# [TOTAL_GC_TIME].Time(ms)                                            259
# [TOTAL_GC_TIME_%].Time(%)                            0.0182193568356002
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    498.844105
# [READ].MinLatency(us)                                             172.0
# [READ].MaxLatency(us)                                          206591.0
# [READ].95thPercentileLatency(us)                                 1061.0
# [READ].99thPercentileLatency(us)                                 1720.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    332.875
# [CLEANUP].MinLatency(us)                                          100.0
# [CLEANUP].MaxLatency(us)                                         1687.0
# [CLEANUP].95thPercentileLatency(us)                              1687.0
# [CLEANUP].99thPercentileLatency(us)                              1687.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-1  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               f7ks4.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420719.0
# [OVERALL].Throughput(ops/sec)                              22523.806608
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       317
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.022312645920833044
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            317
# [TOTAL_GC_TIME_%].Time(%)                          0.022312645920833044
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    453.232291
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                           45119.0
# [READ].95thPercentileLatency(us)                                  915.0
# [READ].99thPercentileLatency(us)                                 1562.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                  1603.5625
# [CLEANUP].MinLatency(us)                                          122.0
# [CLEANUP].MaxLatency(us)                                         2495.0
# [CLEANUP].95thPercentileLatency(us)                              1984.0
# [CLEANUP].99thPercentileLatency(us)                              2495.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-3  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               xxzk7.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420749.0
# [OVERALL].Throughput(ops/sec)                              11261.665502
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       268
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.018863289715495137
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            268
# [TOTAL_GC_TIME_%].Time(%)                          0.018863289715495137
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    479.042125
# [READ].MinLatency(us)                                             166.0
# [READ].MaxLatency(us)                                          207871.0
# [READ].95thPercentileLatency(us)                                 1018.0
# [READ].99thPercentileLatency(us)                                 1733.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    671.625
# [CLEANUP].MinLatency(us)                                          111.0
# [CLEANUP].MaxLatency(us)                                         1589.0
# [CLEANUP].95thPercentileLatency(us)                              1589.0
# [CLEANUP].99thPercentileLatency(us)                              1589.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-4  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               p9jm9.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420736.0
# [OVERALL].Throughput(ops/sec)                              11261.768548
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       257
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.01808921573043831
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            257
# [TOTAL_GC_TIME_%].Time(%)                           0.01808921573043831
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    504.233178
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                          206591.0
# [READ].95thPercentileLatency(us)                                 1015.0
# [READ].99thPercentileLatency(us)                                 1682.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                      664.5
# [CLEANUP].MinLatency(us)                                          119.0
# [CLEANUP].MaxLatency(us)                                         1922.0
# [CLEANUP].95thPercentileLatency(us)                              1922.0
# [CLEANUP].99thPercentileLatency(us)                              1922.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-5  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               t6hxp.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420706.0
# [OVERALL].Throughput(ops/sec)                              11262.006355
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       219
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.015414871197841075
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            219
# [TOTAL_GC_TIME_%].Time(%)                          0.015414871197841075
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    485.007418
# [READ].MinLatency(us)                                             169.0
# [READ].MaxLatency(us)                                          208767.0
# [READ].95thPercentileLatency(us)                                  975.0
# [READ].99thPercentileLatency(us)                                 1627.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                   1097.125
# [CLEANUP].MinLatency(us)                                          280.0
# [CLEANUP].MaxLatency(us)                                         1342.0
# [CLEANUP].95thPercentileLatency(us)                              1342.0
# [CLEANUP].99thPercentileLatency(us)                              1342.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-6  \
# connection                                   PostgreSQL-64-8-196608-2-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                4
# pod                                               bnhmd.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1422989.0
# [OVERALL].Throughput(ops/sec)                              11243.937936
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       225
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.015811787722884718
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            225
# [TOTAL_GC_TIME_%].Time(%)                          0.015811787722884718
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    493.822293
# [READ].MinLatency(us)                                             157.0
# [READ].MaxLatency(us)                                          208639.0
# [READ].95thPercentileLatency(us)                                 1028.0
# [READ].99thPercentileLatency(us)                                 1802.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                     831.75
# [CLEANUP].MinLatency(us)                                          111.0
# [CLEANUP].MaxLatency(us)                                         1858.0
# [CLEANUP].95thPercentileLatency(us)                              1858.0
# [CLEANUP].99thPercentileLatency(us)                              1858.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-1  \
# connection                                   PostgreSQL-64-8-196608-1-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                4
# pod                                               pxgl2.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420687.0
# [OVERALL].Throughput(ops/sec)                              11262.156971
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       228
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.016048573683013923
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            228
# [TOTAL_GC_TIME_%].Time(%)                          0.016048573683013923
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    509.577609
# [READ].MinLatency(us)                                             169.0
# [READ].MaxLatency(us)                                          207487.0
# [READ].95thPercentileLatency(us)                                  851.0
# [READ].99thPercentileLatency(us)                                 1271.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                    802.875
# [CLEANUP].MinLatency(us)                                          103.0
# [CLEANUP].MaxLatency(us)                                         1920.0
# [CLEANUP].95thPercentileLatency(us)                              1920.0
# [CLEANUP].99thPercentileLatency(us)                              1920.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-2  \
# connection                                   PostgreSQL-64-8-196608-1-4
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                4
# pod                                               srcd7.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               8
# target                                                            11264
# sf                                                                   16
# workload                                                              c
# operations                                                     16000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420711.0
# [OVERALL].Throughput(ops/sec)                              11261.966719
# [TOTAL_GCS_Copy].Count                                               65
# [TOTAL_GC_TIME_Copy].Time(ms)                                       276
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.01942689259110403
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                    65
# [TOTAL_GC_TIME].Time(ms)                                            276
# [TOTAL_GC_TIME_%].Time(%)                           0.01942689259110403
# [READ].Operations                                              16000000
# [READ].AverageLatency(us)                                    467.653649
# [READ].MinLatency(us)                                             169.0
# [READ].MaxLatency(us)                                          208511.0
# [READ].95thPercentileLatency(us)                                  828.0
# [READ].99thPercentileLatency(us)                                 1272.0
# [READ].Return=OK                                               16000000
# [CLEANUP].Operations                                                  8
# [CLEANUP].AverageLatency(us)                                      762.0
# [CLEANUP].MinLatency(us)                                           89.0
# [CLEANUP].MaxLatency(us)                                         1237.0
# [CLEANUP].95thPercentileLatency(us)                              1237.0
# [CLEANUP].99thPercentileLatency(us)                              1237.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-3  ...  \
# connection                                   PostgreSQL-64-8-196608-1-4  ...
# configuration                                    PostgreSQL-64-8-196608  ...
# experiment_run                                                        1  ...
# client                                                                4  ...
# pod                                               9xp2x.dbmsbenchmarker  ...
# pod_count                                                            16  ...
# threads                                                               8  ...
# target                                                            11264  ...
# sf                                                                   16  ...
# workload                                                              c  ...
# operations                                                     16000000  ...
# batchsize                                                            -1  ...
# exceptions                                                            0  ...
# [OVERALL].RunTime(ms)                                         1420730.0  ...
# [OVERALL].Throughput(ops/sec)                              11261.816109  ...
# [TOTAL_GCS_Copy].Count                                               65  ...
# [TOTAL_GC_TIME_Copy].Time(ms)                                       280  ...
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.019708178190085378  ...
# [TOTAL_GCS_MarkSweepCompact].Count                                    0  ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0  ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0  ...
# [TOTAL_GCs].Count                                                    65  ...
# [TOTAL_GC_TIME].Time(ms)                                            280  ...
# [TOTAL_GC_TIME_%].Time(%)                          0.019708178190085378  ...
# [READ].Operations                                              16000000  ...
# [READ].AverageLatency(us)                                    486.925145  ...
# [READ].MinLatency(us)                                             173.0  ...
# [READ].MaxLatency(us)                                          209279.0  ...
# [READ].95thPercentileLatency(us)                                  859.0  ...
# [READ].99thPercentileLatency(us)                                 1340.0  ...
# [READ].Return=OK                                               16000000  ...
# [CLEANUP].Operations                                                  8  ...
# [CLEANUP].AverageLatency(us)                                   1073.375  ...
# [CLEANUP].MinLatency(us)                                          165.0  ...
# [CLEANUP].MaxLatency(us)                                         1356.0  ...
# [CLEANUP].95thPercentileLatency(us)                              1356.0  ...
# [CLEANUP].99thPercentileLatency(us)                              1356.0  ...
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-14  \
# connection                                    PostgreSQL-64-8-196608-1-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         1
# client                                                                 4
# pod                                                hswrp.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420755.0
# [OVERALL].Throughput(ops/sec)                               11261.617943
# [TOTAL_GCS_Copy].Count                                                64
# [TOTAL_GC_TIME_Copy].Time(ms)                                        190
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.013373171306805183
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     64
# [TOTAL_GC_TIME].Time(ms)                                             190
# [TOTAL_GC_TIME_%].Time(%)                           0.013373171306805183
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     455.940679
# [READ].MinLatency(us)                                              175.0
# [READ].MaxLatency(us)                                           207103.0
# [READ].95thPercentileLatency(us)                                   767.0
# [READ].99thPercentileLatency(us)                                  1131.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                      261.75
# [CLEANUP].MinLatency(us)                                           109.0
# [CLEANUP].MaxLatency(us)                                           936.0
# [CLEANUP].95thPercentileLatency(us)                                936.0
# [CLEANUP].99thPercentileLatency(us)                                936.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-3-8  \
# connection                                   PostgreSQL-64-8-196608-2-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        2
# client                                                                3
# pod                                               vdhz9.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1467048.0
# [OVERALL].Throughput(ops/sec)                              21812.510565
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       326
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.022221495138536707
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            326
# [TOTAL_GC_TIME_%].Time(%)                          0.022221495138536707
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    522.568726
# [READ].MinLatency(us)                                             163.0
# [READ].MaxLatency(us)                                          101695.0
# [READ].95thPercentileLatency(us)                                 1561.0
# [READ].99thPercentileLatency(us)                                 3919.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                    304.375
# [CLEANUP].MinLatency(us)                                          100.0
# [CLEANUP].MaxLatency(us)                                          929.0
# [CLEANUP].95thPercentileLatency(us)                               859.0
# [CLEANUP].99thPercentileLatency(us)                               929.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-15  \
# connection                                    PostgreSQL-64-8-196608-1-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         1
# client                                                                 4
# pod                                                mqvjr.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420774.0
# [OVERALL].Throughput(ops/sec)                               11261.467341
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        250
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.01759604272037636
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             250
# [TOTAL_GC_TIME_%].Time(%)                            0.01759604272037636
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     443.992645
# [READ].MinLatency(us)                                              174.0
# [READ].MaxLatency(us)                                           205055.0
# [READ].95thPercentileLatency(us)                                   839.0
# [READ].99thPercentileLatency(us)                                  1416.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                     495.625
# [CLEANUP].MinLatency(us)                                           104.0
# [CLEANUP].MaxLatency(us)                                           850.0
# [CLEANUP].95thPercentileLatency(us)                                850.0
# [CLEANUP].99thPercentileLatency(us)                                850.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-5  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               mvlww.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420717.0
# [OVERALL].Throughput(ops/sec)                              22523.838315
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       401
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.028225184889038423
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            401
# [TOTAL_GC_TIME_%].Time(%)                          0.028225184889038423
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    417.528478
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                           36863.0
# [READ].95thPercentileLatency(us)                                  812.0
# [READ].99thPercentileLatency(us)                                 1328.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   1402.625
# [CLEANUP].MinLatency(us)                                          120.0
# [CLEANUP].MaxLatency(us)                                         2009.0
# [CLEANUP].95thPercentileLatency(us)                              1949.0
# [CLEANUP].99thPercentileLatency(us)                              2009.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-6  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               jqbw4.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420708.0
# [OVERALL].Throughput(ops/sec)                              22523.981001
# [TOTAL_GCS_Copy].Count                                              129
# [TOTAL_GC_TIME_Copy].Time(ms)                                       343
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.024142892135470485
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   129
# [TOTAL_GC_TIME].Time(ms)                                            343
# [TOTAL_GC_TIME_%].Time(%)                          0.024142892135470485
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    428.423182
# [READ].MinLatency(us)                                             170.0
# [READ].MaxLatency(us)                                           45087.0
# [READ].95thPercentileLatency(us)                                  844.0
# [READ].99thPercentileLatency(us)                                 1413.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                  1666.1875
# [CLEANUP].MinLatency(us)                                          681.0
# [CLEANUP].MaxLatency(us)                                         2629.0
# [CLEANUP].95thPercentileLatency(us)                              2055.0
# [CLEANUP].99thPercentileLatency(us)                              2629.0
#
# connection_pod                             PostgreSQL-64-8-196608-2-4-16  \
# connection                                    PostgreSQL-64-8-196608-2-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         2
# client                                                                 4
# pod                                                s9vch.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420738.0
# [OVERALL].Throughput(ops/sec)                               11261.752695
# [TOTAL_GCS_Copy].Count                                                64
# [TOTAL_GC_TIME_Copy].Time(ms)                                        240
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.01689262904208939
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     64
# [TOTAL_GC_TIME].Time(ms)                                             240
# [TOTAL_GC_TIME_%].Time(%)                            0.01689262904208939
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     498.772838
# [READ].MinLatency(us)                                              173.0
# [READ].MaxLatency(us)                                           207615.0
# [READ].95thPercentileLatency(us)                                   986.0
# [READ].99thPercentileLatency(us)                                  1610.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                      2091.0
# [CLEANUP].MinLatency(us)                                          1627.0
# [CLEANUP].MaxLatency(us)                                          2319.0
# [CLEANUP].95thPercentileLatency(us)                               2319.0
# [CLEANUP].99thPercentileLatency(us)                               2319.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-2-1  \
# connection                                   PostgreSQL-64-8-196608-1-2
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                2
# pod                                               wlvsp.dbmsbenchmarker
# pod_count                                                             1
# threads                                                             128
# target                                                           180224
# sf                                                                   16
# workload                                                              c
# operations                                                    256000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420982.0
# [OVERALL].Throughput(ops/sec)                             180157.102623
# [TOTAL_GCS_Copy].Count                                             1055
# [TOTAL_GC_TIME_Copy].Time(ms)                                      3179
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.22371852704678877
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                  1055
# [TOTAL_GC_TIME].Time(ms)                                           3179
# [TOTAL_GC_TIME_%].Time(%)                           0.22371852704678877
# [READ].Operations                                             256000000
# [READ].AverageLatency(us)                                    347.865743
# [READ].MinLatency(us)                                             165.0
# [READ].MaxLatency(us)                                          212479.0
# [READ].95thPercentileLatency(us)                                  640.0
# [READ].99thPercentileLatency(us)                                 1029.0
# [READ].Return=OK                                              256000000
# [CLEANUP].Operations                                                128
# [CLEANUP].AverageLatency(us)                                   872.6875
# [CLEANUP].MinLatency(us)                                           76.0
# [CLEANUP].MaxLatency(us)                                         6167.0
# [CLEANUP].95thPercentileLatency(us)                              4931.0
# [CLEANUP].99thPercentileLatency(us)                              5175.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-7  \
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               jqm9s.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420740.0
# [OVERALL].Throughput(ops/sec)                              22523.473683
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       356
# [TOTAL_GC_TIME_%_Copy].Time(%)                       0.0250573644720357
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            356
# [TOTAL_GC_TIME_%].Time(%)                            0.0250573644720357
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    421.755168
# [READ].MinLatency(us)                                             168.0
# [READ].MaxLatency(us)                                           44735.0
# [READ].95thPercentileLatency(us)                                  957.0
# [READ].99thPercentileLatency(us)                                 1652.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                    1212.25
# [CLEANUP].MinLatency(us)                                           93.0
# [CLEANUP].MaxLatency(us)                                         2023.0
# [CLEANUP].95thPercentileLatency(us)                              1963.0
# [CLEANUP].99thPercentileLatency(us)                              2023.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-4-16  \
# connection                                    PostgreSQL-64-8-196608-1-4
# configuration                                     PostgreSQL-64-8-196608
# experiment_run                                                         1
# client                                                                 4
# pod                                                c8w74.dbmsbenchmarker
# pod_count                                                             16
# threads                                                                8
# target                                                             11264
# sf                                                                    16
# workload                                                               c
# operations                                                      16000000
# batchsize                                                             -1
# exceptions                                                             0
# [OVERALL].RunTime(ms)                                          1420755.0
# [OVERALL].Throughput(ops/sec)                               11261.617943
# [TOTAL_GCS_Copy].Count                                                65
# [TOTAL_GC_TIME_Copy].Time(ms)                                        267
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.018792824941668337
# [TOTAL_GCS_MarkSweepCompact].Count                                     0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                              0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                           0.0
# [TOTAL_GCs].Count                                                     65
# [TOTAL_GC_TIME].Time(ms)                                             267
# [TOTAL_GC_TIME_%].Time(%)                           0.018792824941668337
# [READ].Operations                                               16000000
# [READ].AverageLatency(us)                                     469.357513
# [READ].MinLatency(us)                                              171.0
# [READ].MaxLatency(us)                                           209663.0
# [READ].95thPercentileLatency(us)                                   865.0
# [READ].99thPercentileLatency(us)                                  1394.0
# [READ].Return=OK                                                16000000
# [CLEANUP].Operations                                                   8
# [CLEANUP].AverageLatency(us)                                    1140.375
# [CLEANUP].MinLatency(us)                                           110.0
# [CLEANUP].MaxLatency(us)                                          1446.0
# [CLEANUP].95thPercentileLatency(us)                               1446.0
# [CLEANUP].99thPercentileLatency(us)                               1446.0
#
# connection_pod                             PostgreSQL-64-8-196608-1-3-8
# connection                                   PostgreSQL-64-8-196608-1-3
# configuration                                    PostgreSQL-64-8-196608
# experiment_run                                                        1
# client                                                                3
# pod                                               5x59w.dbmsbenchmarker
# pod_count                                                             8
# threads                                                              16
# target                                                            22528
# sf                                                                   16
# workload                                                              c
# operations                                                     32000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                         1420762.0
# [OVERALL].Throughput(ops/sec)                              22523.124915
# [TOTAL_GCS_Copy].Count                                              130
# [TOTAL_GC_TIME_Copy].Time(ms)                                       355
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.024986591702199242
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                   130
# [TOTAL_GC_TIME].Time(ms)                                            355
# [TOTAL_GC_TIME_%].Time(%)                          0.024986591702199242
# [READ].Operations                                              32000000
# [READ].AverageLatency(us)                                    441.947066
# [READ].MinLatency(us)                                             167.0
# [READ].MaxLatency(us)                                           45023.0
# [READ].95thPercentileLatency(us)                                  942.0
# [READ].99thPercentileLatency(us)                                 1622.0
# [READ].Return=OK                                               32000000
# [CLEANUP].Operations                                                 16
# [CLEANUP].AverageLatency(us)                                   1052.625
# [CLEANUP].MinLatency(us)                                           83.0
# [CLEANUP].MaxLatency(us)                                         1928.0
# [CLEANUP].95thPercentileLatency(us)                              1879.0
# [CLEANUP].99thPercentileLatency(us)                              1928.0
#
# [37 rows x 52 columns]

# %% [markdown]
# ## Heatmaps of Macro Values

# %%
df_aggregated = evaluation.benchmarking_aggregate_by_parallel_pods(df_benchmarks)
experiment_run = 2

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 1
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
#metric = '[READ].AverageLatency(us)'
#metric = '[READ].MaxLatency(us)'
#metric = '[READ].MinLatency(us)'
#metric = '[READ].99thPercentileLatency(us)'
pod_count_1 = 1
pod_count_2 = 8
experiment_run = 2
vmin_value = 0
vmax_value = 200
plot_heatmap_compare(df_aggregated, metric, pod_count_1, pod_count_2, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 8
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[OVERALL].Throughput(ops/sec)'
pod_count = 16
experiment_run = 2
vmin_value = 150000
vmax_value = 230000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].AverageLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 200
vmax_value = 1200
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].99thPercentileLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 500
vmax_value = 2000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MaxLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 40000
vmax_value = 200000
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 1
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 8
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %%
metric = '[READ].MinLatency(us)'
pod_count = 16
experiment_run = 2
vmin_value = 140
vmax_value = 160
plot_heatmap(df_aggregated, metric, pod_count, experiment_run, vmin_value=vmin_value, vmax_value=vmax_value)

# %% [markdown]
# ## Line Plots of Micro Data

# %%
metric = 'current_ops_per_sec'
experiment_run = 1
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1

# %%
#metric = 'current_ops_per_sec'
#plot_measures(metric, smoothing=0, preset_client=10)
#plot_measures(metric, smoothing=0, preset_client=11)
#plot_measures(metric, smoothing=0, preset_client=12)

# %%
metric = 'READ_Avg'
experiment_run = 1
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1

# %%
metric = 'READ_99'
experiment_run = 1
target = 180224
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1
# # Metric READ_99
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 1

# %%
metric = 'READ_Max'
experiment_run = 2
target = 147456
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Max
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
metric = 'READ_Min'
experiment_run = 2
target = 147456
threads = 128

pod_count = 1
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 8
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
pod_count = 16
plot_timeseries(df_aggregated, metric, pod_count=pod_count, experiment_run=experiment_run, target=target, threads=threads, smoothing=0)
# Out:
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2
# # Metric READ_Min
# ## Configuration PostgreSQL-64-8-196608
# ### Experiment run 2

# %%
#metric = 'UPDATE_99.9'
#plot_measures(metric, smoothing=0, preset_client=3)
#plot_measures(metric, smoothing=0, preset_client=4)

# %% [markdown]
# ## Bar Plots of Hardware Metrics

# %%
evaluation.transform_monitoring_results(component='stream')

evaluation.get_monitoring_metrics()
# Out:
# ['total_cpu_memory',
#  'total_cpu_memory_cached',
#  'total_cpu_util',
#  'total_cpu_util_max',
#  'total_cpu_throttled',
#  'total_cpu_util_others',
#  'total_cpu_util_s',
#  'total_cpu_util_user_s',
#  'total_cpu_util_sys_s',
#  'total_cpu_throttled_s',
#  'total_cpu_util_others_s',
#  'total_network_rx',
#  'total_network_tx',
#  'total_fs_read',
#  'total_fs_write',
#  'total_gpu_util',
#  'total_gpu_power',
#  'total_gpu_memory']

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'CPUs'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_util_s', component=component).max() - evaluation.get_monitoring_metric('total_cpu_util_s', component=component).min()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'stream'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 1
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 8
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)

# %%
metric = 'Max RAM'
component = 'benchmarker'
pod_count = 16
experiment_run = 1
df = evaluation.get_monitoring_metric('total_cpu_memory', component=component).max()
plot_prometheus_metric(df, metric, component, pod_count, experiment_run)
