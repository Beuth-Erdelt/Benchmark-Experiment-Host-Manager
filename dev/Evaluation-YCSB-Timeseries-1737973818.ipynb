# %%
#!pip list

# %matplotlib inline

import pandas as pd
import os
import re
import matplotlib.pyplot as plt
import pickle
# Some nice output
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
from IPython.display import display, Markdown

import dbmsbenchmarker
import bexhoma
from bexhoma import evaluators
#import evaluator

# %%
cut_at = 1
def plot_measures(metric):
    display(Markdown(f'# Metric {metric}'))
    list_configurations = list(df_benchmarks['configuration'].unique())    
    for configuration in list_configurations:
        #print("Configuration:", configuration)
        display(Markdown(f'## Configuration {configuration}'))
        list_experiment_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration]['experiment_run'].unique()))
        #print(list_experiment_runs)
        for experiment_run in list_experiment_runs:
            #print("Experiment run", experiment_run)
            display(Markdown(f'### Experiment run {experiment_run}'))
            list_runs = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['client'].unique()))
            #print(list_runs)
            #list_targets = sorted(list(df_benchmarks[df_benchmarks['configuration'] == configuration][df_benchmarks['experiment_run'] == experiment_run]['target'].unique()))
            #print(list_targets)
            num_runs = len(list_runs)
            # Create a 2-column grid layout
            n_cols = 2
            n_rows = num_runs#6#int(np.ceil(len(dfs) / n_cols))  # Calculate rows needed
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 5 * n_rows))        
            # Flatten axes for easy iteration (handles cases with n_rows == 1 or n_cols == 1)
            axes = axes.flatten()
            i = 0
            for client in list_runs:
                df_part = df_benchmarks[df_benchmarks['configuration'] == configuration]
                df_part = df_part[df_part['experiment_run'] == (experiment_run)]#['threads']
                df_part = df_part[df_part['client'] == (client)]#num_runs * int(client) -2)]
                #print(df_part.T)
                df_total = evaluation.get_benchmark_logs_timeseries_df_aggregated(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                #print(df_total)
                threads = df_part['threads'].sum()
                pod_count = df_part['pod_count'].mean()
                target = df_part['target'].sum()
                avg = int(df_total['avg'].mean())
                df_total = df_total.rename(columns={'avg': f'avg={avg}'})
                #print(df_part['threads'])
                title = "{}/{} threads - target = {}".format(threads, int(pod_count), target)
                #plt.title(title)
                ax = axes[i]
                i = i + 1
                df_total[:-cut_at].plot(title=title, ax=ax, ylim=(0,df_total[metric].max()))
                #print(df_total[:-cut_at].mean().mean())
                df_total = evaluation.get_benchmark_logs_timeseries_df_single(metric=metric, configuration=configuration, client=client, experiment_run=experiment_run)
                df_combined = pd.DataFrame()
                j=1
                for df in df_total:
                    #df.plot(ylim=(0,df['current_ops_per_sec'].max()))
                    df_single = pd.DataFrame(df[metric][:-cut_at])
                    df_single.columns=["pod "+str(j)]
                    df_combined = pd.merge(df_combined, df_single, how='outer', left_index=True, right_index=True)
                    j = j + 1
                avg = df_combined.mean().mean()
                df_combined[f'avg={avg}']=avg
                #plt.title(title)
                ax = axes[i]
                i = i + 1
                df_combined.plot(title=title, ax=ax, ylim=(0,df[metric].max()), legend=False)
                #print(df_total[:-cut_at].mean().mean())
            # Hide any unused subplots
            for j in range(num_runs*2, len(axes)):
                fig.delaxes(axes[j])
            plt.tight_layout()
            plt.show()

# %%
code = "1737973818"
path = "/home/perdelt/benchmarks"
evaluation = evaluators.ycsb(code=code, path=path)

# %%
df_benchmarks = evaluation.get_df_benchmarking()
#df = df[df.columns.drop(list(df.filter(regex='FAILED')))]
df_benchmarks = evaluation.benchmarking_set_datatypes(df_benchmarks)
df_benchmarks.T
# Out:
# connection_pod                             PostgreSQL-64-8-65536-1-2-1  \
# connection                                   PostgreSQL-64-8-65536-1-2
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               2
# pod                                              wwt6l.dbmsbenchmarker
# pod_count                                                            8
# threads                                                              8
# target                                                            8192
# sf                                                                  16
# workload                                                             a
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         308825.0
# [OVERALL].Throughput(ops/sec)                              6476.159637
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      143
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.04630454140694568
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           143
# [TOTAL_GC_TIME_%].Time(%)                          0.04630454140694568
# [READ].Operations                                               999958
# [READ].AverageLatency(us)                                   614.474393
# [READ].MinLatency(us)                                            161.0
# [READ].MaxLatency(us)                                       16973823.0
# [READ].95thPercentileLatency(us)                                1351.0
# [READ].99thPercentileLatency(us)                                6103.0
# [READ].Return=OK                                                999958
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                   453.625
# [CLEANUP].MinLatency(us)                                         139.0
# [CLEANUP].MaxLatency(us)                                        1035.0
# [CLEANUP].95thPercentileLatency(us)                             1035.0
# [CLEANUP].99thPercentileLatency(us)                             1035.0
# [UPDATE].Operations                                            1000042
# [UPDATE].AverageLatency(us)                                1748.990403
# [UPDATE].MinLatency(us)                                          180.0
# [UPDATE].MaxLatency(us)                                     14065663.0
# [UPDATE].95thPercentileLatency(us)                              2327.0
# [UPDATE].99thPercentileLatency(us)                             31231.0
# [UPDATE].Return=OK                                             1000042
#
# connection_pod                             PostgreSQL-64-8-65536-2-2-1  \
# connection                                   PostgreSQL-64-8-65536-2-2
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       2
# client                                                               2
# pod                                              mvpb7.dbmsbenchmarker
# pod_count                                                            8
# threads                                                              8
# target                                                            8192
# sf                                                                  16
# workload                                                             a
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         308965.0
# [OVERALL].Throughput(ops/sec)                              6473.225123
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      143
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.04628355962649491
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           143
# [TOTAL_GC_TIME_%].Time(%)                          0.04628355962649491
# [READ].Operations                                               999802
# [READ].AverageLatency(us)                                   675.365783
# [READ].MinLatency(us)                                            157.0
# [READ].MaxLatency(us)                                       16130047.0
# [READ].95thPercentileLatency(us)                                1352.0
# [READ].99thPercentileLatency(us)                                6155.0
# [READ].Return=OK                                                999802
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                    465.25
# [CLEANUP].MinLatency(us)                                         151.0
# [CLEANUP].MaxLatency(us)                                        2165.0
# [CLEANUP].95thPercentileLatency(us)                             2165.0
# [CLEANUP].99thPercentileLatency(us)                             2165.0
# [UPDATE].Operations                                            1000198
# [UPDATE].AverageLatency(us)                                1751.471631
# [UPDATE].MinLatency(us)                                          175.0
# [UPDATE].MaxLatency(us)                                     16449535.0
# [UPDATE].95thPercentileLatency(us)                              2341.0
# [UPDATE].99thPercentileLatency(us)                             30815.0
# [UPDATE].Return=OK                                             1000198
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-1  \
# connection                                   PostgreSQL-64-8-65536-1-3
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               3
# pod                                              pzqnd.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              4
# target                                                            4096
# sf                                                                  16
# workload                                                             a
# operations                                                     1000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         387725.0
# [OVERALL].Throughput(ops/sec)                              2579.147592
# [TOTAL_GCS_Copy].Count                                               4
# [TOTAL_GC_TIME_Copy].Time(ms)                                       69
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.01779611838287446
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    4
# [TOTAL_GC_TIME].Time(ms)                                            69
# [TOTAL_GC_TIME_%].Time(%)                          0.01779611838287446
# [READ].Operations                                               499899
# [READ].AverageLatency(us)                                  1079.222335
# [READ].MinLatency(us)                                            160.0
# [READ].MaxLatency(us)                                       50561023.0
# [READ].95thPercentileLatency(us)                                1351.0
# [READ].99thPercentileLatency(us)                                6303.0
# [READ].Return=OK                                                499899
# [CLEANUP].Operations                                                 4
# [CLEANUP].AverageLatency(us)                                     679.5
# [CLEANUP].MinLatency(us)                                         234.0
# [CLEANUP].MaxLatency(us)                                        1988.0
# [CLEANUP].95thPercentileLatency(us)                             1988.0
# [CLEANUP].99thPercentileLatency(us)                             1988.0
# [UPDATE].Operations                                             500101
# [UPDATE].AverageLatency(us)                                1997.178504
# [UPDATE].MinLatency(us)                                          176.0
# [UPDATE].MaxLatency(us)                                     50561023.0
# [UPDATE].95thPercentileLatency(us)                              2241.0
# [UPDATE].99thPercentileLatency(us)                             27839.0
# [UPDATE].Return=OK                                              500101
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-2  \
# connection                                   PostgreSQL-64-8-65536-1-3
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               3
# pod                                              6rr6b.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              4
# target                                                            4096
# sf                                                                  16
# workload                                                             a
# operations                                                     1000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         382392.0
# [OVERALL].Throughput(ops/sec)                              2615.117471
# [TOTAL_GCS_Copy].Count                                               4
# [TOTAL_GC_TIME_Copy].Time(ms)                                       85
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.022228498504152806
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    4
# [TOTAL_GC_TIME].Time(ms)                                            85
# [TOTAL_GC_TIME_%].Time(%)                         0.022228498504152806
# [READ].Operations                                               500629
# [READ].AverageLatency(us)                                   711.362961
# [READ].MinLatency(us)                                            159.0
# [READ].MaxLatency(us)                                       33849343.0
# [READ].95thPercentileLatency(us)                                1344.0
# [READ].99thPercentileLatency(us)                                5431.0
# [READ].Return=OK                                                500629
# [CLEANUP].Operations                                                 4
# [CLEANUP].AverageLatency(us)                                     903.0
# [CLEANUP].MinLatency(us)                                         235.0
# [CLEANUP].MaxLatency(us)                                        2281.0
# [CLEANUP].95thPercentileLatency(us)                             2281.0
# [CLEANUP].99thPercentileLatency(us)                             2281.0
# [UPDATE].Operations                                             499371
# [UPDATE].AverageLatency(us)                                2071.727932
# [UPDATE].MinLatency(us)                                          178.0
# [UPDATE].MaxLatency(us)                                     50888703.0
# [UPDATE].95thPercentileLatency(us)                              2185.0
# [UPDATE].99thPercentileLatency(us)                             25839.0
# [UPDATE].Return=OK                                              499371
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-3  \
# connection                                   PostgreSQL-64-8-65536-1-3
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               3
# pod                                              p44gp.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              4
# target                                                            4096
# sf                                                                  16
# workload                                                             a
# operations                                                     1000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         390479.0
# [OVERALL].Throughput(ops/sec)                              2560.957183
# [TOTAL_GCS_Copy].Count                                               4
# [TOTAL_GC_TIME_Copy].Time(ms)                                       73
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.018694987438505017
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    4
# [TOTAL_GC_TIME].Time(ms)                                            73
# [TOTAL_GC_TIME_%].Time(%)                         0.018694987438505017
# [READ].Operations                                               500096
# [READ].AverageLatency(us)                                   821.593542
# [READ].MinLatency(us)                                            158.0
# [READ].MaxLatency(us)                                       50921471.0
# [READ].95thPercentileLatency(us)                                1307.0
# [READ].99thPercentileLatency(us)                                6043.0
# [READ].Return=OK                                                500096
# [CLEANUP].Operations                                                 4
# [CLEANUP].AverageLatency(us)                                     741.5
# [CLEANUP].MinLatency(us)                                         369.0
# [CLEANUP].MaxLatency(us)                                        1530.0
# [CLEANUP].95thPercentileLatency(us)                             1530.0
# [CLEANUP].99thPercentileLatency(us)                             1530.0
# [UPDATE].Operations                                             499904
# [UPDATE].AverageLatency(us)                                2185.528305
# [UPDATE].MinLatency(us)                                          183.0
# [UPDATE].MaxLatency(us)                                     51281919.0
# [UPDATE].95thPercentileLatency(us)                              2159.0
# [UPDATE].99thPercentileLatency(us)                             28527.0
# [UPDATE].Return=OK                                              499904
#
# connection_pod                             PostgreSQL-64-8-65536-2-3-1  \
# connection                                   PostgreSQL-64-8-65536-2-3
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       2
# client                                                               3
# pod                                              hpgpf.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              4
# target                                                            4096
# sf                                                                  16
# workload                                                             a
# operations                                                     1000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         404510.0
# [OVERALL].Throughput(ops/sec)                              2472.126771
# [TOTAL_GCS_Copy].Count                                               4
# [TOTAL_GC_TIME_Copy].Time(ms)                                       75
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.018540950779955996
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    4
# [TOTAL_GC_TIME].Time(ms)                                            75
# [TOTAL_GC_TIME_%].Time(%)                         0.018540950779955996
# [READ].Operations                                               500144
# [READ].AverageLatency(us)                                   987.396536
# [READ].MinLatency(us)                                            162.0
# [READ].MaxLatency(us)                                       65994751.0
# [READ].95thPercentileLatency(us)                                1242.0
# [READ].99thPercentileLatency(us)                                6179.0
# [READ].Return=OK                                                500144
# [CLEANUP].Operations                                                 4
# [CLEANUP].AverageLatency(us)                                    798.25
# [CLEANUP].MinLatency(us)                                         189.0
# [CLEANUP].MaxLatency(us)                                        1998.0
# [CLEANUP].95thPercentileLatency(us)                             1998.0
# [CLEANUP].99thPercentileLatency(us)                             1998.0
# [UPDATE].Operations                                             499856
# [UPDATE].AverageLatency(us)                                2170.696651
# [UPDATE].MinLatency(us)                                          176.0
# [UPDATE].MaxLatency(us)                                     67239935.0
# [UPDATE].95thPercentileLatency(us)                              2145.0
# [UPDATE].99thPercentileLatency(us)                             29039.0
# [UPDATE].Return=OK                                              499856
#
# connection_pod                             PostgreSQL-64-8-65536-1-2-2  \
# connection                                   PostgreSQL-64-8-65536-1-2
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               2
# pod                                              65c7d.dbmsbenchmarker
# pod_count                                                            8
# threads                                                              8
# target                                                            8192
# sf                                                                  16
# workload                                                             a
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         306249.0
# [OVERALL].Throughput(ops/sec)                              6530.633569
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      155
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.05061241016297195
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           155
# [TOTAL_GC_TIME_%].Time(%)                          0.05061241016297195
# [READ].Operations                                              1000326
# [READ].AverageLatency(us)                                   621.755597
# [READ].MinLatency(us)                                            159.0
# [READ].MaxLatency(us)                                       13549567.0
# [READ].95thPercentileLatency(us)                                1353.0
# [READ].99thPercentileLatency(us)                                5979.0
# [READ].Return=OK                                               1000326
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                    449.75
# [CLEANUP].MinLatency(us)                                         118.0
# [CLEANUP].MaxLatency(us)                                        1571.0
# [CLEANUP].95thPercentileLatency(us)                             1571.0
# [CLEANUP].99thPercentileLatency(us)                             1571.0
# [UPDATE].Operations                                             999674
# [UPDATE].AverageLatency(us)                                1734.954722
# [UPDATE].MinLatency(us)                                          178.0
# [UPDATE].MaxLatency(us)                                     20070399.0
# [UPDATE].95thPercentileLatency(us)                              2321.0
# [UPDATE].99thPercentileLatency(us)                             30399.0
# [UPDATE].Return=OK                                              999674
#
# connection_pod                             PostgreSQL-64-8-65536-1-2-3  \
# connection                                   PostgreSQL-64-8-65536-1-2
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               2
# pod                                              bn754.dbmsbenchmarker
# pod_count                                                            8
# threads                                                              8
# target                                                            8192
# sf                                                                  16
# workload                                                             a
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         302437.0
# [OVERALL].Throughput(ops/sec)                               6612.94749
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      174
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.057532643162046974
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           174
# [TOTAL_GC_TIME_%].Time(%)                         0.057532643162046974
# [READ].Operations                                               999180
# [READ].AverageLatency(us)                                   621.637053
# [READ].MinLatency(us)                                            158.0
# [READ].MaxLatency(us)                                       18300927.0
# [READ].95thPercentileLatency(us)                                1366.0
# [READ].99thPercentileLatency(us)                                6199.0
# [READ].Return=OK                                                999180
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                     372.5
# [CLEANUP].MinLatency(us)                                         140.0
# [CLEANUP].MaxLatency(us)                                        1323.0
# [CLEANUP].95thPercentileLatency(us)                             1323.0
# [CLEANUP].99thPercentileLatency(us)                             1323.0
# [UPDATE].Operations                                            1000820
# [UPDATE].AverageLatency(us)                                1735.577999
# [UPDATE].MinLatency(us)                                          178.0
# [UPDATE].MaxLatency(us)                                     14106623.0
# [UPDATE].95thPercentileLatency(us)                              2379.0
# [UPDATE].99thPercentileLatency(us)                             31503.0
# [UPDATE].Return=OK                                             1000820
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-4  \
# connection                                   PostgreSQL-64-8-65536-1-3
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       1
# client                                                               3
# pod                                              npzhh.dbmsbenchmarker
# pod_count                                                           16
# threads                                                              4
# target                                                            4096
# sf                                                                  16
# workload                                                             a
# operations                                                     1000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         386325.0
# [OVERALL].Throughput(ops/sec)                              2588.494144
# [TOTAL_GCS_Copy].Count                                               4
# [TOTAL_GC_TIME_Copy].Time(ms)                                       78
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.020190254319549603
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    4
# [TOTAL_GC_TIME].Time(ms)                                            78
# [TOTAL_GC_TIME_%].Time(%)                         0.020190254319549603
# [READ].Operations                                               500629
# [READ].AverageLatency(us)                                   994.005323
# [READ].MinLatency(us)                                            162.0
# [READ].MaxLatency(us)                                       34603007.0
# [READ].95thPercentileLatency(us)                                1351.0
# [READ].99thPercentileLatency(us)                                5979.0
# [READ].Return=OK                                                500629
# [CLEANUP].Operations                                                 4
# [CLEANUP].AverageLatency(us)                                    1067.5
# [CLEANUP].MinLatency(us)                                         232.0
# [CLEANUP].MaxLatency(us)                                        2789.0
# [CLEANUP].95thPercentileLatency(us)                             2789.0
# [CLEANUP].99thPercentileLatency(us)                             2789.0
# [UPDATE].Operations                                             499371
# [UPDATE].AverageLatency(us)                                1923.747494
# [UPDATE].MinLatency(us)                                          180.0
# [UPDATE].MaxLatency(us)                                     44072959.0
# [UPDATE].95thPercentileLatency(us)                              2197.0
# [UPDATE].99thPercentileLatency(us)                             27327.0
# [UPDATE].Return=OK                                              499371
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-5  ...  \
# connection                                   PostgreSQL-64-8-65536-1-3  ...
# configuration                                    PostgreSQL-64-8-65536  ...
# experiment_run                                                       1  ...
# client                                                               3  ...
# pod                                              5mt5m.dbmsbenchmarker  ...
# pod_count                                                           16  ...
# threads                                                              4  ...
# target                                                            4096  ...
# sf                                                                  16  ...
# workload                                                             a  ...
# operations                                                     1000000  ...
# batchsize                                                           -1  ...
# exceptions                                                           0  ...
# [OVERALL].RunTime(ms)                                         407844.0  ...
# [OVERALL].Throughput(ops/sec)                               2451.91789  ...
# [TOTAL_GCS_Copy].Count                                               4  ...
# [TOTAL_GC_TIME_Copy].Time(ms)                                       93  ...
# [TOTAL_GC_TIME_%_Copy].Time(%)                    0.022802836378615354  ...
# [TOTAL_GCS_MarkSweepCompact].Count                                   0  ...
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0  ...
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0  ...
# [TOTAL_GCs].Count                                                    4  ...
# [TOTAL_GC_TIME].Time(ms)                                            93  ...
# [TOTAL_GC_TIME_%].Time(%)                         0.022802836378615354  ...
# [READ].Operations                                               499775  ...
# [READ].AverageLatency(us)                                   890.427688  ...
# [READ].MinLatency(us)                                            156.0  ...
# [READ].MaxLatency(us)                                       57966591.0  ...
# [READ].95thPercentileLatency(us)                                1264.0  ...
# [READ].99thPercentileLatency(us)                                5239.0  ...
# [READ].Return=OK                                                499775  ...
# [CLEANUP].Operations                                                 4  ...
# [CLEANUP].AverageLatency(us)                                    1051.0  ...
# [CLEANUP].MinLatency(us)                                         642.0  ...
# [CLEANUP].MaxLatency(us)                                        1957.0  ...
# [CLEANUP].95thPercentileLatency(us)                             1957.0  ...
# [CLEANUP].99thPercentileLatency(us)                             1957.0  ...
# [UPDATE].Operations                                             500225  ...
# [UPDATE].AverageLatency(us)                                1970.872987  ...
# [UPDATE].MinLatency(us)                                          175.0  ...
# [UPDATE].MaxLatency(us)                                     47939583.0  ...
# [UPDATE].95thPercentileLatency(us)                              2059.0  ...
# [UPDATE].99thPercentileLatency(us)                             24447.0  ...
# [UPDATE].Return=OK                                              500225  ...
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-13  \
# connection                                    PostgreSQL-64-8-65536-1-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        1
# client                                                                3
# pod                                               rcv6n.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          382046.0
# [OVERALL].Throughput(ops/sec)                               2617.485852
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        67
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.017537155211676078
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             67
# [TOTAL_GC_TIME_%].Time(%)                          0.017537155211676078
# [READ].Operations                                                499143
# [READ].AverageLatency(us)                                    957.334501
# [READ].MinLatency(us)                                             160.0
# [READ].MaxLatency(us)                                        43417599.0
# [READ].95thPercentileLatency(us)                                 1338.0
# [READ].99thPercentileLatency(us)                                 6343.0
# [READ].Return=OK                                                 499143
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                     782.25
# [CLEANUP].MinLatency(us)                                          209.0
# [CLEANUP].MaxLatency(us)                                         1923.0
# [CLEANUP].95thPercentileLatency(us)                              1923.0
# [CLEANUP].99thPercentileLatency(us)                              1923.0
# [UPDATE].Operations                                              500857
# [UPDATE].AverageLatency(us)                                 2039.006623
# [UPDATE].MinLatency(us)                                           179.0
# [UPDATE].MaxLatency(us)                                      43417599.0
# [UPDATE].95thPercentileLatency(us)                               2239.0
# [UPDATE].99thPercentileLatency(us)                              28687.0
# [UPDATE].Return=OK                                               500857
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-14  \
# connection                                    PostgreSQL-64-8-65536-1-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        1
# client                                                                3
# pod                                               dcwpl.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          378206.0
# [OVERALL].Throughput(ops/sec)                               2644.061702
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        90
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.023796555316414864
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             90
# [TOTAL_GC_TIME_%].Time(%)                          0.023796555316414864
# [READ].Operations                                                500694
# [READ].AverageLatency(us)                                    964.638346
# [READ].MinLatency(us)                                             154.0
# [READ].MaxLatency(us)                                        44204031.0
# [READ].95thPercentileLatency(us)                                 1340.0
# [READ].99thPercentileLatency(us)                                 6483.0
# [READ].Return=OK                                                 500694
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                     692.75
# [CLEANUP].MinLatency(us)                                          141.0
# [CLEANUP].MaxLatency(us)                                         1403.0
# [CLEANUP].95thPercentileLatency(us)                              1403.0
# [CLEANUP].99thPercentileLatency(us)                              1403.0
# [UPDATE].Operations                                              499306
# [UPDATE].AverageLatency(us)                                 2006.006341
# [UPDATE].MinLatency(us)                                           178.0
# [UPDATE].MaxLatency(us)                                      44204031.0
# [UPDATE].95thPercentileLatency(us)                               2253.0
# [UPDATE].99thPercentileLatency(us)                              28767.0
# [UPDATE].Return=OK                                               499306
#
# connection_pod                             PostgreSQL-64-8-65536-2-3-14  \
# connection                                    PostgreSQL-64-8-65536-2-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        2
# client                                                                3
# pod                                               4ntlj.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          401720.0
# [OVERALL].Throughput(ops/sec)                               2489.296027
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        86
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02140794583291845
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             86
# [TOTAL_GC_TIME_%].Time(%)                           0.02140794583291845
# [READ].Operations                                                500117
# [READ].AverageLatency(us)                                    782.020133
# [READ].MinLatency(us)                                             158.0
# [READ].MaxLatency(us)                                        66715647.0
# [READ].95thPercentileLatency(us)                                 1278.0
# [READ].99thPercentileLatency(us)                                 6383.0
# [READ].Return=OK                                                 500117
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                     587.25
# [CLEANUP].MinLatency(us)                                          193.0
# [CLEANUP].MaxLatency(us)                                         1701.0
# [CLEANUP].95thPercentileLatency(us)                              1701.0
# [CLEANUP].99thPercentileLatency(us)                              1701.0
# [UPDATE].Operations                                              499883
# [UPDATE].AverageLatency(us)                                 2390.433191
# [UPDATE].MinLatency(us)                                           174.0
# [UPDATE].MaxLatency(us)                                      67174399.0
# [UPDATE].95thPercentileLatency(us)                               2159.0
# [UPDATE].99thPercentileLatency(us)                              29711.0
# [UPDATE].Return=OK                                               499883
#
# connection_pod                             PostgreSQL-64-8-65536-2-1-1  \
# connection                                   PostgreSQL-64-8-65536-2-1
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       2
# client                                                               1
# pod                                              7stk8.dbmsbenchmarker
# pod_count                                                            1
# threads                                                             64
# target                                                           65536
# sf                                                                  16
# workload                                                             a
# operations                                                    16000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         367396.0
# [OVERALL].Throughput(ops/sec)                             43549.739246
# [TOTAL_GCS_Copy].Count                                              67
# [TOTAL_GC_TIME_Copy].Time(ms)                                      670
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.18236453309235812
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                   67
# [TOTAL_GC_TIME].Time(ms)                                           670
# [TOTAL_GC_TIME_%].Time(%)                          0.18236453309235812
# [READ].Operations                                              8000305
# [READ].AverageLatency(us)                                   905.278543
# [READ].MinLatency(us)                                            163.0
# [READ].MaxLatency(us)                                       12804095.0
# [READ].95thPercentileLatency(us)                                1483.0
# [READ].99thPercentileLatency(us)                                9199.0
# [READ].Return=OK                                               8000305
# [CLEANUP].Operations                                                64
# [CLEANUP].AverageLatency(us)                                 272.09375
# [CLEANUP].MinLatency(us)                                         155.0
# [CLEANUP].MaxLatency(us)                                        1565.0
# [CLEANUP].95thPercentileLatency(us)                              519.0
# [CLEANUP].99thPercentileLatency(us)                              757.0
# [UPDATE].Operations                                            7999695
# [UPDATE].AverageLatency(us)                                 1908.83803
# [UPDATE].MinLatency(us)                                          188.0
# [UPDATE].MaxLatency(us)                                     11223039.0
# [UPDATE].95thPercentileLatency(us)                              2543.0
# [UPDATE].99thPercentileLatency(us)                             30191.0
# [UPDATE].Return=OK                                             7999695
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-15  \
# connection                                    PostgreSQL-64-8-65536-1-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        1
# client                                                                3
# pod                                               btxcp.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# ...
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         310352.0
# [OVERALL].Throughput(ops/sec)                               6444.29551
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      190
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.06122080734134145
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           190
# [TOTAL_GC_TIME_%].Time(%)                          0.06122080734134145
# [READ].Operations                                               999696
# [READ].AverageLatency(us)                                   684.449386
# [READ].MinLatency(us)                                            156.0
# [READ].MaxLatency(us)                                       17776639.0
# [READ].95thPercentileLatency(us)                                1350.0
# [READ].99thPercentileLatency(us)                                6327.0
# [READ].Return=OK                                                999696
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                   561.625
# [CLEANUP].MinLatency(us)                                         139.0
# [CLEANUP].MaxLatency(us)                                        2377.0
# [CLEANUP].95thPercentileLatency(us)                             2377.0
# [CLEANUP].99thPercentileLatency(us)                             2377.0
# [UPDATE].Operations                                            1000304
# [UPDATE].AverageLatency(us)                                1727.105267
# [UPDATE].MinLatency(us)                                          169.0
# [UPDATE].MaxLatency(us)                                     17956863.0
# [UPDATE].95thPercentileLatency(us)                              2319.0
# [UPDATE].99thPercentileLatency(us)                             30527.0
# [UPDATE].Return=OK                                             1000304
#
# connection_pod                             PostgreSQL-64-8-65536-2-2-8  \
# connection                                   PostgreSQL-64-8-65536-2-2
# configuration                                    PostgreSQL-64-8-65536
# experiment_run                                                       2
# client                                                               2
# pod                                              cxlrs.dbmsbenchmarker
# pod_count                                                            8
# threads                                                              8
# target                                                            8192
# sf                                                                  16
# workload                                                             a
# operations                                                     2000000
# batchsize                                                           -1
# exceptions                                                           0
# [OVERALL].RunTime(ms)                                         309991.0
# [OVERALL].Throughput(ops/sec)                              6451.800214
# [TOTAL_GCS_Copy].Count                                               8
# [TOTAL_GC_TIME_Copy].Time(ms)                                      170
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.05484030181521399
# [TOTAL_GCS_MarkSweepCompact].Count                                   0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                            0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                         0.0
# [TOTAL_GCs].Count                                                    8
# [TOTAL_GC_TIME].Time(ms)                                           170
# [TOTAL_GC_TIME_%].Time(%)                          0.05484030181521399
# [READ].Operations                                              1000302
# [READ].AverageLatency(us)                                   660.703096
# [READ].MinLatency(us)                                            157.0
# [READ].MaxLatency(us)                                       18612223.0
# [READ].95thPercentileLatency(us)                                1362.0
# [READ].99thPercentileLatency(us)                                6247.0
# [READ].Return=OK                                               1000302
# [CLEANUP].Operations                                                 8
# [CLEANUP].AverageLatency(us)                                   444.375
# [CLEANUP].MinLatency(us)                                         159.0
# [CLEANUP].MaxLatency(us)                                        1654.0
# [CLEANUP].95thPercentileLatency(us)                             1654.0
# [CLEANUP].99thPercentileLatency(us)                             1654.0
# [UPDATE].Operations                                             999698
# [UPDATE].AverageLatency(us)                                1780.479688
# [UPDATE].MinLatency(us)                                          175.0
# [UPDATE].MaxLatency(us)                                     16236543.0
# [UPDATE].95thPercentileLatency(us)                              2351.0
# [UPDATE].99thPercentileLatency(us)                             30735.0
# [UPDATE].Return=OK                                              999698
#
# connection_pod                             PostgreSQL-64-8-65536-2-3-15  \
# connection                                    PostgreSQL-64-8-65536-2-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        2
# client                                                                3
# pod                                               85krb.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          395171.0
# [OVERALL].Throughput(ops/sec)                               2530.550066
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        88
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02226884057787641
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             88
# [TOTAL_GC_TIME_%].Time(%)                           0.02226884057787641
# [READ].Operations                                                499822
# [READ].AverageLatency(us)                                    830.997269
# [READ].MinLatency(us)                                             161.0
# [READ].MaxLatency(us)                                        60162047.0
# [READ].95thPercentileLatency(us)                                 1302.0
# [READ].99thPercentileLatency(us)                                 6543.0
# [READ].Return=OK                                                 499822
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                      814.0
# [CLEANUP].MinLatency(us)                                          140.0
# [CLEANUP].MaxLatency(us)                                         2817.0
# [CLEANUP].95thPercentileLatency(us)                              2817.0
# [CLEANUP].99thPercentileLatency(us)                              2817.0
# [UPDATE].Operations                                              500178
# [UPDATE].AverageLatency(us)                                 2293.402477
# [UPDATE].MinLatency(us)                                           178.0
# [UPDATE].MaxLatency(us)                                      62849023.0
# [UPDATE].95thPercentileLatency(us)                               2231.0
# [UPDATE].99thPercentileLatency(us)                              29647.0
# [UPDATE].Return=OK                                               500178
#
# connection_pod                             PostgreSQL-64-8-65536-1-3-16  \
# connection                                    PostgreSQL-64-8-65536-1-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        1
# client                                                                3
# pod                                               zp8gr.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          374708.0
# [OVERALL].Throughput(ops/sec)                               2668.744729
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        92
# [TOTAL_GC_TIME_%_Copy].Time(%)                     0.024552451508908273
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             92
# [TOTAL_GC_TIME_%].Time(%)                          0.024552451508908273
# [READ].Operations                                                500334
# [READ].AverageLatency(us)                                    888.117434
# [READ].MinLatency(us)                                             161.0
# [READ].MaxLatency(us)                                        39747583.0
# [READ].95thPercentileLatency(us)                                 1351.0
# [READ].99thPercentileLatency(us)                                 6227.0
# [READ].Return=OK                                                 500334
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                      729.5
# [CLEANUP].MinLatency(us)                                          194.0
# [CLEANUP].MaxLatency(us)                                         2279.0
# [CLEANUP].95thPercentileLatency(us)                              2279.0
# [CLEANUP].99thPercentileLatency(us)                              2279.0
# [UPDATE].Operations                                              499666
# [UPDATE].AverageLatency(us)                                 2083.960538
# [UPDATE].MinLatency(us)                                           173.0
# [UPDATE].MaxLatency(us)                                      39747583.0
# [UPDATE].95thPercentileLatency(us)                               2259.0
# [UPDATE].99thPercentileLatency(us)                              28863.0
# [UPDATE].Return=OK                                               499666
#
# connection_pod                             PostgreSQL-64-8-65536-2-3-16
# connection                                    PostgreSQL-64-8-65536-2-3
# configuration                                     PostgreSQL-64-8-65536
# experiment_run                                                        2
# client                                                                3
# pod                                               wgnxh.dbmsbenchmarker
# pod_count                                                            16
# threads                                                               4
# target                                                             4096
# sf                                                                   16
# workload                                                              a
# operations                                                      1000000
# batchsize                                                            -1
# exceptions                                                            0
# [OVERALL].RunTime(ms)                                          403908.0
# [OVERALL].Throughput(ops/sec)                               2475.811323
# [TOTAL_GCS_Copy].Count                                                4
# [TOTAL_GC_TIME_Copy].Time(ms)                                        89
# [TOTAL_GC_TIME_%_Copy].Time(%)                      0.02203472077799895
# [TOTAL_GCS_MarkSweepCompact].Count                                    0
# [TOTAL_GC_TIME_MarkSweepCompact].Time(ms)                             0
# [TOTAL_GC_TIME_%_MarkSweepCompact].Time(%)                          0.0
# [TOTAL_GCs].Count                                                     4
# [TOTAL_GC_TIME].Time(ms)                                             89
# [TOTAL_GC_TIME_%].Time(%)                           0.02203472077799895
# [READ].Operations                                                500391
# [READ].AverageLatency(us)                                   1064.231521
# [READ].MinLatency(us)                                             160.0
# [READ].MaxLatency(us)                                        65110015.0
# [READ].95thPercentileLatency(us)                                 1333.0
# [READ].99thPercentileLatency(us)                                 6547.0
# [READ].Return=OK                                                 500391
# [CLEANUP].Operations                                                  4
# [CLEANUP].AverageLatency(us)                                     393.75
# [CLEANUP].MinLatency(us)                                          172.0
# [CLEANUP].MaxLatency(us)                                          996.0
# [CLEANUP].95thPercentileLatency(us)                               996.0
# [CLEANUP].99thPercentileLatency(us)                               996.0
# [UPDATE].Operations                                              499609
# [UPDATE].AverageLatency(us)                                  2099.33451
# [UPDATE].MinLatency(us)                                           176.0
# [UPDATE].MaxLatency(us)                                      62390271.0
# [UPDATE].95thPercentileLatency(us)                               2273.0
# [UPDATE].99thPercentileLatency(us)                              30063.0
# [UPDATE].Return=OK                                               499609
#
# [44 rows x 50 columns]

# %%
metric = 'current_ops_per_sec'
plot_measures(metric)
# Out:
# # Metric current_ops_per_sec
# ## Configuration PostgreSQL-64-8-65536
# ### Experiment run 1
# ### Experiment run 2

# %%
metric = 'READ_Avg'
plot_measures(metric)
# Out:
# # Metric READ_Avg
# ## Configuration PostgreSQL-64-8-65536
# ### Experiment run 1
# ### Experiment run 2

# %%
metric = 'READ_99.9'
plot_measures(metric)
# Out:
# # Metric READ_99.9
# ## Configuration PostgreSQL-64-8-65536
# ### Experiment run 1
# ### Experiment run 2

# %%
metric = 'UPDATE_99.9'
plot_measures(metric)
# Out:
# # Metric UPDATE_99.9
# ## Configuration PostgreSQL-64-8-65536
# ### Experiment run 1
# ### Experiment run 2
